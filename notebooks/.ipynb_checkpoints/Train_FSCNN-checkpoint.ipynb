# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import sys
sys.path.append("..")
from seg_net.data import *
from seg_net.fast_scnn import fast_scnn
from data import *
import keras
# Out:
# Using TensorFlow backend.

# %%
INPUT_SHAPE = (1024,2048,3)
LOSS_METRICS = 'BCE_DICE'
MODEL_PATH = '/media/new_hdd2/seg_net/results/Models/Models'
NUM_CLASS = 2

# %%
model = fast_scnn(input_shape = INPUT_SHAPE, num_classes = NUM_CLASS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-7407f4416e3f> in <module>
# ----> 1 model = fast_scnn(input_shape = INPUT_SHAPE, num_classes = NUM_CLASS)
#
# /media/new_hdd2/seg_net/notebooks/fast_scnn.py in fast_scnn(pretrained, input_shape, num_classes)
#      70     gfe_layer = bottleneck_block(gfe_layer, 96, (3, 3), t=6, strides=2, n=3)
#      71     gfe_layer = bottleneck_block(gfe_layer, 128, (3, 3), t=6, strides=1, n=3)
# ---> 72     gfe_layer = pyramid_pooling_block(gfe_layer, [2,4,6,8])
#      73
#      74     """## Step 3: Feature Fusion"""
#
# /media/new_hdd2/seg_net/notebooks/fast_scnn.py in pyramid_pooling_block(input_tensor, bin_sizes)
#      56     concat_list.append(x)
#      57
# ---> 58   return tf.keras.layers.concatenate(concat_list)
#      59
#      60 def fast_scnn(pretrained = None, input_shape = (2048, 1024, 3), num_classes = 19):
#
# ...
