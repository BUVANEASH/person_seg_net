# %% [markdown]
# # Keras to Tensorflow Model

# %%
import keras
import keras.backend as K
import tensorflow as tf
import numpy as np
np.random.seed(0)
import segmentation_models as sm
import sys
import os
sys.path.append("..")
from seg_net.data import *
from seg_net.fast_scnn import fast_scnn
from seg_net.dlv3 import Deeplabv3
# Out:
# Using TensorFlow backend.
# /home/avantariml/.local/lib/python3.5/site-packages/classification_models/resnext/__init__.py:4: UserWarning: Current ResNext models are deprecated, use keras.applications ResNeXt models
#   warnings.warn('Current ResNext models are deprecated, '

# %% [markdown]
# ## Set Model Architecture

# %%
INPUT_SHAPE = (256,256,3) #(768,768,3) (512,512,3)
NUM_CLASS = 1
BACKBONE = 'mobilenetv2'
MODEL_NAME = 'deeplabv3'
LOSS_METRICS = 'BCE_ACC_IOU'
ACTIVATION = 'sigmoid'
DATASET = 'train_person'
IMGNORM = 'divide'
MODEL_PATH_ = '../results/Models/'

model_fname = '{0}_{1}_{2}_{3}_{4}_{5}_{6}_{7}'.format(BACKBONE,
                                                MODEL_NAME,
                                                LOSS_METRICS,
                                                IMGNORM,
                                                NUM_CLASS,
                                                ACTIVATION,
                                                INPUT_SHAPE[0],
                                                DATASET)

MODEL_PATH = '../results/Models/GraphModels'

keras_filename = '{}.hdf5'.format(model_fname)
pb_filename = '{}.pb'.format(model_fname)
pb_op_filename = '{}_op.pb'.format(model_fname)
mlmodel_filename = '{}.mlmodel'.format(model_fname)
mlmodel_fp16_filename = '{}_fp16.mlmodel'.format(model_fname)
mlmodel_Q_filename = '{}_Q.mlmodel'.format(model_fname)
tflite_filename = '{}.tflite'.format(model_fname)
tflite_Q_filename = '{}_Q.tflite'.format(model_fname)

# %% [markdown]
# ## Build and Load Model

# %%
model = sm.Linknet(BACKBONE, encoder_weights='imagenet', 
                  classes=NUM_CLASS,
                  activation=ACTIVATION,
                  input_shape = INPUT_SHAPE)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /home/avantariml/.local/lib/python3.5/site-packages/segmentation_models/backbones/mobilenetv2.py:273: UserWarning: MobileNet shape is undefined. Weights for input shape(224, 224) will be loaded.
#   warnings.warn('MobileNet shape is undefined.'

# %%
model = fast_scnn(input_shape = INPUT_SHAPE, 
                  num_classes = NUM_CLASS, 
                  activation = ACTIVATION, 
                  dropout_rate = 0.3,
                  backbone_name = BACKBONE)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model = Deeplabv3(weights=None, 
                  input_shape=INPUT_SHAPE, 
                  backbone=BACKBONE,
                  classes=NUM_CLASS, 
                  OS=8,
                  activation=ACTIVATION)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.load_weights(os.path.join(MODEL_PATH_,keras_filename))
print("Loading from ",os.path.join(MODEL_PATH_,keras_filename))
# Out:
# Loading from  ../results/Models/mobilenetv2_deeplabv3_BCE_ACC_IOU_divide_1_sigmoid_256_train_person.hdf5

# %%
model.compile('sgd', loss='binary_crossentropy', metrics=['accuracy'])
model.save(os.path.join(MODEL_PATH_,keras_filename))

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, 128, 128, 32) 864         input_layer[0][0]
# __________________________________________________________________________________________________
# Conv_BN (BatchNormalization)    (None, 128, 128, 32) 128         Conv[0][0]
# __________________________________________________________________________________________________
# Conv_Relu6 (ReLU)               (None, 128, 128, 32) 0           Conv_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 128, 128, 32) 288         Conv_Relu6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 128, 128, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 128, 128, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 128, 128, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 128, 128, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand (Conv2D) (None, 128, 128, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand_BN (Batc (None, 128, 128, 96) 384         expanded_conv_1_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand_relu (Re (None, 128, 128, 96) 0           expanded_conv_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise (Dept (None, 64, 64, 96)   864         expanded_conv_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise_BN (B (None, 64, 64, 96)   384         expanded_conv_1_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise_relu  (None, 64, 64, 96)   0           expanded_conv_1_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_1_project (Conv2D (None, 64, 64, 24)   2304        expanded_conv_1_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_1_project_BN (Bat (None, 64, 64, 24)   96          expanded_conv_1_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand (Conv2D) (None, 64, 64, 144)  3456        expanded_conv_1_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand_BN (Batc (None, 64, 64, 144)  576         expanded_conv_2_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand_relu (Re (None, 64, 64, 144)  0           expanded_conv_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise (Dept (None, 64, 64, 144)  1296        expanded_conv_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise_BN (B (None, 64, 64, 144)  576         expanded_conv_2_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise_relu  (None, 64, 64, 144)  0           expanded_conv_2_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_2_project (Conv2D (None, 64, 64, 24)   3456        expanded_conv_2_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_2_project_BN (Bat (None, 64, 64, 24)   96          expanded_conv_2_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_add (Add)       (None, 64, 64, 24)   0           expanded_conv_1_project_BN[0][0]
#                                                                  expanded_conv_2_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand (Conv2D) (None, 64, 64, 144)  3456        expanded_conv_2_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand_BN (Batc (None, 64, 64, 144)  576         expanded_conv_3_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand_relu (Re (None, 64, 64, 144)  0           expanded_conv_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise (Dept (None, 32, 32, 144)  1296        expanded_conv_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise_BN (B (None, 32, 32, 144)  576         expanded_conv_3_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise_relu  (None, 32, 32, 144)  0           expanded_conv_3_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_3_project (Conv2D (None, 32, 32, 32)   4608        expanded_conv_3_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_3_project_BN (Bat (None, 32, 32, 32)   128         expanded_conv_3_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand (Conv2D) (None, 32, 32, 192)  6144        expanded_conv_3_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand_BN (Batc (None, 32, 32, 192)  768         expanded_conv_4_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand_relu (Re (None, 32, 32, 192)  0           expanded_conv_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise (Dept (None, 32, 32, 192)  1728        expanded_conv_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise_BN (B (None, 32, 32, 192)  768         expanded_conv_4_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise_relu  (None, 32, 32, 192)  0           expanded_conv_4_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_4_project (Conv2D (None, 32, 32, 32)   6144        expanded_conv_4_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_4_project_BN (Bat (None, 32, 32, 32)   128         expanded_conv_4_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_add (Add)       (None, 32, 32, 32)   0           expanded_conv_3_project_BN[0][0]
#                                                                  expanded_conv_4_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand (Conv2D) (None, 32, 32, 192)  6144        expanded_conv_4_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand_BN (Batc (None, 32, 32, 192)  768         expanded_conv_5_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand_relu (Re (None, 32, 32, 192)  0           expanded_conv_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise (Dept (None, 32, 32, 192)  1728        expanded_conv_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise_BN (B (None, 32, 32, 192)  768         expanded_conv_5_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise_relu  (None, 32, 32, 192)  0           expanded_conv_5_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_5_project (Conv2D (None, 32, 32, 32)   6144        expanded_conv_5_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_5_project_BN (Bat (None, 32, 32, 32)   128         expanded_conv_5_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_add (Add)       (None, 32, 32, 32)   0           expanded_conv_4_add[0][0]
#                                                                  expanded_conv_5_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand (Conv2D) (None, 32, 32, 192)  6144        expanded_conv_5_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand_BN (Batc (None, 32, 32, 192)  768         expanded_conv_6_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand_relu (Re (None, 32, 32, 192)  0           expanded_conv_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise (Dept (None, 32, 32, 192)  1728        expanded_conv_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise_BN (B (None, 32, 32, 192)  768         expanded_conv_6_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise_relu  (None, 32, 32, 192)  0           expanded_conv_6_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_6_project (Conv2D (None, 32, 32, 64)   12288       expanded_conv_6_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_6_project_BN (Bat (None, 32, 32, 64)   256         expanded_conv_6_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand (Conv2D) (None, 32, 32, 384)  24576       expanded_conv_6_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand_BN (Batc (None, 32, 32, 384)  1536        expanded_conv_7_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand_relu (Re (None, 32, 32, 384)  0           expanded_conv_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise (Dept (None, 32, 32, 384)  3456        expanded_conv_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise_BN (B (None, 32, 32, 384)  1536        expanded_conv_7_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise_relu  (None, 32, 32, 384)  0           expanded_conv_7_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_7_project (Conv2D (None, 32, 32, 64)   24576       expanded_conv_7_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_7_project_BN (Bat (None, 32, 32, 64)   256         expanded_conv_7_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_add (Add)       (None, 32, 32, 64)   0           expanded_conv_6_project_BN[0][0]
#                                                                  expanded_conv_7_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand (Conv2D) (None, 32, 32, 384)  24576       expanded_conv_7_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand_BN (Batc (None, 32, 32, 384)  1536        expanded_conv_8_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand_relu (Re (None, 32, 32, 384)  0           expanded_conv_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise (Dept (None, 32, 32, 384)  3456        expanded_conv_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise_BN (B (None, 32, 32, 384)  1536        expanded_conv_8_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise_relu  (None, 32, 32, 384)  0           expanded_conv_8_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_8_project (Conv2D (None, 32, 32, 64)   24576       expanded_conv_8_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_8_project_BN (Bat (None, 32, 32, 64)   256         expanded_conv_8_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_add (Add)       (None, 32, 32, 64)   0           expanded_conv_7_add[0][0]
#                                                                  expanded_conv_8_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand (Conv2D) (None, 32, 32, 384)  24576       expanded_conv_8_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand_BN (Batc (None, 32, 32, 384)  1536        expanded_conv_9_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand_relu (Re (None, 32, 32, 384)  0           expanded_conv_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise (Dept (None, 32, 32, 384)  3456        expanded_conv_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise_BN (B (None, 32, 32, 384)  1536        expanded_conv_9_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise_relu  (None, 32, 32, 384)  0           expanded_conv_9_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_9_project (Conv2D (None, 32, 32, 64)   24576       expanded_conv_9_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_9_project_BN (Bat (None, 32, 32, 64)   256         expanded_conv_9_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_add (Add)       (None, 32, 32, 64)   0           expanded_conv_8_add[0][0]
#                                                                  expanded_conv_9_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand (Conv2D (None, 32, 32, 384)  24576       expanded_conv_9_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand_BN (Bat (None, 32, 32, 384)  1536        expanded_conv_10_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand_relu (R (None, 32, 32, 384)  0           expanded_conv_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise (Dep (None, 32, 32, 384)  3456        expanded_conv_10_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise_BN ( (None, 32, 32, 384)  1536        expanded_conv_10_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise_relu (None, 32, 32, 384)  0           expanded_conv_10_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_10_project (Conv2 (None, 32, 32, 96)   36864       expanded_conv_10_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_10_project_BN (Ba (None, 32, 32, 96)   384         expanded_conv_10_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand (Conv2D (None, 32, 32, 576)  55296       expanded_conv_10_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand_BN (Bat (None, 32, 32, 576)  2304        expanded_conv_11_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand_relu (R (None, 32, 32, 576)  0           expanded_conv_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise (Dep (None, 32, 32, 576)  5184        expanded_conv_11_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise_BN ( (None, 32, 32, 576)  2304        expanded_conv_11_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise_relu (None, 32, 32, 576)  0           expanded_conv_11_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_11_project (Conv2 (None, 32, 32, 96)   55296       expanded_conv_11_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_11_project_BN (Ba (None, 32, 32, 96)   384         expanded_conv_11_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_add (Add)      (None, 32, 32, 96)   0           expanded_conv_10_project_BN[0][0]
#                                                                  expanded_conv_11_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand (Conv2D (None, 32, 32, 576)  55296       expanded_conv_11_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand_BN (Bat (None, 32, 32, 576)  2304        expanded_conv_12_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand_relu (R (None, 32, 32, 576)  0           expanded_conv_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise (Dep (None, 32, 32, 576)  5184        expanded_conv_12_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise_BN ( (None, 32, 32, 576)  2304        expanded_conv_12_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise_relu (None, 32, 32, 576)  0           expanded_conv_12_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_12_project (Conv2 (None, 32, 32, 96)   55296       expanded_conv_12_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_12_project_BN (Ba (None, 32, 32, 96)   384         expanded_conv_12_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_add (Add)      (None, 32, 32, 96)   0           expanded_conv_11_add[0][0]
#                                                                  expanded_conv_12_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand (Conv2D (None, 32, 32, 576)  55296       expanded_conv_12_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand_BN (Bat (None, 32, 32, 576)  2304        expanded_conv_13_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand_relu (R (None, 32, 32, 576)  0           expanded_conv_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise (Dep (None, 32, 32, 576)  5184        expanded_conv_13_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise_BN ( (None, 32, 32, 576)  2304        expanded_conv_13_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise_relu (None, 32, 32, 576)  0           expanded_conv_13_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_13_project (Conv2 (None, 32, 32, 160)  92160       expanded_conv_13_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_13_project_BN (Ba (None, 32, 32, 160)  640         expanded_conv_13_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand (Conv2D (None, 32, 32, 960)  153600      expanded_conv_13_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand_BN (Bat (None, 32, 32, 960)  3840        expanded_conv_14_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand_relu (R (None, 32, 32, 960)  0           expanded_conv_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise (Dep (None, 32, 32, 960)  8640        expanded_conv_14_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise_BN ( (None, 32, 32, 960)  3840        expanded_conv_14_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise_relu (None, 32, 32, 960)  0           expanded_conv_14_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_14_project (Conv2 (None, 32, 32, 160)  153600      expanded_conv_14_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_14_project_BN (Ba (None, 32, 32, 160)  640         expanded_conv_14_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_add (Add)      (None, 32, 32, 160)  0           expanded_conv_13_project_BN[0][0]
#                                                                  expanded_conv_14_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand (Conv2D (None, 32, 32, 960)  153600      expanded_conv_14_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand_BN (Bat (None, 32, 32, 960)  3840        expanded_conv_15_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand_relu (R (None, 32, 32, 960)  0           expanded_conv_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise (Dep (None, 32, 32, 960)  8640        expanded_conv_15_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise_BN ( (None, 32, 32, 960)  3840        expanded_conv_15_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise_relu (None, 32, 32, 960)  0           expanded_conv_15_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_15_project (Conv2 (None, 32, 32, 160)  153600      expanded_conv_15_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_15_project_BN (Ba (None, 32, 32, 160)  640         expanded_conv_15_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_add (Add)      (None, 32, 32, 160)  0           expanded_conv_14_add[0][0]
#                                                                  expanded_conv_15_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand (Conv2D (None, 32, 32, 960)  153600      expanded_conv_15_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand_BN (Bat (None, 32, 32, 960)  3840        expanded_conv_16_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand_relu (R (None, 32, 32, 960)  0           expanded_conv_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise (Dep (None, 32, 32, 960)  8640        expanded_conv_16_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise_BN ( (None, 32, 32, 960)  3840        expanded_conv_16_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise_relu (None, 32, 32, 960)  0           expanded_conv_16_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_16_project (Conv2 (None, 32, 32, 320)  307200      expanded_conv_16_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_16_project_BN (Ba (None, 32, 32, 320)  1280        expanded_conv_16_project[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 320)    0           expanded_conv_16_project_BN[0][0]
# __________________________________________________________________________________________________
# image_pooling (Conv2D)          (None, 1, 1, 256)    81920       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# image_pooling_BN (BatchNormaliz (None, 1, 1, 256)    1024        image_pooling[0][0]
# __________________________________________________________________________________________________
# aspp0 (Conv2D)                  (None, 32, 32, 256)  81920       expanded_conv_16_project_BN[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 1, 256)    0           image_pooling_BN[0][0]
# __________________________________________________________________________________________________
# aspp0_BN (BatchNormalization)   (None, 32, 32, 256)  1024        aspp0[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_1 (Bilinear (None, 32, 32, 256)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# aspp0_activation (Activation)   (None, 32, 32, 256)  0           aspp0_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 512)  0           bilinear_upsampling_1[0][0]
#                                                                  aspp0_activation[0][0]
# __________________________________________________________________________________________________
# concat_projection (Conv2D)      (None, 32, 32, 256)  131072      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concat_projection_BN (BatchNorm (None, 32, 32, 256)  1024        concat_projection[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 256)  0           concat_projection_BN[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# custom_logits_semantic (Conv2D) (None, 32, 32, 1)    257         dropout_1[0][0]
# __________________________________________________________________________________________________
# bilinear_upsampling_2 (Bilinear (None, 256, 256, 1)  0           custom_logits_semantic[0][0]
# __________________________________________________________________________________________________
# output_layer (Activation)       (None, 256, 256, 1)  0           bilinear_upsampling_2[0][0]
# ==================================================================================================
# Total params: 2,141,505
# Trainable params: 2,108,417
# Non-trainable params: 33,088
# __________________________________________________________________________________________________

# %% [markdown]
# ## save keras model as tf .pb and as CoreML .mlmodel

# %%
from tensorflow.python.tools.optimize_for_inference_lib import optimize_for_inference
import coremltools
from seg_net.keras_to_tensorflow import *
# Out:
# WARNING:root:TensorFlow version 1.13.1 detected. Last version known to be fully compatible is 1.12.0 .

# %%
input_node_names = [node.op.name for node in model.inputs]
print(input_node_names)
# Out:
# ['input_layer']

# %%
# output_names
output_node_names = [node.op.name for node in model.outputs]
print(output_node_names)
# Out:
# ['output_layer/Sigmoid']

# %% [markdown]
# ### Freezing the model to .pb

# %%
graphDef = freeze_keras(K.get_session(), input_node_names, output_node_names, optimize = False,
                        quantize= False, clear_devices = True)
tf.train.write_graph(graphDef, MODEL_PATH, pb_filename, as_text=False)
# Out:
# WARNING:tensorflow:From ../seg_net/keras_to_tensorflow.py:72: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From ../seg_net/keras_to_tensorflow.py:72: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 272 variables.
# INFO:tensorflow:Froze 272 variables.
# INFO:tensorflow:Converted 272 variables to const ops.
# INFO:tensorflow:Converted 272 variables to const ops.
# '../results/Models/GraphModels/mobilenetv2_deeplabv3_BCE_ACC_IOU_divide_1_sigmoid_256_train_person.pb'

# %%
for name in [n.name for n in graphDef.node]:
    print(name)
# Out:
# input_layer
# Conv/kernel
# Conv/kernel/read
# Conv/convolution
# Conv_BN/gamma
# Conv_BN/gamma/read
# Conv_BN/beta
# Conv_BN/beta/read
# Conv_BN/moving_mean
# Conv_BN/moving_mean/read
# Conv_BN/moving_variance
# Conv_BN/moving_variance/read
# Conv_BN/Const_4
# Conv_BN/Const_5
# Conv_BN/FusedBatchNorm
# Conv_BN/keras_learning_phase/input
# Conv_BN/keras_learning_phase
# Conv_BN/cond/pred_id
# Conv_BN/cond/Switch_1
# Conv_BN/cond/FusedBatchNorm
# Conv_BN/cond/FusedBatchNorm/Switch
# Conv_BN/cond/FusedBatchNorm/Switch_1
# Conv_BN/cond/FusedBatchNorm/Switch_2
# Conv_BN/cond/FusedBatchNorm/Switch_3
# Conv_BN/cond/FusedBatchNorm/Switch_4
# Conv_BN/cond/Merge
# Conv_Relu6/Relu6
# expanded_conv_depthwise/depthwise_kernel
# expanded_conv_depthwise/depthwise_kernel/read
# expanded_conv_depthwise/depthwise
# expanded_conv_depthwise_BN/gamma
# expanded_conv_depthwise_BN/gamma/read
# expanded_conv_depthwise_BN/beta
# expanded_conv_depthwise_BN/beta/read
# expanded_conv_depthwise_BN/moving_mean
# expanded_conv_depthwise_BN/moving_mean/read
# expanded_conv_depthwise_BN/moving_variance
# expanded_conv_depthwise_BN/moving_variance/read
# expanded_conv_depthwise_BN/Const_4
# expanded_conv_depthwise_BN/Const_5
# expanded_conv_depthwise_BN/FusedBatchNorm
# expanded_conv_depthwise_BN/cond/pred_id
# expanded_conv_depthwise_BN/cond/Switch_1
# expanded_conv_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_depthwise_BN/cond/Merge
# expanded_conv_depthwise_relu/Relu6
# expanded_conv_project/kernel
# expanded_conv_project/kernel/read
# expanded_conv_project/convolution
# expanded_conv_project_BN/gamma
# expanded_conv_project_BN/gamma/read
# expanded_conv_project_BN/beta
# expanded_conv_project_BN/beta/read
# expanded_conv_project_BN/moving_mean
# expanded_conv_project_BN/moving_mean/read
# expanded_conv_project_BN/moving_variance
# expanded_conv_project_BN/moving_variance/read
# expanded_conv_project_BN/Const_4
# expanded_conv_project_BN/Const_5
# expanded_conv_project_BN/FusedBatchNorm
# expanded_conv_project_BN/cond/pred_id
# expanded_conv_project_BN/cond/Switch_1
# expanded_conv_project_BN/cond/FusedBatchNorm
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_project_BN/cond/Merge
# expanded_conv_1_expand/kernel
# expanded_conv_1_expand/kernel/read
# expanded_conv_1_expand/convolution
# expanded_conv_1_expand_BN/gamma
# expanded_conv_1_expand_BN/gamma/read
# expanded_conv_1_expand_BN/beta
# expanded_conv_1_expand_BN/beta/read
# expanded_conv_1_expand_BN/moving_mean
# expanded_conv_1_expand_BN/moving_mean/read
# expanded_conv_1_expand_BN/moving_variance
# expanded_conv_1_expand_BN/moving_variance/read
# expanded_conv_1_expand_BN/Const_4
# expanded_conv_1_expand_BN/Const_5
# expanded_conv_1_expand_BN/FusedBatchNorm
# expanded_conv_1_expand_BN/cond/pred_id
# expanded_conv_1_expand_BN/cond/Switch_1
# expanded_conv_1_expand_BN/cond/FusedBatchNorm
# expanded_conv_1_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_1_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_1_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_1_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_1_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_1_expand_BN/cond/Merge
# expanded_conv_1_expand_relu/Relu6
# expanded_conv_1_depthwise/depthwise_kernel
# expanded_conv_1_depthwise/depthwise_kernel/read
# expanded_conv_1_depthwise/depthwise
# expanded_conv_1_depthwise_BN/gamma
# expanded_conv_1_depthwise_BN/gamma/read
# expanded_conv_1_depthwise_BN/beta
# expanded_conv_1_depthwise_BN/beta/read
# expanded_conv_1_depthwise_BN/moving_mean
# expanded_conv_1_depthwise_BN/moving_mean/read
# expanded_conv_1_depthwise_BN/moving_variance
# expanded_conv_1_depthwise_BN/moving_variance/read
# expanded_conv_1_depthwise_BN/Const_4
# expanded_conv_1_depthwise_BN/Const_5
# expanded_conv_1_depthwise_BN/FusedBatchNorm
# expanded_conv_1_depthwise_BN/cond/pred_id
# expanded_conv_1_depthwise_BN/cond/Switch_1
# expanded_conv_1_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_1_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_1_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_1_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_1_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_1_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_1_depthwise_BN/cond/Merge
# expanded_conv_1_depthwise_relu/Relu6
# expanded_conv_1_project/kernel
# expanded_conv_1_project/kernel/read
# expanded_conv_1_project/convolution
# expanded_conv_1_project_BN/gamma
# expanded_conv_1_project_BN/gamma/read
# expanded_conv_1_project_BN/beta
# expanded_conv_1_project_BN/beta/read
# expanded_conv_1_project_BN/moving_mean
# expanded_conv_1_project_BN/moving_mean/read
# expanded_conv_1_project_BN/moving_variance
# expanded_conv_1_project_BN/moving_variance/read
# expanded_conv_1_project_BN/Const_4
# expanded_conv_1_project_BN/Const_5
# expanded_conv_1_project_BN/FusedBatchNorm
# expanded_conv_1_project_BN/cond/pred_id
# expanded_conv_1_project_BN/cond/Switch_1
# expanded_conv_1_project_BN/cond/FusedBatchNorm
# expanded_conv_1_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_1_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_1_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_1_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_1_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_1_project_BN/cond/Merge
# expanded_conv_2_expand/kernel
# expanded_conv_2_expand/kernel/read
# expanded_conv_2_expand/convolution
# expanded_conv_2_expand_BN/gamma
# expanded_conv_2_expand_BN/gamma/read
# expanded_conv_2_expand_BN/beta
# expanded_conv_2_expand_BN/beta/read
# expanded_conv_2_expand_BN/moving_mean
# expanded_conv_2_expand_BN/moving_mean/read
# expanded_conv_2_expand_BN/moving_variance
# expanded_conv_2_expand_BN/moving_variance/read
# expanded_conv_2_expand_BN/Const_4
# expanded_conv_2_expand_BN/Const_5
# expanded_conv_2_expand_BN/FusedBatchNorm
# expanded_conv_2_expand_BN/cond/pred_id
# expanded_conv_2_expand_BN/cond/Switch_1
# expanded_conv_2_expand_BN/cond/FusedBatchNorm
# expanded_conv_2_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_2_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_2_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_2_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_2_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_2_expand_BN/cond/Merge
# expanded_conv_2_expand_relu/Relu6
# expanded_conv_2_depthwise/depthwise_kernel
# expanded_conv_2_depthwise/depthwise_kernel/read
# expanded_conv_2_depthwise/depthwise
# expanded_conv_2_depthwise_BN/gamma
# expanded_conv_2_depthwise_BN/gamma/read
# expanded_conv_2_depthwise_BN/beta
# expanded_conv_2_depthwise_BN/beta/read
# expanded_conv_2_depthwise_BN/moving_mean
# expanded_conv_2_depthwise_BN/moving_mean/read
# expanded_conv_2_depthwise_BN/moving_variance
# expanded_conv_2_depthwise_BN/moving_variance/read
# expanded_conv_2_depthwise_BN/Const_4
# expanded_conv_2_depthwise_BN/Const_5
# expanded_conv_2_depthwise_BN/FusedBatchNorm
# expanded_conv_2_depthwise_BN/cond/pred_id
# expanded_conv_2_depthwise_BN/cond/Switch_1
# expanded_conv_2_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_2_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_2_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_2_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_2_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_2_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_2_depthwise_BN/cond/Merge
# expanded_conv_2_depthwise_relu/Relu6
# expanded_conv_2_project/kernel
# expanded_conv_2_project/kernel/read
# expanded_conv_2_project/convolution
# expanded_conv_2_project_BN/gamma
# expanded_conv_2_project_BN/gamma/read
# expanded_conv_2_project_BN/beta
# expanded_conv_2_project_BN/beta/read
# expanded_conv_2_project_BN/moving_mean
# expanded_conv_2_project_BN/moving_mean/read
# expanded_conv_2_project_BN/moving_variance
# expanded_conv_2_project_BN/moving_variance/read
# expanded_conv_2_project_BN/Const_4
# expanded_conv_2_project_BN/Const_5
# expanded_conv_2_project_BN/FusedBatchNorm
# expanded_conv_2_project_BN/cond/pred_id
# expanded_conv_2_project_BN/cond/Switch_1
# expanded_conv_2_project_BN/cond/FusedBatchNorm
# expanded_conv_2_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_2_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_2_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_2_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_2_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_2_project_BN/cond/Merge
# expanded_conv_2_add/add
# expanded_conv_3_expand/kernel
# expanded_conv_3_expand/kernel/read
# expanded_conv_3_expand/convolution
# expanded_conv_3_expand_BN/gamma
# expanded_conv_3_expand_BN/gamma/read
# expanded_conv_3_expand_BN/beta
# expanded_conv_3_expand_BN/beta/read
# expanded_conv_3_expand_BN/moving_mean
# expanded_conv_3_expand_BN/moving_mean/read
# expanded_conv_3_expand_BN/moving_variance
# expanded_conv_3_expand_BN/moving_variance/read
# expanded_conv_3_expand_BN/Const_4
# expanded_conv_3_expand_BN/Const_5
# expanded_conv_3_expand_BN/FusedBatchNorm
# expanded_conv_3_expand_BN/cond/pred_id
# expanded_conv_3_expand_BN/cond/Switch_1
# expanded_conv_3_expand_BN/cond/FusedBatchNorm
# expanded_conv_3_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_3_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_3_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_3_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_3_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_3_expand_BN/cond/Merge
# expanded_conv_3_expand_relu/Relu6
# expanded_conv_3_depthwise/depthwise_kernel
# expanded_conv_3_depthwise/depthwise_kernel/read
# expanded_conv_3_depthwise/depthwise
# expanded_conv_3_depthwise_BN/gamma
# expanded_conv_3_depthwise_BN/gamma/read
# expanded_conv_3_depthwise_BN/beta
# expanded_conv_3_depthwise_BN/beta/read
# expanded_conv_3_depthwise_BN/moving_mean
# expanded_conv_3_depthwise_BN/moving_mean/read
# expanded_conv_3_depthwise_BN/moving_variance
# expanded_conv_3_depthwise_BN/moving_variance/read
# expanded_conv_3_depthwise_BN/Const_4
# expanded_conv_3_depthwise_BN/Const_5
# expanded_conv_3_depthwise_BN/FusedBatchNorm
# expanded_conv_3_depthwise_BN/cond/pred_id
# expanded_conv_3_depthwise_BN/cond/Switch_1
# expanded_conv_3_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_3_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_3_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_3_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_3_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_3_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_3_depthwise_BN/cond/Merge
# expanded_conv_3_depthwise_relu/Relu6
# expanded_conv_3_project/kernel
# expanded_conv_3_project/kernel/read
# expanded_conv_3_project/convolution
# expanded_conv_3_project_BN/gamma
# expanded_conv_3_project_BN/gamma/read
# expanded_conv_3_project_BN/beta
# expanded_conv_3_project_BN/beta/read
# expanded_conv_3_project_BN/moving_mean
# expanded_conv_3_project_BN/moving_mean/read
# expanded_conv_3_project_BN/moving_variance
# expanded_conv_3_project_BN/moving_variance/read
# expanded_conv_3_project_BN/Const_4
# expanded_conv_3_project_BN/Const_5
# expanded_conv_3_project_BN/FusedBatchNorm
# expanded_conv_3_project_BN/cond/pred_id
# expanded_conv_3_project_BN/cond/Switch_1
# expanded_conv_3_project_BN/cond/FusedBatchNorm
# expanded_conv_3_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_3_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_3_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_3_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_3_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_3_project_BN/cond/Merge
# expanded_conv_4_expand/kernel
# expanded_conv_4_expand/kernel/read
# expanded_conv_4_expand/convolution
# expanded_conv_4_expand_BN/gamma
# expanded_conv_4_expand_BN/gamma/read
# expanded_conv_4_expand_BN/beta
# expanded_conv_4_expand_BN/beta/read
# expanded_conv_4_expand_BN/moving_mean
# expanded_conv_4_expand_BN/moving_mean/read
# expanded_conv_4_expand_BN/moving_variance
# expanded_conv_4_expand_BN/moving_variance/read
# expanded_conv_4_expand_BN/Const_4
# expanded_conv_4_expand_BN/Const_5
# expanded_conv_4_expand_BN/FusedBatchNorm
# expanded_conv_4_expand_BN/cond/pred_id
# expanded_conv_4_expand_BN/cond/Switch_1
# expanded_conv_4_expand_BN/cond/FusedBatchNorm
# expanded_conv_4_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_4_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_4_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_4_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_4_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_4_expand_BN/cond/Merge
# expanded_conv_4_expand_relu/Relu6
# expanded_conv_4_depthwise/depthwise_kernel
# expanded_conv_4_depthwise/depthwise_kernel/read
# expanded_conv_4_depthwise/depthwise
# expanded_conv_4_depthwise_BN/gamma
# expanded_conv_4_depthwise_BN/gamma/read
# expanded_conv_4_depthwise_BN/beta
# expanded_conv_4_depthwise_BN/beta/read
# expanded_conv_4_depthwise_BN/moving_mean
# expanded_conv_4_depthwise_BN/moving_mean/read
# expanded_conv_4_depthwise_BN/moving_variance
# expanded_conv_4_depthwise_BN/moving_variance/read
# expanded_conv_4_depthwise_BN/Const_4
# expanded_conv_4_depthwise_BN/Const_5
# expanded_conv_4_depthwise_BN/FusedBatchNorm
# expanded_conv_4_depthwise_BN/cond/pred_id
# expanded_conv_4_depthwise_BN/cond/Switch_1
# expanded_conv_4_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_4_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_4_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_4_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_4_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_4_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_4_depthwise_BN/cond/Merge
# expanded_conv_4_depthwise_relu/Relu6
# expanded_conv_4_project/kernel
# expanded_conv_4_project/kernel/read
# expanded_conv_4_project/convolution
# expanded_conv_4_project_BN/gamma
# expanded_conv_4_project_BN/gamma/read
# expanded_conv_4_project_BN/beta
# expanded_conv_4_project_BN/beta/read
# expanded_conv_4_project_BN/moving_mean
# expanded_conv_4_project_BN/moving_mean/read
# expanded_conv_4_project_BN/moving_variance
# expanded_conv_4_project_BN/moving_variance/read
# expanded_conv_4_project_BN/Const_4
# expanded_conv_4_project_BN/Const_5
# expanded_conv_4_project_BN/FusedBatchNorm
# expanded_conv_4_project_BN/cond/pred_id
# expanded_conv_4_project_BN/cond/Switch_1
# expanded_conv_4_project_BN/cond/FusedBatchNorm
# expanded_conv_4_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_4_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_4_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_4_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_4_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_4_project_BN/cond/Merge
# expanded_conv_4_add/add
# expanded_conv_5_expand/kernel
# expanded_conv_5_expand/kernel/read
# expanded_conv_5_expand/convolution
# expanded_conv_5_expand_BN/gamma
# expanded_conv_5_expand_BN/gamma/read
# expanded_conv_5_expand_BN/beta
# expanded_conv_5_expand_BN/beta/read
# expanded_conv_5_expand_BN/moving_mean
# expanded_conv_5_expand_BN/moving_mean/read
# expanded_conv_5_expand_BN/moving_variance
# expanded_conv_5_expand_BN/moving_variance/read
# expanded_conv_5_expand_BN/Const_4
# expanded_conv_5_expand_BN/Const_5
# expanded_conv_5_expand_BN/FusedBatchNorm
# expanded_conv_5_expand_BN/cond/pred_id
# expanded_conv_5_expand_BN/cond/Switch_1
# expanded_conv_5_expand_BN/cond/FusedBatchNorm
# expanded_conv_5_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_5_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_5_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_5_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_5_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_5_expand_BN/cond/Merge
# expanded_conv_5_expand_relu/Relu6
# expanded_conv_5_depthwise/depthwise_kernel
# expanded_conv_5_depthwise/depthwise_kernel/read
# expanded_conv_5_depthwise/depthwise
# expanded_conv_5_depthwise_BN/gamma
# expanded_conv_5_depthwise_BN/gamma/read
# expanded_conv_5_depthwise_BN/beta
# expanded_conv_5_depthwise_BN/beta/read
# expanded_conv_5_depthwise_BN/moving_mean
# expanded_conv_5_depthwise_BN/moving_mean/read
# expanded_conv_5_depthwise_BN/moving_variance
# expanded_conv_5_depthwise_BN/moving_variance/read
# expanded_conv_5_depthwise_BN/Const_4
# expanded_conv_5_depthwise_BN/Const_5
# expanded_conv_5_depthwise_BN/FusedBatchNorm
# expanded_conv_5_depthwise_BN/cond/pred_id
# expanded_conv_5_depthwise_BN/cond/Switch_1
# expanded_conv_5_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_5_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_5_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_5_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_5_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_5_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_5_depthwise_BN/cond/Merge
# expanded_conv_5_depthwise_relu/Relu6
# expanded_conv_5_project/kernel
# expanded_conv_5_project/kernel/read
# expanded_conv_5_project/convolution
# expanded_conv_5_project_BN/gamma
# expanded_conv_5_project_BN/gamma/read
# expanded_conv_5_project_BN/beta
# expanded_conv_5_project_BN/beta/read
# expanded_conv_5_project_BN/moving_mean
# expanded_conv_5_project_BN/moving_mean/read
# expanded_conv_5_project_BN/moving_variance
# expanded_conv_5_project_BN/moving_variance/read
# expanded_conv_5_project_BN/Const_4
# expanded_conv_5_project_BN/Const_5
# expanded_conv_5_project_BN/FusedBatchNorm
# expanded_conv_5_project_BN/cond/pred_id
# expanded_conv_5_project_BN/cond/Switch_1
# expanded_conv_5_project_BN/cond/FusedBatchNorm
# expanded_conv_5_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_5_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_5_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_5_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_5_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_5_project_BN/cond/Merge
# expanded_conv_5_add/add
# expanded_conv_6_expand/kernel
# expanded_conv_6_expand/kernel/read
# expanded_conv_6_expand/convolution
# expanded_conv_6_expand_BN/gamma
# expanded_conv_6_expand_BN/gamma/read
# expanded_conv_6_expand_BN/beta
# expanded_conv_6_expand_BN/beta/read
# expanded_conv_6_expand_BN/moving_mean
# expanded_conv_6_expand_BN/moving_mean/read
# expanded_conv_6_expand_BN/moving_variance
# expanded_conv_6_expand_BN/moving_variance/read
# expanded_conv_6_expand_BN/Const_4
# expanded_conv_6_expand_BN/Const_5
# expanded_conv_6_expand_BN/FusedBatchNorm
# expanded_conv_6_expand_BN/cond/pred_id
# expanded_conv_6_expand_BN/cond/Switch_1
# expanded_conv_6_expand_BN/cond/FusedBatchNorm
# expanded_conv_6_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_6_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_6_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_6_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_6_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_6_expand_BN/cond/Merge
# expanded_conv_6_expand_relu/Relu6
# expanded_conv_6_depthwise/depthwise_kernel
# expanded_conv_6_depthwise/depthwise_kernel/read
# expanded_conv_6_depthwise/depthwise
# expanded_conv_6_depthwise_BN/gamma
# expanded_conv_6_depthwise_BN/gamma/read
# expanded_conv_6_depthwise_BN/beta
# expanded_conv_6_depthwise_BN/beta/read
# expanded_conv_6_depthwise_BN/moving_mean
# expanded_conv_6_depthwise_BN/moving_mean/read
# expanded_conv_6_depthwise_BN/moving_variance
# expanded_conv_6_depthwise_BN/moving_variance/read
# expanded_conv_6_depthwise_BN/Const_4
# expanded_conv_6_depthwise_BN/Const_5
# expanded_conv_6_depthwise_BN/FusedBatchNorm
# expanded_conv_6_depthwise_BN/cond/pred_id
# expanded_conv_6_depthwise_BN/cond/Switch_1
# expanded_conv_6_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_6_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_6_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_6_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_6_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_6_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_6_depthwise_BN/cond/Merge
# expanded_conv_6_depthwise_relu/Relu6
# expanded_conv_6_project/kernel
# expanded_conv_6_project/kernel/read
# expanded_conv_6_project/convolution
# expanded_conv_6_project_BN/gamma
# expanded_conv_6_project_BN/gamma/read
# expanded_conv_6_project_BN/beta
# expanded_conv_6_project_BN/beta/read
# expanded_conv_6_project_BN/moving_mean
# expanded_conv_6_project_BN/moving_mean/read
# expanded_conv_6_project_BN/moving_variance
# expanded_conv_6_project_BN/moving_variance/read
# expanded_conv_6_project_BN/Const_4
# expanded_conv_6_project_BN/Const_5
# expanded_conv_6_project_BN/FusedBatchNorm
# expanded_conv_6_project_BN/cond/pred_id
# expanded_conv_6_project_BN/cond/Switch_1
# expanded_conv_6_project_BN/cond/FusedBatchNorm
# expanded_conv_6_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_6_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_6_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_6_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_6_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_6_project_BN/cond/Merge
# expanded_conv_7_expand/kernel
# expanded_conv_7_expand/kernel/read
# expanded_conv_7_expand/convolution
# expanded_conv_7_expand_BN/gamma
# expanded_conv_7_expand_BN/gamma/read
# expanded_conv_7_expand_BN/beta
# expanded_conv_7_expand_BN/beta/read
# expanded_conv_7_expand_BN/moving_mean
# expanded_conv_7_expand_BN/moving_mean/read
# expanded_conv_7_expand_BN/moving_variance
# expanded_conv_7_expand_BN/moving_variance/read
# expanded_conv_7_expand_BN/Const_4
# expanded_conv_7_expand_BN/Const_5
# expanded_conv_7_expand_BN/FusedBatchNorm
# expanded_conv_7_expand_BN/cond/pred_id
# expanded_conv_7_expand_BN/cond/Switch_1
# expanded_conv_7_expand_BN/cond/FusedBatchNorm
# expanded_conv_7_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_7_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_7_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_7_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_7_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_7_expand_BN/cond/Merge
# expanded_conv_7_expand_relu/Relu6
# expanded_conv_7_depthwise/depthwise_kernel
# expanded_conv_7_depthwise/depthwise_kernel/read
# expanded_conv_7_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_7_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_7_depthwise/depthwise/SpaceToBatchND
# expanded_conv_7_depthwise/depthwise
# expanded_conv_7_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_7_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_7_depthwise/depthwise/BatchToSpaceND
# expanded_conv_7_depthwise_BN/gamma
# expanded_conv_7_depthwise_BN/gamma/read
# expanded_conv_7_depthwise_BN/beta
# expanded_conv_7_depthwise_BN/beta/read
# expanded_conv_7_depthwise_BN/moving_mean
# expanded_conv_7_depthwise_BN/moving_mean/read
# expanded_conv_7_depthwise_BN/moving_variance
# expanded_conv_7_depthwise_BN/moving_variance/read
# expanded_conv_7_depthwise_BN/Const_4
# expanded_conv_7_depthwise_BN/Const_5
# expanded_conv_7_depthwise_BN/FusedBatchNorm
# expanded_conv_7_depthwise_BN/cond/pred_id
# expanded_conv_7_depthwise_BN/cond/Switch_1
# expanded_conv_7_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_7_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_7_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_7_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_7_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_7_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_7_depthwise_BN/cond/Merge
# expanded_conv_7_depthwise_relu/Relu6
# expanded_conv_7_project/kernel
# expanded_conv_7_project/kernel/read
# expanded_conv_7_project/convolution
# expanded_conv_7_project_BN/gamma
# expanded_conv_7_project_BN/gamma/read
# expanded_conv_7_project_BN/beta
# expanded_conv_7_project_BN/beta/read
# expanded_conv_7_project_BN/moving_mean
# expanded_conv_7_project_BN/moving_mean/read
# expanded_conv_7_project_BN/moving_variance
# expanded_conv_7_project_BN/moving_variance/read
# expanded_conv_7_project_BN/Const_4
# expanded_conv_7_project_BN/Const_5
# expanded_conv_7_project_BN/FusedBatchNorm
# expanded_conv_7_project_BN/cond/pred_id
# expanded_conv_7_project_BN/cond/Switch_1
# expanded_conv_7_project_BN/cond/FusedBatchNorm
# expanded_conv_7_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_7_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_7_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_7_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_7_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_7_project_BN/cond/Merge
# expanded_conv_7_add/add
# expanded_conv_8_expand/kernel
# expanded_conv_8_expand/kernel/read
# expanded_conv_8_expand/convolution
# expanded_conv_8_expand_BN/gamma
# expanded_conv_8_expand_BN/gamma/read
# expanded_conv_8_expand_BN/beta
# expanded_conv_8_expand_BN/beta/read
# expanded_conv_8_expand_BN/moving_mean
# expanded_conv_8_expand_BN/moving_mean/read
# expanded_conv_8_expand_BN/moving_variance
# expanded_conv_8_expand_BN/moving_variance/read
# expanded_conv_8_expand_BN/Const_4
# expanded_conv_8_expand_BN/Const_5
# expanded_conv_8_expand_BN/FusedBatchNorm
# expanded_conv_8_expand_BN/cond/pred_id
# expanded_conv_8_expand_BN/cond/Switch_1
# expanded_conv_8_expand_BN/cond/FusedBatchNorm
# expanded_conv_8_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_8_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_8_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_8_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_8_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_8_expand_BN/cond/Merge
# expanded_conv_8_expand_relu/Relu6
# expanded_conv_8_depthwise/depthwise_kernel
# expanded_conv_8_depthwise/depthwise_kernel/read
# expanded_conv_8_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_8_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_8_depthwise/depthwise/SpaceToBatchND
# expanded_conv_8_depthwise/depthwise
# expanded_conv_8_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_8_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_8_depthwise/depthwise/BatchToSpaceND
# expanded_conv_8_depthwise_BN/gamma
# expanded_conv_8_depthwise_BN/gamma/read
# expanded_conv_8_depthwise_BN/beta
# expanded_conv_8_depthwise_BN/beta/read
# expanded_conv_8_depthwise_BN/moving_mean
# expanded_conv_8_depthwise_BN/moving_mean/read
# expanded_conv_8_depthwise_BN/moving_variance
# expanded_conv_8_depthwise_BN/moving_variance/read
# expanded_conv_8_depthwise_BN/Const_4
# expanded_conv_8_depthwise_BN/Const_5
# expanded_conv_8_depthwise_BN/FusedBatchNorm
# expanded_conv_8_depthwise_BN/cond/pred_id
# expanded_conv_8_depthwise_BN/cond/Switch_1
# expanded_conv_8_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_8_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_8_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_8_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_8_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_8_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_8_depthwise_BN/cond/Merge
# expanded_conv_8_depthwise_relu/Relu6
# expanded_conv_8_project/kernel
# expanded_conv_8_project/kernel/read
# expanded_conv_8_project/convolution
# expanded_conv_8_project_BN/gamma
# expanded_conv_8_project_BN/gamma/read
# expanded_conv_8_project_BN/beta
# expanded_conv_8_project_BN/beta/read
# expanded_conv_8_project_BN/moving_mean
# expanded_conv_8_project_BN/moving_mean/read
# expanded_conv_8_project_BN/moving_variance
# expanded_conv_8_project_BN/moving_variance/read
# expanded_conv_8_project_BN/Const_4
# expanded_conv_8_project_BN/Const_5
# expanded_conv_8_project_BN/FusedBatchNorm
# expanded_conv_8_project_BN/cond/pred_id
# expanded_conv_8_project_BN/cond/Switch_1
# expanded_conv_8_project_BN/cond/FusedBatchNorm
# expanded_conv_8_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_8_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_8_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_8_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_8_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_8_project_BN/cond/Merge
# expanded_conv_8_add/add
# expanded_conv_9_expand/kernel
# expanded_conv_9_expand/kernel/read
# expanded_conv_9_expand/convolution
# expanded_conv_9_expand_BN/gamma
# expanded_conv_9_expand_BN/gamma/read
# expanded_conv_9_expand_BN/beta
# expanded_conv_9_expand_BN/beta/read
# expanded_conv_9_expand_BN/moving_mean
# expanded_conv_9_expand_BN/moving_mean/read
# expanded_conv_9_expand_BN/moving_variance
# expanded_conv_9_expand_BN/moving_variance/read
# expanded_conv_9_expand_BN/Const_4
# expanded_conv_9_expand_BN/Const_5
# expanded_conv_9_expand_BN/FusedBatchNorm
# expanded_conv_9_expand_BN/cond/pred_id
# expanded_conv_9_expand_BN/cond/Switch_1
# expanded_conv_9_expand_BN/cond/FusedBatchNorm
# expanded_conv_9_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_9_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_9_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_9_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_9_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_9_expand_BN/cond/Merge
# expanded_conv_9_expand_relu/Relu6
# expanded_conv_9_depthwise/depthwise_kernel
# expanded_conv_9_depthwise/depthwise_kernel/read
# expanded_conv_9_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_9_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_9_depthwise/depthwise/SpaceToBatchND
# expanded_conv_9_depthwise/depthwise
# expanded_conv_9_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_9_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_9_depthwise/depthwise/BatchToSpaceND
# expanded_conv_9_depthwise_BN/gamma
# expanded_conv_9_depthwise_BN/gamma/read
# expanded_conv_9_depthwise_BN/beta
# expanded_conv_9_depthwise_BN/beta/read
# expanded_conv_9_depthwise_BN/moving_mean
# expanded_conv_9_depthwise_BN/moving_mean/read
# expanded_conv_9_depthwise_BN/moving_variance
# expanded_conv_9_depthwise_BN/moving_variance/read
# expanded_conv_9_depthwise_BN/Const_4
# expanded_conv_9_depthwise_BN/Const_5
# expanded_conv_9_depthwise_BN/FusedBatchNorm
# expanded_conv_9_depthwise_BN/cond/pred_id
# expanded_conv_9_depthwise_BN/cond/Switch_1
# expanded_conv_9_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_9_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_9_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_9_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_9_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_9_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_9_depthwise_BN/cond/Merge
# expanded_conv_9_depthwise_relu/Relu6
# expanded_conv_9_project/kernel
# expanded_conv_9_project/kernel/read
# expanded_conv_9_project/convolution
# expanded_conv_9_project_BN/gamma
# expanded_conv_9_project_BN/gamma/read
# expanded_conv_9_project_BN/beta
# expanded_conv_9_project_BN/beta/read
# expanded_conv_9_project_BN/moving_mean
# expanded_conv_9_project_BN/moving_mean/read
# expanded_conv_9_project_BN/moving_variance
# expanded_conv_9_project_BN/moving_variance/read
# expanded_conv_9_project_BN/Const_4
# expanded_conv_9_project_BN/Const_5
# expanded_conv_9_project_BN/FusedBatchNorm
# expanded_conv_9_project_BN/cond/pred_id
# expanded_conv_9_project_BN/cond/Switch_1
# expanded_conv_9_project_BN/cond/FusedBatchNorm
# expanded_conv_9_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_9_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_9_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_9_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_9_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_9_project_BN/cond/Merge
# expanded_conv_9_add/add
# expanded_conv_10_expand/kernel
# expanded_conv_10_expand/kernel/read
# expanded_conv_10_expand/convolution
# expanded_conv_10_expand_BN/gamma
# expanded_conv_10_expand_BN/gamma/read
# expanded_conv_10_expand_BN/beta
# expanded_conv_10_expand_BN/beta/read
# expanded_conv_10_expand_BN/moving_mean
# expanded_conv_10_expand_BN/moving_mean/read
# expanded_conv_10_expand_BN/moving_variance
# expanded_conv_10_expand_BN/moving_variance/read
# expanded_conv_10_expand_BN/Const_4
# expanded_conv_10_expand_BN/Const_5
# expanded_conv_10_expand_BN/FusedBatchNorm
# expanded_conv_10_expand_BN/cond/pred_id
# expanded_conv_10_expand_BN/cond/Switch_1
# expanded_conv_10_expand_BN/cond/FusedBatchNorm
# expanded_conv_10_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_10_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_10_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_10_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_10_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_10_expand_BN/cond/Merge
# expanded_conv_10_expand_relu/Relu6
# expanded_conv_10_depthwise/depthwise_kernel
# expanded_conv_10_depthwise/depthwise_kernel/read
# expanded_conv_10_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_10_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_10_depthwise/depthwise/SpaceToBatchND
# expanded_conv_10_depthwise/depthwise
# expanded_conv_10_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_10_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_10_depthwise/depthwise/BatchToSpaceND
# expanded_conv_10_depthwise_BN/gamma
# expanded_conv_10_depthwise_BN/gamma/read
# expanded_conv_10_depthwise_BN/beta
# expanded_conv_10_depthwise_BN/beta/read
# expanded_conv_10_depthwise_BN/moving_mean
# expanded_conv_10_depthwise_BN/moving_mean/read
# expanded_conv_10_depthwise_BN/moving_variance
# expanded_conv_10_depthwise_BN/moving_variance/read
# expanded_conv_10_depthwise_BN/Const_4
# expanded_conv_10_depthwise_BN/Const_5
# expanded_conv_10_depthwise_BN/FusedBatchNorm
# expanded_conv_10_depthwise_BN/cond/pred_id
# expanded_conv_10_depthwise_BN/cond/Switch_1
# expanded_conv_10_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_10_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_10_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_10_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_10_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_10_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_10_depthwise_BN/cond/Merge
# expanded_conv_10_depthwise_relu/Relu6
# expanded_conv_10_project/kernel
# expanded_conv_10_project/kernel/read
# expanded_conv_10_project/convolution
# expanded_conv_10_project_BN/gamma
# expanded_conv_10_project_BN/gamma/read
# expanded_conv_10_project_BN/beta
# expanded_conv_10_project_BN/beta/read
# expanded_conv_10_project_BN/moving_mean
# expanded_conv_10_project_BN/moving_mean/read
# expanded_conv_10_project_BN/moving_variance
# expanded_conv_10_project_BN/moving_variance/read
# expanded_conv_10_project_BN/Const_4
# expanded_conv_10_project_BN/Const_5
# expanded_conv_10_project_BN/FusedBatchNorm
# expanded_conv_10_project_BN/cond/pred_id
# expanded_conv_10_project_BN/cond/Switch_1
# expanded_conv_10_project_BN/cond/FusedBatchNorm
# expanded_conv_10_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_10_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_10_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_10_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_10_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_10_project_BN/cond/Merge
# expanded_conv_11_expand/kernel
# expanded_conv_11_expand/kernel/read
# expanded_conv_11_expand/convolution
# expanded_conv_11_expand_BN/gamma
# expanded_conv_11_expand_BN/gamma/read
# expanded_conv_11_expand_BN/beta
# expanded_conv_11_expand_BN/beta/read
# expanded_conv_11_expand_BN/moving_mean
# expanded_conv_11_expand_BN/moving_mean/read
# expanded_conv_11_expand_BN/moving_variance
# expanded_conv_11_expand_BN/moving_variance/read
# expanded_conv_11_expand_BN/Const_4
# expanded_conv_11_expand_BN/Const_5
# expanded_conv_11_expand_BN/FusedBatchNorm
# expanded_conv_11_expand_BN/cond/pred_id
# expanded_conv_11_expand_BN/cond/Switch_1
# expanded_conv_11_expand_BN/cond/FusedBatchNorm
# expanded_conv_11_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_11_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_11_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_11_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_11_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_11_expand_BN/cond/Merge
# expanded_conv_11_expand_relu/Relu6
# expanded_conv_11_depthwise/depthwise_kernel
# expanded_conv_11_depthwise/depthwise_kernel/read
# expanded_conv_11_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_11_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_11_depthwise/depthwise/SpaceToBatchND
# expanded_conv_11_depthwise/depthwise
# expanded_conv_11_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_11_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_11_depthwise/depthwise/BatchToSpaceND
# expanded_conv_11_depthwise_BN/gamma
# expanded_conv_11_depthwise_BN/gamma/read
# expanded_conv_11_depthwise_BN/beta
# expanded_conv_11_depthwise_BN/beta/read
# expanded_conv_11_depthwise_BN/moving_mean
# expanded_conv_11_depthwise_BN/moving_mean/read
# expanded_conv_11_depthwise_BN/moving_variance
# expanded_conv_11_depthwise_BN/moving_variance/read
# expanded_conv_11_depthwise_BN/Const_4
# expanded_conv_11_depthwise_BN/Const_5
# expanded_conv_11_depthwise_BN/FusedBatchNorm
# expanded_conv_11_depthwise_BN/cond/pred_id
# expanded_conv_11_depthwise_BN/cond/Switch_1
# expanded_conv_11_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_11_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_11_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_11_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_11_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_11_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_11_depthwise_BN/cond/Merge
# expanded_conv_11_depthwise_relu/Relu6
# expanded_conv_11_project/kernel
# expanded_conv_11_project/kernel/read
# expanded_conv_11_project/convolution
# expanded_conv_11_project_BN/gamma
# expanded_conv_11_project_BN/gamma/read
# expanded_conv_11_project_BN/beta
# expanded_conv_11_project_BN/beta/read
# expanded_conv_11_project_BN/moving_mean
# expanded_conv_11_project_BN/moving_mean/read
# expanded_conv_11_project_BN/moving_variance
# expanded_conv_11_project_BN/moving_variance/read
# expanded_conv_11_project_BN/Const_4
# expanded_conv_11_project_BN/Const_5
# expanded_conv_11_project_BN/FusedBatchNorm
# expanded_conv_11_project_BN/cond/pred_id
# expanded_conv_11_project_BN/cond/Switch_1
# expanded_conv_11_project_BN/cond/FusedBatchNorm
# expanded_conv_11_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_11_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_11_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_11_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_11_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_11_project_BN/cond/Merge
# expanded_conv_11_add/add
# expanded_conv_12_expand/kernel
# expanded_conv_12_expand/kernel/read
# expanded_conv_12_expand/convolution
# expanded_conv_12_expand_BN/gamma
# expanded_conv_12_expand_BN/gamma/read
# expanded_conv_12_expand_BN/beta
# expanded_conv_12_expand_BN/beta/read
# expanded_conv_12_expand_BN/moving_mean
# expanded_conv_12_expand_BN/moving_mean/read
# expanded_conv_12_expand_BN/moving_variance
# expanded_conv_12_expand_BN/moving_variance/read
# expanded_conv_12_expand_BN/Const_4
# expanded_conv_12_expand_BN/Const_5
# expanded_conv_12_expand_BN/FusedBatchNorm
# expanded_conv_12_expand_BN/cond/pred_id
# expanded_conv_12_expand_BN/cond/Switch_1
# expanded_conv_12_expand_BN/cond/FusedBatchNorm
# expanded_conv_12_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_12_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_12_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_12_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_12_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_12_expand_BN/cond/Merge
# expanded_conv_12_expand_relu/Relu6
# expanded_conv_12_depthwise/depthwise_kernel
# expanded_conv_12_depthwise/depthwise_kernel/read
# expanded_conv_12_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_12_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_12_depthwise/depthwise/SpaceToBatchND
# expanded_conv_12_depthwise/depthwise
# expanded_conv_12_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_12_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_12_depthwise/depthwise/BatchToSpaceND
# expanded_conv_12_depthwise_BN/gamma
# expanded_conv_12_depthwise_BN/gamma/read
# expanded_conv_12_depthwise_BN/beta
# expanded_conv_12_depthwise_BN/beta/read
# expanded_conv_12_depthwise_BN/moving_mean
# expanded_conv_12_depthwise_BN/moving_mean/read
# expanded_conv_12_depthwise_BN/moving_variance
# expanded_conv_12_depthwise_BN/moving_variance/read
# expanded_conv_12_depthwise_BN/Const_4
# expanded_conv_12_depthwise_BN/Const_5
# expanded_conv_12_depthwise_BN/FusedBatchNorm
# expanded_conv_12_depthwise_BN/cond/pred_id
# expanded_conv_12_depthwise_BN/cond/Switch_1
# expanded_conv_12_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_12_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_12_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_12_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_12_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_12_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_12_depthwise_BN/cond/Merge
# expanded_conv_12_depthwise_relu/Relu6
# expanded_conv_12_project/kernel
# expanded_conv_12_project/kernel/read
# expanded_conv_12_project/convolution
# expanded_conv_12_project_BN/gamma
# expanded_conv_12_project_BN/gamma/read
# expanded_conv_12_project_BN/beta
# expanded_conv_12_project_BN/beta/read
# expanded_conv_12_project_BN/moving_mean
# expanded_conv_12_project_BN/moving_mean/read
# expanded_conv_12_project_BN/moving_variance
# expanded_conv_12_project_BN/moving_variance/read
# expanded_conv_12_project_BN/Const_4
# expanded_conv_12_project_BN/Const_5
# expanded_conv_12_project_BN/FusedBatchNorm
# expanded_conv_12_project_BN/cond/pred_id
# expanded_conv_12_project_BN/cond/Switch_1
# expanded_conv_12_project_BN/cond/FusedBatchNorm
# expanded_conv_12_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_12_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_12_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_12_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_12_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_12_project_BN/cond/Merge
# expanded_conv_12_add/add
# expanded_conv_13_expand/kernel
# expanded_conv_13_expand/kernel/read
# expanded_conv_13_expand/convolution
# expanded_conv_13_expand_BN/gamma
# expanded_conv_13_expand_BN/gamma/read
# expanded_conv_13_expand_BN/beta
# expanded_conv_13_expand_BN/beta/read
# expanded_conv_13_expand_BN/moving_mean
# expanded_conv_13_expand_BN/moving_mean/read
# expanded_conv_13_expand_BN/moving_variance
# expanded_conv_13_expand_BN/moving_variance/read
# expanded_conv_13_expand_BN/Const_4
# expanded_conv_13_expand_BN/Const_5
# expanded_conv_13_expand_BN/FusedBatchNorm
# expanded_conv_13_expand_BN/cond/pred_id
# expanded_conv_13_expand_BN/cond/Switch_1
# expanded_conv_13_expand_BN/cond/FusedBatchNorm
# expanded_conv_13_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_13_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_13_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_13_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_13_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_13_expand_BN/cond/Merge
# expanded_conv_13_expand_relu/Relu6
# expanded_conv_13_depthwise/depthwise_kernel
# expanded_conv_13_depthwise/depthwise_kernel/read
# expanded_conv_13_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_13_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_13_depthwise/depthwise/SpaceToBatchND
# expanded_conv_13_depthwise/depthwise
# expanded_conv_13_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_13_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_13_depthwise/depthwise/BatchToSpaceND
# expanded_conv_13_depthwise_BN/gamma
# expanded_conv_13_depthwise_BN/gamma/read
# expanded_conv_13_depthwise_BN/beta
# expanded_conv_13_depthwise_BN/beta/read
# expanded_conv_13_depthwise_BN/moving_mean
# expanded_conv_13_depthwise_BN/moving_mean/read
# expanded_conv_13_depthwise_BN/moving_variance
# expanded_conv_13_depthwise_BN/moving_variance/read
# expanded_conv_13_depthwise_BN/Const_4
# expanded_conv_13_depthwise_BN/Const_5
# expanded_conv_13_depthwise_BN/FusedBatchNorm
# expanded_conv_13_depthwise_BN/cond/pred_id
# expanded_conv_13_depthwise_BN/cond/Switch_1
# expanded_conv_13_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_13_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_13_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_13_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_13_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_13_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_13_depthwise_BN/cond/Merge
# expanded_conv_13_depthwise_relu/Relu6
# expanded_conv_13_project/kernel
# expanded_conv_13_project/kernel/read
# expanded_conv_13_project/convolution
# expanded_conv_13_project_BN/gamma
# expanded_conv_13_project_BN/gamma/read
# expanded_conv_13_project_BN/beta
# expanded_conv_13_project_BN/beta/read
# expanded_conv_13_project_BN/moving_mean
# expanded_conv_13_project_BN/moving_mean/read
# expanded_conv_13_project_BN/moving_variance
# expanded_conv_13_project_BN/moving_variance/read
# expanded_conv_13_project_BN/Const_4
# expanded_conv_13_project_BN/Const_5
# expanded_conv_13_project_BN/FusedBatchNorm
# expanded_conv_13_project_BN/cond/pred_id
# expanded_conv_13_project_BN/cond/Switch_1
# expanded_conv_13_project_BN/cond/FusedBatchNorm
# expanded_conv_13_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_13_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_13_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_13_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_13_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_13_project_BN/cond/Merge
# expanded_conv_14_expand/kernel
# expanded_conv_14_expand/kernel/read
# expanded_conv_14_expand/convolution
# expanded_conv_14_expand_BN/gamma
# expanded_conv_14_expand_BN/gamma/read
# expanded_conv_14_expand_BN/beta
# expanded_conv_14_expand_BN/beta/read
# expanded_conv_14_expand_BN/moving_mean
# expanded_conv_14_expand_BN/moving_mean/read
# expanded_conv_14_expand_BN/moving_variance
# expanded_conv_14_expand_BN/moving_variance/read
# expanded_conv_14_expand_BN/Const_4
# expanded_conv_14_expand_BN/Const_5
# expanded_conv_14_expand_BN/FusedBatchNorm
# expanded_conv_14_expand_BN/cond/pred_id
# expanded_conv_14_expand_BN/cond/Switch_1
# expanded_conv_14_expand_BN/cond/FusedBatchNorm
# expanded_conv_14_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_14_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_14_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_14_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_14_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_14_expand_BN/cond/Merge
# expanded_conv_14_expand_relu/Relu6
# expanded_conv_14_depthwise/depthwise_kernel
# expanded_conv_14_depthwise/depthwise_kernel/read
# expanded_conv_14_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_14_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_14_depthwise/depthwise/SpaceToBatchND
# expanded_conv_14_depthwise/depthwise
# expanded_conv_14_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_14_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_14_depthwise/depthwise/BatchToSpaceND
# expanded_conv_14_depthwise_BN/gamma
# expanded_conv_14_depthwise_BN/gamma/read
# expanded_conv_14_depthwise_BN/beta
# expanded_conv_14_depthwise_BN/beta/read
# expanded_conv_14_depthwise_BN/moving_mean
# expanded_conv_14_depthwise_BN/moving_mean/read
# expanded_conv_14_depthwise_BN/moving_variance
# expanded_conv_14_depthwise_BN/moving_variance/read
# expanded_conv_14_depthwise_BN/Const_4
# expanded_conv_14_depthwise_BN/Const_5
# expanded_conv_14_depthwise_BN/FusedBatchNorm
# expanded_conv_14_depthwise_BN/cond/pred_id
# expanded_conv_14_depthwise_BN/cond/Switch_1
# expanded_conv_14_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_14_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_14_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_14_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_14_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_14_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_14_depthwise_BN/cond/Merge
# expanded_conv_14_depthwise_relu/Relu6
# expanded_conv_14_project/kernel
# expanded_conv_14_project/kernel/read
# expanded_conv_14_project/convolution
# expanded_conv_14_project_BN/gamma
# expanded_conv_14_project_BN/gamma/read
# expanded_conv_14_project_BN/beta
# expanded_conv_14_project_BN/beta/read
# expanded_conv_14_project_BN/moving_mean
# expanded_conv_14_project_BN/moving_mean/read
# expanded_conv_14_project_BN/moving_variance
# expanded_conv_14_project_BN/moving_variance/read
# expanded_conv_14_project_BN/Const_4
# expanded_conv_14_project_BN/Const_5
# expanded_conv_14_project_BN/FusedBatchNorm
# expanded_conv_14_project_BN/cond/pred_id
# expanded_conv_14_project_BN/cond/Switch_1
# expanded_conv_14_project_BN/cond/FusedBatchNorm
# expanded_conv_14_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_14_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_14_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_14_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_14_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_14_project_BN/cond/Merge
# expanded_conv_14_add/add
# expanded_conv_15_expand/kernel
# expanded_conv_15_expand/kernel/read
# expanded_conv_15_expand/convolution
# expanded_conv_15_expand_BN/gamma
# expanded_conv_15_expand_BN/gamma/read
# expanded_conv_15_expand_BN/beta
# expanded_conv_15_expand_BN/beta/read
# expanded_conv_15_expand_BN/moving_mean
# expanded_conv_15_expand_BN/moving_mean/read
# expanded_conv_15_expand_BN/moving_variance
# expanded_conv_15_expand_BN/moving_variance/read
# expanded_conv_15_expand_BN/Const_4
# expanded_conv_15_expand_BN/Const_5
# expanded_conv_15_expand_BN/FusedBatchNorm
# expanded_conv_15_expand_BN/cond/pred_id
# expanded_conv_15_expand_BN/cond/Switch_1
# expanded_conv_15_expand_BN/cond/FusedBatchNorm
# expanded_conv_15_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_15_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_15_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_15_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_15_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_15_expand_BN/cond/Merge
# expanded_conv_15_expand_relu/Relu6
# expanded_conv_15_depthwise/depthwise_kernel
# expanded_conv_15_depthwise/depthwise_kernel/read
# expanded_conv_15_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_15_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_15_depthwise/depthwise/SpaceToBatchND
# expanded_conv_15_depthwise/depthwise
# expanded_conv_15_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_15_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_15_depthwise/depthwise/BatchToSpaceND
# expanded_conv_15_depthwise_BN/gamma
# expanded_conv_15_depthwise_BN/gamma/read
# expanded_conv_15_depthwise_BN/beta
# expanded_conv_15_depthwise_BN/beta/read
# expanded_conv_15_depthwise_BN/moving_mean
# expanded_conv_15_depthwise_BN/moving_mean/read
# expanded_conv_15_depthwise_BN/moving_variance
# expanded_conv_15_depthwise_BN/moving_variance/read
# expanded_conv_15_depthwise_BN/Const_4
# expanded_conv_15_depthwise_BN/Const_5
# expanded_conv_15_depthwise_BN/FusedBatchNorm
# expanded_conv_15_depthwise_BN/cond/pred_id
# expanded_conv_15_depthwise_BN/cond/Switch_1
# expanded_conv_15_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_15_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_15_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_15_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_15_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_15_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_15_depthwise_BN/cond/Merge
# expanded_conv_15_depthwise_relu/Relu6
# expanded_conv_15_project/kernel
# expanded_conv_15_project/kernel/read
# expanded_conv_15_project/convolution
# expanded_conv_15_project_BN/gamma
# expanded_conv_15_project_BN/gamma/read
# expanded_conv_15_project_BN/beta
# expanded_conv_15_project_BN/beta/read
# expanded_conv_15_project_BN/moving_mean
# expanded_conv_15_project_BN/moving_mean/read
# expanded_conv_15_project_BN/moving_variance
# expanded_conv_15_project_BN/moving_variance/read
# expanded_conv_15_project_BN/Const_4
# expanded_conv_15_project_BN/Const_5
# expanded_conv_15_project_BN/FusedBatchNorm
# expanded_conv_15_project_BN/cond/pred_id
# expanded_conv_15_project_BN/cond/Switch_1
# expanded_conv_15_project_BN/cond/FusedBatchNorm
# expanded_conv_15_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_15_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_15_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_15_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_15_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_15_project_BN/cond/Merge
# expanded_conv_15_add/add
# expanded_conv_16_expand/kernel
# expanded_conv_16_expand/kernel/read
# expanded_conv_16_expand/convolution
# expanded_conv_16_expand_BN/gamma
# expanded_conv_16_expand_BN/gamma/read
# expanded_conv_16_expand_BN/beta
# expanded_conv_16_expand_BN/beta/read
# expanded_conv_16_expand_BN/moving_mean
# expanded_conv_16_expand_BN/moving_mean/read
# expanded_conv_16_expand_BN/moving_variance
# expanded_conv_16_expand_BN/moving_variance/read
# expanded_conv_16_expand_BN/Const_4
# expanded_conv_16_expand_BN/Const_5
# expanded_conv_16_expand_BN/FusedBatchNorm
# expanded_conv_16_expand_BN/cond/pred_id
# expanded_conv_16_expand_BN/cond/Switch_1
# expanded_conv_16_expand_BN/cond/FusedBatchNorm
# expanded_conv_16_expand_BN/cond/FusedBatchNorm/Switch
# expanded_conv_16_expand_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_16_expand_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_16_expand_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_16_expand_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_16_expand_BN/cond/Merge
# expanded_conv_16_expand_relu/Relu6
# expanded_conv_16_depthwise/depthwise_kernel
# expanded_conv_16_depthwise/depthwise_kernel/read
# expanded_conv_16_depthwise/depthwise/SpaceToBatchND/block_shape
# expanded_conv_16_depthwise/depthwise/SpaceToBatchND/paddings
# expanded_conv_16_depthwise/depthwise/SpaceToBatchND
# expanded_conv_16_depthwise/depthwise
# expanded_conv_16_depthwise/depthwise/BatchToSpaceND/block_shape
# expanded_conv_16_depthwise/depthwise/BatchToSpaceND/crops
# expanded_conv_16_depthwise/depthwise/BatchToSpaceND
# expanded_conv_16_depthwise_BN/gamma
# expanded_conv_16_depthwise_BN/gamma/read
# expanded_conv_16_depthwise_BN/beta
# expanded_conv_16_depthwise_BN/beta/read
# expanded_conv_16_depthwise_BN/moving_mean
# expanded_conv_16_depthwise_BN/moving_mean/read
# expanded_conv_16_depthwise_BN/moving_variance
# expanded_conv_16_depthwise_BN/moving_variance/read
# expanded_conv_16_depthwise_BN/Const_4
# expanded_conv_16_depthwise_BN/Const_5
# expanded_conv_16_depthwise_BN/FusedBatchNorm
# expanded_conv_16_depthwise_BN/cond/pred_id
# expanded_conv_16_depthwise_BN/cond/Switch_1
# expanded_conv_16_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_16_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_16_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_16_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_16_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_16_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_16_depthwise_BN/cond/Merge
# expanded_conv_16_depthwise_relu/Relu6
# expanded_conv_16_project/kernel
# expanded_conv_16_project/kernel/read
# expanded_conv_16_project/convolution
# expanded_conv_16_project_BN/gamma
# expanded_conv_16_project_BN/gamma/read
# expanded_conv_16_project_BN/beta
# expanded_conv_16_project_BN/beta/read
# expanded_conv_16_project_BN/moving_mean
# expanded_conv_16_project_BN/moving_mean/read
# expanded_conv_16_project_BN/moving_variance
# expanded_conv_16_project_BN/moving_variance/read
# expanded_conv_16_project_BN/Const_4
# expanded_conv_16_project_BN/Const_5
# expanded_conv_16_project_BN/FusedBatchNorm
# expanded_conv_16_project_BN/cond/pred_id
# expanded_conv_16_project_BN/cond/Switch_1
# expanded_conv_16_project_BN/cond/FusedBatchNorm
# expanded_conv_16_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_16_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_16_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_16_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_16_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_16_project_BN/cond/Merge
# average_pooling2d_1/AvgPool
# image_pooling/kernel
# image_pooling/kernel/read
# image_pooling/convolution
# image_pooling_BN/gamma
# image_pooling_BN/gamma/read
# image_pooling_BN/beta
# image_pooling_BN/beta/read
# image_pooling_BN/moving_mean
# image_pooling_BN/moving_mean/read
# image_pooling_BN/moving_variance
# image_pooling_BN/moving_variance/read
# image_pooling_BN/Const_4
# image_pooling_BN/Const_5
# image_pooling_BN/FusedBatchNorm
# image_pooling_BN/cond/pred_id
# image_pooling_BN/cond/Switch_1
# image_pooling_BN/cond/FusedBatchNorm
# image_pooling_BN/cond/FusedBatchNorm/Switch
# image_pooling_BN/cond/FusedBatchNorm/Switch_1
# image_pooling_BN/cond/FusedBatchNorm/Switch_2
# image_pooling_BN/cond/FusedBatchNorm/Switch_3
# image_pooling_BN/cond/FusedBatchNorm/Switch_4
# image_pooling_BN/cond/Merge
# activation_1/Relu
# bilinear_upsampling_1/ResizeBilinear/size
# bilinear_upsampling_1/ResizeBilinear
# aspp0/kernel
# aspp0/kernel/read
# aspp0/convolution
# aspp0_BN/gamma
# aspp0_BN/gamma/read
# aspp0_BN/beta
# aspp0_BN/beta/read
# aspp0_BN/moving_mean
# aspp0_BN/moving_mean/read
# aspp0_BN/moving_variance
# aspp0_BN/moving_variance/read
# aspp0_BN/Const_4
# aspp0_BN/Const_5
# aspp0_BN/FusedBatchNorm
# aspp0_BN/cond/pred_id
# aspp0_BN/cond/Switch_1
# aspp0_BN/cond/FusedBatchNorm
# aspp0_BN/cond/FusedBatchNorm/Switch
# aspp0_BN/cond/FusedBatchNorm/Switch_1
# aspp0_BN/cond/FusedBatchNorm/Switch_2
# aspp0_BN/cond/FusedBatchNorm/Switch_3
# aspp0_BN/cond/FusedBatchNorm/Switch_4
# aspp0_BN/cond/Merge
# aspp0_activation/Relu
# concatenate_1/concat/axis
# concatenate_1/concat
# concat_projection/kernel
# concat_projection/kernel/read
# concat_projection/convolution
# concat_projection_BN/gamma
# concat_projection_BN/gamma/read
# concat_projection_BN/beta
# concat_projection_BN/beta/read
# concat_projection_BN/moving_mean
# concat_projection_BN/moving_mean/read
# concat_projection_BN/moving_variance
# concat_projection_BN/moving_variance/read
# concat_projection_BN/Const_4
# concat_projection_BN/Const_5
# concat_projection_BN/FusedBatchNorm
# concat_projection_BN/cond/pred_id
# concat_projection_BN/cond/Switch_1
# concat_projection_BN/cond/FusedBatchNorm
# concat_projection_BN/cond/FusedBatchNorm/Switch
# concat_projection_BN/cond/FusedBatchNorm/Switch_1
# concat_projection_BN/cond/FusedBatchNorm/Switch_2
# concat_projection_BN/cond/FusedBatchNorm/Switch_3
# concat_projection_BN/cond/FusedBatchNorm/Switch_4
# concat_projection_BN/cond/Merge
# activation_2/Relu
# dropout_1/cond/Switch
# dropout_1/cond/switch_t
# dropout_1/cond/pred_id
# dropout_1/cond/mul/y
# dropout_1/cond/mul
# dropout_1/cond/mul/Switch
# dropout_1/cond/dropout/rate
# dropout_1/cond/dropout/Shape
# dropout_1/cond/dropout/sub/x
# dropout_1/cond/dropout/sub
# dropout_1/cond/dropout/random_uniform/min
# dropout_1/cond/dropout/random_uniform/max
# dropout_1/cond/dropout/random_uniform/RandomUniform
# dropout_1/cond/dropout/random_uniform/sub
# dropout_1/cond/dropout/random_uniform/mul
# dropout_1/cond/dropout/random_uniform
# dropout_1/cond/dropout/add
# dropout_1/cond/dropout/Floor
# dropout_1/cond/dropout/truediv
# dropout_1/cond/dropout/mul
# dropout_1/cond/Switch_1
# dropout_1/cond/Merge
# custom_logits_semantic/kernel
# custom_logits_semantic/kernel/read
# custom_logits_semantic/bias
# custom_logits_semantic/bias/read
# custom_logits_semantic/convolution
# custom_logits_semantic/BiasAdd
# bilinear_upsampling_2/ResizeBilinear/size
# bilinear_upsampling_2/ResizeBilinear
# output_layer/Sigmoid

# %%
#sess.run(tf.global_variables_initializer())
graphDef = K.get_session().graph.as_graph_def()
output_node_names_gv = output_node_names + [v.op.name for v in tf.global_variables()]
graphDef = optimize_for_inference(graphDef,
                                   input_node_names,
                                   output_node_names,
                                   tf.float32.as_datatype_enum,
                                   toco_compatible=True)
tf.train.write_graph(graphDef, MODEL_PATH, pb_op_filename, as_text=False)
# Out:
# WARNING:tensorflow:Didn't find expected conv Constant input to 'Conv/convolution', found name: "Conv/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'Conv/convolution', found name: "Conv/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'Conv_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'Conv_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_project/convolution', found name: "expanded_conv_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 16
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_project/convolution', found name: "expanded_conv_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 16
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_1_expand/convolution', found name: "expanded_conv_1_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 16
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_1_expand/convolution', found name: "expanded_conv_1_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 16
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_1_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_1_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_1_project/convolution', found name: "expanded_conv_1_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 24
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_1_project/convolution', found name: "expanded_conv_1_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 24
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_1_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_1_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_2_expand/convolution', found name: "expanded_conv_2_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 24
#       }
#       dim {
#         size: 144
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_2_expand/convolution', found name: "expanded_conv_2_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 24
#       }
#       dim {
#         size: 144
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_2_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_2_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_2_project/convolution', found name: "expanded_conv_2_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 144
#       }
#       dim {
#         size: 24
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_2_project/convolution', found name: "expanded_conv_2_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 144
#       }
#       dim {
#         size: 24
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_2_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_2_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_3_expand/convolution', found name: "expanded_conv_3_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 24
#       }
#       dim {
#         size: 144
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_3_expand/convolution', found name: "expanded_conv_3_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 24
#       }
#       dim {
#         size: 144
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_3_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_3_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_3_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_3_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_3_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_3_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_3_project/convolution', found name: "expanded_conv_3_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 144
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_3_project/convolution', found name: "expanded_conv_3_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 144
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_3_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_3_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_4_expand/convolution', found name: "expanded_conv_4_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_4_expand/convolution', found name: "expanded_conv_4_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_4_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_4_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_4_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_4_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_4_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_4_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_4_project/convolution', found name: "expanded_conv_4_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_4_project/convolution', found name: "expanded_conv_4_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_4_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_4_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_5_expand/convolution', found name: "expanded_conv_5_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_5_expand/convolution', found name: "expanded_conv_5_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_5_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_5_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_5_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_5_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_5_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_5_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_5_project/convolution', found name: "expanded_conv_5_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_5_project/convolution', found name: "expanded_conv_5_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_5_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_5_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_6_expand/convolution', found name: "expanded_conv_6_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_6_expand/convolution', found name: "expanded_conv_6_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_6_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_6_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_6_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_6_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_6_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_6_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_6_project/convolution', found name: "expanded_conv_6_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_6_project/convolution', found name: "expanded_conv_6_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_6_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_6_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_7_expand/convolution', found name: "expanded_conv_7_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_7_expand/convolution', found name: "expanded_conv_7_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_7_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_7_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_7_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_7_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_7_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_7_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_7_project/convolution', found name: "expanded_conv_7_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_7_project/convolution', found name: "expanded_conv_7_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_7_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_7_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_8_expand/convolution', found name: "expanded_conv_8_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_8_expand/convolution', found name: "expanded_conv_8_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_8_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_8_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_8_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_8_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_8_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_8_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_8_project/convolution', found name: "expanded_conv_8_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_8_project/convolution', found name: "expanded_conv_8_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_8_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_8_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_9_expand/convolution', found name: "expanded_conv_9_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_9_expand/convolution', found name: "expanded_conv_9_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_9_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_9_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_9_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_9_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_9_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_9_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_9_project/convolution', found name: "expanded_conv_9_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_9_project/convolution', found name: "expanded_conv_9_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_9_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_9_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_10_expand/convolution', found name: "expanded_conv_10_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_10_expand/convolution', found name: "expanded_conv_10_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_10_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_10_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_10_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_10_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_10_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_10_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_10_project/convolution', found name: "expanded_conv_10_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_10_project/convolution', found name: "expanded_conv_10_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_10_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_10_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_11_expand/convolution', found name: "expanded_conv_11_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_11_expand/convolution', found name: "expanded_conv_11_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_11_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_11_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_11_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_11_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_11_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_11_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_11_project/convolution', found name: "expanded_conv_11_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_11_project/convolution', found name: "expanded_conv_11_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_11_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_11_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_12_expand/convolution', found name: "expanded_conv_12_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_12_expand/convolution', found name: "expanded_conv_12_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_12_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_12_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_12_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_12_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_12_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_12_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_12_project/convolution', found name: "expanded_conv_12_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_12_project/convolution', found name: "expanded_conv_12_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_12_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_12_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_13_expand/convolution', found name: "expanded_conv_13_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_13_expand/convolution', found name: "expanded_conv_13_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_13_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_13_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_13_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_13_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_13_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_13_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_13_project/convolution', found name: "expanded_conv_13_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_13_project/convolution', found name: "expanded_conv_13_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_13_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_13_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_14_expand/convolution', found name: "expanded_conv_14_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_14_expand/convolution', found name: "expanded_conv_14_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_14_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_14_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_14_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_14_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_14_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_14_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_14_project/convolution', found name: "expanded_conv_14_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_14_project/convolution', found name: "expanded_conv_14_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_14_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_14_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_15_expand/convolution', found name: "expanded_conv_15_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_15_expand/convolution', found name: "expanded_conv_15_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_15_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_15_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_15_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_15_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_15_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_15_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_15_project/convolution', found name: "expanded_conv_15_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_15_project/convolution', found name: "expanded_conv_15_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_15_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_15_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_16_expand/convolution', found name: "expanded_conv_16_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_16_expand/convolution', found name: "expanded_conv_16_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_16_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_16_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_16_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_16_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_16_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_16_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_16_project/convolution', found name: "expanded_conv_16_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 320
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_16_project/convolution', found name: "expanded_conv_16_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 320
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_16_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_16_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'image_pooling/convolution', found name: "image_pooling/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 320
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'image_pooling/convolution', found name: "image_pooling/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 320
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'image_pooling_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'image_pooling_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'aspp0/convolution', found name: "aspp0/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 320
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'aspp0/convolution', found name: "aspp0/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 320
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'aspp0_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'aspp0_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'concat_projection/convolution', found name: "concat_projection/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 512
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'concat_projection/convolution', found name: "concat_projection/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 512
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'concat_projection_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'concat_projection_BN/cond/FusedBatchNorm'
# '../results/Models/GraphModels/mobilenetv2_deeplabv3_BCE_ACC_IOU_divide_1_sigmoid_256_train_person_op.pb'

# %% [markdown]
# ### keras to .tflite

# %%
tf.keras.losses.custom_loss = sm.losses.bce_dice_loss

# %%
converter = tf.lite.TFLiteConverter.from_keras_model_file(os.path.join(MODEL_PATH_,keras_filename))
converter.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
                        tf.lite.OpsSet.SELECT_TF_OPS]
tflite_model = converter.convert()
with open(os.path.join(MODEL_PATH,tflite_filename), "wb") as f:
    f.write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9ddef07ea4ee> in <module>
# ----> 1 converter = tf.lite.TFLiteConverter.from_keras_model_file(os.path.join(MODEL_PATH_,keras_filename))
#       2 converter.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
#       3                         tf.lite.OpsSet.SELECT_TF_OPS]
#       4 tflite_model = converter.convert()
#       5 with open(os.path.join(MODEL_PATH,tflite_filename), "wb") as f:
#
# ~/.local/lib/python3.5/site-packages/tensorflow/lite/python/lite.py in from_keras_model_file(cls, model_file, input_arrays, input_shapes, output_arrays)
#     368     _keras.backend.clear_session()
#     369     _keras.backend.set_learning_phase(False)
# --> 370     keras_model = _keras.models.load_model(model_file)
#     371     sess = _keras.backend.get_session()
#     372
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     232       raise ValueError('No model found in config file.')
#     233     model_config = json.loads(model_config.decode('utf-8'))
# --> 234     model = model_from_config(model_config, custom_objects=custom_objects)
#     235
#     236     # set weights
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/engine/saving.py in model_from_config(config, custom_objects)
#     322                     '`Sequential.from_config(config)`?')
#     323   from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# --> 324   return deserialize(config, custom_objects=custom_objects)
#     325
#     326
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/layers/serialization.py in deserialize(config, custom_objects)
#      72       module_objects=globs,
#      73       custom_objects=custom_objects,
# ---> 74       printable_module_name='layer')
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     190             custom_objects=dict(
#     191                 list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 192                 list(custom_objects.items())))
#     193       with CustomObjectScope(custom_objects):
#     194         return cls.from_config(cls_config)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/engine/network.py in from_config(cls, config, custom_objects)
#    1261     # First, we create all layers and enqueue nodes to be processed
#    1262     for layer_data in config['layers']:
# -> 1263       process_layer(layer_data)
#    1264     # Then we process nodes in order of layer depth.
#    1265     # Nodes that cannot yet be processed (if the inbound node
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/engine/network.py in process_layer(layer_data)
#    1247       from tensorflow.python.keras.layers import deserialize as deserialize_layer  # pylint: disable=g-import-not-at-top
#    1248
# -> 1249       layer = deserialize_layer(layer_data, custom_objects=custom_objects)
#    1250       created_layers[layer_name] = layer
#    1251
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/layers/serialization.py in deserialize(config, custom_objects)
#      72       module_objects=globs,
#      73       custom_objects=custom_objects,
# ---> 74       printable_module_name='layer')
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     179     config = identifier
#     180     (cls, cls_config) = class_and_config_for_serialized_keras_object(
# --> 181         config, module_objects, custom_objects, printable_module_name)
#     182
#     183     if hasattr(cls, 'from_config'):
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/utils/generic_utils.py in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     164     cls = module_objects.get(class_name)
#     165     if cls is None:
# --> 166       raise ValueError('Unknown ' + printable_module_name + ': ' + class_name)
#     167   return (cls, config['config'])
#     168
#
# ValueError: Unknown layer: BilinearUpsampling

# %%
converter_Q = tf.lite.TFLiteConverter.from_keras_model_file(os.path.join(MODEL_PATH_,keras_filename))
converter_Q.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
                        tf.lite.OpsSet.SELECT_TF_OPS]
converter_Q.post_training_quantize=True
tflite_Q_model = converter_Q.convert()
with open(os.path.join(MODEL_PATH,tflite_Q_filename), "wb") as f:
    f.write(tflite_Q_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-fa42aabfd0a6> in <module>
# ----> 1 converter_Q = tf.lite.TFLiteConverter.from_keras_model_file(os.path.join(MODEL_PATH_,keras_filename))
#       2 converter_Q.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
#       3                         tf.lite.OpsSet.SELECT_TF_OPS]
#       4 converter_Q.post_training_quantize=True
#       5 tflite_Q_model = converter_Q.convert()
#
# ~/.local/lib/python3.5/site-packages/tensorflow/lite/python/lite.py in from_keras_model_file(cls, model_file, input_arrays, input_shapes, output_arrays)
#     368     _keras.backend.clear_session()
#     369     _keras.backend.set_learning_phase(False)
# --> 370     keras_model = _keras.models.load_model(model_file)
#     371     sess = _keras.backend.get_session()
#     372
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     232       raise ValueError('No model found in config file.')
#     233     model_config = json.loads(model_config.decode('utf-8'))
# --> 234     model = model_from_config(model_config, custom_objects=custom_objects)
#     235
#     236     # set weights
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/engine/saving.py in model_from_config(config, custom_objects)
#     322                     '`Sequential.from_config(config)`?')
#     323   from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# --> 324   return deserialize(config, custom_objects=custom_objects)
#     325
#     326
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/layers/serialization.py in deserialize(config, custom_objects)
#      72       module_objects=globs,
#      73       custom_objects=custom_objects,
# ---> 74       printable_module_name='layer')
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     190             custom_objects=dict(
#     191                 list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 192                 list(custom_objects.items())))
#     193       with CustomObjectScope(custom_objects):
#     194         return cls.from_config(cls_config)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/engine/network.py in from_config(cls, config, custom_objects)
#    1261     # First, we create all layers and enqueue nodes to be processed
#    1262     for layer_data in config['layers']:
# -> 1263       process_layer(layer_data)
#    1264     # Then we process nodes in order of layer depth.
#    1265     # Nodes that cannot yet be processed (if the inbound node
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/engine/network.py in process_layer(layer_data)
#    1247       from tensorflow.python.keras.layers import deserialize as deserialize_layer  # pylint: disable=g-import-not-at-top
#    1248
# -> 1249       layer = deserialize_layer(layer_data, custom_objects=custom_objects)
#    1250       created_layers[layer_name] = layer
#    1251
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/layers/serialization.py in deserialize(config, custom_objects)
#      72       module_objects=globs,
#      73       custom_objects=custom_objects,
# ---> 74       printable_module_name='layer')
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     192                 list(custom_objects.items())))
#     193       with CustomObjectScope(custom_objects):
# --> 194         return cls.from_config(cls_config)
#     195     else:
#     196       # Then `cls` may be a function returning a class.
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/engine/base_layer.py in from_config(cls, config)
#     400         A layer instance.
#     401     """
# --> 402     return cls(**config)
#     403
#     404   def compute_output_shape(self, input_shape):
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/layers/core.py in __init__(self, activation, **kwargs)
#     324     super(Activation, self).__init__(**kwargs)
#     325     self.supports_masking = True
# --> 326     self.activation = activations.get(activation)
#     327
#     328   def call(self, inputs):
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/activations.py in get(identifier)
#     209   if isinstance(identifier, six.string_types):
#     210     identifier = str(identifier)
# --> 211     return deserialize(identifier)
#     212   elif callable(identifier):
#     213     return identifier
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/activations.py in deserialize(name, custom_objects)
#     200       module_objects=globals(),
#     201       custom_objects=custom_objects,
# --> 202       printable_module_name='activation function')
#     203
#     204
#
# ~/.local/lib/python3.5/site-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     210       if fn is None:
#     211         raise ValueError('Unknown ' + printable_module_name + ':' +
# --> 212                          function_name)
#     213     return fn
#     214   else:
#
# ValueError: Unknown activation function:relu6

# %%
# Converting a tf.keras model.
converter = tf.lite.TFLiteConverter.from_session(K.get_session(), model.inputs, model.outputs)
converter.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
                        tf.lite.OpsSet.SELECT_TF_OPS]
tflite_model = converter.convert()
with open(os.path.join(MODEL_PATH,tflite_filename), "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Froze 404 variables.
# INFO:tensorflow:Froze 404 variables.
# INFO:tensorflow:Converted 404 variables to const ops.
# INFO:tensorflow:Converted 404 variables to const ops.
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# <ipython-input-38-f09a5aea73d4> in <module>
#       3 converter.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
#       4                         tf.lite.OpsSet.SELECT_TF_OPS]
# ----> 5 tflite_model = converter.convert()
#       6 with open(os.path.join(MODEL_PATH,tflite_filename), "wb") as f:
#       7     f.write(tflite_model)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/lite/python/lite.py in convert(self)
#     453           input_tensors=self._input_tensors,
#     454           output_tensors=self._output_tensors,
# --> 455           **converter_kwargs)
#     456     else:
#     457       result = _toco_convert_graph_def(
#
# ~/.local/lib/python3.5/site-packages/tensorflow/lite/python/convert.py in toco_convert_impl(input_data, input_tensors, output_tensors, *args, **kwargs)
#     440   data = toco_convert_protos(model_flags.SerializeToString(),
#     441                              toco_flags.SerializeToString(),
# --> 442                              input_data.SerializeToString())
#     443   return data
#     444
#
# ~/.local/lib/python3.5/site-packages/tensorflow/lite/python/convert.py in toco_convert_protos(model_flags_str, toco_flags_str, input_data_str)
#     203       stderr = _try_convert_to_unicode(stderr)
#     204       raise ConverterError(
# --> 205           "TOCO failed. See console for info.\n%s\n%s\n" % (stdout, stderr))
#     206   finally:
#     207     # Must manually cleanup files.
#
# ConverterError: TOCO failed. See console for info.
# 2019-05-23 12:51:19.589630: I tensorflow/lite/toco/graph_transformations/graph_transformations.cc:39] Before Removing unused ops: 2173 operators, 3475 arrays (0 quantized)
# 2019-05-23 12:51:19.670897: I tensorflow/lite/toco/graph_transformations/graph_transformations.cc:39] Before general graph transformations: 2173 operators, 3475 arrays (0 quantized)
# 2019-05-23 12:51:19.671821: F tensorflow/lite/toco/graph_transformations/resolve_constant_unary.cc:234] Unsupported cast op input type
# Aborted (core dumped)

# %%
# Converting a tf.keras model.
converter_Q = tf.lite.TFLiteConverter.from_session(K.get_session(), model.inputs, model.outputs)
converter_Q.post_training_quantize=True
tflite_Q_model = converter_Q.convert()
with open(os.path.join(MODEL_PATH,tflite_Q_filename), "wb") as f:
    f.write(tflite_Q_model)
# Out:
# INFO:tensorflow:Froze 404 variables.
# INFO:tensorflow:Froze 404 variables.
# INFO:tensorflow:Converted 404 variables to const ops.
# INFO:tensorflow:Converted 404 variables to const ops.
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# <ipython-input-11-1d8a60bb6067> in <module>
#       2 converter_Q = tf.lite.TFLiteConverter.from_session(K.get_session(), model.inputs, model.outputs)
#       3 converter_Q.post_training_quantize=True
# ----> 4 tflite_Q_model = converter_Q.convert()
#       5 with open(os.path.join(MODEL_PATH,tflite_Q_filename), "wb") as f:
#       6     f.write(tflite_Q_model)
#
# ~/.local/lib/python3.5/site-packages/tensorflow/lite/python/lite.py in convert(self)
#     453           input_tensors=self._input_tensors,
#     454           output_tensors=self._output_tensors,
# --> 455           **converter_kwargs)
#     456     else:
#     457       result = _toco_convert_graph_def(
#
# ~/.local/lib/python3.5/site-packages/tensorflow/lite/python/convert.py in toco_convert_impl(input_data, input_tensors, output_tensors, *args, **kwargs)
#     440   data = toco_convert_protos(model_flags.SerializeToString(),
#     441                              toco_flags.SerializeToString(),
# --> 442                              input_data.SerializeToString())
#     443   return data
#     444
#
# ~/.local/lib/python3.5/site-packages/tensorflow/lite/python/convert.py in toco_convert_protos(model_flags_str, toco_flags_str, input_data_str)
#     203       stderr = _try_convert_to_unicode(stderr)
#     204       raise ConverterError(
# --> 205           "TOCO failed. See console for info.\n%s\n%s\n" % (stdout, stderr))
#     206   finally:
#     207     # Must manually cleanup files.
#
# ConverterError: TOCO failed. See console for info.
# 2019-05-23 10:05:58.309350: I tensorflow/lite/toco/graph_transformations/graph_transformations.cc:39] Before Removing unused ops: 2173 operators, 3475 arrays (0 quantized)
# 2019-05-23 10:05:58.392009: I tensorflow/lite/toco/graph_transformations/graph_transformations.cc:39] Before general graph transformations: 2173 operators, 3475 arrays (0 quantized)
# 2019-05-23 10:05:58.392686: F tensorflow/lite/toco/graph_transformations/resolve_constant_unary.cc:234] Unsupported cast op input type
# Aborted (core dumped)

# %% [markdown]
# ### keras to .mlmodel

# %%
def convert_lambda(layer):
    
    import keras.backend as K
    # Only convert this Lambda layer if it is for our tf image resize function.
    if layer.function == K.tf.image.resize_images:

        from coremltools.proto import NeuralNetwork_pb2

        params = NeuralNetwork_pb2.CustomLayerParams()

        # The name of the Swift or Obj-C class that implements this layer.
        params.className = "Resize"

        # The desciption is shown in Xcode's mlmodel viewer.
        params.description = "A resize function"

        return params
    else:
        return None
    
coreml_model = coremltools.converters.keras.convert(model,
                                                    input_names=input_node_names,
                                                    image_input_names=input_node_names,
                                                    output_names=output_node_names,
                                                    image_scale=1/255.0,
                                                    add_custom_layers=True,
                                                    custom_conversion_functions={ "Lambda": convert_lambda }
                                                   )
# Out:
# 0 : input_1, <keras.engine.input_layer.InputLayer object at 0x7fcf804444a8>
# 1 : Conv1_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf80444400>
# 2 : Conv1, <keras.layers.convolutional.Conv2D object at 0x7fcf80444fd0>
# 3 : bn_Conv1, <keras.layers.normalization.BatchNormalization object at 0x7fcf80444630>
# 4 : Conv1_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf804b6e48>
# 5 : expanded_conv_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcf80239400>
# 6 : expanded_conv_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf802462e8>
# 7 : expanded_conv_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf64725fd0>
# 8 : expanded_conv_project, <keras.layers.convolutional.Conv2D object at 0x7fcf646dfa90>
# 9 : expanded_conv_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf6464f550>
# 10 : block_1_expand, <keras.layers.convolutional.Conv2D object at 0x7fcf645bfc18>
# 11 : block_1_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf64545eb8>
# 12 : block_1_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf6456a390>
# 13 : block_1_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf644e1a20>
# 14 : block_1_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcf644e1ac8>
# 15 : block_1_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf64380d68>
# 16 : block_1_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf64380550>
# 17 : block_1_project, <keras.layers.convolutional.Conv2D object at 0x7fcf643b87b8>
# 18 : block_1_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf6432a860>
# 19 : block_2_expand, <keras.layers.convolutional.Conv2D object at 0x7fcf642b6898>
# 20 : block_2_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf64190f60>
# 21 : block_2_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf64226be0>
# 22 : block_2_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcf641b86a0>
# 23 : block_2_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf80465470>
# 24 : block_2_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf804821d0>
# 25 : block_2_project, <keras.layers.convolutional.Conv2D object at 0x7fcf80499b38>
# 26 : block_2_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf80308400>
# 27 : block_2_add, <keras.layers.merge.Add object at 0x7fcf803085f8>
# 28 : block_3_expand, <keras.layers.convolutional.Conv2D object at 0x7fcf80325400>
# 29 : block_3_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf802cd898>
# 30 : block_3_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf800f7518>
# 31 : block_3_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf8018e550>
# 32 : block_3_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcf8018e908>
# 33 : block_3_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcfb43220f0>
# 34 : block_3_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcfb430ea20>
# 35 : block_3_project, <keras.layers.convolutional.Conv2D object at 0x7fcf804c4240>
# 36 : block_3_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf8037bf60>
# 37 : block_4_expand, <keras.layers.convolutional.Conv2D object at 0x7fcf803aac18>
# 38 : block_4_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf80194e10>
# 39 : block_4_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf6478e9b0>
# 40 : block_4_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcf8043ee48>
# 41 : block_4_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf6474add8>
# 42 : block_4_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf445b4f98>
# 43 : block_4_project, <keras.layers.convolutional.Conv2D object at 0x7fcf4456e908>
# 44 : block_4_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf444dd3c8>
# 45 : block_4_add, <keras.layers.merge.Add object at 0x7fcf4444de10>
# 46 : block_5_expand, <keras.layers.convolutional.Conv2D object at 0x7fcf4441b978>
# 47 : block_5_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf443f5780>
# 48 : block_5_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf443f5748>
# 49 : block_5_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcf44364ef0>
# 50 : block_5_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf442eaeb8>
# 51 : block_5_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf442894e0>
# 52 : block_5_project, <keras.layers.convolutional.Conv2D object at 0x7fcf44219dd8>
# 53 : block_5_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf44183a90>
# 54 : block_5_add, <keras.layers.merge.Add object at 0x7fcf441a63c8>
# 55 : block_6_expand, <keras.layers.convolutional.Conv2D object at 0x7fcf44112be0>
# 56 : block_6_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf4409d240>
# 57 : block_6_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf4403c198>
# 58 : block_6_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf207e69b0>
# 59 : block_6_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcf207e66a0>
# 60 : block_6_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf206db7f0>
# 61 : block_6_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf206c31d0>
# 62 : block_6_project, <keras.layers.convolutional.Conv2D object at 0x7fcf2064d0b8>
# 63 : block_6_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf20609898>
# 64 : block_7_expand, <keras.layers.convolutional.Conv2D object at 0x7fcf20628208>
# 65 : block_7_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf204ed240>
# 66 : block_7_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf20487ef0>
# 67 : block_7_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcf203fca58>
# 68 : block_7_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf204b4160>
# 69 : block_7_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf203a7cf8>
# 70 : block_7_project, <keras.layers.convolutional.Conv2D object at 0x7fcf20363b00>
# 71 : block_7_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf202d1550>
# 72 : block_7_add, <keras.layers.merge.Add object at 0x7fcf2023fc50>
# 73 : block_8_expand, <keras.layers.convolutional.Conv2D object at 0x7fcf20215a20>
# 74 : block_8_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf201ee240>
# 75 : block_8_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf201ee9e8>
# 76 : block_8_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcf200fbac8>
# 77 : block_8_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcf200e8a90>
# 78 : block_8_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcf20088710>
# 79 : block_8_project, <keras.layers.convolutional.Conv2D object at 0x7fcf20077e80>
# 80 : block_8_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fced8742cc0>
# 81 : block_8_add, <keras.layers.merge.Add object at 0x7fced8753668>
# 82 : block_9_expand, <keras.layers.convolutional.Conv2D object at 0x7fced86d3dd8>
# 83 : block_9_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fced8661a58>
# 84 : block_9_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fced85eb898>
# 85 : block_9_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fced853d518>
# 86 : block_9_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fced84f9b70>
# 87 : block_9_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fced84df9e8>
# 88 : block_9_project, <keras.layers.convolutional.Conv2D object at 0x7fced84a39b0>
# 89 : block_9_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fced8411780>
# 90 : block_9_add, <keras.layers.merge.Add object at 0x7fced84330b8>
# 91 : block_10_expand, <keras.layers.convolutional.Conv2D object at 0x7fced83a9860>
# 92 : block_10_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fced8330048>
# 93 : block_10_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fced8296f28>
# 94 : block_10_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fced820ba58>
# 95 : block_10_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fced8241320>
# 96 : block_10_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fced813acf8>
# 97 : block_10_project, <keras.layers.convolutional.Conv2D object at 0x7fced8175b00>
# 98 : block_10_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fced80e4a20>
# 99 : block_11_expand, <keras.layers.convolutional.Conv2D object at 0x7fced804df98>
# 100 : block_11_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc60132ac8>
# 101 : block_11_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc600cfc88>
# 102 : block_11_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcc600bd978>
# 103 : block_11_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc60047eb8>
# 104 : block_11_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc587d44e0>
# 105 : block_11_project, <keras.layers.convolutional.Conv2D object at 0x7fcc58763e10>
# 106 : block_11_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc586d4ac8>
# 107 : block_11_add, <keras.layers.merge.Add object at 0x7fcc586ed400>
# 108 : block_12_expand, <keras.layers.convolutional.Conv2D object at 0x7fcc58660be0>
# 109 : block_12_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc585eb860>
# 110 : block_12_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc585796a0>
# 111 : block_12_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcc58519978>
# 112 : block_12_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc5848c668>
# 113 : block_12_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc5846fcf8>
# 114 : block_12_project, <keras.layers.convolutional.Conv2D object at 0x7fcc58430e48>
# 115 : block_12_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc5839c0f0>
# 116 : block_12_add, <keras.layers.merge.Add object at 0x7fcc582fff98>
# 117 : block_13_expand, <keras.layers.convolutional.Conv2D object at 0x7fcc582f5a90>
# 118 : block_13_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc582b5550>
# 119 : block_13_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc5821cd68>
# 120 : block_13_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcc58192518>
# 121 : block_13_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcc581aef98>
# 122 : block_13_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc580c19b0>
# 123 : block_13_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc580c1278>
# 124 : block_13_project, <keras.layers.convolutional.Conv2D object at 0x7fcc580f9c50>
# 125 : block_13_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc58069588>
# 126 : block_14_expand, <keras.layers.convolutional.Conv2D object at 0x7fcc4df93da0>
# 127 : block_14_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc4df27be0>
# 128 : block_14_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc4dfbf198>
# 129 : block_14_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcc4de07940>
# 130 : block_14_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc4ddc1a90>
# 131 : block_14_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc4dde1710>
# 132 : block_14_project, <keras.layers.convolutional.Conv2D object at 0x7fcc4dd52e48>
# 133 : block_14_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc4dcddcc0>
# 134 : block_14_add, <keras.layers.merge.Add object at 0x7fcc4dcf8668>
# 135 : block_15_expand, <keras.layers.convolutional.Conv2D object at 0x7fcc4dc6bdd8>
# 136 : block_15_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc4dbfba90>
# 137 : block_15_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc4db9a3c8>
# 138 : block_15_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcc4db05ba8>
# 139 : block_15_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc4da94b38>
# 140 : block_15_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc4da7a9e8>
# 141 : block_15_project, <keras.layers.convolutional.Conv2D object at 0x7fcc4da3d9b0>
# 142 : block_15_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc4d9ac780>
# 143 : block_15_add, <keras.layers.merge.Add object at 0x7fcc4d94e0b8>
# 144 : block_16_expand, <keras.layers.convolutional.Conv2D object at 0x7fcc4d8c6898>
# 145 : block_16_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc4d84b048>
# 146 : block_16_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc4d830f60>
# 147 : block_16_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fcc4d7a5a58>
# 148 : block_16_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc4d7db630>
# 149 : block_16_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc4d6d2cf8>
# 150 : block_16_project, <keras.layers.convolutional.Conv2D object at 0x7fcc4d68db00>
# 151 : block_16_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fcc4d67c550>
# 152 : Conv_1, <keras.layers.convolutional.Conv2D object at 0x7fcc4d5eec50>
# 153 : Conv_1_bn, <keras.layers.normalization.BatchNormalization object at 0x7fcc4d57ea58>
# 154 : out_relu, <keras.layers.advanced_activations.ReLU object at 0x7fcc4d51c3c8>
# 155 : decoder_stage0_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcc4d591048>
# 156 : decoder_stage0_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcc4cc6a9b0>
# 157 : decoder_stage0_relu1, <keras.layers.core.Activation object at 0x7fcc4d413828>
# 158 : decoder_stage0_upsample2, <keras.layers.convolutional.UpSampling2D object at 0x7fcc4cc4b240>
# 159 : decoder_stage0_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcc4cc5d438>
# 160 : decoder_stage0_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcc4cb2d470>
# 161 : decoder_stage0_relu2, <keras.layers.core.Activation object at 0x7fcc4cb2deb8>
# 162 : decoder_stage0_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcc4cafb9e8>
# 163 : decoder_stage0_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcc4cab8c18>
# 164 : decoder_stage0_relu3, <keras.layers.core.Activation object at 0x7fcc4ca2bfd0>
# 165 : add_1, <keras.layers.merge.Add object at 0x7fcc4c9fa6d8>
# 166 : decoder_stage1_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcc4c9b5a58>
# 167 : decoder_stage1_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcc4c954908>
# 168 : decoder_stage1_relu1, <keras.layers.core.Activation object at 0x7fcc4c8c4b38>
# 169 : decoder_stage1_upsample2, <keras.layers.convolutional.UpSampling2D object at 0x7fcc4c8908d0>
# 170 : decoder_stage1_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcc4c84c860>
# 171 : decoder_stage1_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcc4c7f7470>
# 172 : decoder_stage1_relu2, <keras.layers.core.Activation object at 0x7fcc4c7f7e48>
# 173 : decoder_stage1_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcc4c745908>
# 174 : decoder_stage1_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcc4c700b38>
# 175 : decoder_stage1_relu3, <keras.layers.core.Activation object at 0x7fcc4c6f2e80>
# 176 : add_2, <keras.layers.merge.Add object at 0x7fcc4c6439e8>
# 177 : decoder_stage2_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcc4c6940f0>
# 178 : decoder_stage2_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcc4c61d748>
# 179 : decoder_stage2_relu1, <keras.layers.core.Activation object at 0x7fcc4c58da90>
# 180 : decoder_stage2_upsample2, <keras.layers.convolutional.UpSampling2D object at 0x7fcc4c55db70>
# 181 : decoder_stage2_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcc4c515748>
# 182 : decoder_stage2_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcc4c443390>
# 183 : decoder_stage2_relu2, <keras.layers.core.Activation object at 0x7fcc4c443d30>
# 184 : decoder_stage2_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcc4c4104e0>
# 185 : decoder_stage2_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcc4c3d20f0>
# 186 : decoder_stage2_relu3, <keras.layers.core.Activation object at 0x7fcc4c42db70>
# 187 : add_3, <keras.layers.merge.Add object at 0x7fcc4c310908>
# 188 : decoder_stage3_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcc4c341eb8>
# 189 : decoder_stage3_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcc4c2e76a0>
# 190 : decoder_stage3_relu1, <keras.layers.core.Activation object at 0x7fcc4c25b978>
# 191 : decoder_stage3_upsample2, <keras.layers.convolutional.UpSampling2D object at 0x7fcc4c226978>
# 192 : decoder_stage3_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcc4c1e06a0>
# 193 : decoder_stage3_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcc4c170278>
# 194 : decoder_stage3_relu2, <keras.layers.core.Activation object at 0x7fcc4c10ec50>
# 195 : decoder_stage3_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcc4c0dde80>
# 196 : decoder_stage3_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcc4c089898>
# 197 : decoder_stage3_relu3, <keras.layers.core.Activation object at 0x7fcc4c029898>
# 198 : add_4, <keras.layers.merge.Add object at 0x7fcc4c0fd908>
# 199 : decoder_stage4_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcc4c00bef0>
# 200 : decoder_stage4_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcc41fb1978>
# 201 : decoder_stage4_relu1, <keras.layers.core.Activation object at 0x7fcc41f248d0>
# 202 : decoder_stage4_upsample2, <keras.layers.convolutional.UpSampling2D object at 0x7fcc41ef4908>
# 203 : decoder_stage4_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcc41eb35c0>
# 204 : decoder_stage4_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcc41e3f7f0>
# 205 : decoder_stage4_relu2, <keras.layers.core.Activation object at 0x7fcc41ddcb70>
# 206 : decoder_stage4_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcc41d90b00>
# 207 : decoder_stage4_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcc41d6b828>
# 208 : decoder_stage4_relu3, <keras.layers.core.Activation object at 0x7fcc41d6bdd8>
# 209 : final_conv, <keras.layers.convolutional.Conv2D object at 0x7fcc41cdceb8>
# 210 : sigmoid, <keras.layers.core.Activation object at 0x7fcc41c64b00>

# %%
spec = coreml_model.get_spec()
print(spec.description)
# Out:
# input {
#   name: "input_1"
#   type {
#     imageType {
#       width: 512
#       height: 512
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "sigmoid/Sigmoid"
#   type {
#     multiArrayType {
#       shape: 1
#       shape: 512
#       shape: 512
#       dataType: DOUBLE
#     }
#   }
# }

# %%
coreml_model.save(os.path.join(MODEL_PATH, mlmodel_filename))

# %%
coreml_model.
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-65-1f85d863ea50> in <module>
# ----> 1 coreml_model.predict(input)
#
# ~/.local/lib/python3.5/site-packages/coremltools/models/model.py in predict(self, data, useCPUOnly, **kwargs)
#     328         else:
#     329             if _macos_version() < (10, 13):
# --> 330                 raise Exception('Model prediction is only supported on macOS version 10.13 or later.')
#     331
#     332             try:
#
# Exception: Model prediction is only supported on macOS version 10.13 or later.

# %%
model_spec = coremltools.utils.load_spec(os.path.join(MODEL_PATH, mlmodel_filename))
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, os.path.join(MODEL_PATH, mlmodel_fp16_filename))

# %%
quantized_coreml_spec = coremltools.models.neural_network.quantization_utils.quantize_weights(coreml_model,8) 
coremltools.utils.save_spec(quantized_coreml_spec, os.path.join(MODEL_PATH, mlmodel_Q_filename))
# Out:
# Quantizing using linear quantization
# Optimizing Neural Network before Quantization:
# Fused Conv1->bn_Conv1
# Fused expanded_conv_depthwise->expanded_conv_depthwise_BN
# Fused expanded_conv_project->expanded_conv_project_BN
# Fused block_1_expand->block_1_expand_BN
# Fused block_1_depthwise->block_1_depthwise_BN
# Fused block_1_project->block_1_project_BN
# Fused block_2_expand->block_2_expand_BN
# Fused block_2_depthwise->block_2_depthwise_BN
# Fused block_2_project->block_2_project_BN
# Fused block_3_expand->block_3_expand_BN
# Fused block_3_depthwise->block_3_depthwise_BN
# Fused block_3_project->block_3_project_BN
# Fused block_4_expand->block_4_expand_BN
# Fused block_4_depthwise->block_4_depthwise_BN
# Fused block_4_project->block_4_project_BN
# Fused block_5_expand->block_5_expand_BN
# Fused block_5_depthwise->block_5_depthwise_BN
# Fused block_5_project->block_5_project_BN
# Fused block_6_expand->block_6_expand_BN
# Fused block_6_depthwise->block_6_depthwise_BN
# Fused block_6_project->block_6_project_BN
# Fused block_7_expand->block_7_expand_BN
# Fused block_7_depthwise->block_7_depthwise_BN
# Fused block_7_project->block_7_project_BN
# Fused block_8_expand->block_8_expand_BN
# Fused block_8_depthwise->block_8_depthwise_BN
# Fused block_8_project->block_8_project_BN
# Fused block_9_expand->block_9_expand_BN
# Fused block_9_depthwise->block_9_depthwise_BN
# Fused block_9_project->block_9_project_BN
# Fused block_10_expand->block_10_expand_BN
# Fused block_10_depthwise->block_10_depthwise_BN
# Fused block_10_project->block_10_project_BN
# Fused block_11_expand->block_11_expand_BN
# Fused block_11_depthwise->block_11_depthwise_BN
# Fused block_11_project->block_11_project_BN
# Fused block_12_expand->block_12_expand_BN
# Fused block_12_depthwise->block_12_depthwise_BN
# Fused block_12_project->block_12_project_BN
# Fused block_13_expand->block_13_expand_BN
# Fused block_13_depthwise->block_13_depthwise_BN
# Fused block_13_project->block_13_project_BN
# Fused block_14_expand->block_14_expand_BN
# Fused block_14_depthwise->block_14_depthwise_BN
# Fused block_14_project->block_14_project_BN
# Fused block_15_expand->block_15_expand_BN
# Fused block_15_depthwise->block_15_depthwise_BN
# Fused block_15_project->block_15_project_BN
# Fused block_16_expand->block_16_expand_BN
# Fused block_16_depthwise->block_16_depthwise_BN
# Fused block_16_project->block_16_project_BN
# Fused Conv_1->Conv_1_bn
# Fused decoder_stage0_conv1->decoder_stage0_bn1
# Fused decoder_stage0_conv2->decoder_stage0_bn2
# Fused decoder_stage0_conv3->decoder_stage0_bn3
# Fused decoder_stage1_conv1->decoder_stage1_bn1
# Fused decoder_stage1_conv2->decoder_stage1_bn2
# Fused decoder_stage1_conv3->decoder_stage1_bn3
# Fused decoder_stage2_conv1->decoder_stage2_bn1
# Fused decoder_stage2_conv2->decoder_stage2_bn2
# Fused decoder_stage2_conv3->decoder_stage2_bn3
# Fused decoder_stage3_conv1->decoder_stage3_bn1
# Fused decoder_stage3_conv2->decoder_stage3_bn2
# Fused decoder_stage3_conv3->decoder_stage3_bn3
# Fused decoder_stage4_conv1->decoder_stage4_bn1
# Fused decoder_stage4_conv2->decoder_stage4_bn2
# Fused decoder_stage4_conv3->decoder_stage4_bn3
# Finished optimizing network. Quantizing neural network..
# Quantizing layer Conv1
# Quantizing layer expanded_conv_depthwise
# Quantizing layer expanded_conv_project
# Quantizing layer block_1_expand
# Quantizing layer block_1_depthwise
# Quantizing layer block_1_project
# Quantizing layer block_2_expand
# Quantizing layer block_2_depthwise
# Quantizing layer block_2_project
# Quantizing layer block_3_expand
# Quantizing layer block_3_depthwise
# Quantizing layer block_3_project
# Quantizing layer block_4_expand
# Quantizing layer block_4_depthwise
# Quantizing layer block_4_project
# Quantizing layer block_5_expand
# Quantizing layer block_5_depthwise
# Quantizing layer block_5_project
# Quantizing layer block_6_expand
# Quantizing layer block_6_depthwise
# Quantizing layer block_6_project
# Quantizing layer block_7_expand
# Quantizing layer block_7_depthwise
# Quantizing layer block_7_project
# Quantizing layer block_8_expand
# Quantizing layer block_8_depthwise
# Quantizing layer block_8_project
# Quantizing layer block_9_expand
# Quantizing layer block_9_depthwise
# Quantizing layer block_9_project
# Quantizing layer block_10_expand
# Quantizing layer block_10_depthwise
# Quantizing layer block_10_project
# Quantizing layer block_11_expand
# Quantizing layer block_11_depthwise
# Quantizing layer block_11_project
# Quantizing layer block_12_expand
# Quantizing layer block_12_depthwise
# Quantizing layer block_12_project
# Quantizing layer block_13_expand
# Quantizing layer block_13_depthwise
# Quantizing layer block_13_project
# Quantizing layer block_14_expand
# Quantizing layer block_14_depthwise
# Quantizing layer block_14_project
# Quantizing layer block_15_expand
# Quantizing layer block_15_depthwise
# Quantizing layer block_15_project
# Quantizing layer block_16_expand
# Quantizing layer block_16_depthwise
# Quantizing layer block_16_project
# Quantizing layer Conv_1
# Quantizing layer decoder_stage0_conv1
# Quantizing layer decoder_stage0_conv2
# Quantizing layer decoder_stage0_conv3
# Quantizing layer decoder_stage1_conv1
# Quantizing layer decoder_stage1_conv2
# Quantizing layer decoder_stage1_conv3
# Quantizing layer decoder_stage2_conv1
# Quantizing layer decoder_stage2_conv2
# Quantizing layer decoder_stage2_conv3
# Quantizing layer decoder_stage3_conv1
# Quantizing layer decoder_stage3_conv2
# Quantizing layer decoder_stage3_conv3
# Quantizing layer decoder_stage4_conv1
# Quantizing layer decoder_stage4_conv2
# Quantizing layer decoder_stage4_conv3
# Quantizing layer final_conv
# WARNING! Unable to return a quantized MLModel instance since OS != macOS 10.14 or later
# Returning quantized model specification instead

# %% [markdown]
# ## load & inference the model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import skimage
import glob
import os
import cv2

# %%
# Load Test Images
test_path = "../data/raw/test"
fnames = sorted(glob.glob(os.path.join(test_path,"*.jpg")))
images = []
outs = []
for f in fnames:
    img = skimage.io.imread(f)
    images.append(img)

# %%
sess = tf.Session()

# %%
# load model from pb file
#with tf.gfile.GFile(os.path.join(MODEL_PATH,pb_op_filename),'rb') as f:
#pb_op_filename = "/media/new_hdd2/seg_net/results/Models/GraphModels/mobilenetv2_Linknet_BCE_ACC_IOU_divide_1_sigmoid_512_train_matte_Qotp.pb"
with tf.gfile.GFile(os.path.join(MODEL_PATH,pb_filename),'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    sess.graph.as_default()
    g_in = tf.import_graph_def(graph_def)
print("Loading from ",os.path.join(MODEL_PATH,pb_filename))
# Out:
# Loading from  ../results/Models/GraphModels/mobilenetv2_deeplabv3_BCE_ACC_IOU_divide_1_sigmoid_256_train_person.pb

# %%
# %%time
# Choose a random image and preprocess for inference.
i = random.choice(range(0,len(images)))
img  = images[i]
img_ = np.expand_dims(cv2.resize(img,INPUT_SHAPE[:2]),axis=0)
img_ = preprocess_input(img_, imgNorm=IMGNORM)
# inference by the model (op name must comes with :0 to specify the index of its output)
tensor_output = sess.graph.get_tensor_by_name('import/output_layer/Sigmoid:0')
tensor_input = sess.graph.get_tensor_by_name('import/input_layer:0')
output = sess.run(tensor_output, {tensor_input: img_})
# Resize and Apply Mask on input image.
mask = skimage.transform.resize(np.squeeze(output),img.shape[:2],preserve_range=True)
im = cv2.multiply(np.repeat(np.expand_dims(mask,axis=-1),3,axis=2).astype(float), img.astype(float))/255
plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(im)
# Out:
# CPU times: user 46.1 ms, sys: 37 ms, total: 83.1 ms
# Wall time: 32 ms

# %%
sess.close()

# %% [markdown]
# ### Testing TFLite model using Python API

# %%
# Load TFLite model and allocate tensors.
#interpreter = tf.lite.Interpreter(model_path=os.path.join(MODEL_PATH,tflite_filename))
interpreter = tf.lite.Interpreter(model_path=os.path.join(MODEL_PATH,tflite_Q_filename))
#interpreter = tf.lite.Interpreter(model_path="/media/new_hdd2/seg_net/results/Models/Models/sample_tf.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
input_details[0]['shape']
# Out:
# array([  1, 512, 512,   3], dtype=int32)

# %%
# %%time
# Choose a random image and preprocess for inference.
i = random.choice(range(0,len(images)))
img  = images[i]#skimage.io.imread("/home/avantariml/Downloads/IMG_3309.jpg")
img_ = np.expand_dims(cv2.resize(img,INPUT_SHAPE[:2]),axis=0)
#img_ = np.expand_dims(cv2.resize(img,(257, 257)),axis=0)
img_ = preprocess_input(img_, imgNorm="divide")
interpreter.set_tensor(input_details[0]['index'], img_)
interpreter.invoke()
output = interpreter.get_tensor(output_details[0]['index'])
# Resize and Apply Mask on input image.
mask = skimage.transform.resize(np.squeeze(output),img.shape[:2],preserve_range=True)
im = cv2.multiply(np.repeat(np.expand_dims(mask,axis=-1),3,axis=2).astype(float), img.astype(float))/255
plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(im)#(np.squeeze(output))
# Out:
# CPU times: user 3.47 s, sys: 531 ms, total: 4 s
# Wall time: 3.81 s
