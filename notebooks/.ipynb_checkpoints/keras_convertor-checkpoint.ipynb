# %% [markdown]
# # Keras to Tensorflow Model

# %%
import keras
import keras.backend as K
import tensorflow as tf
import numpy as np
np.random.seed(0)
import segmentation_models as sm
import sys
import os
sys.path.append("..")
from seg_net.data import *
from seg_net.fast_scnn import fast_scnn
from seg_net.dlv3 import Deeplabv3
from seg_net.gunet import Unet
# Out:
# Using TensorFlow backend.
# /home/avantariml/.local/lib/python3.5/site-packages/classification_models/resnext/__init__.py:4: UserWarning: Current ResNext models are deprecated, use keras.applications ResNeXt models
#   warnings.warn('Current ResNext models are deprecated, '

# %% [markdown]
# ## Set Model Architecture

# %%
INPUT_SHAPE =  (256,256,3) #(768,768,3) (512,512,3) (256,256,3)
NUM_CLASS = 1
BACKBONE = 'mobilenetv2'
MODEL_NAME = 'GUnet'
LOSS_METRICS = 'BCE_ACC_IOU'
ACTIVATION = 'sigmoid'
DATASET = "train_matte"
IMGNORM = 'divide'
MODEL_PATH_ = '../results/Models/'

model_fname = '{0}_{1}_{2}_{3}_{4}_{5}_{6}_{7}'.format(BACKBONE,
                                                MODEL_NAME,
                                                LOSS_METRICS,
                                                IMGNORM,
                                                NUM_CLASS,
                                                ACTIVATION,
                                                INPUT_SHAPE[0],
                                                DATASET)

MODEL_PATH = '../results/Models/GraphModels'

keras_filename = '{}.hdf5'.format(model_fname)
pb_filename = '{}.pb'.format(model_fname)
pb_op_filename = '{}_op.pb'.format(model_fname)
mlmodel_filename = '{}.mlmodel'.format(model_fname)
mlmodel_fp16_filename = '{}_fp16.mlmodel'.format(model_fname)
mlmodel_Q_filename = '{}_Q.mlmodel'.format(model_fname)
tflite_filename = '{}.tflite'.format(model_fname)
tflite_Q_filename = '{}_Q.tflite'.format(model_fname)

# %% [markdown]
# ## Build and Load Model

# %%
model = Unet(pretrained = None,
             backbone = BACKBONE,
             input_shape = INPUT_SHAPE,
             classes = NUM_CLASS,
             activation = ACTIVATION,
             sep_conv = True,
             densenet_matting_filters = 128,
             densenet_matting_layers = 3,
             matt_sep_conv = True,
             freeze_encoder = False)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ../seg_net/mobilenet_v2.py:319: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '

# %%
model = sm.Linknet(BACKBONE, encoder_weights='imagenet', 
                  classes=NUM_CLASS,
                  activation=ACTIVATION,
                  input_shape = INPUT_SHAPE)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /home/avantariml/.local/lib/python3.5/site-packages/segmentation_models/backbones/mobilenetv2.py:273: UserWarning: MobileNet shape is undefined. Weights for input shape(224, 224) will be loaded.
#   warnings.warn('MobileNet shape is undefined.'

# %%
model = fast_scnn(input_shape = INPUT_SHAPE, 
                  num_classes = NUM_CLASS, 
                  activation = ACTIVATION, 
                  dropout_rate = 0.3,
                  backbone_name = BACKBONE)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model = Deeplabv3(weights=None, 
                  input_shape=INPUT_SHAPE, 
                  backbone=BACKBONE,
                  classes=NUM_CLASS, 
                  OS=8,
                  activation=ACTIVATION)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.load_weights(os.path.join(MODEL_PATH_,keras_filename))
print("Loading from ",os.path.join(MODEL_PATH_,keras_filename))
# Out:
# Loading from  ../results/Models/mobilenetv2_GUnet_MSE_ACC_IOU_divide_1_sigmoid_256_train_matte.hdf5

# %%
model.compile('sgd', loss='binary_crossentropy', metrics=['accuracy'])
model.save(os.path.join(MODEL_PATH_,keras_filename))

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 257, 257, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 128, 128, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 128, 128, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 128, 128, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 128, 128, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 128, 128, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 128, 128, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 128, 128, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 128, 128, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 128, 128, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 128, 128, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 128, 128, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 129, 129, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 64, 64, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 64, 64, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 64, 64, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 64, 64, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 64, 64, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 64, 64, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 64, 64, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 64, 64, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 64, 64, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 64, 64, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 64, 64, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 64, 64, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 64, 64, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 64, 64, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 64, 64, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 64, 64, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 64, 64, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 65, 65, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 32, 32, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 32, 32, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 32, 32, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 32, 32, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 32, 32, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 32, 32, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 32, 32, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 32, 32, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 32, 32, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 32, 32, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 32, 32, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 32, 32, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 32, 32, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 32, 32, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 32, 32, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 32, 32, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 32, 32, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 32, 32, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 32, 32, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 32, 32, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 32, 32, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 32, 32, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 32, 32, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 32, 32, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 32, 32, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 32, 32, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 33, 33, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 16, 16, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 16, 16, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 16, 16, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 16, 16, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 16, 16, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 16, 16, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 16, 16, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 16, 16, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 16, 16, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 16, 16, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 16, 16, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 16, 16, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 16, 16, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 16, 16, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 16, 16, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 16, 16, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 16, 16, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 16, 16, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 16, 16, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 16, 16, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 16, 16, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 16, 16, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 16, 16, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 16, 16, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 16, 16, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 16, 16, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 16, 16, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 16, 16, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 16, 16, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 16, 16, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 16, 16, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 16, 16, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 16, 16, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 16, 16, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 16, 16, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 16, 16, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 16, 16, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 16, 16, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 16, 16, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 16, 16, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 16, 16, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 16, 16, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 16, 16, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 16, 16, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 16, 16, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 16, 16, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 16, 16, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 16, 16, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 16, 16, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 16, 16, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 16, 16, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 16, 16, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 16, 16, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 16, 16, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 16, 16, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 16, 16, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 16, 16, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 16, 16, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 16, 16, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 16, 16, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 16, 16, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 17, 17, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 8, 8, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 8, 8, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 8, 8, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 8, 8, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 8, 8, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 8, 8, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 8, 8, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 8, 8, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 8, 8, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 8, 8, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 8, 8, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 8, 8, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 8, 8, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 8, 8, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 8, 8, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 8, 8, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 8, 8, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 8, 8, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 8, 8, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 8, 8, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 8, 8, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 8, 8, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 8, 8, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 8, 8, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 8, 8, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 8, 8, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 8, 8, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 8, 8, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 8, 8, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 8, 8, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 8, 8, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 8, 8, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 8, 8, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 8, 8, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 1280) 0           out_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 1856) 0           lambda_1[0][0]
#                                                                  block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_1_depthwise (Dep (None, 16, 16, 1856) 16704       concatenate_1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_1_depthwise_BN ( (None, 16, 16, 1856) 7424        decoder_stage0_1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16, 16, 1856) 0           decoder_stage0_1_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage0_1_pointwise (Con (None, 16, 16, 256)  475136      activation_1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_1_pointwise_BN ( (None, 16, 16, 256)  1024        decoder_stage0_1_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 256)  0           decoder_stage0_1_pointwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage0_2_depthwise (Dep (None, 16, 16, 256)  2304        activation_2[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_2_depthwise_BN ( (None, 16, 16, 256)  1024        decoder_stage0_2_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 256)  0           decoder_stage0_2_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage0_2_pointwise (Con (None, 16, 16, 256)  65536       activation_3[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_2_pointwise_BN ( (None, 16, 16, 256)  1024        decoder_stage0_2_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 256)  0           decoder_stage0_2_pointwise_BN[0][
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32, 32, 256)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 448)  0           lambda_2[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_1_depthwise (Dep (None, 32, 32, 448)  4032        concatenate_2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_1_depthwise_BN ( (None, 32, 32, 448)  1792        decoder_stage1_1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 448)  0           decoder_stage1_1_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage1_1_pointwise (Con (None, 32, 32, 128)  57344       activation_5[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_1_pointwise_BN ( (None, 32, 32, 128)  512         decoder_stage1_1_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 128)  0           decoder_stage1_1_pointwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage1_2_depthwise (Dep (None, 32, 32, 128)  1152        activation_6[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_2_depthwise_BN ( (None, 32, 32, 128)  512         decoder_stage1_2_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 128)  0           decoder_stage1_2_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage1_2_pointwise (Con (None, 32, 32, 128)  16384       activation_7[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_2_pointwise_BN ( (None, 32, 32, 128)  512         decoder_stage1_2_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 128)  0           decoder_stage1_2_pointwise_BN[0][
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64, 64, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 272)  0           lambda_3[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_1_depthwise (Dep (None, 64, 64, 272)  2448        concatenate_3[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_1_depthwise_BN ( (None, 64, 64, 272)  1088        decoder_stage2_1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 272)  0           decoder_stage2_1_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage2_1_pointwise (Con (None, 64, 64, 64)   17408       activation_9[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_1_pointwise_BN ( (None, 64, 64, 64)   256         decoder_stage2_1_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 64)   0           decoder_stage2_1_pointwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage2_2_depthwise (Dep (None, 64, 64, 64)   576         activation_10[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_2_depthwise_BN ( (None, 64, 64, 64)   256         decoder_stage2_2_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 64)   0           decoder_stage2_2_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage2_2_pointwise (Con (None, 64, 64, 64)   4096        activation_11[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_2_pointwise_BN ( (None, 64, 64, 64)   256         decoder_stage2_2_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 64)   0           decoder_stage2_2_pointwise_BN[0][
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128, 128, 64) 0           activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 160 0           lambda_4[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_1_depthwise (Dep (None, 128, 128, 160 1440        concatenate_4[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_1_depthwise_BN ( (None, 128, 128, 160 640         decoder_stage3_1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 128, 160 0           decoder_stage3_1_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage3_1_pointwise (Con (None, 128, 128, 32) 5120        activation_13[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_1_pointwise_BN ( (None, 128, 128, 32) 128         decoder_stage3_1_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 32) 0           decoder_stage3_1_pointwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage3_2_depthwise (Dep (None, 128, 128, 32) 288         activation_14[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_2_depthwise_BN ( (None, 128, 128, 32) 128         decoder_stage3_2_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 32) 0           decoder_stage3_2_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage3_2_pointwise (Con (None, 128, 128, 32) 1024        activation_15[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_2_pointwise_BN ( (None, 128, 128, 32) 128         decoder_stage3_2_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 32) 0           decoder_stage3_2_pointwise_BN[0][
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 256, 256, 32) 0           activation_16[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_1_depthwise (Dep (None, 256, 256, 32) 288         lambda_5[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_1_depthwise_BN ( (None, 256, 256, 32) 128         decoder_stage4_1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 32) 0           decoder_stage4_1_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage4_1_pointwise (Con (None, 256, 256, 16) 512         activation_17[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_1_pointwise_BN ( (None, 256, 256, 16) 64          decoder_stage4_1_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 256, 256, 16) 0           decoder_stage4_1_pointwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage4_2_depthwise (Dep (None, 256, 256, 16) 144         activation_18[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_2_depthwise_BN ( (None, 256, 256, 16) 64          decoder_stage4_2_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 256, 256, 16) 0           decoder_stage4_2_depthwise_BN[0][
# __________________________________________________________________________________________________
# decoder_stage4_2_pointwise (Con (None, 256, 256, 16) 256         activation_19[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_2_pointwise_BN ( (None, 256, 256, 16) 64          decoder_stage4_2_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 256, 256, 16) 0           decoder_stage4_2_pointwise_BN[0][
# __________________________________________________________________________________________________
# densenet_matt1_depthwise (Depth (None, 256, 256, 16) 144         activation_20[0][0]
# __________________________________________________________________________________________________
# densenet_matt1_depthwise_BN (Ba (None, 256, 256, 16) 64          densenet_matt1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 256, 256, 16) 0           densenet_matt1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# densenet_matt1_pointwise (Conv2 (None, 256, 256, 128 2048        activation_21[0][0]
# __________________________________________________________________________________________________
# densenet_matt1_pointwise_BN (Ba (None, 256, 256, 128 512         densenet_matt1_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 256, 256, 128 0           densenet_matt1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# densenet_matt2_depthwise (Depth (None, 256, 256, 128 1152        activation_22[0][0]
# __________________________________________________________________________________________________
# densenet_matt2_depthwise_BN (Ba (None, 256, 256, 128 512         densenet_matt2_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 256, 256, 128 0           densenet_matt2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# densenet_matt2_pointwise (Conv2 (None, 256, 256, 128 16384       activation_23[0][0]
# __________________________________________________________________________________________________
# densenet_matt2_pointwise_BN (Ba (None, 256, 256, 128 512         densenet_matt2_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 256, 256, 128 0           densenet_matt2_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# densenet_matt3_depthwise (Depth (None, 256, 256, 128 1152        activation_24[0][0]
# __________________________________________________________________________________________________
# densenet_matt3_depthwise_BN (Ba (None, 256, 256, 128 512         densenet_matt3_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 256, 256, 128 0           densenet_matt3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# densenet_matt3_pointwise (Conv2 (None, 256, 256, 128 16384       activation_25[0][0]
# __________________________________________________________________________________________________
# densenet_matt3_pointwise_BN (Ba (None, 256, 256, 128 512         densenet_matt3_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 256, 256, 128 0           densenet_matt3_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# final_conv (SeparableConv2D)    (None, 256, 256, 1)  1281        activation_26[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 256, 256, 1)  0           final_conv[0][0]
# ==================================================================================================
# Total params: 2,988,369
# Trainable params: 2,944,433
# Non-trainable params: 43,936
# __________________________________________________________________________________________________

# %% [markdown]
# ## save keras model as tf .pb and as CoreML .mlmodel

# %%
from tensorflow.python.tools.optimize_for_inference_lib import optimize_for_inference
import coremltools
from seg_net.keras_to_tensorflow import *
# Out:
# WARNING:root:TensorFlow version 1.13.1 detected. Last version known to be fully compatible is 1.12.0 .

# %%
input_node_names = [node.op.name for node in model.inputs]
print(input_node_names)
# Out:
# ['input_1']

# %%
# output_names
output_node_names = [node.op.name for node in model.outputs]
print(output_node_names)
# Out:
# ['sigmoid/Sigmoid']

# %% [markdown]
# ### Freezing the model to .pb

# %%
const_graphDef = freeze_keras(K.get_session(), output_node_names, transform = None, 
                              clear_devices = True, add_tf_global = False)
tf.train.write_graph(const_graphDef, MODEL_PATH, pb_filename, as_text=False)
# Out:
# WARNING:tensorflow:From ../seg_net/keras_to_tensorflow.py:82: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From ../seg_net/keras_to_tensorflow.py:82: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 393 variables.
# INFO:tensorflow:Froze 393 variables.
# INFO:tensorflow:Converted 393 variables to const ops.
# INFO:tensorflow:Converted 393 variables to const ops.
# '../results/Models/GraphModels/mobilenetv2_GUnet_MSE_ACC_IOU_divide_1_sigmoid_256_train_matte.pb'

# %%
for name in [n.name for n in const_graphDef.node]:
    print(name)
# Out:
# input_1
# Conv1_pad/Pad/paddings
# Conv1_pad/Pad
# Conv1/kernel
# Conv1/kernel/read
# Conv1/convolution
# bn_Conv1/gamma
# bn_Conv1/gamma/read
# bn_Conv1/beta
# bn_Conv1/beta/read
# bn_Conv1/moving_mean
# bn_Conv1/moving_mean/read
# bn_Conv1/moving_variance
# bn_Conv1/moving_variance/read
# bn_Conv1/Const_4
# bn_Conv1/Const_5
# bn_Conv1/FusedBatchNorm
# bn_Conv1/keras_learning_phase/input
# bn_Conv1/keras_learning_phase
# bn_Conv1/cond/pred_id
# bn_Conv1/cond/Switch_1
# bn_Conv1/cond/FusedBatchNorm
# bn_Conv1/cond/FusedBatchNorm/Switch
# bn_Conv1/cond/FusedBatchNorm/Switch_1
# bn_Conv1/cond/FusedBatchNorm/Switch_2
# bn_Conv1/cond/FusedBatchNorm/Switch_3
# bn_Conv1/cond/FusedBatchNorm/Switch_4
# bn_Conv1/cond/Merge
# Conv1_relu/Relu6
# expanded_conv_depthwise/depthwise_kernel
# expanded_conv_depthwise/depthwise_kernel/read
# expanded_conv_depthwise/depthwise
# expanded_conv_depthwise_BN/gamma
# expanded_conv_depthwise_BN/gamma/read
# expanded_conv_depthwise_BN/beta
# expanded_conv_depthwise_BN/beta/read
# expanded_conv_depthwise_BN/moving_mean
# expanded_conv_depthwise_BN/moving_mean/read
# expanded_conv_depthwise_BN/moving_variance
# expanded_conv_depthwise_BN/moving_variance/read
# expanded_conv_depthwise_BN/Const_4
# expanded_conv_depthwise_BN/Const_5
# expanded_conv_depthwise_BN/FusedBatchNorm
# expanded_conv_depthwise_BN/cond/pred_id
# expanded_conv_depthwise_BN/cond/Switch_1
# expanded_conv_depthwise_BN/cond/FusedBatchNorm
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_depthwise_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_depthwise_BN/cond/Merge
# expanded_conv_depthwise_relu/Relu6
# expanded_conv_project/kernel
# expanded_conv_project/kernel/read
# expanded_conv_project/convolution
# expanded_conv_project_BN/gamma
# expanded_conv_project_BN/gamma/read
# expanded_conv_project_BN/beta
# expanded_conv_project_BN/beta/read
# expanded_conv_project_BN/moving_mean
# expanded_conv_project_BN/moving_mean/read
# expanded_conv_project_BN/moving_variance
# expanded_conv_project_BN/moving_variance/read
# expanded_conv_project_BN/Const_4
# expanded_conv_project_BN/Const_5
# expanded_conv_project_BN/FusedBatchNorm
# expanded_conv_project_BN/cond/pred_id
# expanded_conv_project_BN/cond/Switch_1
# expanded_conv_project_BN/cond/FusedBatchNorm
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch_1
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch_2
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch_3
# expanded_conv_project_BN/cond/FusedBatchNorm/Switch_4
# expanded_conv_project_BN/cond/Merge
# block_1_expand/kernel
# block_1_expand/kernel/read
# block_1_expand/convolution
# block_1_expand_BN/gamma
# block_1_expand_BN/gamma/read
# block_1_expand_BN/beta
# block_1_expand_BN/beta/read
# block_1_expand_BN/moving_mean
# block_1_expand_BN/moving_mean/read
# block_1_expand_BN/moving_variance
# block_1_expand_BN/moving_variance/read
# block_1_expand_BN/Const_4
# block_1_expand_BN/Const_5
# block_1_expand_BN/FusedBatchNorm
# block_1_expand_BN/cond/pred_id
# block_1_expand_BN/cond/Switch_1
# block_1_expand_BN/cond/FusedBatchNorm
# block_1_expand_BN/cond/FusedBatchNorm/Switch
# block_1_expand_BN/cond/FusedBatchNorm/Switch_1
# block_1_expand_BN/cond/FusedBatchNorm/Switch_2
# block_1_expand_BN/cond/FusedBatchNorm/Switch_3
# block_1_expand_BN/cond/FusedBatchNorm/Switch_4
# block_1_expand_BN/cond/Merge
# block_1_expand_relu/Relu6
# block_1_pad/Pad/paddings
# block_1_pad/Pad
# block_1_depthwise/depthwise_kernel
# block_1_depthwise/depthwise_kernel/read
# block_1_depthwise/depthwise
# block_1_depthwise_BN/gamma
# block_1_depthwise_BN/gamma/read
# block_1_depthwise_BN/beta
# block_1_depthwise_BN/beta/read
# block_1_depthwise_BN/moving_mean
# block_1_depthwise_BN/moving_mean/read
# block_1_depthwise_BN/moving_variance
# block_1_depthwise_BN/moving_variance/read
# block_1_depthwise_BN/Const_4
# block_1_depthwise_BN/Const_5
# block_1_depthwise_BN/FusedBatchNorm
# block_1_depthwise_BN/cond/pred_id
# block_1_depthwise_BN/cond/Switch_1
# block_1_depthwise_BN/cond/FusedBatchNorm
# block_1_depthwise_BN/cond/FusedBatchNorm/Switch
# block_1_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_1_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_1_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_1_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_1_depthwise_BN/cond/Merge
# block_1_depthwise_relu/Relu6
# block_1_project/kernel
# block_1_project/kernel/read
# block_1_project/convolution
# block_1_project_BN/gamma
# block_1_project_BN/gamma/read
# block_1_project_BN/beta
# block_1_project_BN/beta/read
# block_1_project_BN/moving_mean
# block_1_project_BN/moving_mean/read
# block_1_project_BN/moving_variance
# block_1_project_BN/moving_variance/read
# block_1_project_BN/Const_4
# block_1_project_BN/Const_5
# block_1_project_BN/FusedBatchNorm
# block_1_project_BN/cond/pred_id
# block_1_project_BN/cond/Switch_1
# block_1_project_BN/cond/FusedBatchNorm
# block_1_project_BN/cond/FusedBatchNorm/Switch
# block_1_project_BN/cond/FusedBatchNorm/Switch_1
# block_1_project_BN/cond/FusedBatchNorm/Switch_2
# block_1_project_BN/cond/FusedBatchNorm/Switch_3
# block_1_project_BN/cond/FusedBatchNorm/Switch_4
# block_1_project_BN/cond/Merge
# block_2_expand/kernel
# block_2_expand/kernel/read
# block_2_expand/convolution
# block_2_expand_BN/gamma
# block_2_expand_BN/gamma/read
# block_2_expand_BN/beta
# block_2_expand_BN/beta/read
# block_2_expand_BN/moving_mean
# block_2_expand_BN/moving_mean/read
# block_2_expand_BN/moving_variance
# block_2_expand_BN/moving_variance/read
# block_2_expand_BN/Const_4
# block_2_expand_BN/Const_5
# block_2_expand_BN/FusedBatchNorm
# block_2_expand_BN/cond/pred_id
# block_2_expand_BN/cond/Switch_1
# block_2_expand_BN/cond/FusedBatchNorm
# block_2_expand_BN/cond/FusedBatchNorm/Switch
# block_2_expand_BN/cond/FusedBatchNorm/Switch_1
# block_2_expand_BN/cond/FusedBatchNorm/Switch_2
# block_2_expand_BN/cond/FusedBatchNorm/Switch_3
# block_2_expand_BN/cond/FusedBatchNorm/Switch_4
# block_2_expand_BN/cond/Merge
# block_2_expand_relu/Relu6
# block_2_depthwise/depthwise_kernel
# block_2_depthwise/depthwise_kernel/read
# block_2_depthwise/depthwise
# block_2_depthwise_BN/gamma
# block_2_depthwise_BN/gamma/read
# block_2_depthwise_BN/beta
# block_2_depthwise_BN/beta/read
# block_2_depthwise_BN/moving_mean
# block_2_depthwise_BN/moving_mean/read
# block_2_depthwise_BN/moving_variance
# block_2_depthwise_BN/moving_variance/read
# block_2_depthwise_BN/Const_4
# block_2_depthwise_BN/Const_5
# block_2_depthwise_BN/FusedBatchNorm
# block_2_depthwise_BN/cond/pred_id
# block_2_depthwise_BN/cond/Switch_1
# block_2_depthwise_BN/cond/FusedBatchNorm
# block_2_depthwise_BN/cond/FusedBatchNorm/Switch
# block_2_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_2_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_2_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_2_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_2_depthwise_BN/cond/Merge
# block_2_depthwise_relu/Relu6
# block_2_project/kernel
# block_2_project/kernel/read
# block_2_project/convolution
# block_2_project_BN/gamma
# block_2_project_BN/gamma/read
# block_2_project_BN/beta
# block_2_project_BN/beta/read
# block_2_project_BN/moving_mean
# block_2_project_BN/moving_mean/read
# block_2_project_BN/moving_variance
# block_2_project_BN/moving_variance/read
# block_2_project_BN/Const_4
# block_2_project_BN/Const_5
# block_2_project_BN/FusedBatchNorm
# block_2_project_BN/cond/pred_id
# block_2_project_BN/cond/Switch_1
# block_2_project_BN/cond/FusedBatchNorm
# block_2_project_BN/cond/FusedBatchNorm/Switch
# block_2_project_BN/cond/FusedBatchNorm/Switch_1
# block_2_project_BN/cond/FusedBatchNorm/Switch_2
# block_2_project_BN/cond/FusedBatchNorm/Switch_3
# block_2_project_BN/cond/FusedBatchNorm/Switch_4
# block_2_project_BN/cond/Merge
# block_2_add/add
# block_3_expand/kernel
# block_3_expand/kernel/read
# block_3_expand/convolution
# block_3_expand_BN/gamma
# block_3_expand_BN/gamma/read
# block_3_expand_BN/beta
# block_3_expand_BN/beta/read
# block_3_expand_BN/moving_mean
# block_3_expand_BN/moving_mean/read
# block_3_expand_BN/moving_variance
# block_3_expand_BN/moving_variance/read
# block_3_expand_BN/Const_4
# block_3_expand_BN/Const_5
# block_3_expand_BN/FusedBatchNorm
# block_3_expand_BN/cond/pred_id
# block_3_expand_BN/cond/Switch_1
# block_3_expand_BN/cond/FusedBatchNorm
# block_3_expand_BN/cond/FusedBatchNorm/Switch
# block_3_expand_BN/cond/FusedBatchNorm/Switch_1
# block_3_expand_BN/cond/FusedBatchNorm/Switch_2
# block_3_expand_BN/cond/FusedBatchNorm/Switch_3
# block_3_expand_BN/cond/FusedBatchNorm/Switch_4
# block_3_expand_BN/cond/Merge
# block_3_expand_relu/Relu6
# block_3_pad/Pad/paddings
# block_3_pad/Pad
# block_3_depthwise/depthwise_kernel
# block_3_depthwise/depthwise_kernel/read
# block_3_depthwise/depthwise
# block_3_depthwise_BN/gamma
# block_3_depthwise_BN/gamma/read
# block_3_depthwise_BN/beta
# block_3_depthwise_BN/beta/read
# block_3_depthwise_BN/moving_mean
# block_3_depthwise_BN/moving_mean/read
# block_3_depthwise_BN/moving_variance
# block_3_depthwise_BN/moving_variance/read
# block_3_depthwise_BN/Const_4
# block_3_depthwise_BN/Const_5
# block_3_depthwise_BN/FusedBatchNorm
# block_3_depthwise_BN/cond/pred_id
# block_3_depthwise_BN/cond/Switch_1
# block_3_depthwise_BN/cond/FusedBatchNorm
# block_3_depthwise_BN/cond/FusedBatchNorm/Switch
# block_3_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_3_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_3_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_3_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_3_depthwise_BN/cond/Merge
# block_3_depthwise_relu/Relu6
# block_3_project/kernel
# block_3_project/kernel/read
# block_3_project/convolution
# block_3_project_BN/gamma
# block_3_project_BN/gamma/read
# block_3_project_BN/beta
# block_3_project_BN/beta/read
# block_3_project_BN/moving_mean
# block_3_project_BN/moving_mean/read
# block_3_project_BN/moving_variance
# block_3_project_BN/moving_variance/read
# block_3_project_BN/Const_4
# block_3_project_BN/Const_5
# block_3_project_BN/FusedBatchNorm
# block_3_project_BN/cond/pred_id
# block_3_project_BN/cond/Switch_1
# block_3_project_BN/cond/FusedBatchNorm
# block_3_project_BN/cond/FusedBatchNorm/Switch
# block_3_project_BN/cond/FusedBatchNorm/Switch_1
# block_3_project_BN/cond/FusedBatchNorm/Switch_2
# block_3_project_BN/cond/FusedBatchNorm/Switch_3
# block_3_project_BN/cond/FusedBatchNorm/Switch_4
# block_3_project_BN/cond/Merge
# block_4_expand/kernel
# block_4_expand/kernel/read
# block_4_expand/convolution
# block_4_expand_BN/gamma
# block_4_expand_BN/gamma/read
# block_4_expand_BN/beta
# block_4_expand_BN/beta/read
# block_4_expand_BN/moving_mean
# block_4_expand_BN/moving_mean/read
# block_4_expand_BN/moving_variance
# block_4_expand_BN/moving_variance/read
# block_4_expand_BN/Const_4
# block_4_expand_BN/Const_5
# block_4_expand_BN/FusedBatchNorm
# block_4_expand_BN/cond/pred_id
# block_4_expand_BN/cond/Switch_1
# block_4_expand_BN/cond/FusedBatchNorm
# block_4_expand_BN/cond/FusedBatchNorm/Switch
# block_4_expand_BN/cond/FusedBatchNorm/Switch_1
# block_4_expand_BN/cond/FusedBatchNorm/Switch_2
# block_4_expand_BN/cond/FusedBatchNorm/Switch_3
# block_4_expand_BN/cond/FusedBatchNorm/Switch_4
# block_4_expand_BN/cond/Merge
# block_4_expand_relu/Relu6
# block_4_depthwise/depthwise_kernel
# block_4_depthwise/depthwise_kernel/read
# block_4_depthwise/depthwise
# block_4_depthwise_BN/gamma
# block_4_depthwise_BN/gamma/read
# block_4_depthwise_BN/beta
# block_4_depthwise_BN/beta/read
# block_4_depthwise_BN/moving_mean
# block_4_depthwise_BN/moving_mean/read
# block_4_depthwise_BN/moving_variance
# block_4_depthwise_BN/moving_variance/read
# block_4_depthwise_BN/Const_4
# block_4_depthwise_BN/Const_5
# block_4_depthwise_BN/FusedBatchNorm
# block_4_depthwise_BN/cond/pred_id
# block_4_depthwise_BN/cond/Switch_1
# block_4_depthwise_BN/cond/FusedBatchNorm
# block_4_depthwise_BN/cond/FusedBatchNorm/Switch
# block_4_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_4_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_4_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_4_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_4_depthwise_BN/cond/Merge
# block_4_depthwise_relu/Relu6
# block_4_project/kernel
# block_4_project/kernel/read
# block_4_project/convolution
# block_4_project_BN/gamma
# block_4_project_BN/gamma/read
# block_4_project_BN/beta
# block_4_project_BN/beta/read
# block_4_project_BN/moving_mean
# block_4_project_BN/moving_mean/read
# block_4_project_BN/moving_variance
# block_4_project_BN/moving_variance/read
# block_4_project_BN/Const_4
# block_4_project_BN/Const_5
# block_4_project_BN/FusedBatchNorm
# block_4_project_BN/cond/pred_id
# block_4_project_BN/cond/Switch_1
# block_4_project_BN/cond/FusedBatchNorm
# block_4_project_BN/cond/FusedBatchNorm/Switch
# block_4_project_BN/cond/FusedBatchNorm/Switch_1
# block_4_project_BN/cond/FusedBatchNorm/Switch_2
# block_4_project_BN/cond/FusedBatchNorm/Switch_3
# block_4_project_BN/cond/FusedBatchNorm/Switch_4
# block_4_project_BN/cond/Merge
# block_4_add/add
# block_5_expand/kernel
# block_5_expand/kernel/read
# block_5_expand/convolution
# block_5_expand_BN/gamma
# block_5_expand_BN/gamma/read
# block_5_expand_BN/beta
# block_5_expand_BN/beta/read
# block_5_expand_BN/moving_mean
# block_5_expand_BN/moving_mean/read
# block_5_expand_BN/moving_variance
# block_5_expand_BN/moving_variance/read
# block_5_expand_BN/Const_4
# block_5_expand_BN/Const_5
# block_5_expand_BN/FusedBatchNorm
# block_5_expand_BN/cond/pred_id
# block_5_expand_BN/cond/Switch_1
# block_5_expand_BN/cond/FusedBatchNorm
# block_5_expand_BN/cond/FusedBatchNorm/Switch
# block_5_expand_BN/cond/FusedBatchNorm/Switch_1
# block_5_expand_BN/cond/FusedBatchNorm/Switch_2
# block_5_expand_BN/cond/FusedBatchNorm/Switch_3
# block_5_expand_BN/cond/FusedBatchNorm/Switch_4
# block_5_expand_BN/cond/Merge
# block_5_expand_relu/Relu6
# block_5_depthwise/depthwise_kernel
# block_5_depthwise/depthwise_kernel/read
# block_5_depthwise/depthwise
# block_5_depthwise_BN/gamma
# block_5_depthwise_BN/gamma/read
# block_5_depthwise_BN/beta
# block_5_depthwise_BN/beta/read
# block_5_depthwise_BN/moving_mean
# block_5_depthwise_BN/moving_mean/read
# block_5_depthwise_BN/moving_variance
# block_5_depthwise_BN/moving_variance/read
# block_5_depthwise_BN/Const_4
# block_5_depthwise_BN/Const_5
# block_5_depthwise_BN/FusedBatchNorm
# block_5_depthwise_BN/cond/pred_id
# block_5_depthwise_BN/cond/Switch_1
# block_5_depthwise_BN/cond/FusedBatchNorm
# block_5_depthwise_BN/cond/FusedBatchNorm/Switch
# block_5_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_5_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_5_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_5_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_5_depthwise_BN/cond/Merge
# block_5_depthwise_relu/Relu6
# block_5_project/kernel
# block_5_project/kernel/read
# block_5_project/convolution
# block_5_project_BN/gamma
# block_5_project_BN/gamma/read
# block_5_project_BN/beta
# block_5_project_BN/beta/read
# block_5_project_BN/moving_mean
# block_5_project_BN/moving_mean/read
# block_5_project_BN/moving_variance
# block_5_project_BN/moving_variance/read
# block_5_project_BN/Const_4
# block_5_project_BN/Const_5
# block_5_project_BN/FusedBatchNorm
# block_5_project_BN/cond/pred_id
# block_5_project_BN/cond/Switch_1
# block_5_project_BN/cond/FusedBatchNorm
# block_5_project_BN/cond/FusedBatchNorm/Switch
# block_5_project_BN/cond/FusedBatchNorm/Switch_1
# block_5_project_BN/cond/FusedBatchNorm/Switch_2
# block_5_project_BN/cond/FusedBatchNorm/Switch_3
# block_5_project_BN/cond/FusedBatchNorm/Switch_4
# block_5_project_BN/cond/Merge
# block_5_add/add
# block_6_expand/kernel
# block_6_expand/kernel/read
# block_6_expand/convolution
# block_6_expand_BN/gamma
# block_6_expand_BN/gamma/read
# block_6_expand_BN/beta
# block_6_expand_BN/beta/read
# block_6_expand_BN/moving_mean
# block_6_expand_BN/moving_mean/read
# block_6_expand_BN/moving_variance
# block_6_expand_BN/moving_variance/read
# block_6_expand_BN/Const_4
# block_6_expand_BN/Const_5
# block_6_expand_BN/FusedBatchNorm
# block_6_expand_BN/cond/pred_id
# block_6_expand_BN/cond/Switch_1
# block_6_expand_BN/cond/FusedBatchNorm
# block_6_expand_BN/cond/FusedBatchNorm/Switch
# block_6_expand_BN/cond/FusedBatchNorm/Switch_1
# block_6_expand_BN/cond/FusedBatchNorm/Switch_2
# block_6_expand_BN/cond/FusedBatchNorm/Switch_3
# block_6_expand_BN/cond/FusedBatchNorm/Switch_4
# block_6_expand_BN/cond/Merge
# block_6_expand_relu/Relu6
# block_6_pad/Pad/paddings
# block_6_pad/Pad
# block_6_depthwise/depthwise_kernel
# block_6_depthwise/depthwise_kernel/read
# block_6_depthwise/depthwise
# block_6_depthwise_BN/gamma
# block_6_depthwise_BN/gamma/read
# block_6_depthwise_BN/beta
# block_6_depthwise_BN/beta/read
# block_6_depthwise_BN/moving_mean
# block_6_depthwise_BN/moving_mean/read
# block_6_depthwise_BN/moving_variance
# block_6_depthwise_BN/moving_variance/read
# block_6_depthwise_BN/Const_4
# block_6_depthwise_BN/Const_5
# block_6_depthwise_BN/FusedBatchNorm
# block_6_depthwise_BN/cond/pred_id
# block_6_depthwise_BN/cond/Switch_1
# block_6_depthwise_BN/cond/FusedBatchNorm
# block_6_depthwise_BN/cond/FusedBatchNorm/Switch
# block_6_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_6_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_6_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_6_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_6_depthwise_BN/cond/Merge
# block_6_depthwise_relu/Relu6
# block_6_project/kernel
# block_6_project/kernel/read
# block_6_project/convolution
# block_6_project_BN/gamma
# block_6_project_BN/gamma/read
# block_6_project_BN/beta
# block_6_project_BN/beta/read
# block_6_project_BN/moving_mean
# block_6_project_BN/moving_mean/read
# block_6_project_BN/moving_variance
# block_6_project_BN/moving_variance/read
# block_6_project_BN/Const_4
# block_6_project_BN/Const_5
# block_6_project_BN/FusedBatchNorm
# block_6_project_BN/cond/pred_id
# block_6_project_BN/cond/Switch_1
# block_6_project_BN/cond/FusedBatchNorm
# block_6_project_BN/cond/FusedBatchNorm/Switch
# block_6_project_BN/cond/FusedBatchNorm/Switch_1
# block_6_project_BN/cond/FusedBatchNorm/Switch_2
# block_6_project_BN/cond/FusedBatchNorm/Switch_3
# block_6_project_BN/cond/FusedBatchNorm/Switch_4
# block_6_project_BN/cond/Merge
# block_7_expand/kernel
# block_7_expand/kernel/read
# block_7_expand/convolution
# block_7_expand_BN/gamma
# block_7_expand_BN/gamma/read
# block_7_expand_BN/beta
# block_7_expand_BN/beta/read
# block_7_expand_BN/moving_mean
# block_7_expand_BN/moving_mean/read
# block_7_expand_BN/moving_variance
# block_7_expand_BN/moving_variance/read
# block_7_expand_BN/Const_4
# block_7_expand_BN/Const_5
# block_7_expand_BN/FusedBatchNorm
# block_7_expand_BN/cond/pred_id
# block_7_expand_BN/cond/Switch_1
# block_7_expand_BN/cond/FusedBatchNorm
# block_7_expand_BN/cond/FusedBatchNorm/Switch
# block_7_expand_BN/cond/FusedBatchNorm/Switch_1
# block_7_expand_BN/cond/FusedBatchNorm/Switch_2
# block_7_expand_BN/cond/FusedBatchNorm/Switch_3
# block_7_expand_BN/cond/FusedBatchNorm/Switch_4
# block_7_expand_BN/cond/Merge
# block_7_expand_relu/Relu6
# block_7_depthwise/depthwise_kernel
# block_7_depthwise/depthwise_kernel/read
# block_7_depthwise/depthwise
# block_7_depthwise_BN/gamma
# block_7_depthwise_BN/gamma/read
# block_7_depthwise_BN/beta
# block_7_depthwise_BN/beta/read
# block_7_depthwise_BN/moving_mean
# block_7_depthwise_BN/moving_mean/read
# block_7_depthwise_BN/moving_variance
# block_7_depthwise_BN/moving_variance/read
# block_7_depthwise_BN/Const_4
# block_7_depthwise_BN/Const_5
# block_7_depthwise_BN/FusedBatchNorm
# block_7_depthwise_BN/cond/pred_id
# block_7_depthwise_BN/cond/Switch_1
# block_7_depthwise_BN/cond/FusedBatchNorm
# block_7_depthwise_BN/cond/FusedBatchNorm/Switch
# block_7_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_7_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_7_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_7_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_7_depthwise_BN/cond/Merge
# block_7_depthwise_relu/Relu6
# block_7_project/kernel
# block_7_project/kernel/read
# block_7_project/convolution
# block_7_project_BN/gamma
# block_7_project_BN/gamma/read
# block_7_project_BN/beta
# block_7_project_BN/beta/read
# block_7_project_BN/moving_mean
# block_7_project_BN/moving_mean/read
# block_7_project_BN/moving_variance
# block_7_project_BN/moving_variance/read
# block_7_project_BN/Const_4
# block_7_project_BN/Const_5
# block_7_project_BN/FusedBatchNorm
# block_7_project_BN/cond/pred_id
# block_7_project_BN/cond/Switch_1
# block_7_project_BN/cond/FusedBatchNorm
# block_7_project_BN/cond/FusedBatchNorm/Switch
# block_7_project_BN/cond/FusedBatchNorm/Switch_1
# block_7_project_BN/cond/FusedBatchNorm/Switch_2
# block_7_project_BN/cond/FusedBatchNorm/Switch_3
# block_7_project_BN/cond/FusedBatchNorm/Switch_4
# block_7_project_BN/cond/Merge
# block_7_add/add
# block_8_expand/kernel
# block_8_expand/kernel/read
# block_8_expand/convolution
# block_8_expand_BN/gamma
# block_8_expand_BN/gamma/read
# block_8_expand_BN/beta
# block_8_expand_BN/beta/read
# block_8_expand_BN/moving_mean
# block_8_expand_BN/moving_mean/read
# block_8_expand_BN/moving_variance
# block_8_expand_BN/moving_variance/read
# block_8_expand_BN/Const_4
# block_8_expand_BN/Const_5
# block_8_expand_BN/FusedBatchNorm
# block_8_expand_BN/cond/pred_id
# block_8_expand_BN/cond/Switch_1
# block_8_expand_BN/cond/FusedBatchNorm
# block_8_expand_BN/cond/FusedBatchNorm/Switch
# block_8_expand_BN/cond/FusedBatchNorm/Switch_1
# block_8_expand_BN/cond/FusedBatchNorm/Switch_2
# block_8_expand_BN/cond/FusedBatchNorm/Switch_3
# block_8_expand_BN/cond/FusedBatchNorm/Switch_4
# block_8_expand_BN/cond/Merge
# block_8_expand_relu/Relu6
# block_8_depthwise/depthwise_kernel
# block_8_depthwise/depthwise_kernel/read
# block_8_depthwise/depthwise
# block_8_depthwise_BN/gamma
# block_8_depthwise_BN/gamma/read
# block_8_depthwise_BN/beta
# block_8_depthwise_BN/beta/read
# block_8_depthwise_BN/moving_mean
# block_8_depthwise_BN/moving_mean/read
# block_8_depthwise_BN/moving_variance
# block_8_depthwise_BN/moving_variance/read
# block_8_depthwise_BN/Const_4
# block_8_depthwise_BN/Const_5
# block_8_depthwise_BN/FusedBatchNorm
# block_8_depthwise_BN/cond/pred_id
# block_8_depthwise_BN/cond/Switch_1
# block_8_depthwise_BN/cond/FusedBatchNorm
# block_8_depthwise_BN/cond/FusedBatchNorm/Switch
# block_8_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_8_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_8_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_8_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_8_depthwise_BN/cond/Merge
# block_8_depthwise_relu/Relu6
# block_8_project/kernel
# block_8_project/kernel/read
# block_8_project/convolution
# block_8_project_BN/gamma
# block_8_project_BN/gamma/read
# block_8_project_BN/beta
# block_8_project_BN/beta/read
# block_8_project_BN/moving_mean
# block_8_project_BN/moving_mean/read
# block_8_project_BN/moving_variance
# block_8_project_BN/moving_variance/read
# block_8_project_BN/Const_4
# block_8_project_BN/Const_5
# block_8_project_BN/FusedBatchNorm
# block_8_project_BN/cond/pred_id
# block_8_project_BN/cond/Switch_1
# block_8_project_BN/cond/FusedBatchNorm
# block_8_project_BN/cond/FusedBatchNorm/Switch
# block_8_project_BN/cond/FusedBatchNorm/Switch_1
# block_8_project_BN/cond/FusedBatchNorm/Switch_2
# block_8_project_BN/cond/FusedBatchNorm/Switch_3
# block_8_project_BN/cond/FusedBatchNorm/Switch_4
# block_8_project_BN/cond/Merge
# block_8_add/add
# block_9_expand/kernel
# block_9_expand/kernel/read
# block_9_expand/convolution
# block_9_expand_BN/gamma
# block_9_expand_BN/gamma/read
# block_9_expand_BN/beta
# block_9_expand_BN/beta/read
# block_9_expand_BN/moving_mean
# block_9_expand_BN/moving_mean/read
# block_9_expand_BN/moving_variance
# block_9_expand_BN/moving_variance/read
# block_9_expand_BN/Const_4
# block_9_expand_BN/Const_5
# block_9_expand_BN/FusedBatchNorm
# block_9_expand_BN/cond/pred_id
# block_9_expand_BN/cond/Switch_1
# block_9_expand_BN/cond/FusedBatchNorm
# block_9_expand_BN/cond/FusedBatchNorm/Switch
# block_9_expand_BN/cond/FusedBatchNorm/Switch_1
# block_9_expand_BN/cond/FusedBatchNorm/Switch_2
# block_9_expand_BN/cond/FusedBatchNorm/Switch_3
# block_9_expand_BN/cond/FusedBatchNorm/Switch_4
# block_9_expand_BN/cond/Merge
# block_9_expand_relu/Relu6
# block_9_depthwise/depthwise_kernel
# block_9_depthwise/depthwise_kernel/read
# block_9_depthwise/depthwise
# block_9_depthwise_BN/gamma
# block_9_depthwise_BN/gamma/read
# block_9_depthwise_BN/beta
# block_9_depthwise_BN/beta/read
# block_9_depthwise_BN/moving_mean
# block_9_depthwise_BN/moving_mean/read
# block_9_depthwise_BN/moving_variance
# block_9_depthwise_BN/moving_variance/read
# block_9_depthwise_BN/Const_4
# block_9_depthwise_BN/Const_5
# block_9_depthwise_BN/FusedBatchNorm
# block_9_depthwise_BN/cond/pred_id
# block_9_depthwise_BN/cond/Switch_1
# block_9_depthwise_BN/cond/FusedBatchNorm
# block_9_depthwise_BN/cond/FusedBatchNorm/Switch
# block_9_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_9_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_9_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_9_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_9_depthwise_BN/cond/Merge
# block_9_depthwise_relu/Relu6
# block_9_project/kernel
# block_9_project/kernel/read
# block_9_project/convolution
# block_9_project_BN/gamma
# block_9_project_BN/gamma/read
# block_9_project_BN/beta
# block_9_project_BN/beta/read
# block_9_project_BN/moving_mean
# block_9_project_BN/moving_mean/read
# block_9_project_BN/moving_variance
# block_9_project_BN/moving_variance/read
# block_9_project_BN/Const_4
# block_9_project_BN/Const_5
# block_9_project_BN/FusedBatchNorm
# block_9_project_BN/cond/pred_id
# block_9_project_BN/cond/Switch_1
# block_9_project_BN/cond/FusedBatchNorm
# block_9_project_BN/cond/FusedBatchNorm/Switch
# block_9_project_BN/cond/FusedBatchNorm/Switch_1
# block_9_project_BN/cond/FusedBatchNorm/Switch_2
# block_9_project_BN/cond/FusedBatchNorm/Switch_3
# block_9_project_BN/cond/FusedBatchNorm/Switch_4
# block_9_project_BN/cond/Merge
# block_9_add/add
# block_10_expand/kernel
# block_10_expand/kernel/read
# block_10_expand/convolution
# block_10_expand_BN/gamma
# block_10_expand_BN/gamma/read
# block_10_expand_BN/beta
# block_10_expand_BN/beta/read
# block_10_expand_BN/moving_mean
# block_10_expand_BN/moving_mean/read
# block_10_expand_BN/moving_variance
# block_10_expand_BN/moving_variance/read
# block_10_expand_BN/Const_4
# block_10_expand_BN/Const_5
# block_10_expand_BN/FusedBatchNorm
# block_10_expand_BN/cond/pred_id
# block_10_expand_BN/cond/Switch_1
# block_10_expand_BN/cond/FusedBatchNorm
# block_10_expand_BN/cond/FusedBatchNorm/Switch
# block_10_expand_BN/cond/FusedBatchNorm/Switch_1
# block_10_expand_BN/cond/FusedBatchNorm/Switch_2
# block_10_expand_BN/cond/FusedBatchNorm/Switch_3
# block_10_expand_BN/cond/FusedBatchNorm/Switch_4
# block_10_expand_BN/cond/Merge
# block_10_expand_relu/Relu6
# block_10_depthwise/depthwise_kernel
# block_10_depthwise/depthwise_kernel/read
# block_10_depthwise/depthwise
# block_10_depthwise_BN/gamma
# block_10_depthwise_BN/gamma/read
# block_10_depthwise_BN/beta
# block_10_depthwise_BN/beta/read
# block_10_depthwise_BN/moving_mean
# block_10_depthwise_BN/moving_mean/read
# block_10_depthwise_BN/moving_variance
# block_10_depthwise_BN/moving_variance/read
# block_10_depthwise_BN/Const_4
# block_10_depthwise_BN/Const_5
# block_10_depthwise_BN/FusedBatchNorm
# block_10_depthwise_BN/cond/pred_id
# block_10_depthwise_BN/cond/Switch_1
# block_10_depthwise_BN/cond/FusedBatchNorm
# block_10_depthwise_BN/cond/FusedBatchNorm/Switch
# block_10_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_10_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_10_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_10_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_10_depthwise_BN/cond/Merge
# block_10_depthwise_relu/Relu6
# block_10_project/kernel
# block_10_project/kernel/read
# block_10_project/convolution
# block_10_project_BN/gamma
# block_10_project_BN/gamma/read
# block_10_project_BN/beta
# block_10_project_BN/beta/read
# block_10_project_BN/moving_mean
# block_10_project_BN/moving_mean/read
# block_10_project_BN/moving_variance
# block_10_project_BN/moving_variance/read
# block_10_project_BN/Const_4
# block_10_project_BN/Const_5
# block_10_project_BN/FusedBatchNorm
# block_10_project_BN/cond/pred_id
# block_10_project_BN/cond/Switch_1
# block_10_project_BN/cond/FusedBatchNorm
# block_10_project_BN/cond/FusedBatchNorm/Switch
# block_10_project_BN/cond/FusedBatchNorm/Switch_1
# block_10_project_BN/cond/FusedBatchNorm/Switch_2
# block_10_project_BN/cond/FusedBatchNorm/Switch_3
# block_10_project_BN/cond/FusedBatchNorm/Switch_4
# block_10_project_BN/cond/Merge
# block_11_expand/kernel
# block_11_expand/kernel/read
# block_11_expand/convolution
# block_11_expand_BN/gamma
# block_11_expand_BN/gamma/read
# block_11_expand_BN/beta
# block_11_expand_BN/beta/read
# block_11_expand_BN/moving_mean
# block_11_expand_BN/moving_mean/read
# block_11_expand_BN/moving_variance
# block_11_expand_BN/moving_variance/read
# block_11_expand_BN/Const_4
# block_11_expand_BN/Const_5
# block_11_expand_BN/FusedBatchNorm
# block_11_expand_BN/cond/pred_id
# block_11_expand_BN/cond/Switch_1
# block_11_expand_BN/cond/FusedBatchNorm
# block_11_expand_BN/cond/FusedBatchNorm/Switch
# block_11_expand_BN/cond/FusedBatchNorm/Switch_1
# block_11_expand_BN/cond/FusedBatchNorm/Switch_2
# block_11_expand_BN/cond/FusedBatchNorm/Switch_3
# block_11_expand_BN/cond/FusedBatchNorm/Switch_4
# block_11_expand_BN/cond/Merge
# block_11_expand_relu/Relu6
# block_11_depthwise/depthwise_kernel
# block_11_depthwise/depthwise_kernel/read
# block_11_depthwise/depthwise
# block_11_depthwise_BN/gamma
# block_11_depthwise_BN/gamma/read
# block_11_depthwise_BN/beta
# block_11_depthwise_BN/beta/read
# block_11_depthwise_BN/moving_mean
# block_11_depthwise_BN/moving_mean/read
# block_11_depthwise_BN/moving_variance
# block_11_depthwise_BN/moving_variance/read
# block_11_depthwise_BN/Const_4
# block_11_depthwise_BN/Const_5
# block_11_depthwise_BN/FusedBatchNorm
# block_11_depthwise_BN/cond/pred_id
# block_11_depthwise_BN/cond/Switch_1
# block_11_depthwise_BN/cond/FusedBatchNorm
# block_11_depthwise_BN/cond/FusedBatchNorm/Switch
# block_11_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_11_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_11_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_11_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_11_depthwise_BN/cond/Merge
# block_11_depthwise_relu/Relu6
# block_11_project/kernel
# block_11_project/kernel/read
# block_11_project/convolution
# block_11_project_BN/gamma
# block_11_project_BN/gamma/read
# block_11_project_BN/beta
# block_11_project_BN/beta/read
# block_11_project_BN/moving_mean
# block_11_project_BN/moving_mean/read
# block_11_project_BN/moving_variance
# block_11_project_BN/moving_variance/read
# block_11_project_BN/Const_4
# block_11_project_BN/Const_5
# block_11_project_BN/FusedBatchNorm
# block_11_project_BN/cond/pred_id
# block_11_project_BN/cond/Switch_1
# block_11_project_BN/cond/FusedBatchNorm
# block_11_project_BN/cond/FusedBatchNorm/Switch
# block_11_project_BN/cond/FusedBatchNorm/Switch_1
# block_11_project_BN/cond/FusedBatchNorm/Switch_2
# block_11_project_BN/cond/FusedBatchNorm/Switch_3
# block_11_project_BN/cond/FusedBatchNorm/Switch_4
# block_11_project_BN/cond/Merge
# block_11_add/add
# block_12_expand/kernel
# block_12_expand/kernel/read
# block_12_expand/convolution
# block_12_expand_BN/gamma
# block_12_expand_BN/gamma/read
# block_12_expand_BN/beta
# block_12_expand_BN/beta/read
# block_12_expand_BN/moving_mean
# block_12_expand_BN/moving_mean/read
# block_12_expand_BN/moving_variance
# block_12_expand_BN/moving_variance/read
# block_12_expand_BN/Const_4
# block_12_expand_BN/Const_5
# block_12_expand_BN/FusedBatchNorm
# block_12_expand_BN/cond/pred_id
# block_12_expand_BN/cond/Switch_1
# block_12_expand_BN/cond/FusedBatchNorm
# block_12_expand_BN/cond/FusedBatchNorm/Switch
# block_12_expand_BN/cond/FusedBatchNorm/Switch_1
# block_12_expand_BN/cond/FusedBatchNorm/Switch_2
# block_12_expand_BN/cond/FusedBatchNorm/Switch_3
# block_12_expand_BN/cond/FusedBatchNorm/Switch_4
# block_12_expand_BN/cond/Merge
# block_12_expand_relu/Relu6
# block_12_depthwise/depthwise_kernel
# block_12_depthwise/depthwise_kernel/read
# block_12_depthwise/depthwise
# block_12_depthwise_BN/gamma
# block_12_depthwise_BN/gamma/read
# block_12_depthwise_BN/beta
# block_12_depthwise_BN/beta/read
# block_12_depthwise_BN/moving_mean
# block_12_depthwise_BN/moving_mean/read
# block_12_depthwise_BN/moving_variance
# block_12_depthwise_BN/moving_variance/read
# block_12_depthwise_BN/Const_4
# block_12_depthwise_BN/Const_5
# block_12_depthwise_BN/FusedBatchNorm
# block_12_depthwise_BN/cond/pred_id
# block_12_depthwise_BN/cond/Switch_1
# block_12_depthwise_BN/cond/FusedBatchNorm
# block_12_depthwise_BN/cond/FusedBatchNorm/Switch
# block_12_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_12_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_12_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_12_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_12_depthwise_BN/cond/Merge
# block_12_depthwise_relu/Relu6
# block_12_project/kernel
# block_12_project/kernel/read
# block_12_project/convolution
# block_12_project_BN/gamma
# block_12_project_BN/gamma/read
# block_12_project_BN/beta
# block_12_project_BN/beta/read
# block_12_project_BN/moving_mean
# block_12_project_BN/moving_mean/read
# block_12_project_BN/moving_variance
# block_12_project_BN/moving_variance/read
# block_12_project_BN/Const_4
# block_12_project_BN/Const_5
# block_12_project_BN/FusedBatchNorm
# block_12_project_BN/cond/pred_id
# block_12_project_BN/cond/Switch_1
# block_12_project_BN/cond/FusedBatchNorm
# block_12_project_BN/cond/FusedBatchNorm/Switch
# block_12_project_BN/cond/FusedBatchNorm/Switch_1
# block_12_project_BN/cond/FusedBatchNorm/Switch_2
# block_12_project_BN/cond/FusedBatchNorm/Switch_3
# block_12_project_BN/cond/FusedBatchNorm/Switch_4
# block_12_project_BN/cond/Merge
# block_12_add/add
# block_13_expand/kernel
# block_13_expand/kernel/read
# block_13_expand/convolution
# block_13_expand_BN/gamma
# block_13_expand_BN/gamma/read
# block_13_expand_BN/beta
# block_13_expand_BN/beta/read
# block_13_expand_BN/moving_mean
# block_13_expand_BN/moving_mean/read
# block_13_expand_BN/moving_variance
# block_13_expand_BN/moving_variance/read
# block_13_expand_BN/Const_4
# block_13_expand_BN/Const_5
# block_13_expand_BN/FusedBatchNorm
# block_13_expand_BN/cond/pred_id
# block_13_expand_BN/cond/Switch_1
# block_13_expand_BN/cond/FusedBatchNorm
# block_13_expand_BN/cond/FusedBatchNorm/Switch
# block_13_expand_BN/cond/FusedBatchNorm/Switch_1
# block_13_expand_BN/cond/FusedBatchNorm/Switch_2
# block_13_expand_BN/cond/FusedBatchNorm/Switch_3
# block_13_expand_BN/cond/FusedBatchNorm/Switch_4
# block_13_expand_BN/cond/Merge
# block_13_expand_relu/Relu6
# block_13_pad/Pad/paddings
# block_13_pad/Pad
# block_13_depthwise/depthwise_kernel
# block_13_depthwise/depthwise_kernel/read
# block_13_depthwise/depthwise
# block_13_depthwise_BN/gamma
# block_13_depthwise_BN/gamma/read
# block_13_depthwise_BN/beta
# block_13_depthwise_BN/beta/read
# block_13_depthwise_BN/moving_mean
# block_13_depthwise_BN/moving_mean/read
# block_13_depthwise_BN/moving_variance
# block_13_depthwise_BN/moving_variance/read
# block_13_depthwise_BN/Const_4
# block_13_depthwise_BN/Const_5
# block_13_depthwise_BN/FusedBatchNorm
# block_13_depthwise_BN/cond/pred_id
# block_13_depthwise_BN/cond/Switch_1
# block_13_depthwise_BN/cond/FusedBatchNorm
# block_13_depthwise_BN/cond/FusedBatchNorm/Switch
# block_13_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_13_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_13_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_13_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_13_depthwise_BN/cond/Merge
# block_13_depthwise_relu/Relu6
# block_13_project/kernel
# block_13_project/kernel/read
# block_13_project/convolution
# block_13_project_BN/gamma
# block_13_project_BN/gamma/read
# block_13_project_BN/beta
# block_13_project_BN/beta/read
# block_13_project_BN/moving_mean
# block_13_project_BN/moving_mean/read
# block_13_project_BN/moving_variance
# block_13_project_BN/moving_variance/read
# block_13_project_BN/Const_4
# block_13_project_BN/Const_5
# block_13_project_BN/FusedBatchNorm
# block_13_project_BN/cond/pred_id
# block_13_project_BN/cond/Switch_1
# block_13_project_BN/cond/FusedBatchNorm
# block_13_project_BN/cond/FusedBatchNorm/Switch
# block_13_project_BN/cond/FusedBatchNorm/Switch_1
# block_13_project_BN/cond/FusedBatchNorm/Switch_2
# block_13_project_BN/cond/FusedBatchNorm/Switch_3
# block_13_project_BN/cond/FusedBatchNorm/Switch_4
# block_13_project_BN/cond/Merge
# block_14_expand/kernel
# block_14_expand/kernel/read
# block_14_expand/convolution
# block_14_expand_BN/gamma
# block_14_expand_BN/gamma/read
# block_14_expand_BN/beta
# block_14_expand_BN/beta/read
# block_14_expand_BN/moving_mean
# block_14_expand_BN/moving_mean/read
# block_14_expand_BN/moving_variance
# block_14_expand_BN/moving_variance/read
# block_14_expand_BN/Const_4
# block_14_expand_BN/Const_5
# block_14_expand_BN/FusedBatchNorm
# block_14_expand_BN/cond/pred_id
# block_14_expand_BN/cond/Switch_1
# block_14_expand_BN/cond/FusedBatchNorm
# block_14_expand_BN/cond/FusedBatchNorm/Switch
# block_14_expand_BN/cond/FusedBatchNorm/Switch_1
# block_14_expand_BN/cond/FusedBatchNorm/Switch_2
# block_14_expand_BN/cond/FusedBatchNorm/Switch_3
# block_14_expand_BN/cond/FusedBatchNorm/Switch_4
# block_14_expand_BN/cond/Merge
# block_14_expand_relu/Relu6
# block_14_depthwise/depthwise_kernel
# block_14_depthwise/depthwise_kernel/read
# block_14_depthwise/depthwise
# block_14_depthwise_BN/gamma
# block_14_depthwise_BN/gamma/read
# block_14_depthwise_BN/beta
# block_14_depthwise_BN/beta/read
# block_14_depthwise_BN/moving_mean
# block_14_depthwise_BN/moving_mean/read
# block_14_depthwise_BN/moving_variance
# block_14_depthwise_BN/moving_variance/read
# block_14_depthwise_BN/Const_4
# block_14_depthwise_BN/Const_5
# block_14_depthwise_BN/FusedBatchNorm
# block_14_depthwise_BN/cond/pred_id
# block_14_depthwise_BN/cond/Switch_1
# block_14_depthwise_BN/cond/FusedBatchNorm
# block_14_depthwise_BN/cond/FusedBatchNorm/Switch
# block_14_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_14_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_14_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_14_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_14_depthwise_BN/cond/Merge
# block_14_depthwise_relu/Relu6
# block_14_project/kernel
# block_14_project/kernel/read
# block_14_project/convolution
# block_14_project_BN/gamma
# block_14_project_BN/gamma/read
# block_14_project_BN/beta
# block_14_project_BN/beta/read
# block_14_project_BN/moving_mean
# block_14_project_BN/moving_mean/read
# block_14_project_BN/moving_variance
# block_14_project_BN/moving_variance/read
# block_14_project_BN/Const_4
# block_14_project_BN/Const_5
# block_14_project_BN/FusedBatchNorm
# block_14_project_BN/cond/pred_id
# block_14_project_BN/cond/Switch_1
# block_14_project_BN/cond/FusedBatchNorm
# block_14_project_BN/cond/FusedBatchNorm/Switch
# block_14_project_BN/cond/FusedBatchNorm/Switch_1
# block_14_project_BN/cond/FusedBatchNorm/Switch_2
# block_14_project_BN/cond/FusedBatchNorm/Switch_3
# block_14_project_BN/cond/FusedBatchNorm/Switch_4
# block_14_project_BN/cond/Merge
# block_14_add/add
# block_15_expand/kernel
# block_15_expand/kernel/read
# block_15_expand/convolution
# block_15_expand_BN/gamma
# block_15_expand_BN/gamma/read
# block_15_expand_BN/beta
# block_15_expand_BN/beta/read
# block_15_expand_BN/moving_mean
# block_15_expand_BN/moving_mean/read
# block_15_expand_BN/moving_variance
# block_15_expand_BN/moving_variance/read
# block_15_expand_BN/Const_4
# block_15_expand_BN/Const_5
# block_15_expand_BN/FusedBatchNorm
# block_15_expand_BN/cond/pred_id
# block_15_expand_BN/cond/Switch_1
# block_15_expand_BN/cond/FusedBatchNorm
# block_15_expand_BN/cond/FusedBatchNorm/Switch
# block_15_expand_BN/cond/FusedBatchNorm/Switch_1
# block_15_expand_BN/cond/FusedBatchNorm/Switch_2
# block_15_expand_BN/cond/FusedBatchNorm/Switch_3
# block_15_expand_BN/cond/FusedBatchNorm/Switch_4
# block_15_expand_BN/cond/Merge
# block_15_expand_relu/Relu6
# block_15_depthwise/depthwise_kernel
# block_15_depthwise/depthwise_kernel/read
# block_15_depthwise/depthwise
# block_15_depthwise_BN/gamma
# block_15_depthwise_BN/gamma/read
# block_15_depthwise_BN/beta
# block_15_depthwise_BN/beta/read
# block_15_depthwise_BN/moving_mean
# block_15_depthwise_BN/moving_mean/read
# block_15_depthwise_BN/moving_variance
# block_15_depthwise_BN/moving_variance/read
# block_15_depthwise_BN/Const_4
# block_15_depthwise_BN/Const_5
# block_15_depthwise_BN/FusedBatchNorm
# block_15_depthwise_BN/cond/pred_id
# block_15_depthwise_BN/cond/Switch_1
# block_15_depthwise_BN/cond/FusedBatchNorm
# block_15_depthwise_BN/cond/FusedBatchNorm/Switch
# block_15_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_15_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_15_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_15_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_15_depthwise_BN/cond/Merge
# block_15_depthwise_relu/Relu6
# block_15_project/kernel
# block_15_project/kernel/read
# block_15_project/convolution
# block_15_project_BN/gamma
# block_15_project_BN/gamma/read
# block_15_project_BN/beta
# block_15_project_BN/beta/read
# block_15_project_BN/moving_mean
# block_15_project_BN/moving_mean/read
# block_15_project_BN/moving_variance
# block_15_project_BN/moving_variance/read
# block_15_project_BN/Const_4
# block_15_project_BN/Const_5
# block_15_project_BN/FusedBatchNorm
# block_15_project_BN/cond/pred_id
# block_15_project_BN/cond/Switch_1
# block_15_project_BN/cond/FusedBatchNorm
# block_15_project_BN/cond/FusedBatchNorm/Switch
# block_15_project_BN/cond/FusedBatchNorm/Switch_1
# block_15_project_BN/cond/FusedBatchNorm/Switch_2
# block_15_project_BN/cond/FusedBatchNorm/Switch_3
# block_15_project_BN/cond/FusedBatchNorm/Switch_4
# block_15_project_BN/cond/Merge
# block_15_add/add
# block_16_expand/kernel
# block_16_expand/kernel/read
# block_16_expand/convolution
# block_16_expand_BN/gamma
# block_16_expand_BN/gamma/read
# block_16_expand_BN/beta
# block_16_expand_BN/beta/read
# block_16_expand_BN/moving_mean
# block_16_expand_BN/moving_mean/read
# block_16_expand_BN/moving_variance
# block_16_expand_BN/moving_variance/read
# block_16_expand_BN/Const_4
# block_16_expand_BN/Const_5
# block_16_expand_BN/FusedBatchNorm
# block_16_expand_BN/cond/pred_id
# block_16_expand_BN/cond/Switch_1
# block_16_expand_BN/cond/FusedBatchNorm
# block_16_expand_BN/cond/FusedBatchNorm/Switch
# block_16_expand_BN/cond/FusedBatchNorm/Switch_1
# block_16_expand_BN/cond/FusedBatchNorm/Switch_2
# block_16_expand_BN/cond/FusedBatchNorm/Switch_3
# block_16_expand_BN/cond/FusedBatchNorm/Switch_4
# block_16_expand_BN/cond/Merge
# block_16_expand_relu/Relu6
# block_16_depthwise/depthwise_kernel
# block_16_depthwise/depthwise_kernel/read
# block_16_depthwise/depthwise
# block_16_depthwise_BN/gamma
# block_16_depthwise_BN/gamma/read
# block_16_depthwise_BN/beta
# block_16_depthwise_BN/beta/read
# block_16_depthwise_BN/moving_mean
# block_16_depthwise_BN/moving_mean/read
# block_16_depthwise_BN/moving_variance
# block_16_depthwise_BN/moving_variance/read
# block_16_depthwise_BN/Const_4
# block_16_depthwise_BN/Const_5
# block_16_depthwise_BN/FusedBatchNorm
# block_16_depthwise_BN/cond/pred_id
# block_16_depthwise_BN/cond/Switch_1
# block_16_depthwise_BN/cond/FusedBatchNorm
# block_16_depthwise_BN/cond/FusedBatchNorm/Switch
# block_16_depthwise_BN/cond/FusedBatchNorm/Switch_1
# block_16_depthwise_BN/cond/FusedBatchNorm/Switch_2
# block_16_depthwise_BN/cond/FusedBatchNorm/Switch_3
# block_16_depthwise_BN/cond/FusedBatchNorm/Switch_4
# block_16_depthwise_BN/cond/Merge
# block_16_depthwise_relu/Relu6
# block_16_project/kernel
# block_16_project/kernel/read
# block_16_project/convolution
# block_16_project_BN/gamma
# block_16_project_BN/gamma/read
# block_16_project_BN/beta
# block_16_project_BN/beta/read
# block_16_project_BN/moving_mean
# block_16_project_BN/moving_mean/read
# block_16_project_BN/moving_variance
# block_16_project_BN/moving_variance/read
# block_16_project_BN/Const_4
# block_16_project_BN/Const_5
# block_16_project_BN/FusedBatchNorm
# block_16_project_BN/cond/pred_id
# block_16_project_BN/cond/Switch_1
# block_16_project_BN/cond/FusedBatchNorm
# block_16_project_BN/cond/FusedBatchNorm/Switch
# block_16_project_BN/cond/FusedBatchNorm/Switch_1
# block_16_project_BN/cond/FusedBatchNorm/Switch_2
# block_16_project_BN/cond/FusedBatchNorm/Switch_3
# block_16_project_BN/cond/FusedBatchNorm/Switch_4
# block_16_project_BN/cond/Merge
# Conv_1/kernel
# Conv_1/kernel/read
# Conv_1/convolution
# Conv_1_bn/gamma
# Conv_1_bn/gamma/read
# Conv_1_bn/beta
# Conv_1_bn/beta/read
# Conv_1_bn/moving_mean
# Conv_1_bn/moving_mean/read
# Conv_1_bn/moving_variance
# Conv_1_bn/moving_variance/read
# Conv_1_bn/Const_4
# Conv_1_bn/Const_5
# Conv_1_bn/FusedBatchNorm
# Conv_1_bn/cond/pred_id
# Conv_1_bn/cond/Switch_1
# Conv_1_bn/cond/FusedBatchNorm
# Conv_1_bn/cond/FusedBatchNorm/Switch
# Conv_1_bn/cond/FusedBatchNorm/Switch_1
# Conv_1_bn/cond/FusedBatchNorm/Switch_2
# Conv_1_bn/cond/FusedBatchNorm/Switch_3
# Conv_1_bn/cond/FusedBatchNorm/Switch_4
# Conv_1_bn/cond/Merge
# out_relu/Relu6
# lambda_1/ResizeBilinear/size
# lambda_1/ResizeBilinear
# concatenate_1/concat/axis
# concatenate_1/concat
# decoder_stage0_1_depthwise/depthwise_kernel
# decoder_stage0_1_depthwise/depthwise_kernel/read
# decoder_stage0_1_depthwise/depthwise
# decoder_stage0_1_depthwise_BN/gamma
# decoder_stage0_1_depthwise_BN/gamma/read
# decoder_stage0_1_depthwise_BN/beta
# decoder_stage0_1_depthwise_BN/beta/read
# decoder_stage0_1_depthwise_BN/moving_mean
# decoder_stage0_1_depthwise_BN/moving_mean/read
# decoder_stage0_1_depthwise_BN/moving_variance
# decoder_stage0_1_depthwise_BN/moving_variance/read
# decoder_stage0_1_depthwise_BN/Const_4
# decoder_stage0_1_depthwise_BN/Const_5
# decoder_stage0_1_depthwise_BN/FusedBatchNorm
# decoder_stage0_1_depthwise_BN/cond/pred_id
# decoder_stage0_1_depthwise_BN/cond/Switch_1
# decoder_stage0_1_depthwise_BN/cond/FusedBatchNorm
# decoder_stage0_1_depthwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage0_1_depthwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage0_1_depthwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage0_1_depthwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage0_1_depthwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage0_1_depthwise_BN/cond/Merge
# activation_1/Relu
# decoder_stage0_1_pointwise/kernel
# decoder_stage0_1_pointwise/kernel/read
# decoder_stage0_1_pointwise/convolution
# decoder_stage0_1_pointwise_BN/gamma
# decoder_stage0_1_pointwise_BN/gamma/read
# decoder_stage0_1_pointwise_BN/beta
# decoder_stage0_1_pointwise_BN/beta/read
# decoder_stage0_1_pointwise_BN/moving_mean
# decoder_stage0_1_pointwise_BN/moving_mean/read
# decoder_stage0_1_pointwise_BN/moving_variance
# decoder_stage0_1_pointwise_BN/moving_variance/read
# decoder_stage0_1_pointwise_BN/Const_4
# decoder_stage0_1_pointwise_BN/Const_5
# decoder_stage0_1_pointwise_BN/FusedBatchNorm
# decoder_stage0_1_pointwise_BN/cond/pred_id
# decoder_stage0_1_pointwise_BN/cond/Switch_1
# decoder_stage0_1_pointwise_BN/cond/FusedBatchNorm
# decoder_stage0_1_pointwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage0_1_pointwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage0_1_pointwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage0_1_pointwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage0_1_pointwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage0_1_pointwise_BN/cond/Merge
# activation_2/Relu
# decoder_stage0_2_depthwise/depthwise_kernel
# decoder_stage0_2_depthwise/depthwise_kernel/read
# decoder_stage0_2_depthwise/depthwise
# decoder_stage0_2_depthwise_BN/gamma
# decoder_stage0_2_depthwise_BN/gamma/read
# decoder_stage0_2_depthwise_BN/beta
# decoder_stage0_2_depthwise_BN/beta/read
# decoder_stage0_2_depthwise_BN/moving_mean
# decoder_stage0_2_depthwise_BN/moving_mean/read
# decoder_stage0_2_depthwise_BN/moving_variance
# decoder_stage0_2_depthwise_BN/moving_variance/read
# decoder_stage0_2_depthwise_BN/Const_4
# decoder_stage0_2_depthwise_BN/Const_5
# decoder_stage0_2_depthwise_BN/FusedBatchNorm
# decoder_stage0_2_depthwise_BN/cond/pred_id
# decoder_stage0_2_depthwise_BN/cond/Switch_1
# decoder_stage0_2_depthwise_BN/cond/FusedBatchNorm
# decoder_stage0_2_depthwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage0_2_depthwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage0_2_depthwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage0_2_depthwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage0_2_depthwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage0_2_depthwise_BN/cond/Merge
# activation_3/Relu
# decoder_stage0_2_pointwise/kernel
# decoder_stage0_2_pointwise/kernel/read
# decoder_stage0_2_pointwise/convolution
# decoder_stage0_2_pointwise_BN/gamma
# decoder_stage0_2_pointwise_BN/gamma/read
# decoder_stage0_2_pointwise_BN/beta
# decoder_stage0_2_pointwise_BN/beta/read
# decoder_stage0_2_pointwise_BN/moving_mean
# decoder_stage0_2_pointwise_BN/moving_mean/read
# decoder_stage0_2_pointwise_BN/moving_variance
# decoder_stage0_2_pointwise_BN/moving_variance/read
# decoder_stage0_2_pointwise_BN/Const_4
# decoder_stage0_2_pointwise_BN/Const_5
# decoder_stage0_2_pointwise_BN/FusedBatchNorm
# decoder_stage0_2_pointwise_BN/cond/pred_id
# decoder_stage0_2_pointwise_BN/cond/Switch_1
# decoder_stage0_2_pointwise_BN/cond/FusedBatchNorm
# decoder_stage0_2_pointwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage0_2_pointwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage0_2_pointwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage0_2_pointwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage0_2_pointwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage0_2_pointwise_BN/cond/Merge
# activation_4/Relu
# lambda_2/ResizeBilinear/size
# lambda_2/ResizeBilinear
# concatenate_2/concat/axis
# concatenate_2/concat
# decoder_stage1_1_depthwise/depthwise_kernel
# ...
# decoder_stage2_2_pointwise_BN/beta
# decoder_stage2_2_pointwise_BN/beta/read
# decoder_stage2_2_pointwise_BN/moving_mean
# decoder_stage2_2_pointwise_BN/moving_mean/read
# decoder_stage2_2_pointwise_BN/moving_variance
# decoder_stage2_2_pointwise_BN/moving_variance/read
# decoder_stage2_2_pointwise_BN/Const_4
# decoder_stage2_2_pointwise_BN/Const_5
# decoder_stage2_2_pointwise_BN/FusedBatchNorm
# decoder_stage2_2_pointwise_BN/cond/pred_id
# decoder_stage2_2_pointwise_BN/cond/Switch_1
# decoder_stage2_2_pointwise_BN/cond/FusedBatchNorm
# decoder_stage2_2_pointwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage2_2_pointwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage2_2_pointwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage2_2_pointwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage2_2_pointwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage2_2_pointwise_BN/cond/Merge
# activation_12/Relu
# lambda_4/ResizeBilinear/size
# lambda_4/ResizeBilinear
# concatenate_4/concat/axis
# concatenate_4/concat
# decoder_stage3_1_depthwise/depthwise_kernel
# decoder_stage3_1_depthwise/depthwise_kernel/read
# decoder_stage3_1_depthwise/depthwise
# decoder_stage3_1_depthwise_BN/gamma
# decoder_stage3_1_depthwise_BN/gamma/read
# decoder_stage3_1_depthwise_BN/beta
# decoder_stage3_1_depthwise_BN/beta/read
# decoder_stage3_1_depthwise_BN/moving_mean
# decoder_stage3_1_depthwise_BN/moving_mean/read
# decoder_stage3_1_depthwise_BN/moving_variance
# decoder_stage3_1_depthwise_BN/moving_variance/read
# decoder_stage3_1_depthwise_BN/Const_4
# decoder_stage3_1_depthwise_BN/Const_5
# decoder_stage3_1_depthwise_BN/FusedBatchNorm
# decoder_stage3_1_depthwise_BN/cond/pred_id
# decoder_stage3_1_depthwise_BN/cond/Switch_1
# decoder_stage3_1_depthwise_BN/cond/FusedBatchNorm
# decoder_stage3_1_depthwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage3_1_depthwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage3_1_depthwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage3_1_depthwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage3_1_depthwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage3_1_depthwise_BN/cond/Merge
# activation_13/Relu
# decoder_stage3_1_pointwise/kernel
# decoder_stage3_1_pointwise/kernel/read
# decoder_stage3_1_pointwise/convolution
# decoder_stage3_1_pointwise_BN/gamma
# decoder_stage3_1_pointwise_BN/gamma/read
# decoder_stage3_1_pointwise_BN/beta
# decoder_stage3_1_pointwise_BN/beta/read
# decoder_stage3_1_pointwise_BN/moving_mean
# decoder_stage3_1_pointwise_BN/moving_mean/read
# decoder_stage3_1_pointwise_BN/moving_variance
# decoder_stage3_1_pointwise_BN/moving_variance/read
# decoder_stage3_1_pointwise_BN/Const_4
# decoder_stage3_1_pointwise_BN/Const_5
# decoder_stage3_1_pointwise_BN/FusedBatchNorm
# decoder_stage3_1_pointwise_BN/cond/pred_id
# decoder_stage3_1_pointwise_BN/cond/Switch_1
# decoder_stage3_1_pointwise_BN/cond/FusedBatchNorm
# decoder_stage3_1_pointwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage3_1_pointwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage3_1_pointwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage3_1_pointwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage3_1_pointwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage3_1_pointwise_BN/cond/Merge
# activation_14/Relu
# decoder_stage3_2_depthwise/depthwise_kernel
# decoder_stage3_2_depthwise/depthwise_kernel/read
# decoder_stage3_2_depthwise/depthwise
# decoder_stage3_2_depthwise_BN/gamma
# decoder_stage3_2_depthwise_BN/gamma/read
# decoder_stage3_2_depthwise_BN/beta
# decoder_stage3_2_depthwise_BN/beta/read
# decoder_stage3_2_depthwise_BN/moving_mean
# decoder_stage3_2_depthwise_BN/moving_mean/read
# decoder_stage3_2_depthwise_BN/moving_variance
# decoder_stage3_2_depthwise_BN/moving_variance/read
# decoder_stage3_2_depthwise_BN/Const_4
# decoder_stage3_2_depthwise_BN/Const_5
# decoder_stage3_2_depthwise_BN/FusedBatchNorm
# decoder_stage3_2_depthwise_BN/cond/pred_id
# decoder_stage3_2_depthwise_BN/cond/Switch_1
# decoder_stage3_2_depthwise_BN/cond/FusedBatchNorm
# decoder_stage3_2_depthwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage3_2_depthwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage3_2_depthwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage3_2_depthwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage3_2_depthwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage3_2_depthwise_BN/cond/Merge
# activation_15/Relu
# decoder_stage3_2_pointwise/kernel
# decoder_stage3_2_pointwise/kernel/read
# decoder_stage3_2_pointwise/convolution
# decoder_stage3_2_pointwise_BN/gamma
# decoder_stage3_2_pointwise_BN/gamma/read
# decoder_stage3_2_pointwise_BN/beta
# decoder_stage3_2_pointwise_BN/beta/read
# decoder_stage3_2_pointwise_BN/moving_mean
# decoder_stage3_2_pointwise_BN/moving_mean/read
# decoder_stage3_2_pointwise_BN/moving_variance
# decoder_stage3_2_pointwise_BN/moving_variance/read
# decoder_stage3_2_pointwise_BN/Const_4
# decoder_stage3_2_pointwise_BN/Const_5
# decoder_stage3_2_pointwise_BN/FusedBatchNorm
# decoder_stage3_2_pointwise_BN/cond/pred_id
# decoder_stage3_2_pointwise_BN/cond/Switch_1
# decoder_stage3_2_pointwise_BN/cond/FusedBatchNorm
# decoder_stage3_2_pointwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage3_2_pointwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage3_2_pointwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage3_2_pointwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage3_2_pointwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage3_2_pointwise_BN/cond/Merge
# activation_16/Relu
# lambda_5/ResizeBilinear/size
# lambda_5/ResizeBilinear
# decoder_stage4_1_depthwise/depthwise_kernel
# decoder_stage4_1_depthwise/depthwise_kernel/read
# decoder_stage4_1_depthwise/depthwise
# decoder_stage4_1_depthwise_BN/gamma
# decoder_stage4_1_depthwise_BN/gamma/read
# decoder_stage4_1_depthwise_BN/beta
# decoder_stage4_1_depthwise_BN/beta/read
# decoder_stage4_1_depthwise_BN/moving_mean
# decoder_stage4_1_depthwise_BN/moving_mean/read
# decoder_stage4_1_depthwise_BN/moving_variance
# decoder_stage4_1_depthwise_BN/moving_variance/read
# decoder_stage4_1_depthwise_BN/Const_4
# decoder_stage4_1_depthwise_BN/Const_5
# decoder_stage4_1_depthwise_BN/FusedBatchNorm
# decoder_stage4_1_depthwise_BN/cond/pred_id
# decoder_stage4_1_depthwise_BN/cond/Switch_1
# decoder_stage4_1_depthwise_BN/cond/FusedBatchNorm
# decoder_stage4_1_depthwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage4_1_depthwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage4_1_depthwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage4_1_depthwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage4_1_depthwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage4_1_depthwise_BN/cond/Merge
# activation_17/Relu
# decoder_stage4_1_pointwise/kernel
# decoder_stage4_1_pointwise/kernel/read
# decoder_stage4_1_pointwise/convolution
# decoder_stage4_1_pointwise_BN/gamma
# decoder_stage4_1_pointwise_BN/gamma/read
# decoder_stage4_1_pointwise_BN/beta
# decoder_stage4_1_pointwise_BN/beta/read
# decoder_stage4_1_pointwise_BN/moving_mean
# decoder_stage4_1_pointwise_BN/moving_mean/read
# decoder_stage4_1_pointwise_BN/moving_variance
# decoder_stage4_1_pointwise_BN/moving_variance/read
# decoder_stage4_1_pointwise_BN/Const_4
# decoder_stage4_1_pointwise_BN/Const_5
# decoder_stage4_1_pointwise_BN/FusedBatchNorm
# decoder_stage4_1_pointwise_BN/cond/pred_id
# decoder_stage4_1_pointwise_BN/cond/Switch_1
# decoder_stage4_1_pointwise_BN/cond/FusedBatchNorm
# decoder_stage4_1_pointwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage4_1_pointwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage4_1_pointwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage4_1_pointwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage4_1_pointwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage4_1_pointwise_BN/cond/Merge
# activation_18/Relu
# decoder_stage4_2_depthwise/depthwise_kernel
# decoder_stage4_2_depthwise/depthwise_kernel/read
# decoder_stage4_2_depthwise/depthwise
# decoder_stage4_2_depthwise_BN/gamma
# decoder_stage4_2_depthwise_BN/gamma/read
# decoder_stage4_2_depthwise_BN/beta
# decoder_stage4_2_depthwise_BN/beta/read
# decoder_stage4_2_depthwise_BN/moving_mean
# decoder_stage4_2_depthwise_BN/moving_mean/read
# decoder_stage4_2_depthwise_BN/moving_variance
# decoder_stage4_2_depthwise_BN/moving_variance/read
# decoder_stage4_2_depthwise_BN/Const_4
# decoder_stage4_2_depthwise_BN/Const_5
# decoder_stage4_2_depthwise_BN/FusedBatchNorm
# decoder_stage4_2_depthwise_BN/cond/pred_id
# decoder_stage4_2_depthwise_BN/cond/Switch_1
# decoder_stage4_2_depthwise_BN/cond/FusedBatchNorm
# decoder_stage4_2_depthwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage4_2_depthwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage4_2_depthwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage4_2_depthwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage4_2_depthwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage4_2_depthwise_BN/cond/Merge
# activation_19/Relu
# decoder_stage4_2_pointwise/kernel
# decoder_stage4_2_pointwise/kernel/read
# decoder_stage4_2_pointwise/convolution
# decoder_stage4_2_pointwise_BN/gamma
# decoder_stage4_2_pointwise_BN/gamma/read
# decoder_stage4_2_pointwise_BN/beta
# decoder_stage4_2_pointwise_BN/beta/read
# decoder_stage4_2_pointwise_BN/moving_mean
# decoder_stage4_2_pointwise_BN/moving_mean/read
# decoder_stage4_2_pointwise_BN/moving_variance
# decoder_stage4_2_pointwise_BN/moving_variance/read
# decoder_stage4_2_pointwise_BN/Const_4
# decoder_stage4_2_pointwise_BN/Const_5
# decoder_stage4_2_pointwise_BN/FusedBatchNorm
# decoder_stage4_2_pointwise_BN/cond/pred_id
# decoder_stage4_2_pointwise_BN/cond/Switch_1
# decoder_stage4_2_pointwise_BN/cond/FusedBatchNorm
# decoder_stage4_2_pointwise_BN/cond/FusedBatchNorm/Switch
# decoder_stage4_2_pointwise_BN/cond/FusedBatchNorm/Switch_1
# decoder_stage4_2_pointwise_BN/cond/FusedBatchNorm/Switch_2
# decoder_stage4_2_pointwise_BN/cond/FusedBatchNorm/Switch_3
# decoder_stage4_2_pointwise_BN/cond/FusedBatchNorm/Switch_4
# decoder_stage4_2_pointwise_BN/cond/Merge
# activation_20/Relu
# densenet_matt1_depthwise/depthwise_kernel
# densenet_matt1_depthwise/depthwise_kernel/read
# densenet_matt1_depthwise/depthwise
# densenet_matt1_depthwise_BN/gamma
# densenet_matt1_depthwise_BN/gamma/read
# densenet_matt1_depthwise_BN/beta
# densenet_matt1_depthwise_BN/beta/read
# densenet_matt1_depthwise_BN/moving_mean
# densenet_matt1_depthwise_BN/moving_mean/read
# densenet_matt1_depthwise_BN/moving_variance
# densenet_matt1_depthwise_BN/moving_variance/read
# densenet_matt1_depthwise_BN/Const_4
# densenet_matt1_depthwise_BN/Const_5
# densenet_matt1_depthwise_BN/FusedBatchNorm
# densenet_matt1_depthwise_BN/cond/pred_id
# densenet_matt1_depthwise_BN/cond/Switch_1
# densenet_matt1_depthwise_BN/cond/FusedBatchNorm
# densenet_matt1_depthwise_BN/cond/FusedBatchNorm/Switch
# densenet_matt1_depthwise_BN/cond/FusedBatchNorm/Switch_1
# densenet_matt1_depthwise_BN/cond/FusedBatchNorm/Switch_2
# densenet_matt1_depthwise_BN/cond/FusedBatchNorm/Switch_3
# densenet_matt1_depthwise_BN/cond/FusedBatchNorm/Switch_4
# densenet_matt1_depthwise_BN/cond/Merge
# activation_21/Relu
# densenet_matt1_pointwise/kernel
# densenet_matt1_pointwise/kernel/read
# densenet_matt1_pointwise/convolution
# densenet_matt1_pointwise_BN/gamma
# densenet_matt1_pointwise_BN/gamma/read
# densenet_matt1_pointwise_BN/beta
# densenet_matt1_pointwise_BN/beta/read
# densenet_matt1_pointwise_BN/moving_mean
# densenet_matt1_pointwise_BN/moving_mean/read
# densenet_matt1_pointwise_BN/moving_variance
# densenet_matt1_pointwise_BN/moving_variance/read
# densenet_matt1_pointwise_BN/Const_4
# densenet_matt1_pointwise_BN/Const_5
# densenet_matt1_pointwise_BN/FusedBatchNorm
# densenet_matt1_pointwise_BN/cond/pred_id
# densenet_matt1_pointwise_BN/cond/Switch_1
# densenet_matt1_pointwise_BN/cond/FusedBatchNorm
# densenet_matt1_pointwise_BN/cond/FusedBatchNorm/Switch
# densenet_matt1_pointwise_BN/cond/FusedBatchNorm/Switch_1
# densenet_matt1_pointwise_BN/cond/FusedBatchNorm/Switch_2
# densenet_matt1_pointwise_BN/cond/FusedBatchNorm/Switch_3
# densenet_matt1_pointwise_BN/cond/FusedBatchNorm/Switch_4
# densenet_matt1_pointwise_BN/cond/Merge
# activation_22/Relu
# densenet_matt2_depthwise/depthwise_kernel
# densenet_matt2_depthwise/depthwise_kernel/read
# densenet_matt2_depthwise/depthwise
# densenet_matt2_depthwise_BN/gamma
# densenet_matt2_depthwise_BN/gamma/read
# densenet_matt2_depthwise_BN/beta
# densenet_matt2_depthwise_BN/beta/read
# densenet_matt2_depthwise_BN/moving_mean
# densenet_matt2_depthwise_BN/moving_mean/read
# densenet_matt2_depthwise_BN/moving_variance
# densenet_matt2_depthwise_BN/moving_variance/read
# densenet_matt2_depthwise_BN/Const_4
# densenet_matt2_depthwise_BN/Const_5
# densenet_matt2_depthwise_BN/FusedBatchNorm
# densenet_matt2_depthwise_BN/cond/pred_id
# densenet_matt2_depthwise_BN/cond/Switch_1
# densenet_matt2_depthwise_BN/cond/FusedBatchNorm
# densenet_matt2_depthwise_BN/cond/FusedBatchNorm/Switch
# densenet_matt2_depthwise_BN/cond/FusedBatchNorm/Switch_1
# densenet_matt2_depthwise_BN/cond/FusedBatchNorm/Switch_2
# densenet_matt2_depthwise_BN/cond/FusedBatchNorm/Switch_3
# densenet_matt2_depthwise_BN/cond/FusedBatchNorm/Switch_4
# densenet_matt2_depthwise_BN/cond/Merge
# activation_23/Relu
# densenet_matt2_pointwise/kernel
# densenet_matt2_pointwise/kernel/read
# densenet_matt2_pointwise/convolution
# densenet_matt2_pointwise_BN/gamma
# densenet_matt2_pointwise_BN/gamma/read
# densenet_matt2_pointwise_BN/beta
# densenet_matt2_pointwise_BN/beta/read
# densenet_matt2_pointwise_BN/moving_mean
# densenet_matt2_pointwise_BN/moving_mean/read
# densenet_matt2_pointwise_BN/moving_variance
# densenet_matt2_pointwise_BN/moving_variance/read
# densenet_matt2_pointwise_BN/Const_4
# densenet_matt2_pointwise_BN/Const_5
# densenet_matt2_pointwise_BN/FusedBatchNorm
# densenet_matt2_pointwise_BN/cond/pred_id
# densenet_matt2_pointwise_BN/cond/Switch_1
# densenet_matt2_pointwise_BN/cond/FusedBatchNorm
# densenet_matt2_pointwise_BN/cond/FusedBatchNorm/Switch
# densenet_matt2_pointwise_BN/cond/FusedBatchNorm/Switch_1
# densenet_matt2_pointwise_BN/cond/FusedBatchNorm/Switch_2
# densenet_matt2_pointwise_BN/cond/FusedBatchNorm/Switch_3
# densenet_matt2_pointwise_BN/cond/FusedBatchNorm/Switch_4
# densenet_matt2_pointwise_BN/cond/Merge
# activation_24/Relu
# densenet_matt3_depthwise/depthwise_kernel
# densenet_matt3_depthwise/depthwise_kernel/read
# densenet_matt3_depthwise/depthwise
# densenet_matt3_depthwise_BN/gamma
# densenet_matt3_depthwise_BN/gamma/read
# densenet_matt3_depthwise_BN/beta
# densenet_matt3_depthwise_BN/beta/read
# densenet_matt3_depthwise_BN/moving_mean
# densenet_matt3_depthwise_BN/moving_mean/read
# densenet_matt3_depthwise_BN/moving_variance
# densenet_matt3_depthwise_BN/moving_variance/read
# densenet_matt3_depthwise_BN/Const_4
# densenet_matt3_depthwise_BN/Const_5
# densenet_matt3_depthwise_BN/FusedBatchNorm
# densenet_matt3_depthwise_BN/cond/pred_id
# densenet_matt3_depthwise_BN/cond/Switch_1
# densenet_matt3_depthwise_BN/cond/FusedBatchNorm
# densenet_matt3_depthwise_BN/cond/FusedBatchNorm/Switch
# densenet_matt3_depthwise_BN/cond/FusedBatchNorm/Switch_1
# densenet_matt3_depthwise_BN/cond/FusedBatchNorm/Switch_2
# densenet_matt3_depthwise_BN/cond/FusedBatchNorm/Switch_3
# densenet_matt3_depthwise_BN/cond/FusedBatchNorm/Switch_4
# densenet_matt3_depthwise_BN/cond/Merge
# activation_25/Relu
# densenet_matt3_pointwise/kernel
# densenet_matt3_pointwise/kernel/read
# densenet_matt3_pointwise/convolution
# densenet_matt3_pointwise_BN/gamma
# densenet_matt3_pointwise_BN/gamma/read
# densenet_matt3_pointwise_BN/beta
# densenet_matt3_pointwise_BN/beta/read
# densenet_matt3_pointwise_BN/moving_mean
# densenet_matt3_pointwise_BN/moving_mean/read
# densenet_matt3_pointwise_BN/moving_variance
# densenet_matt3_pointwise_BN/moving_variance/read
# densenet_matt3_pointwise_BN/Const_4
# densenet_matt3_pointwise_BN/Const_5
# densenet_matt3_pointwise_BN/FusedBatchNorm
# densenet_matt3_pointwise_BN/cond/pred_id
# densenet_matt3_pointwise_BN/cond/Switch_1
# densenet_matt3_pointwise_BN/cond/FusedBatchNorm
# densenet_matt3_pointwise_BN/cond/FusedBatchNorm/Switch
# densenet_matt3_pointwise_BN/cond/FusedBatchNorm/Switch_1
# densenet_matt3_pointwise_BN/cond/FusedBatchNorm/Switch_2
# densenet_matt3_pointwise_BN/cond/FusedBatchNorm/Switch_3
# densenet_matt3_pointwise_BN/cond/FusedBatchNorm/Switch_4
# densenet_matt3_pointwise_BN/cond/Merge
# activation_26/Relu
# final_conv/depthwise_kernel
# final_conv/depthwise_kernel/read
# final_conv/pointwise_kernel
# final_conv/pointwise_kernel/read
# final_conv/bias
# final_conv/bias/read
# final_conv/separable_conv2d/depthwise
# final_conv/separable_conv2d
# final_conv/BiasAdd
# sigmoid/Sigmoid

# %%
opt_graphDef = optimize_for_inference(const_graphDef,
                                   input_node_names,
                                   output_node_names,
                                   tf.float32.as_datatype_enum,
                                   toco_compatible=True)
tf.train.write_graph(opt_graphDef, MODEL_PATH, pb_op_filename, as_text=False)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node bn_Conv1/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node bn_Conv1/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'bn_Conv1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'bn_Conv1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (16,), for node expanded_conv_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (16,), for node expanded_conv_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (96,), for node block_1_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (96,), for node block_1_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (24,), for node block_1_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (24,), for node block_1_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (144,), for node block_2_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (144,), for node block_2_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (24,), for node block_2_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (24,), for node block_2_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (144,), for node block_3_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (144,), for node block_3_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node block_3_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node block_3_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (192,), for node block_4_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (192,), for node block_4_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node block_4_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node block_4_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (192,), for node block_5_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (192,), for node block_5_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node block_5_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node block_5_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (192,), for node block_6_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (192,), for node block_6_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node block_6_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node block_6_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (384,), for node block_7_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (384,), for node block_7_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node block_7_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node block_7_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (384,), for node block_8_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (384,), for node block_8_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node block_8_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node block_8_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (384,), for node block_9_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (384,), for node block_9_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node block_9_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node block_9_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (384,), for node block_10_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (384,), for node block_10_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (96,), for node block_10_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (96,), for node block_10_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (576,), for node block_11_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (576,), for node block_11_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (96,), for node block_11_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (96,), for node block_11_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (576,), for node block_12_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (576,), for node block_12_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (96,), for node block_12_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (96,), for node block_12_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (576,), for node block_13_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (576,), for node block_13_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (160,), for node block_13_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (160,), for node block_13_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (960,), for node block_14_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (960,), for node block_14_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (160,), for node block_14_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (160,), for node block_14_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (960,), for node block_15_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (960,), for node block_15_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (160,), for node block_15_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (160,), for node block_15_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (960,), for node block_16_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (960,), for node block_16_expand_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (320,), for node block_16_project_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (320,), for node block_16_project_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (1280,), for node Conv_1_bn/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (1280,), for node Conv_1_bn/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'Conv_1_bn/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'Conv_1_bn/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (256,), for node decoder_stage0_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (256,), for node decoder_stage0_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (256,), for node decoder_stage0_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (256,), for node decoder_stage0_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node decoder_stage1_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node decoder_stage1_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node decoder_stage1_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node decoder_stage1_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node decoder_stage2_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node decoder_stage2_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node decoder_stage2_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (64,), for node decoder_stage2_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node decoder_stage3_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node decoder_stage3_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node decoder_stage3_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (32,), for node decoder_stage3_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (16,), for node decoder_stage4_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (16,), for node decoder_stage4_1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (16,), for node decoder_stage4_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (16,), for node decoder_stage4_2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node densenet_matt1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node densenet_matt1_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt1_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node densenet_matt2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node densenet_matt2_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt2_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt3_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt3_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt3_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt3_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node densenet_matt3_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Incorrect shape for mean, found (0,), expected (128,), for node densenet_matt3_pointwise_BN/FusedBatchNorm
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt3_pointwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'densenet_matt3_pointwise_BN/cond/FusedBatchNorm'
# '../results/Models/GraphModels/mobilenetv2_GUnet_MSE_ACC_IOU_divide_1_sigmoid_256_train_matte_op.pb'

# %% [markdown]
# ### keras to .tflite

# %%
tf.keras.losses.custom_loss = sm.losses.bce_dice_loss

# %%
'''converter = tf.lite.TFLiteConverter.from_keras_model_file(os.path.join(MODEL_PATH_,keras_filename))
converter.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
                        tf.lite.OpsSet.SELECT_TF_OPS]
tflite_model = converter.convert()
with open(os.path.join(MODEL_PATH,tflite_filename), "wb") as f:
    f.write(tflite_model)'''
# Out:
# 'converter = tf.lite.TFLiteConverter.from_keras_model_file(os.path.join(MODEL_PATH_,keras_filename))\nconverter.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,\n                        tf.lite.OpsSet.SELECT_TF_OPS]\ntflite_model = converter.convert()\nwith open(os.path.join(MODEL_PATH,tflite_filename), "wb") as f:\n    f.write(tflite_model)'

# %%
'''converter_Q = tf.lite.TFLiteConverter.from_keras_model_file(os.path.join(MODEL_PATH_,keras_filename))
converter_Q.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
                        tf.lite.OpsSet.SELECT_TF_OPS]
converter_Q.post_training_quantize=True
tflite_Q_model = converter_Q.convert()
with open(os.path.join(MODEL_PATH,tflite_Q_filename), "wb") as f:
    f.write(tflite_Q_model)'''
# Out:
# 'converter_Q = tf.lite.TFLiteConverter.from_keras_model_file(os.path.join(MODEL_PATH_,keras_filename))\nconverter_Q.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,\n                        tf.lite.OpsSet.SELECT_TF_OPS]\nconverter_Q.post_training_quantize=True\ntflite_Q_model = converter_Q.convert()\nwith open(os.path.join(MODEL_PATH,tflite_Q_filename), "wb") as f:\n    f.write(tflite_Q_model)'

# %%
# Converting a tf.keras model.
converter = tf.lite.TFLiteConverter.from_session(K.get_session(), model.inputs, model.outputs)
converter.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
                        tf.lite.OpsSet.SELECT_TF_OPS]
tflite_model = converter.convert()
with open(os.path.join(MODEL_PATH,tflite_filename), "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Froze 393 variables.
# INFO:tensorflow:Froze 393 variables.
# INFO:tensorflow:Converted 393 variables to const ops.
# INFO:tensorflow:Converted 393 variables to const ops.

# %%
# Converting a tf.keras model.
converter_Q = tf.lite.TFLiteConverter.from_session(K.get_session(), model.inputs, model.outputs)
converter_Q.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,
                        tf.lite.OpsSet.SELECT_TF_OPS]
converter_Q.post_training_quantize=True
tflite_Q_model = converter_Q.convert()
with open(os.path.join(MODEL_PATH,tflite_Q_filename), "wb") as f:
    f.write(tflite_Q_model)
# Out:
# INFO:tensorflow:Froze 393 variables.
# INFO:tensorflow:Froze 393 variables.
# INFO:tensorflow:Converted 393 variables to const ops.
# INFO:tensorflow:Converted 393 variables to const ops.

# %% [markdown]
# ### keras to .mlmodel

# %%
coremltools.models.neural_network.NeuralNetworkBuilder.add_resize_bilinear()

# %%
def convert_lambda(layer):
    from coremltools.proto import NeuralNetwork_pb2
    params = NeuralNetwork_pb2.CustomLayerParams()
    # The name of the Swift or Obj-C class that implements this layer.
    params.className = "resize_bilinear"
    # The desciption is shown in Xcode's mlmodel viewer.
    params.description = "A resize function"
    return params

coreml_model = coremltools.converters.keras.convert(model,
                                                    input_names=input_node_names,
                                                    image_input_names=input_node_names,
                                                    output_names=output_node_names,
                                                    image_scale=1/255.0,
                                                    add_custom_layers=True,
                                                    custom_conversion_functions={ "Lambda": convert_lambda }
                                                   )
# Out:
# 0 : input_1, <keras.engine.input_layer.InputLayer object at 0x7f1ad8406748>
# 1 : Conv1_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7f1a25d759b0>
# 2 : Conv1, <keras.layers.convolutional.Conv2D object at 0x7f1a25d75a58>
# 3 : bn_Conv1, <keras.layers.normalization.BatchNormalization object at 0x7f1a25528278>
# 4 : Conv1_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a25528940>
# 5 : expanded_conv_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a255285c0>
# 6 : expanded_conv_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a244b5668>
# 7 : expanded_conv_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a254f84e0>
# 8 : expanded_conv_project, <keras.layers.convolutional.Conv2D object at 0x7f1a243dadd8>
# 9 : expanded_conv_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a244b5a58>
# 10 : block_1_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a243aca58>
# 11 : block_1_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a24259710>
# 12 : block_1_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a24270be0>
# 13 : block_1_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7f1a24214a20>
# 14 : block_1_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a242149e8>
# 15 : block_1_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a2416af60>
# 16 : block_1_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a2416a828>
# 17 : block_1_project, <keras.layers.convolutional.Conv2D object at 0x7f1a2424e828>
# 18 : block_1_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a240fbcc0>
# 19 : block_2_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a2405eb38>
# 20 : block_2_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a24041cf8>
# 21 : block_2_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a1c744550>
# 22 : block_2_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a1c7740b8>
# 23 : block_2_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a1c774dd8>
# 24 : block_2_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a1c641fd0>
# 25 : block_2_project, <keras.layers.convolutional.Conv2D object at 0x7f1a1c66ccf8>
# 26 : block_2_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a1c5d34a8>
# 27 : block_2_add, <keras.layers.merge.Add object at 0x7f1a1c543eb8>
# 28 : block_3_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a1c500ba8>
# 29 : block_3_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a1c4f89e8>
# 30 : block_3_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a1c45aac8>
# 31 : block_3_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7f1a1c5112b0>
# 32 : block_3_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a1c476f60>
# 33 : block_3_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a1c339e48>
# 34 : block_3_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a1c3394e0>
# 35 : block_3_project, <keras.layers.convolutional.Conv2D object at 0x7f1a1c322f28>
# 36 : block_3_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a1c2c4048>
# 37 : block_4_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a1c24e940>
# 38 : block_4_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a1c1fccf8>
# 39 : block_4_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a1c1bb780>
# 40 : block_4_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a1c149710>
# 41 : block_4_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a1c11b4a8>
# 42 : block_4_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a1c080c18>
# 43 : block_4_project, <keras.layers.convolutional.Conv2D object at 0x7f1a1c0a5860>
# 44 : block_4_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a147d5e80>
# 45 : block_4_add, <keras.layers.merge.Add object at 0x7f1a1473bbe0>
# 46 : block_5_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a146fd400>
# 47 : block_5_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a146ce358>
# 48 : block_5_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a146b5978>
# 49 : block_5_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a14663438>
# 50 : block_5_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a146636d8>
# 51 : block_5_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a145ae780>
# 52 : block_5_project, <keras.layers.convolutional.Conv2D object at 0x7f1a14558320>
# 53 : block_5_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a144c4668>
# 54 : block_5_add, <keras.layers.merge.Add object at 0x7f1a144a6d68>
# 55 : block_6_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a14453358>
# 56 : block_6_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a143bb470>
# 57 : block_6_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a143a8eb8>
# 58 : block_6_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7f1a1431da90>
# 59 : block_6_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a14378a20>
# 60 : block_6_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a142a6eb8>
# 61 : block_6_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a142a66d8>
# 62 : block_6_project, <keras.layers.convolutional.Conv2D object at 0x7f1a14243dd8>
# 63 : block_6_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a1422d4a8>
# 64 : block_7_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a1419cf28>
# 65 : block_7_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a1416b550>
# 66 : block_7_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a1412d978>
# 67 : block_7_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a140b6908>
# 68 : block_7_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a0c7ca6a0>
# 69 : block_7_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a0c7aeac8>
# 70 : block_7_project, <keras.layers.convolutional.Conv2D object at 0x7f1a0c70dd30>
# 71 : block_7_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a0c6c5780>
# 72 : block_7_add, <keras.layers.merge.Add object at 0x7f1a0c6acdd8>
# 73 : block_8_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a0c66f5f8>
# 74 : block_8_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a0c5bf550>
# 75 : block_8_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a0c5a3ba8>
# 76 : block_8_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a0c5673c8>
# 77 : block_8_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a0c539160>
# 78 : block_8_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a0c49f8d0>
# 79 : block_8_project, <keras.layers.convolutional.Conv2D object at 0x7f1a0c44f4a8>
# 80 : block_8_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a0c437128>
# 81 : block_8_add, <keras.layers.merge.Add object at 0x7f1a0c39cf60>
# 82 : block_9_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a0c346550>
# 83 : block_9_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a0c3304e0>
# 84 : block_9_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a0c292d30>
# 85 : block_9_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1a0c23f320>
# 86 : block_9_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a0c23fc88>
# 87 : block_9_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f1a0c193ba8>
# 88 : block_9_project, <keras.layers.convolutional.Conv2D object at 0x7f1a0c103be0>
# 89 : block_9_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1a0c120390>
# 90 : block_9_add, <keras.layers.merge.Add object at 0x7f1a0c120198>
# 91 : block_10_expand, <keras.layers.convolutional.Conv2D object at 0x7f1a0c04acc0>
# 92 : block_10_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19fc7c0dd8>
# 93 : block_10_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19fc7de828>
# 94 : block_10_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19fc769908>
# 95 : block_10_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19fc73a6a0>
# 96 : block_10_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19fc69bb00>
# 97 : block_10_project, <keras.layers.convolutional.Conv2D object at 0x7f19fc67bd30>
# 98 : block_10_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19fc631780>
# 99 : block_11_expand, <keras.layers.convolutional.Conv2D object at 0x7f19fc59add8>
# 100 : block_11_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19fc574c88>
# 101 : block_11_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19fc493b38>
# 102 : block_11_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19fc4b9978>
# 103 : block_11_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19fc4b9518>
# 104 : block_11_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19fc38f828>
# 105 : block_11_project, <keras.layers.convolutional.Conv2D object at 0x7f19fc3bbdd8>
# 106 : block_11_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19fc325588>
# 107 : block_11_add, <keras.layers.merge.Add object at 0x7f19fc28be10>
# 108 : block_12_expand, <keras.layers.convolutional.Conv2D object at 0x7f19fc2b7400>
# 109 : block_12_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19fc220550>
# 110 : block_12_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19fc18dbe0>
# 111 : block_12_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19fc1efba8>
# 112 : block_12_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19fc1b0278>
# 113 : block_12_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19fc087780>
# 114 : block_12_project, <keras.layers.convolutional.Conv2D object at 0x7f19fc078a58>
# 115 : block_12_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e8787978>
# 116 : block_12_add, <keras.layers.merge.Add object at 0x7f19e87d5860>
# 117 : block_13_expand, <keras.layers.convolutional.Conv2D object at 0x7f19e87619e8>
# 118 : block_13_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e8730940>
# 119 : block_13_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19e86cd7b8>
# 120 : block_13_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7f19e865a7b8>
# 121 : block_13_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19e8674cc0>
# 122 : block_13_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e85909b0>
# 123 : block_13_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19e85b7f98>
# 124 : block_13_project, <keras.layers.convolutional.Conv2D object at 0x7f19e856bf28>
# 125 : block_13_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e8523fd0>
# 126 : block_14_expand, <keras.layers.convolutional.Conv2D object at 0x7f19e84c07f0>
# 127 : block_14_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e8400cc0>
# 128 : block_14_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19e8385d30>
# 129 : block_14_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19e83abb70>
# 130 : block_14_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e8319208>
# 131 : block_14_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19e8281978>
# 132 : block_14_project, <keras.layers.convolutional.Conv2D object at 0x7f19e82a25c0>
# 133 : block_14_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e8234128>
# 134 : block_14_add, <keras.layers.merge.Add object at 0x7f19e81fafd0>
# 135 : block_15_expand, <keras.layers.convolutional.Conv2D object at 0x7f19e81a75c0>
# 136 : block_15_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e810f588>
# 137 : block_15_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19e80f3dd8>
# 138 : block_15_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19e80a13c8>
# 139 : block_15_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e80a1d30>
# 140 : block_15_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19e07b3c18>
# 141 : block_15_project, <keras.layers.convolutional.Conv2D object at 0x7f19e0755c18>
# 142 : block_15_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e06be400>
# 143 : block_15_add, <keras.layers.merge.Add object at 0x7f19e06be198>
# 144 : block_16_expand, <keras.layers.convolutional.Conv2D object at 0x7f19e06ade80>
# 145 : block_16_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e05eb940>
# 146 : block_16_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19e05fd208>
# 147 : block_16_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19e0561908>
# 148 : block_16_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e0515c50>
# 149 : block_16_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19e047eef0>
# 150 : block_16_project, <keras.layers.convolutional.Conv2D object at 0x7f19e0471dd8>
# 151 : block_16_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e040fcf8>
# 152 : Conv_1, <keras.layers.convolutional.Conv2D object at 0x7f19e042d6a0>
# 153 : Conv_1_bn, <keras.layers.normalization.BatchNormalization object at 0x7f19e0354c50>
# 154 : out_relu, <keras.layers.advanced_activations.ReLU object at 0x7f19e02f0c18>
# 155 : lambda_1, <keras.layers.core.Lambda object at 0x7f19e0201a90>
# 156 : concatenate_1, <keras.layers.merge.Concatenate object at 0x7f1a4216d080>
# 157 : decoder_stage0_1_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1ada4a4080>
# 158 : decoder_stage0_1_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e0111e10>
# 159 : activation_1, <keras.layers.core.Activation object at 0x7f19e0338160>
# 160 : decoder_stage0_1_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f19e0134828>
# 161 : decoder_stage0_1_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19b4710358>
# 162 : activation_2, <keras.layers.core.Activation object at 0x7f19b4609438>
# 163 : decoder_stage0_2_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19e00b3e80>
# 164 : decoder_stage0_2_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19b443dac8>
# 165 : activation_3, <keras.layers.core.Activation object at 0x7f19b4422f60>
# 166 : decoder_stage0_2_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f19b43fbe80>
# 167 : decoder_stage0_2_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19b43b45c0>
# 168 : activation_4, <keras.layers.core.Activation object at 0x7f19b43515f8>
# 169 : lambda_2, <keras.layers.core.Lambda object at 0x7f19b42df5c0>
# 170 : concatenate_2, <keras.layers.merge.Concatenate object at 0x7f19b42c2550>
# 171 : decoder_stage1_1_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19b4216e80>
# 172 : decoder_stage1_1_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19b41e02e8>
# 173 : activation_5, <keras.layers.core.Activation object at 0x7f19b41e0c18>
# 174 : decoder_stage1_1_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f19b425ac50>
# 175 : decoder_stage1_1_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19b41a9f28>
# 176 : activation_6, <keras.layers.core.Activation object at 0x7f19b41448d0>
# 177 : decoder_stage1_2_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19b40cf8d0>
# 178 : decoder_stage1_2_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19b409d7b8>
# 179 : activation_7, <keras.layers.core.Activation object at 0x7f1975fcbe80>
# 180 : decoder_stage1_2_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f1975fef898>
# 181 : decoder_stage1_2_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1975f5f2e8>
# 182 : activation_8, <keras.layers.core.Activation object at 0x7f1975f7e320>
# 183 : lambda_3, <keras.layers.core.Lambda object at 0x7f1975ef62b0>
# 184 : concatenate_3, <keras.layers.merge.Concatenate object at 0x7f1975ee8240>
# 185 : decoder_stage2_1_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1975dc25f8>
# 186 : decoder_stage2_1_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1975decd68>
# 187 : activation_9, <keras.layers.core.Activation object at 0x7f1975dece80>
# 188 : decoder_stage2_1_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f1975d98e80>
# 189 : decoder_stage2_1_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1975d515f8>
# 190 : activation_10, <keras.layers.core.Activation object at 0x7f1975d6c630>
# 191 : decoder_stage2_2_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1975cfa5c0>
# 192 : decoder_stage2_2_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1975c4b4a8>
# 193 : activation_11, <keras.layers.core.Activation object at 0x7f1975c33e80>
# 194 : decoder_stage2_2_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f1975bd7588>
# 195 : decoder_stage2_2_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1975b4b6a0>
# 196 : activation_12, <keras.layers.core.Activation object at 0x7f1975b4b630>
# 197 : lambda_4, <keras.layers.core.Lambda object at 0x7f1975ad7160>
# 198 : concatenate_4, <keras.layers.merge.Concatenate object at 0x7f1975ad7f98>
# 199 : decoder_stage3_1_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1975a2eb38>
# 200 : decoder_stage3_1_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19759d0c88>
# 201 : activation_13, <keras.layers.core.Activation object at 0x7f19759d0e48>
# 202 : decoder_stage3_1_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f19759ed4a8>
# 203 : decoder_stage3_1_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19759b92e8>
# 204 : activation_14, <keras.layers.core.Activation object at 0x7f1975956320>
# 205 : decoder_stage3_2_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19758e72b0>
# 206 : decoder_stage3_2_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19758c3240>
# 207 : activation_15, <keras.layers.core.Activation object at 0x7f197581c630>
# 208 : decoder_stage3_2_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f19757c8e48>
# 209 : decoder_stage3_2_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19757b0d68>
# 210 : activation_16, <keras.layers.core.Activation object at 0x7f197571fbe0>
# 211 : lambda_5, <keras.layers.core.Lambda object at 0x7f19756c0128>
# 212 : decoder_stage4_1_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f19756c0b00>
# 213 : decoder_stage4_1_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19e0140518>
# 214 : activation_17, <keras.layers.core.Activation object at 0x7f19e00a4470>
# 215 : decoder_stage4_1_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f19e00b3048>
# 216 : decoder_stage4_1_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1975618198>
# 217 : activation_18, <keras.layers.core.Activation object at 0x7f19755ab128>
# 218 : decoder_stage4_2_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f197553d2e8>
# 219 : decoder_stage4_2_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1975516278>
# 220 : activation_19, <keras.layers.core.Activation object at 0x7f197546b7f0>
# 221 : decoder_stage4_2_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f1975419e10>
# 222 : decoder_stage4_2_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19753825c0>
# 223 : activation_20, <keras.layers.core.Activation object at 0x7f1975382e10>
# 224 : densenet_matt1_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f197530e198>
# 225 : densenet_matt1_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f197530efd0>
# 226 : activation_21, <keras.layers.core.Activation object at 0x7f19752594e0>
# 227 : densenet_matt1_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f1975207cf8>
# 228 : densenet_matt1_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19751efb70>
# 229 : activation_22, <keras.layers.core.Activation object at 0x7f197515bc18>
# 230 : densenet_matt2_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f197517d160>
# 231 : densenet_matt2_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f19750c8da0>
# 232 : activation_23, <keras.layers.core.Activation object at 0x7f19750e9908>
# 233 : densenet_matt2_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f1975053f28>
# 234 : densenet_matt2_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1974fc5fd0>
# 235 : activation_24, <keras.layers.core.Activation object at 0x7f1974fe0978>
# 236 : densenet_matt3_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7f1974f69940>
# 237 : densenet_matt3_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1974f398d0>
# 238 : activation_25, <keras.layers.core.Activation object at 0x7f1974e9feb8>
# 239 : densenet_matt3_pointwise, <keras.layers.convolutional.Conv2D object at 0x7f1974e7cda0>
# 240 : densenet_matt3_pointwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7f1974e30588>
# 241 : activation_26, <keras.layers.core.Activation object at 0x7f1974dcb5c0>
# 242 : final_conv, <keras.layers.convolutional.SeparableConv2D object at 0x7f1974d5b630>
# 243 : sigmoid, <keras.layers.core.Activation object at 0x7f1974d27320>

# %%
# Look at the layers in the converted Core ML model.
print("\nLayers in the converted model:")
for i, layer in enumerate(coreml_model._spec.neuralNetwork.layers):
    if layer.HasField("custom"):
        print("Layer %d = %s --> custom layer = %s" % (i, layer.name, layer.custom.className))
    else:
        print("Layer %d = %s" % (i, layer.name))
# Out:
# Layers in the converted model:
# Layer 0 = Conv1_pad
# Layer 1 = Conv1
# Layer 2 = bn_Conv1
# Layer 3 = Conv1_relu
# Layer 4 = Conv1_relu__neg__
# Layer 5 = Conv1_relu__clip__
# Layer 6 = Conv1_relu_neg2
# Layer 7 = expanded_conv_depthwise
# Layer 8 = expanded_conv_depthwise_BN
# Layer 9 = expanded_conv_depthwise_relu
# Layer 10 = expanded_conv_depthwise_relu__neg__
# Layer 11 = expanded_conv_depthwise_relu__clip__
# Layer 12 = expanded_conv_depthwise_relu_neg2
# Layer 13 = expanded_conv_project
# Layer 14 = expanded_conv_project_BN
# Layer 15 = block_1_expand
# Layer 16 = block_1_expand_BN
# Layer 17 = block_1_expand_relu
# Layer 18 = block_1_expand_relu__neg__
# Layer 19 = block_1_expand_relu__clip__
# Layer 20 = block_1_expand_relu_neg2
# Layer 21 = block_1_pad
# Layer 22 = block_1_depthwise
# Layer 23 = block_1_depthwise_BN
# Layer 24 = block_1_depthwise_relu
# Layer 25 = block_1_depthwise_relu__neg__
# Layer 26 = block_1_depthwise_relu__clip__
# Layer 27 = block_1_depthwise_relu_neg2
# Layer 28 = block_1_project
# Layer 29 = block_1_project_BN
# Layer 30 = block_2_expand
# Layer 31 = block_2_expand_BN
# Layer 32 = block_2_expand_relu
# Layer 33 = block_2_expand_relu__neg__
# Layer 34 = block_2_expand_relu__clip__
# Layer 35 = block_2_expand_relu_neg2
# Layer 36 = block_2_depthwise
# Layer 37 = block_2_depthwise_BN
# Layer 38 = block_2_depthwise_relu
# Layer 39 = block_2_depthwise_relu__neg__
# Layer 40 = block_2_depthwise_relu__clip__
# Layer 41 = block_2_depthwise_relu_neg2
# Layer 42 = block_2_project
# Layer 43 = block_2_project_BN
# Layer 44 = block_2_add
# Layer 45 = block_3_expand
# Layer 46 = block_3_expand_BN
# Layer 47 = block_3_expand_relu
# Layer 48 = block_3_expand_relu__neg__
# Layer 49 = block_3_expand_relu__clip__
# Layer 50 = block_3_expand_relu_neg2
# Layer 51 = block_3_pad
# Layer 52 = block_3_depthwise
# Layer 53 = block_3_depthwise_BN
# Layer 54 = block_3_depthwise_relu
# Layer 55 = block_3_depthwise_relu__neg__
# Layer 56 = block_3_depthwise_relu__clip__
# Layer 57 = block_3_depthwise_relu_neg2
# Layer 58 = block_3_project
# Layer 59 = block_3_project_BN
# Layer 60 = block_4_expand
# Layer 61 = block_4_expand_BN
# Layer 62 = block_4_expand_relu
# Layer 63 = block_4_expand_relu__neg__
# Layer 64 = block_4_expand_relu__clip__
# Layer 65 = block_4_expand_relu_neg2
# Layer 66 = block_4_depthwise
# Layer 67 = block_4_depthwise_BN
# Layer 68 = block_4_depthwise_relu
# Layer 69 = block_4_depthwise_relu__neg__
# Layer 70 = block_4_depthwise_relu__clip__
# Layer 71 = block_4_depthwise_relu_neg2
# Layer 72 = block_4_project
# Layer 73 = block_4_project_BN
# Layer 74 = block_4_add
# Layer 75 = block_5_expand
# Layer 76 = block_5_expand_BN
# Layer 77 = block_5_expand_relu
# Layer 78 = block_5_expand_relu__neg__
# Layer 79 = block_5_expand_relu__clip__
# Layer 80 = block_5_expand_relu_neg2
# Layer 81 = block_5_depthwise
# Layer 82 = block_5_depthwise_BN
# Layer 83 = block_5_depthwise_relu
# Layer 84 = block_5_depthwise_relu__neg__
# Layer 85 = block_5_depthwise_relu__clip__
# Layer 86 = block_5_depthwise_relu_neg2
# Layer 87 = block_5_project
# Layer 88 = block_5_project_BN
# Layer 89 = block_5_add
# Layer 90 = block_6_expand
# Layer 91 = block_6_expand_BN
# Layer 92 = block_6_expand_relu
# Layer 93 = block_6_expand_relu__neg__
# Layer 94 = block_6_expand_relu__clip__
# Layer 95 = block_6_expand_relu_neg2
# Layer 96 = block_6_pad
# Layer 97 = block_6_depthwise
# Layer 98 = block_6_depthwise_BN
# Layer 99 = block_6_depthwise_relu
# Layer 100 = block_6_depthwise_relu__neg__
# Layer 101 = block_6_depthwise_relu__clip__
# Layer 102 = block_6_depthwise_relu_neg2
# Layer 103 = block_6_project
# Layer 104 = block_6_project_BN
# Layer 105 = block_7_expand
# Layer 106 = block_7_expand_BN
# Layer 107 = block_7_expand_relu
# Layer 108 = block_7_expand_relu__neg__
# Layer 109 = block_7_expand_relu__clip__
# Layer 110 = block_7_expand_relu_neg2
# Layer 111 = block_7_depthwise
# Layer 112 = block_7_depthwise_BN
# Layer 113 = block_7_depthwise_relu
# Layer 114 = block_7_depthwise_relu__neg__
# Layer 115 = block_7_depthwise_relu__clip__
# Layer 116 = block_7_depthwise_relu_neg2
# Layer 117 = block_7_project
# Layer 118 = block_7_project_BN
# Layer 119 = block_7_add
# Layer 120 = block_8_expand
# Layer 121 = block_8_expand_BN
# Layer 122 = block_8_expand_relu
# Layer 123 = block_8_expand_relu__neg__
# Layer 124 = block_8_expand_relu__clip__
# Layer 125 = block_8_expand_relu_neg2
# Layer 126 = block_8_depthwise
# Layer 127 = block_8_depthwise_BN
# Layer 128 = block_8_depthwise_relu
# Layer 129 = block_8_depthwise_relu__neg__
# Layer 130 = block_8_depthwise_relu__clip__
# Layer 131 = block_8_depthwise_relu_neg2
# Layer 132 = block_8_project
# Layer 133 = block_8_project_BN
# Layer 134 = block_8_add
# Layer 135 = block_9_expand
# Layer 136 = block_9_expand_BN
# Layer 137 = block_9_expand_relu
# Layer 138 = block_9_expand_relu__neg__
# Layer 139 = block_9_expand_relu__clip__
# Layer 140 = block_9_expand_relu_neg2
# Layer 141 = block_9_depthwise
# Layer 142 = block_9_depthwise_BN
# Layer 143 = block_9_depthwise_relu
# Layer 144 = block_9_depthwise_relu__neg__
# Layer 145 = block_9_depthwise_relu__clip__
# Layer 146 = block_9_depthwise_relu_neg2
# Layer 147 = block_9_project
# Layer 148 = block_9_project_BN
# Layer 149 = block_9_add
# Layer 150 = block_10_expand
# Layer 151 = block_10_expand_BN
# Layer 152 = block_10_expand_relu
# Layer 153 = block_10_expand_relu__neg__
# Layer 154 = block_10_expand_relu__clip__
# Layer 155 = block_10_expand_relu_neg2
# Layer 156 = block_10_depthwise
# Layer 157 = block_10_depthwise_BN
# Layer 158 = block_10_depthwise_relu
# Layer 159 = block_10_depthwise_relu__neg__
# Layer 160 = block_10_depthwise_relu__clip__
# Layer 161 = block_10_depthwise_relu_neg2
# Layer 162 = block_10_project
# Layer 163 = block_10_project_BN
# Layer 164 = block_11_expand
# Layer 165 = block_11_expand_BN
# Layer 166 = block_11_expand_relu
# Layer 167 = block_11_expand_relu__neg__
# Layer 168 = block_11_expand_relu__clip__
# Layer 169 = block_11_expand_relu_neg2
# Layer 170 = block_11_depthwise
# Layer 171 = block_11_depthwise_BN
# Layer 172 = block_11_depthwise_relu
# Layer 173 = block_11_depthwise_relu__neg__
# Layer 174 = block_11_depthwise_relu__clip__
# Layer 175 = block_11_depthwise_relu_neg2
# Layer 176 = block_11_project
# Layer 177 = block_11_project_BN
# Layer 178 = block_11_add
# Layer 179 = block_12_expand
# Layer 180 = block_12_expand_BN
# Layer 181 = block_12_expand_relu
# Layer 182 = block_12_expand_relu__neg__
# Layer 183 = block_12_expand_relu__clip__
# Layer 184 = block_12_expand_relu_neg2
# Layer 185 = block_12_depthwise
# Layer 186 = block_12_depthwise_BN
# Layer 187 = block_12_depthwise_relu
# Layer 188 = block_12_depthwise_relu__neg__
# Layer 189 = block_12_depthwise_relu__clip__
# Layer 190 = block_12_depthwise_relu_neg2
# Layer 191 = block_12_project
# Layer 192 = block_12_project_BN
# Layer 193 = block_12_add
# Layer 194 = block_13_expand
# Layer 195 = block_13_expand_BN
# Layer 196 = block_13_expand_relu
# Layer 197 = block_13_expand_relu__neg__
# Layer 198 = block_13_expand_relu__clip__
# Layer 199 = block_13_expand_relu_neg2
# Layer 200 = block_13_pad
# Layer 201 = block_13_depthwise
# Layer 202 = block_13_depthwise_BN
# Layer 203 = block_13_depthwise_relu
# Layer 204 = block_13_depthwise_relu__neg__
# Layer 205 = block_13_depthwise_relu__clip__
# Layer 206 = block_13_depthwise_relu_neg2
# Layer 207 = block_13_project
# Layer 208 = block_13_project_BN
# Layer 209 = block_14_expand
# Layer 210 = block_14_expand_BN
# Layer 211 = block_14_expand_relu
# Layer 212 = block_14_expand_relu__neg__
# Layer 213 = block_14_expand_relu__clip__
# Layer 214 = block_14_expand_relu_neg2
# Layer 215 = block_14_depthwise
# Layer 216 = block_14_depthwise_BN
# Layer 217 = block_14_depthwise_relu
# Layer 218 = block_14_depthwise_relu__neg__
# Layer 219 = block_14_depthwise_relu__clip__
# Layer 220 = block_14_depthwise_relu_neg2
# Layer 221 = block_14_project
# Layer 222 = block_14_project_BN
# Layer 223 = block_14_add
# Layer 224 = block_15_expand
# Layer 225 = block_15_expand_BN
# Layer 226 = block_15_expand_relu
# Layer 227 = block_15_expand_relu__neg__
# Layer 228 = block_15_expand_relu__clip__
# Layer 229 = block_15_expand_relu_neg2
# Layer 230 = block_15_depthwise
# Layer 231 = block_15_depthwise_BN
# Layer 232 = block_15_depthwise_relu
# Layer 233 = block_15_depthwise_relu__neg__
# Layer 234 = block_15_depthwise_relu__clip__
# Layer 235 = block_15_depthwise_relu_neg2
# Layer 236 = block_15_project
# Layer 237 = block_15_project_BN
# Layer 238 = block_15_add
# Layer 239 = block_16_expand
# Layer 240 = block_16_expand_BN
# Layer 241 = block_16_expand_relu
# Layer 242 = block_16_expand_relu__neg__
# Layer 243 = block_16_expand_relu__clip__
# Layer 244 = block_16_expand_relu_neg2
# Layer 245 = block_16_depthwise
# Layer 246 = block_16_depthwise_BN
# Layer 247 = block_16_depthwise_relu
# Layer 248 = block_16_depthwise_relu__neg__
# Layer 249 = block_16_depthwise_relu__clip__
# Layer 250 = block_16_depthwise_relu_neg2
# Layer 251 = block_16_project
# Layer 252 = block_16_project_BN
# Layer 253 = Conv_1
# Layer 254 = Conv_1_bn
# Layer 255 = out_relu
# Layer 256 = out_relu__neg__
# Layer 257 = out_relu__clip__
# Layer 258 = out_relu_neg2
# Layer 259 = lambda_1 --> custom layer = resize_bilinear
# Layer 260 = concatenate_1
# Layer 261 = decoder_stage0_1_depthwise
# Layer 262 = decoder_stage0_1_depthwise_BN
# Layer 263 = activation_1
# Layer 264 = decoder_stage0_1_pointwise
# Layer 265 = decoder_stage0_1_pointwise_BN
# Layer 266 = activation_2
# Layer 267 = decoder_stage0_2_depthwise
# Layer 268 = decoder_stage0_2_depthwise_BN
# Layer 269 = activation_3
# Layer 270 = decoder_stage0_2_pointwise
# Layer 271 = decoder_stage0_2_pointwise_BN
# Layer 272 = activation_4
# Layer 273 = lambda_2 --> custom layer = resize_bilinear
# Layer 274 = concatenate_2
# Layer 275 = decoder_stage1_1_depthwise
# Layer 276 = decoder_stage1_1_depthwise_BN
# Layer 277 = activation_5
# Layer 278 = decoder_stage1_1_pointwise
# Layer 279 = decoder_stage1_1_pointwise_BN
# Layer 280 = activation_6
# Layer 281 = decoder_stage1_2_depthwise
# Layer 282 = decoder_stage1_2_depthwise_BN
# Layer 283 = activation_7
# Layer 284 = decoder_stage1_2_pointwise
# Layer 285 = decoder_stage1_2_pointwise_BN
# Layer 286 = activation_8
# Layer 287 = lambda_3 --> custom layer = resize_bilinear
# Layer 288 = concatenate_3
# Layer 289 = decoder_stage2_1_depthwise
# Layer 290 = decoder_stage2_1_depthwise_BN
# Layer 291 = activation_9
# Layer 292 = decoder_stage2_1_pointwise
# Layer 293 = decoder_stage2_1_pointwise_BN
# Layer 294 = activation_10
# Layer 295 = decoder_stage2_2_depthwise
# Layer 296 = decoder_stage2_2_depthwise_BN
# Layer 297 = activation_11
# Layer 298 = decoder_stage2_2_pointwise
# Layer 299 = decoder_stage2_2_pointwise_BN
# Layer 300 = activation_12
# Layer 301 = lambda_4 --> custom layer = resize_bilinear
# Layer 302 = concatenate_4
# Layer 303 = decoder_stage3_1_depthwise
# Layer 304 = decoder_stage3_1_depthwise_BN
# Layer 305 = activation_13
# Layer 306 = decoder_stage3_1_pointwise
# Layer 307 = decoder_stage3_1_pointwise_BN
# Layer 308 = activation_14
# Layer 309 = decoder_stage3_2_depthwise
# Layer 310 = decoder_stage3_2_depthwise_BN
# Layer 311 = activation_15
# Layer 312 = decoder_stage3_2_pointwise
# Layer 313 = decoder_stage3_2_pointwise_BN
# Layer 314 = activation_16
# Layer 315 = lambda_5 --> custom layer = resize_bilinear
# Layer 316 = decoder_stage4_1_depthwise
# Layer 317 = decoder_stage4_1_depthwise_BN
# Layer 318 = activation_17
# Layer 319 = decoder_stage4_1_pointwise
# Layer 320 = decoder_stage4_1_pointwise_BN
# Layer 321 = activation_18
# Layer 322 = decoder_stage4_2_depthwise
# Layer 323 = decoder_stage4_2_depthwise_BN
# Layer 324 = activation_19
# Layer 325 = decoder_stage4_2_pointwise
# Layer 326 = decoder_stage4_2_pointwise_BN
# Layer 327 = activation_20
# Layer 328 = densenet_matt1_depthwise
# Layer 329 = densenet_matt1_depthwise_BN
# Layer 330 = activation_21
# Layer 331 = densenet_matt1_pointwise
# Layer 332 = densenet_matt1_pointwise_BN
# Layer 333 = activation_22
# Layer 334 = densenet_matt2_depthwise
# Layer 335 = densenet_matt2_depthwise_BN
# Layer 336 = activation_23
# Layer 337 = densenet_matt2_pointwise
# Layer 338 = densenet_matt2_pointwise_BN
# Layer 339 = activation_24
# Layer 340 = densenet_matt3_depthwise
# Layer 341 = densenet_matt3_depthwise_BN
# Layer 342 = activation_25
# Layer 343 = densenet_matt3_pointwise
# Layer 344 = densenet_matt3_pointwise_BN
# Layer 345 = activation_26
# Layer 346 = final_conv_step_1
# Layer 347 = final_conv_step_2
# Layer 348 = sigmoid

# %%
spec = coreml_model.get_spec()
print(spec.description)
# Out:
# input {
#   name: "input_1"
#   type {
#     imageType {
#       width: 256
#       height: 256
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "sigmoid/Sigmoid"
#   type {
#     multiArrayType {
#       shape: 1
#       shape: 256
#       shape: 256
#       dataType: DOUBLE
#     }
#   }
# }

# %%
coreml_model.save(os.path.join(MODEL_PATH, mlmodel_filename))

# %%
model =  coremltools.models.MLModel(os.path.join(MODEL_PATH, mlmodel_filename))

# %%
model_fp16_spec = coremltools.utils.convert_neural_network_weights_to_fp16(coreml_model)
model_fp16_spec.save(os.path.join(MODEL_PATH, mlmodel_fp16_filename))
#coremltools.utils.save_spec(model_fp16_spec, os.path.join(MODEL_PATH, mlmodel_fp16_filename))

# %%
quantized_coreml_spec = coremltools.models.neural_network.quantization_utils.quantize_weights(coreml_model,8) 
coremltools.utils.save_spec(quantized_coreml_spec, os.path.join(MODEL_PATH, mlmodel_Q_filename))
# Out:
# Quantizing using linear quantization
# Optimizing Neural Network before Quantization:
# Fused Conv1->bn_Conv1
# Fused expanded_conv_depthwise->expanded_conv_depthwise_BN
# Fused expanded_conv_project->expanded_conv_project_BN
# Fused block_1_expand->block_1_expand_BN
# Fused block_1_depthwise->block_1_depthwise_BN
# Fused block_1_project->block_1_project_BN
# Fused block_2_expand->block_2_expand_BN
# Fused block_2_depthwise->block_2_depthwise_BN
# Fused block_2_project->block_2_project_BN
# Fused block_3_expand->block_3_expand_BN
# Fused block_3_depthwise->block_3_depthwise_BN
# Fused block_3_project->block_3_project_BN
# Fused block_4_expand->block_4_expand_BN
# Fused block_4_depthwise->block_4_depthwise_BN
# Fused block_4_project->block_4_project_BN
# Fused block_5_expand->block_5_expand_BN
# Fused block_5_depthwise->block_5_depthwise_BN
# Fused block_5_project->block_5_project_BN
# Fused block_6_expand->block_6_expand_BN
# Fused block_6_depthwise->block_6_depthwise_BN
# Fused block_6_project->block_6_project_BN
# Fused block_7_expand->block_7_expand_BN
# Fused block_7_depthwise->block_7_depthwise_BN
# Fused block_7_project->block_7_project_BN
# Fused block_8_expand->block_8_expand_BN
# Fused block_8_depthwise->block_8_depthwise_BN
# Fused block_8_project->block_8_project_BN
# Fused block_9_expand->block_9_expand_BN
# Fused block_9_depthwise->block_9_depthwise_BN
# Fused block_9_project->block_9_project_BN
# Fused block_10_expand->block_10_expand_BN
# Fused block_10_depthwise->block_10_depthwise_BN
# Fused block_10_project->block_10_project_BN
# Fused block_11_expand->block_11_expand_BN
# Fused block_11_depthwise->block_11_depthwise_BN
# Fused block_11_project->block_11_project_BN
# Fused block_12_expand->block_12_expand_BN
# Fused block_12_depthwise->block_12_depthwise_BN
# Fused block_12_project->block_12_project_BN
# Fused block_13_expand->block_13_expand_BN
# Fused block_13_depthwise->block_13_depthwise_BN
# Fused block_13_project->block_13_project_BN
# Fused block_14_expand->block_14_expand_BN
# Fused block_14_depthwise->block_14_depthwise_BN
# Fused block_14_project->block_14_project_BN
# Fused block_15_expand->block_15_expand_BN
# Fused block_15_depthwise->block_15_depthwise_BN
# Fused block_15_project->block_15_project_BN
# Fused block_16_expand->block_16_expand_BN
# Fused block_16_depthwise->block_16_depthwise_BN
# Fused block_16_project->block_16_project_BN
# Fused Conv_1->Conv_1_bn
# Fused decoder_stage0_1_depthwise->decoder_stage0_1_depthwise_BN
# Fused decoder_stage0_1_pointwise->decoder_stage0_1_pointwise_BN
# Fused decoder_stage0_2_depthwise->decoder_stage0_2_depthwise_BN
# Fused decoder_stage0_2_pointwise->decoder_stage0_2_pointwise_BN
# Fused decoder_stage1_1_depthwise->decoder_stage1_1_depthwise_BN
# Fused decoder_stage1_1_pointwise->decoder_stage1_1_pointwise_BN
# Fused decoder_stage1_2_depthwise->decoder_stage1_2_depthwise_BN
# Fused decoder_stage1_2_pointwise->decoder_stage1_2_pointwise_BN
# Fused decoder_stage2_1_depthwise->decoder_stage2_1_depthwise_BN
# Fused decoder_stage2_1_pointwise->decoder_stage2_1_pointwise_BN
# Fused decoder_stage2_2_depthwise->decoder_stage2_2_depthwise_BN
# Fused decoder_stage2_2_pointwise->decoder_stage2_2_pointwise_BN
# Fused decoder_stage3_1_depthwise->decoder_stage3_1_depthwise_BN
# Fused decoder_stage3_1_pointwise->decoder_stage3_1_pointwise_BN
# Fused decoder_stage3_2_depthwise->decoder_stage3_2_depthwise_BN
# Fused decoder_stage3_2_pointwise->decoder_stage3_2_pointwise_BN
# Fused decoder_stage4_1_depthwise->decoder_stage4_1_depthwise_BN
# Fused decoder_stage4_1_pointwise->decoder_stage4_1_pointwise_BN
# Fused decoder_stage4_2_depthwise->decoder_stage4_2_depthwise_BN
# Fused decoder_stage4_2_pointwise->decoder_stage4_2_pointwise_BN
# Fused densenet_matt1_depthwise->densenet_matt1_depthwise_BN
# Fused densenet_matt1_pointwise->densenet_matt1_pointwise_BN
# Fused densenet_matt2_depthwise->densenet_matt2_depthwise_BN
# Fused densenet_matt2_pointwise->densenet_matt2_pointwise_BN
# Fused densenet_matt3_depthwise->densenet_matt3_depthwise_BN
# Fused densenet_matt3_pointwise->densenet_matt3_pointwise_BN
# Finished optimizing network. Quantizing neural network..
# Quantizing layer Conv1
# Quantizing layer expanded_conv_depthwise
# Quantizing layer expanded_conv_project
# Quantizing layer block_1_expand
# Quantizing layer block_1_depthwise
# Quantizing layer block_1_project
# Quantizing layer block_2_expand
# Quantizing layer block_2_depthwise
# Quantizing layer block_2_project
# Quantizing layer block_3_expand
# Quantizing layer block_3_depthwise
# Quantizing layer block_3_project
# Quantizing layer block_4_expand
# Quantizing layer block_4_depthwise
# Quantizing layer block_4_project
# Quantizing layer block_5_expand
# Quantizing layer block_5_depthwise
# Quantizing layer block_5_project
# Quantizing layer block_6_expand
# Quantizing layer block_6_depthwise
# Quantizing layer block_6_project
# Quantizing layer block_7_expand
# Quantizing layer block_7_depthwise
# Quantizing layer block_7_project
# Quantizing layer block_8_expand
# Quantizing layer block_8_depthwise
# Quantizing layer block_8_project
# Quantizing layer block_9_expand
# Quantizing layer block_9_depthwise
# Quantizing layer block_9_project
# Quantizing layer block_10_expand
# Quantizing layer block_10_depthwise
# Quantizing layer block_10_project
# Quantizing layer block_11_expand
# Quantizing layer block_11_depthwise
# Quantizing layer block_11_project
# Quantizing layer block_12_expand
# Quantizing layer block_12_depthwise
# Quantizing layer block_12_project
# Quantizing layer block_13_expand
# Quantizing layer block_13_depthwise
# Quantizing layer block_13_project
# Quantizing layer block_14_expand
# Quantizing layer block_14_depthwise
# Quantizing layer block_14_project
# Quantizing layer block_15_expand
# Quantizing layer block_15_depthwise
# Quantizing layer block_15_project
# Quantizing layer block_16_expand
# Quantizing layer block_16_depthwise
# Quantizing layer block_16_project
# Quantizing layer Conv_1
# Quantizing layer decoder_stage0_1_depthwise
# Quantizing layer decoder_stage0_1_pointwise
# Quantizing layer decoder_stage0_2_depthwise
# Quantizing layer decoder_stage0_2_pointwise
# Quantizing layer decoder_stage1_1_depthwise
# Quantizing layer decoder_stage1_1_pointwise
# Quantizing layer decoder_stage1_2_depthwise
# Quantizing layer decoder_stage1_2_pointwise
# Quantizing layer decoder_stage2_1_depthwise
# Quantizing layer decoder_stage2_1_pointwise
# Quantizing layer decoder_stage2_2_depthwise
# Quantizing layer decoder_stage2_2_pointwise
# Quantizing layer decoder_stage3_1_depthwise
# Quantizing layer decoder_stage3_1_pointwise
# Quantizing layer decoder_stage3_2_depthwise
# Quantizing layer decoder_stage3_2_pointwise
# Quantizing layer decoder_stage4_1_depthwise
# Quantizing layer decoder_stage4_1_pointwise
# Quantizing layer decoder_stage4_2_depthwise
# Quantizing layer decoder_stage4_2_pointwise
# Quantizing layer densenet_matt1_depthwise
# Quantizing layer densenet_matt1_pointwise
# Quantizing layer densenet_matt2_depthwise
# Quantizing layer densenet_matt2_pointwise
# Quantizing layer densenet_matt3_depthwise
# Quantizing layer densenet_matt3_pointwise
# Quantizing layer final_conv_step_1
# Quantizing layer final_conv_step_2
# WARNING! Unable to return a quantized MLModel instance since OS != macOS 10.14 or later
# Returning quantized model specification instead

# %% [markdown]
# ## load & inference the model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import skimage
import glob
import os
import cv2

# %%
# Load Test Images
path = "../data/raw/test"
fnames = sorted(glob.glob(os.path.join(path,"*.jpg")))
images = []
images_ = []
for f in fnames:
    img = skimage.io.imread(f)
    img_ = np.expand_dims(cv2.resize(img,INPUT_SHAPE[:2]),axis=0)
    img_ = preprocess_input(img_, imgNorm=IMGNORM)
    images_.append(img_)
    images.append(img)

# %%
sess = tf.Session()

# %%
# load model from pb file
with tf.gfile.GFile(os.path.join(MODEL_PATH,pb_op_filename),'rb') as f:
#pb_op_filename = "/media/new_hdd2/seg_net/results/Models/GraphModels/mobilenetv2_Linknet_BCE_ACC_IOU_divide_1_sigmoid_512_train_matte_Qotp.pb"
#with tf.gfile.GFile(os.path.join(MODEL_PATH,pb_filename),'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    sess.graph.as_default()
    g_in = tf.import_graph_def(graph_def)
print("Loading from ",os.path.join(MODEL_PATH,pb_filename))
# Out:
# Loading from  ../results/Models/GraphModels/mobilenetv2_GUnet_MSE_ACC_IOU_divide_1_sigmoid_256_train_matte.pb

# %%
tensor_output = sess.graph.get_tensor_by_name('import/sigmoid/Sigmoid:0')
tensor_input = sess.graph.get_tensor_by_name('import/input_1:0')
outs = []

# %%
# %%timeit
_ = sess.run(tensor_output, {tensor_input: images_[0]})
# Out:
# 12.2 ms ± 176 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
for img_ in images_:
    # inference by the model (op name must comes with :0 to specify the index of its output)
    output = sess.run(tensor_output, {tensor_input: img_})
    outs.append(np.squeeze(output))

# %%
sess.close()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for inp,otp in zip(images,outs):
    f, axarr = plt.subplots(1,2)
    axarr[0].imshow(skimage.transform.resize(inp,otp.shape,anti_aliasing=True))
    if NUM_CLASS>1:
        axarr[1].imshow(otp.argmax(axis=-1), cmap='Greys',  interpolation='nearest')
    else:
        axarr[1].imshow(otp*255, cmap='Greys',  interpolation='nearest')
# Out:
# /home/avantariml/.local/lib/python3.5/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ### Testing TFLite model using Python API

# %%
# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path=os.path.join(MODEL_PATH,tflite_filename))
#interpreter = tf.lite.Interpreter(model_path=os.path.join(MODEL_PATH,tflite_Q_filename))
#interpreter = tf.lite.Interpreter(model_path="/media/new_hdd2/seg_net/results/Models/Models/sample_tf.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
input_details[0]['shape']
outs = []

# %%
import random
i = random.choice(range(0,len(fnames)))
inp = np.copy(images[i])
img_ = np.copy(images_[i])

# %%
# %%timeit
interpreter.set_tensor(input_details[0]['index'], img_)
interpreter.invoke()
output = interpreter.get_tensor(output_details[0]['index'])
# Out:
# 211 ms ± 6.61 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%time
for img_ in images_:
    # inference by the model (op name must comes with :0 to specify the index of its output)
    interpreter.set_tensor(input_details[0]['index'], img_)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    outs.append(np.squeeze(output))
# Out:
# CPU times: user 7.28 s, sys: 677 ms, total: 7.95 s
# Wall time: 4.53 s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for inp,otp in zip(images,outs):
    f, axarr = plt.subplots(1,2)
    axarr[0].imshow(skimage.transform.resize(inp,otp.shape,anti_aliasing=True))
    if NUM_CLASS>1:
        axarr[1].imshow(otp.argmax(axis=-1), cmap='Greys',  interpolation='nearest')
    else:
        axarr[1].imshow(otp*255, cmap='Greys',  interpolation='nearest')
