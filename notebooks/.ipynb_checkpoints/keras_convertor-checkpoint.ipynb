# %% [markdown]
# # Keras to Tensorflow Model

# %%
import keras
import tensorflow as tf
import coremltools
import numpy as np
np.random.seed(0)
import segmentation_models as sm
import sys
import os
sys.path.append("..")
from seg_net.keras_to_tensorflow import *
from seg_net.data import *
# Out:
# Using TensorFlow backend.
# WARNING:root:TensorFlow version 1.13.1 detected. Last version known to be fully compatible is 1.12.0 .
# /home/avantariml/.local/lib/python3.5/site-packages/classification_models/resnext/__init__.py:4: UserWarning: Current ResNext models are deprecated, use keras.applications ResNeXt models
#   warnings.warn('Current ResNext models are deprecated, '

# %% [markdown]
# ## Set Model Architecture

# %%
INPUT_SHAPE = (768,768,3) #(528,528,3) (512,512,3) (768,768,3)
NUM_CLASS = 1
BACKBONE = 'resnet50'
MODEL_NAME = 'Unet'
LOSS_METRICS = 'BCE_ACC_IOU'
MODEL_PATH = '../results/Models/Models'
ACTIVATION = 'sigmoid'

# Output protocol buffer model path
model_fname = '{0}_{1}_{2}_{3}_{4}_{5}'.format(BACKBONE,
                                              MODEL_NAME,
                                              LOSS_METRICS,
                                              NUM_CLASS,
                                              ACTIVATION,
                                              INPUT_SHAPE[0])
keras_filename = '{}.hdf5'.format(model_fname)
pb_filename = '{}.pb'.format(model_fname)
pb_q_filename = '{}_Q.pb'.format(model_fname)
mlmodel_filename = '{}.mlmodel'.format(model_fname)
tflite_filename = '{}.tflite'.format(model_fname)

# %% [markdown]
# ## Build and Load Model

# %%
model = sm.Unet(BACKBONE, encoder_weights='imagenet', 
                  classes=NUM_CLASS,
                  activation=ACTIVATION,
                  input_shape = INPUT_SHAPE)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.load_weights(os.path.join(MODEL_PATH,keras_filename))

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 768, 768, 3)  0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 768, 768, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 774, 774, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 384, 384, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 384, 384, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 384, 384, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 386, 386, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 192, 192, 64) 0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 192, 192, 64) 256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 192, 192, 64) 0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 192, 192, 64) 4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 192, 192, 64) 256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 192, 192, 64) 0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 194, 194, 64) 0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 192, 192, 64) 36864       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn3 (BatchNormaliz (None, 192, 192, 64) 256         stage1_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu3 (Activation) (None, 192, 192, 64) 0           stage1_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv3 (Conv2D)     (None, 192, 192, 256 16384       stage1_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 192, 192, 256 16384       stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 192, 192, 256 0           stage1_unit1_conv3[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 192, 192, 256 1024        add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 192, 192, 256 0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 192, 192, 64) 16384       stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 192, 192, 64) 256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 192, 192, 64) 0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 194, 194, 64) 0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 192, 192, 64) 36864       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn3 (BatchNormaliz (None, 192, 192, 64) 256         stage1_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu3 (Activation) (None, 192, 192, 64) 0           stage1_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv3 (Conv2D)     (None, 192, 192, 256 16384       stage1_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 192, 192, 256 0           stage1_unit2_conv3[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, 192, 192, 256 1024        add_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, 192, 192, 256 0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, 192, 192, 64) 16384       stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, 192, 192, 64) 256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, 192, 192, 64) 0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 194, 194, 64) 0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, 192, 192, 64) 36864       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn3 (BatchNormaliz (None, 192, 192, 64) 256         stage1_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu3 (Activation) (None, 192, 192, 64) 0           stage1_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv3 (Conv2D)     (None, 192, 192, 256 16384       stage1_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 192, 192, 256 0           stage1_unit3_conv3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 192, 192, 256 1024        add_3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 192, 192, 256 0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 192, 192, 128 32768       stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 192, 192, 128 512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 192, 192, 128 0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 194, 194, 128 0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 96, 96, 128)  147456      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn3 (BatchNormaliz (None, 96, 96, 128)  512         stage2_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu3 (Activation) (None, 96, 96, 128)  0           stage2_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv3 (Conv2D)     (None, 96, 96, 512)  65536       stage2_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 96, 96, 512)  131072      stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 96, 96, 512)  0           stage2_unit1_conv3[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 96, 96, 512)  2048        add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 96, 96, 512)  0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 96, 96, 128)  65536       stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 96, 96, 128)  512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 96, 96, 128)  0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 98, 98, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 96, 96, 128)  147456      zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn3 (BatchNormaliz (None, 96, 96, 128)  512         stage2_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu3 (Activation) (None, 96, 96, 128)  0           stage2_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv3 (Conv2D)     (None, 96, 96, 512)  65536       stage2_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 96, 96, 512)  0           stage2_unit2_conv3[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, 96, 96, 512)  2048        add_5[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, 96, 96, 512)  0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, 96, 96, 128)  65536       stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, 96, 96, 128)  512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, 96, 96, 128)  0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 98, 98, 128)  0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, 96, 96, 128)  147456      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn3 (BatchNormaliz (None, 96, 96, 128)  512         stage2_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu3 (Activation) (None, 96, 96, 128)  0           stage2_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv3 (Conv2D)     (None, 96, 96, 512)  65536       stage2_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 96, 96, 512)  0           stage2_unit3_conv3[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, 96, 96, 512)  2048        add_6[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, 96, 96, 512)  0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, 96, 96, 128)  65536       stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, 96, 96, 128)  512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, 96, 96, 128)  0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 98, 98, 128)  0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, 96, 96, 128)  147456      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn3 (BatchNormaliz (None, 96, 96, 128)  512         stage2_unit4_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu3 (Activation) (None, 96, 96, 128)  0           stage2_unit4_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv3 (Conv2D)     (None, 96, 96, 512)  65536       stage2_unit4_relu3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 96, 96, 512)  0           stage2_unit4_conv3[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 96, 96, 512)  2048        add_7[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 96, 96, 512)  0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 96, 96, 256)  131072      stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 96, 96, 256)  1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 96, 96, 256)  0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 98, 98, 256)  0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 48, 48, 256)  589824      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn3 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu3 (Activation) (None, 48, 48, 256)  0           stage3_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv3 (Conv2D)     (None, 48, 48, 1024) 262144      stage3_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 48, 48, 1024) 524288      stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 48, 48, 1024) 0           stage3_unit1_conv3[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 48, 48, 1024) 4096        add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 48, 48, 1024) 0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 48, 48, 256)  262144      stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 48, 48, 256)  0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 50, 50, 256)  0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 48, 48, 256)  589824      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn3 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu3 (Activation) (None, 48, 48, 256)  0           stage3_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv3 (Conv2D)     (None, 48, 48, 1024) 262144      stage3_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 48, 48, 1024) 0           stage3_unit2_conv3[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, 48, 48, 1024) 4096        add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, 48, 48, 1024) 0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, 48, 48, 256)  262144      stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, 48, 48, 256)  0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 50, 50, 256)  0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, 48, 48, 256)  589824      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn3 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu3 (Activation) (None, 48, 48, 256)  0           stage3_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv3 (Conv2D)     (None, 48, 48, 1024) 262144      stage3_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 48, 48, 1024) 0           stage3_unit3_conv3[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, 48, 48, 1024) 4096        add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, 48, 48, 1024) 0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, 48, 48, 256)  262144      stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, 48, 48, 256)  0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 50, 50, 256)  0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, 48, 48, 256)  589824      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn3 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit4_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu3 (Activation) (None, 48, 48, 256)  0           stage3_unit4_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv3 (Conv2D)     (None, 48, 48, 1024) 262144      stage3_unit4_relu3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 48, 48, 1024) 0           stage3_unit4_conv3[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, 48, 48, 1024) 4096        add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, 48, 48, 1024) 0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, 48, 48, 256)  262144      stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, 48, 48, 256)  0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 50, 50, 256)  0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, 48, 48, 256)  589824      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn3 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit5_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu3 (Activation) (None, 48, 48, 256)  0           stage3_unit5_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv3 (Conv2D)     (None, 48, 48, 1024) 262144      stage3_unit5_relu3[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 48, 48, 1024) 0           stage3_unit5_conv3[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, 48, 48, 1024) 4096        add_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, 48, 48, 1024) 0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, 48, 48, 256)  262144      stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, 48, 48, 256)  0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 50, 50, 256)  0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, 48, 48, 256)  589824      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn3 (BatchNormaliz (None, 48, 48, 256)  1024        stage3_unit6_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu3 (Activation) (None, 48, 48, 256)  0           stage3_unit6_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv3 (Conv2D)     (None, 48, 48, 1024) 262144      stage3_unit6_relu3[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 48, 48, 1024) 0           stage3_unit6_conv3[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 48, 48, 1024) 4096        add_13[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 48, 48, 1024) 0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 48, 48, 512)  524288      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 48, 48, 512)  2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 48, 48, 512)  0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 50, 50, 512)  0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 24, 24, 512)  2359296     zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn3 (BatchNormaliz (None, 24, 24, 512)  2048        stage4_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu3 (Activation) (None, 24, 24, 512)  0           stage4_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv3 (Conv2D)     (None, 24, 24, 2048) 1048576     stage4_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 24, 24, 2048) 2097152     stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 24, 24, 2048) 0           stage4_unit1_conv3[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 24, 24, 2048) 8192        add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 24, 24, 2048) 0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 24, 24, 512)  1048576     stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 24, 24, 512)  2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 24, 24, 512)  0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 26, 26, 512)  0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 24, 24, 512)  2359296     zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn3 (BatchNormaliz (None, 24, 24, 512)  2048        stage4_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu3 (Activation) (None, 24, 24, 512)  0           stage4_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv3 (Conv2D)     (None, 24, 24, 2048) 1048576     stage4_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 24, 24, 2048) 0           stage4_unit2_conv3[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, 24, 24, 2048) 8192        add_15[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, 24, 24, 2048) 0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, 24, 24, 512)  1048576     stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, 24, 24, 512)  2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, 24, 24, 512)  0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 26, 26, 512)  0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, 24, 24, 512)  2359296     zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn3 (BatchNormaliz (None, 24, 24, 512)  2048        stage4_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu3 (Activation) (None, 24, 24, 512)  0           stage4_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv3 (Conv2D)     (None, 24, 24, 2048) 1048576     stage4_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 24, 24, 2048) 0           stage4_unit3_conv3[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 24, 24, 2048) 8192        add_16[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 24, 24, 2048) 0           bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsample (UpSamp (None, 48, 48, 2048) 0           relu1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 48, 48, 3072) 0           decoder_stage0_upsample[0][0]
#                                                                  stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv1 (Conv2D)   (None, 48, 48, 256)  7077888     concatenate_1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_bn1 (BatchNormal (None, 48, 48, 256)  1024        decoder_stage0_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu1 (Activatio (None, 48, 48, 256)  0           decoder_stage0_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv2 (Conv2D)   (None, 48, 48, 256)  589824      decoder_stage0_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_bn2 (BatchNormal (None, 48, 48, 256)  1024        decoder_stage0_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu2 (Activatio (None, 48, 48, 256)  0           decoder_stage0_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsample (UpSamp (None, 96, 96, 256)  0           decoder_stage0_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 96, 96, 768)  0           decoder_stage1_upsample[0][0]
#                                                                  stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv1 (Conv2D)   (None, 96, 96, 128)  884736      concatenate_2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_bn1 (BatchNormal (None, 96, 96, 128)  512         decoder_stage1_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu1 (Activatio (None, 96, 96, 128)  0           decoder_stage1_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv2 (Conv2D)   (None, 96, 96, 128)  147456      decoder_stage1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_bn2 (BatchNormal (None, 96, 96, 128)  512         decoder_stage1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu2 (Activatio (None, 96, 96, 128)  0           decoder_stage1_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsample (UpSamp (None, 192, 192, 128 0           decoder_stage1_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 192, 192, 384 0           decoder_stage2_upsample[0][0]
#                                                                  stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv1 (Conv2D)   (None, 192, 192, 64) 221184      concatenate_3[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_bn1 (BatchNormal (None, 192, 192, 64) 256         decoder_stage2_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu1 (Activatio (None, 192, 192, 64) 0           decoder_stage2_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv2 (Conv2D)   (None, 192, 192, 64) 36864       decoder_stage2_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_bn2 (BatchNormal (None, 192, 192, 64) 256         decoder_stage2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu2 (Activatio (None, 192, 192, 64) 0           decoder_stage2_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsample (UpSamp (None, 384, 384, 64) 0           decoder_stage2_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 384, 384, 128 0           decoder_stage3_upsample[0][0]
#                                                                  relu0[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv1 (Conv2D)   (None, 384, 384, 32) 36864       concatenate_4[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_bn1 (BatchNormal (None, 384, 384, 32) 128         decoder_stage3_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu1 (Activatio (None, 384, 384, 32) 0           decoder_stage3_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv2 (Conv2D)   (None, 384, 384, 32) 9216        decoder_stage3_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_bn2 (BatchNormal (None, 384, 384, 32) 128         decoder_stage3_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu2 (Activatio (None, 384, 384, 32) 0           decoder_stage3_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsample (UpSamp (None, 768, 768, 32) 0           decoder_stage3_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv1 (Conv2D)   (None, 768, 768, 16) 4608        decoder_stage4_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_bn1 (BatchNormal (None, 768, 768, 16) 64          decoder_stage4_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu1 (Activatio (None, 768, 768, 16) 0           decoder_stage4_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv2 (Conv2D)   (None, 768, 768, 16) 2304        decoder_stage4_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_bn2 (BatchNormal (None, 768, 768, 16) 64          decoder_stage4_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu2 (Activatio (None, 768, 768, 16) 0           decoder_stage4_bn2[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 768, 768, 1)  145         decoder_stage4_relu2[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 768, 768, 1)  0           final_conv[0][0]
# ==================================================================================================
# Total params: 32,561,114
# Trainable params: 32,513,556
# Non-trainable params: 47,558
# __________________________________________________________________________________________________

# %% [markdown]
# ## save keras model as tf .pb and as CoreML .mlmodel

# %%
input_node_names = [node.op.name for node in model.inputs]
print(input_node_names)
# Out:
# ['data']

# %%
# output_names
output_node_names = [node.op.name for node in model.outputs]
print(output_node_names)
# Out:
# ['sigmoid/Sigmoid']

# %% [markdown]
# ### Freezing the model to .pb

# %%
from keras import backend as K
#frozen_graph = freeze_session(K.get_session(),output_names=[out.op.name for out in model.outputs])
frozen_graph =  freeze_keras(K.get_session(), model, quantize=False)
#frozen_graph_Q =  freeze_keras(K.get_session(), model, quantize=True)
tf.train.write_graph(frozen_graph, MODEL_PATH, pb_filename, as_text=False)
# Out:
# WARNING:tensorflow:From ../seg_net/keras_to_tensorflow.py:72: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From ../seg_net/keras_to_tensorflow.py:72: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 308 variables.
# INFO:tensorflow:Froze 308 variables.
# INFO:tensorflow:Converted 308 variables to const ops.
# INFO:tensorflow:Converted 308 variables to const ops.
# '../results/Models/Models/resnet50_Unet_BCE_ACC_IOU_1_sigmoid_768.pb'

# %%
# print all operation names 
#print('\n===== ouptut operation names =====\n')
#for op in sess.graph.get_operations():
#    print(op)   
for names in [n.name for n in tf.get_default_graph().as_graph_def().node]:
    print(names)
# Out:
# data
# bn_data/Const
# bn_data/beta
# bn_data/beta/Assign
# bn_data/beta/read
# bn_data/Const_1
# bn_data/moving_mean
# bn_data/moving_mean/Assign
# bn_data/moving_mean/read
# bn_data/Const_2
# bn_data/moving_variance
# bn_data/moving_variance/Assign
# bn_data/moving_variance/read
# bn_data/IsVariableInitialized
# bn_data/IsVariableInitialized_1
# bn_data/IsVariableInitialized_2
# bn_data/init
# bn_data/Const_3
# bn_data/Const_4
# bn_data/Const_5
# bn_data/FusedBatchNorm
# bn_data/Shape
# bn_data/strided_slice/stack
# bn_data/strided_slice/stack_1
# bn_data/strided_slice/stack_2
# bn_data/strided_slice
# bn_data/Shape_1
# bn_data/strided_slice_1/stack
# bn_data/strided_slice_1/stack_1
# bn_data/strided_slice_1/stack_2
# bn_data/strided_slice_1
# bn_data/Shape_2
# bn_data/strided_slice_2/stack
# bn_data/strided_slice_2/stack_1
# bn_data/strided_slice_2/stack_2
# bn_data/strided_slice_2
# bn_data/Rank/packed
# bn_data/Rank
# bn_data/range/start
# bn_data/range/delta
# bn_data/range
# bn_data/Prod/input
# bn_data/Prod
# bn_data/Cast
# bn_data/sub/y
# bn_data/sub
# bn_data/truediv
# bn_data/mul
# bn_data/AssignMovingAvg/decay
# bn_data/AssignMovingAvg/bn_data/moving_mean/zeros
# bn_data/moving_mean/biased
# bn_data/moving_mean/biased/Assign
# bn_data/moving_mean/biased/read
# bn_data/moving_mean/local_step/Initializer/zeros
# bn_data/moving_mean/local_step
# bn_data/moving_mean/local_step/Assign
# bn_data/moving_mean/local_step/read
# bn_data/AssignMovingAvg/bn_data/moving_mean/sub
# bn_data/AssignMovingAvg/bn_data/moving_mean/mul
# bn_data/AssignMovingAvg/bn_data/moving_mean/bn_data/moving_mean
# bn_data/AssignMovingAvg/bn_data/moving_mean/AssignAdd/value
# bn_data/AssignMovingAvg/bn_data/moving_mean/AssignAdd
# bn_data/AssignMovingAvg/bn_data/moving_mean/read
# bn_data/AssignMovingAvg/bn_data/moving_mean/sub_1/x
# bn_data/AssignMovingAvg/bn_data/moving_mean/sub_1
# bn_data/AssignMovingAvg/bn_data/moving_mean/read_1
# bn_data/AssignMovingAvg/bn_data/moving_mean/Pow
# bn_data/AssignMovingAvg/bn_data/moving_mean/sub_2/x
# bn_data/AssignMovingAvg/bn_data/moving_mean/sub_2
# bn_data/AssignMovingAvg/bn_data/moving_mean/truediv
# bn_data/AssignMovingAvg/bn_data/moving_mean/sub_3
# bn_data/AssignMovingAvg
# bn_data/AssignMovingAvg_1/decay
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/zeros
# bn_data/moving_variance/biased
# bn_data/moving_variance/biased/Assign
# bn_data/moving_variance/biased/read
# bn_data/moving_variance/local_step/Initializer/zeros
# bn_data/moving_variance/local_step
# bn_data/moving_variance/local_step/Assign
# bn_data/moving_variance/local_step/read
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/sub
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/mul
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/bn_data/moving_variance
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/AssignAdd/value
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/AssignAdd
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/read
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/sub_1/x
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/sub_1
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/read_1
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/Pow
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/sub_2/x
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/sub_2
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/truediv
# bn_data/AssignMovingAvg_1/bn_data/moving_variance/sub_3
# bn_data/AssignMovingAvg_1
# bn_data/keras_learning_phase/input
# bn_data/keras_learning_phase
# bn_data/cond/Switch
# bn_data/cond/switch_t
# bn_data/cond/switch_f
# bn_data/cond/pred_id
# bn_data/cond/Switch_1
# bn_data/cond/ones_like/Shape
# bn_data/cond/ones_like/Const
# bn_data/cond/ones_like
# bn_data/cond/FusedBatchNorm
# bn_data/cond/FusedBatchNorm/Switch
# bn_data/cond/FusedBatchNorm/Switch_1
# bn_data/cond/FusedBatchNorm/Switch_2
# bn_data/cond/FusedBatchNorm/Switch_3
# bn_data/cond/Merge
# zero_padding2d_1/Pad/paddings
# zero_padding2d_1/Pad
# conv0/random_uniform/shape
# conv0/random_uniform/min
# conv0/random_uniform/max
# conv0/random_uniform/RandomUniform
# conv0/random_uniform/sub
# conv0/random_uniform/mul
# conv0/random_uniform
# conv0/kernel
# conv0/kernel/Assign
# conv0/kernel/read
# conv0/convolution/dilation_rate
# conv0/convolution
# bn0/Const
# bn0/gamma
# bn0/gamma/Assign
# bn0/gamma/read
# bn0/Const_1
# bn0/beta
# bn0/beta/Assign
# bn0/beta/read
# bn0/Const_2
# bn0/moving_mean
# bn0/moving_mean/Assign
# bn0/moving_mean/read
# bn0/Const_3
# bn0/moving_variance
# bn0/moving_variance/Assign
# bn0/moving_variance/read
# bn0/Const_4
# bn0/Const_5
# bn0/FusedBatchNorm
# bn0/Shape
# bn0/strided_slice/stack
# bn0/strided_slice/stack_1
# bn0/strided_slice/stack_2
# bn0/strided_slice
# bn0/Shape_1
# bn0/strided_slice_1/stack
# bn0/strided_slice_1/stack_1
# bn0/strided_slice_1/stack_2
# bn0/strided_slice_1
# bn0/Shape_2
# bn0/strided_slice_2/stack
# bn0/strided_slice_2/stack_1
# bn0/strided_slice_2/stack_2
# bn0/strided_slice_2
# bn0/Rank/packed
# bn0/Rank
# bn0/range/start
# bn0/range/delta
# bn0/range
# bn0/Prod/input
# bn0/Prod
# bn0/Cast
# bn0/sub/y
# bn0/sub
# bn0/truediv
# bn0/mul
# bn0/AssignMovingAvg/decay
# bn0/AssignMovingAvg/bn0/moving_mean/zeros
# bn0/moving_mean/biased
# bn0/moving_mean/biased/Assign
# bn0/moving_mean/biased/read
# bn0/moving_mean/local_step/Initializer/zeros
# bn0/moving_mean/local_step
# bn0/moving_mean/local_step/Assign
# bn0/moving_mean/local_step/read
# bn0/AssignMovingAvg/bn0/moving_mean/sub
# bn0/AssignMovingAvg/bn0/moving_mean/mul
# bn0/AssignMovingAvg/bn0/moving_mean/bn0/moving_mean
# bn0/AssignMovingAvg/bn0/moving_mean/AssignAdd/value
# bn0/AssignMovingAvg/bn0/moving_mean/AssignAdd
# bn0/AssignMovingAvg/bn0/moving_mean/read
# bn0/AssignMovingAvg/bn0/moving_mean/sub_1/x
# bn0/AssignMovingAvg/bn0/moving_mean/sub_1
# bn0/AssignMovingAvg/bn0/moving_mean/read_1
# bn0/AssignMovingAvg/bn0/moving_mean/Pow
# bn0/AssignMovingAvg/bn0/moving_mean/sub_2/x
# bn0/AssignMovingAvg/bn0/moving_mean/sub_2
# bn0/AssignMovingAvg/bn0/moving_mean/truediv
# bn0/AssignMovingAvg/bn0/moving_mean/sub_3
# bn0/AssignMovingAvg
# bn0/AssignMovingAvg_1/decay
# bn0/AssignMovingAvg_1/bn0/moving_variance/zeros
# bn0/moving_variance/biased
# bn0/moving_variance/biased/Assign
# bn0/moving_variance/biased/read
# bn0/moving_variance/local_step/Initializer/zeros
# bn0/moving_variance/local_step
# bn0/moving_variance/local_step/Assign
# bn0/moving_variance/local_step/read
# bn0/AssignMovingAvg_1/bn0/moving_variance/sub
# bn0/AssignMovingAvg_1/bn0/moving_variance/mul
# bn0/AssignMovingAvg_1/bn0/moving_variance/bn0/moving_variance
# bn0/AssignMovingAvg_1/bn0/moving_variance/AssignAdd/value
# bn0/AssignMovingAvg_1/bn0/moving_variance/AssignAdd
# bn0/AssignMovingAvg_1/bn0/moving_variance/read
# bn0/AssignMovingAvg_1/bn0/moving_variance/sub_1/x
# bn0/AssignMovingAvg_1/bn0/moving_variance/sub_1
# bn0/AssignMovingAvg_1/bn0/moving_variance/read_1
# bn0/AssignMovingAvg_1/bn0/moving_variance/Pow
# bn0/AssignMovingAvg_1/bn0/moving_variance/sub_2/x
# bn0/AssignMovingAvg_1/bn0/moving_variance/sub_2
# bn0/AssignMovingAvg_1/bn0/moving_variance/truediv
# bn0/AssignMovingAvg_1/bn0/moving_variance/sub_3
# bn0/AssignMovingAvg_1
# bn0/cond/Switch
# bn0/cond/switch_t
# bn0/cond/switch_f
# bn0/cond/pred_id
# bn0/cond/Switch_1
# bn0/cond/FusedBatchNorm
# bn0/cond/FusedBatchNorm/Switch
# bn0/cond/FusedBatchNorm/Switch_1
# bn0/cond/FusedBatchNorm/Switch_2
# bn0/cond/FusedBatchNorm/Switch_3
# bn0/cond/FusedBatchNorm/Switch_4
# bn0/cond/Merge
# relu0/Relu
# zero_padding2d_2/Pad/paddings
# zero_padding2d_2/Pad
# pooling0/MaxPool
# stage1_unit1_bn1/Const
# stage1_unit1_bn1/gamma
# stage1_unit1_bn1/gamma/Assign
# stage1_unit1_bn1/gamma/read
# stage1_unit1_bn1/Const_1
# stage1_unit1_bn1/beta
# stage1_unit1_bn1/beta/Assign
# stage1_unit1_bn1/beta/read
# stage1_unit1_bn1/Const_2
# stage1_unit1_bn1/moving_mean
# stage1_unit1_bn1/moving_mean/Assign
# stage1_unit1_bn1/moving_mean/read
# stage1_unit1_bn1/Const_3
# stage1_unit1_bn1/moving_variance
# stage1_unit1_bn1/moving_variance/Assign
# stage1_unit1_bn1/moving_variance/read
# stage1_unit1_bn1/Const_4
# stage1_unit1_bn1/Const_5
# stage1_unit1_bn1/FusedBatchNorm
# stage1_unit1_bn1/Shape
# stage1_unit1_bn1/strided_slice/stack
# stage1_unit1_bn1/strided_slice/stack_1
# stage1_unit1_bn1/strided_slice/stack_2
# stage1_unit1_bn1/strided_slice
# stage1_unit1_bn1/Shape_1
# stage1_unit1_bn1/strided_slice_1/stack
# stage1_unit1_bn1/strided_slice_1/stack_1
# stage1_unit1_bn1/strided_slice_1/stack_2
# stage1_unit1_bn1/strided_slice_1
# stage1_unit1_bn1/Shape_2
# stage1_unit1_bn1/strided_slice_2/stack
# stage1_unit1_bn1/strided_slice_2/stack_1
# stage1_unit1_bn1/strided_slice_2/stack_2
# stage1_unit1_bn1/strided_slice_2
# stage1_unit1_bn1/Rank/packed
# stage1_unit1_bn1/Rank
# stage1_unit1_bn1/range/start
# stage1_unit1_bn1/range/delta
# stage1_unit1_bn1/range
# stage1_unit1_bn1/Prod/input
# stage1_unit1_bn1/Prod
# stage1_unit1_bn1/Cast
# stage1_unit1_bn1/sub/y
# stage1_unit1_bn1/sub
# stage1_unit1_bn1/truediv
# stage1_unit1_bn1/mul
# stage1_unit1_bn1/AssignMovingAvg/decay
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/zeros
# stage1_unit1_bn1/moving_mean/biased
# stage1_unit1_bn1/moving_mean/biased/Assign
# stage1_unit1_bn1/moving_mean/biased/read
# stage1_unit1_bn1/moving_mean/local_step/Initializer/zeros
# stage1_unit1_bn1/moving_mean/local_step
# stage1_unit1_bn1/moving_mean/local_step/Assign
# stage1_unit1_bn1/moving_mean/local_step/read
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/sub
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/mul
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/stage1_unit1_bn1/moving_mean
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/AssignAdd/value
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/AssignAdd
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/read
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/sub_1/x
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/sub_1
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/read_1
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/Pow
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/sub_2/x
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/sub_2
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/truediv
# stage1_unit1_bn1/AssignMovingAvg/stage1_unit1_bn1/moving_mean/sub_3
# stage1_unit1_bn1/AssignMovingAvg
# stage1_unit1_bn1/AssignMovingAvg_1/decay
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/zeros
# stage1_unit1_bn1/moving_variance/biased
# stage1_unit1_bn1/moving_variance/biased/Assign
# stage1_unit1_bn1/moving_variance/biased/read
# stage1_unit1_bn1/moving_variance/local_step/Initializer/zeros
# stage1_unit1_bn1/moving_variance/local_step
# stage1_unit1_bn1/moving_variance/local_step/Assign
# stage1_unit1_bn1/moving_variance/local_step/read
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/sub
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/mul
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/stage1_unit1_bn1/moving_variance
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/AssignAdd/value
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/AssignAdd
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/read
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/sub_1/x
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/sub_1
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/read_1
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/Pow
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/sub_2/x
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/sub_2
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/truediv
# stage1_unit1_bn1/AssignMovingAvg_1/stage1_unit1_bn1/moving_variance/sub_3
# stage1_unit1_bn1/AssignMovingAvg_1
# stage1_unit1_bn1/cond/Switch
# stage1_unit1_bn1/cond/switch_t
# stage1_unit1_bn1/cond/switch_f
# stage1_unit1_bn1/cond/pred_id
# stage1_unit1_bn1/cond/Switch_1
# stage1_unit1_bn1/cond/FusedBatchNorm
# stage1_unit1_bn1/cond/FusedBatchNorm/Switch
# stage1_unit1_bn1/cond/FusedBatchNorm/Switch_1
# stage1_unit1_bn1/cond/FusedBatchNorm/Switch_2
# stage1_unit1_bn1/cond/FusedBatchNorm/Switch_3
# stage1_unit1_bn1/cond/FusedBatchNorm/Switch_4
# stage1_unit1_bn1/cond/Merge
# stage1_unit1_relu1/Relu
# stage1_unit1_sc/random_uniform/shape
# stage1_unit1_sc/random_uniform/min
# stage1_unit1_sc/random_uniform/max
# stage1_unit1_sc/random_uniform/RandomUniform
# stage1_unit1_sc/random_uniform/sub
# stage1_unit1_sc/random_uniform/mul
# stage1_unit1_sc/random_uniform
# stage1_unit1_sc/kernel
# stage1_unit1_sc/kernel/Assign
# stage1_unit1_sc/kernel/read
# stage1_unit1_sc/convolution/dilation_rate
# stage1_unit1_sc/convolution
# stage1_unit1_conv1/random_uniform/shape
# stage1_unit1_conv1/random_uniform/min
# stage1_unit1_conv1/random_uniform/max
# stage1_unit1_conv1/random_uniform/RandomUniform
# stage1_unit1_conv1/random_uniform/sub
# stage1_unit1_conv1/random_uniform/mul
# stage1_unit1_conv1/random_uniform
# stage1_unit1_conv1/kernel
# stage1_unit1_conv1/kernel/Assign
# stage1_unit1_conv1/kernel/read
# stage1_unit1_conv1/convolution/dilation_rate
# stage1_unit1_conv1/convolution
# stage1_unit1_bn2/Const
# stage1_unit1_bn2/gamma
# stage1_unit1_bn2/gamma/Assign
# stage1_unit1_bn2/gamma/read
# stage1_unit1_bn2/Const_1
# stage1_unit1_bn2/beta
# stage1_unit1_bn2/beta/Assign
# stage1_unit1_bn2/beta/read
# stage1_unit1_bn2/Const_2
# stage1_unit1_bn2/moving_mean
# stage1_unit1_bn2/moving_mean/Assign
# stage1_unit1_bn2/moving_mean/read
# stage1_unit1_bn2/Const_3
# stage1_unit1_bn2/moving_variance
# stage1_unit1_bn2/moving_variance/Assign
# stage1_unit1_bn2/moving_variance/read
# stage1_unit1_bn2/Const_4
# stage1_unit1_bn2/Const_5
# stage1_unit1_bn2/FusedBatchNorm
# stage1_unit1_bn2/Shape
# stage1_unit1_bn2/strided_slice/stack
# stage1_unit1_bn2/strided_slice/stack_1
# stage1_unit1_bn2/strided_slice/stack_2
# stage1_unit1_bn2/strided_slice
# stage1_unit1_bn2/Shape_1
# stage1_unit1_bn2/strided_slice_1/stack
# stage1_unit1_bn2/strided_slice_1/stack_1
# stage1_unit1_bn2/strided_slice_1/stack_2
# stage1_unit1_bn2/strided_slice_1
# stage1_unit1_bn2/Shape_2
# stage1_unit1_bn2/strided_slice_2/stack
# stage1_unit1_bn2/strided_slice_2/stack_1
# stage1_unit1_bn2/strided_slice_2/stack_2
# stage1_unit1_bn2/strided_slice_2
# stage1_unit1_bn2/Rank/packed
# stage1_unit1_bn2/Rank
# stage1_unit1_bn2/range/start
# stage1_unit1_bn2/range/delta
# stage1_unit1_bn2/range
# stage1_unit1_bn2/Prod/input
# stage1_unit1_bn2/Prod
# stage1_unit1_bn2/Cast
# stage1_unit1_bn2/sub/y
# stage1_unit1_bn2/sub
# stage1_unit1_bn2/truediv
# stage1_unit1_bn2/mul
# stage1_unit1_bn2/AssignMovingAvg/decay
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/zeros
# stage1_unit1_bn2/moving_mean/biased
# stage1_unit1_bn2/moving_mean/biased/Assign
# stage1_unit1_bn2/moving_mean/biased/read
# stage1_unit1_bn2/moving_mean/local_step/Initializer/zeros
# stage1_unit1_bn2/moving_mean/local_step
# stage1_unit1_bn2/moving_mean/local_step/Assign
# stage1_unit1_bn2/moving_mean/local_step/read
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/sub
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/mul
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/stage1_unit1_bn2/moving_mean
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/AssignAdd/value
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/AssignAdd
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/read
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/sub_1/x
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/sub_1
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/read_1
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/Pow
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/sub_2/x
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/sub_2
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/truediv
# stage1_unit1_bn2/AssignMovingAvg/stage1_unit1_bn2/moving_mean/sub_3
# stage1_unit1_bn2/AssignMovingAvg
# stage1_unit1_bn2/AssignMovingAvg_1/decay
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/zeros
# stage1_unit1_bn2/moving_variance/biased
# stage1_unit1_bn2/moving_variance/biased/Assign
# stage1_unit1_bn2/moving_variance/biased/read
# stage1_unit1_bn2/moving_variance/local_step/Initializer/zeros
# stage1_unit1_bn2/moving_variance/local_step
# stage1_unit1_bn2/moving_variance/local_step/Assign
# stage1_unit1_bn2/moving_variance/local_step/read
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/sub
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/mul
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/stage1_unit1_bn2/moving_variance
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/AssignAdd/value
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/AssignAdd
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/read
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/sub_1/x
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/sub_1
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/read_1
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/Pow
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/sub_2/x
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/sub_2
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/truediv
# stage1_unit1_bn2/AssignMovingAvg_1/stage1_unit1_bn2/moving_variance/sub_3
# stage1_unit1_bn2/AssignMovingAvg_1
# stage1_unit1_bn2/cond/Switch
# stage1_unit1_bn2/cond/switch_t
# stage1_unit1_bn2/cond/switch_f
# stage1_unit1_bn2/cond/pred_id
# stage1_unit1_bn2/cond/Switch_1
# stage1_unit1_bn2/cond/FusedBatchNorm
# stage1_unit1_bn2/cond/FusedBatchNorm/Switch
# stage1_unit1_bn2/cond/FusedBatchNorm/Switch_1
# stage1_unit1_bn2/cond/FusedBatchNorm/Switch_2
# stage1_unit1_bn2/cond/FusedBatchNorm/Switch_3
# stage1_unit1_bn2/cond/FusedBatchNorm/Switch_4
# stage1_unit1_bn2/cond/Merge
# stage1_unit1_relu2/Relu
# zero_padding2d_3/Pad/paddings
# zero_padding2d_3/Pad
# stage1_unit1_conv2/random_uniform/shape
# stage1_unit1_conv2/random_uniform/min
# stage1_unit1_conv2/random_uniform/max
# stage1_unit1_conv2/random_uniform/RandomUniform
# stage1_unit1_conv2/random_uniform/sub
# stage1_unit1_conv2/random_uniform/mul
# stage1_unit1_conv2/random_uniform
# stage1_unit1_conv2/kernel
# stage1_unit1_conv2/kernel/Assign
# stage1_unit1_conv2/kernel/read
# stage1_unit1_conv2/convolution/dilation_rate
# stage1_unit1_conv2/convolution
# stage1_unit1_bn3/Const
# stage1_unit1_bn3/gamma
# stage1_unit1_bn3/gamma/Assign
# stage1_unit1_bn3/gamma/read
# stage1_unit1_bn3/Const_1
# stage1_unit1_bn3/beta
# stage1_unit1_bn3/beta/Assign
# stage1_unit1_bn3/beta/read
# stage1_unit1_bn3/Const_2
# stage1_unit1_bn3/moving_mean
# stage1_unit1_bn3/moving_mean/Assign
# stage1_unit1_bn3/moving_mean/read
# stage1_unit1_bn3/Const_3
# stage1_unit1_bn3/moving_variance
# stage1_unit1_bn3/moving_variance/Assign
# stage1_unit1_bn3/moving_variance/read
# stage1_unit1_bn3/Const_4
# stage1_unit1_bn3/Const_5
# stage1_unit1_bn3/FusedBatchNorm
# stage1_unit1_bn3/Shape
# stage1_unit1_bn3/strided_slice/stack
# stage1_unit1_bn3/strided_slice/stack_1
# stage1_unit1_bn3/strided_slice/stack_2
# stage1_unit1_bn3/strided_slice
# stage1_unit1_bn3/Shape_1
# stage1_unit1_bn3/strided_slice_1/stack
# stage1_unit1_bn3/strided_slice_1/stack_1
# stage1_unit1_bn3/strided_slice_1/stack_2
# stage1_unit1_bn3/strided_slice_1
# stage1_unit1_bn3/Shape_2
# stage1_unit1_bn3/strided_slice_2/stack
# stage1_unit1_bn3/strided_slice_2/stack_1
# stage1_unit1_bn3/strided_slice_2/stack_2
# stage1_unit1_bn3/strided_slice_2
# stage1_unit1_bn3/Rank/packed
# stage1_unit1_bn3/Rank
# stage1_unit1_bn3/range/start
# stage1_unit1_bn3/range/delta
# stage1_unit1_bn3/range
# stage1_unit1_bn3/Prod/input
# stage1_unit1_bn3/Prod
# stage1_unit1_bn3/Cast
# stage1_unit1_bn3/sub/y
# stage1_unit1_bn3/sub
# stage1_unit1_bn3/truediv
# stage1_unit1_bn3/mul
# stage1_unit1_bn3/AssignMovingAvg/decay
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/zeros
# stage1_unit1_bn3/moving_mean/biased
# stage1_unit1_bn3/moving_mean/biased/Assign
# stage1_unit1_bn3/moving_mean/biased/read
# stage1_unit1_bn3/moving_mean/local_step/Initializer/zeros
# stage1_unit1_bn3/moving_mean/local_step
# stage1_unit1_bn3/moving_mean/local_step/Assign
# stage1_unit1_bn3/moving_mean/local_step/read
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/sub
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/mul
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/stage1_unit1_bn3/moving_mean
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/AssignAdd/value
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/AssignAdd
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/read
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/sub_1/x
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/sub_1
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/read_1
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/Pow
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/sub_2/x
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/sub_2
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/truediv
# stage1_unit1_bn3/AssignMovingAvg/stage1_unit1_bn3/moving_mean/sub_3
# stage1_unit1_bn3/AssignMovingAvg
# stage1_unit1_bn3/AssignMovingAvg_1/decay
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/zeros
# stage1_unit1_bn3/moving_variance/biased
# stage1_unit1_bn3/moving_variance/biased/Assign
# stage1_unit1_bn3/moving_variance/biased/read
# stage1_unit1_bn3/moving_variance/local_step/Initializer/zeros
# stage1_unit1_bn3/moving_variance/local_step
# stage1_unit1_bn3/moving_variance/local_step/Assign
# stage1_unit1_bn3/moving_variance/local_step/read
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/sub
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/mul
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/stage1_unit1_bn3/moving_variance
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/AssignAdd/value
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/AssignAdd
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/read
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/sub_1/x
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/sub_1
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/read_1
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/Pow
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/sub_2/x
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/sub_2
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/truediv
# stage1_unit1_bn3/AssignMovingAvg_1/stage1_unit1_bn3/moving_variance/sub_3
# stage1_unit1_bn3/AssignMovingAvg_1
# stage1_unit1_bn3/cond/Switch
# stage1_unit1_bn3/cond/switch_t
# stage1_unit1_bn3/cond/switch_f
# stage1_unit1_bn3/cond/pred_id
# stage1_unit1_bn3/cond/Switch_1
# stage1_unit1_bn3/cond/FusedBatchNorm
# stage1_unit1_bn3/cond/FusedBatchNorm/Switch
# stage1_unit1_bn3/cond/FusedBatchNorm/Switch_1
# stage1_unit1_bn3/cond/FusedBatchNorm/Switch_2
# stage1_unit1_bn3/cond/FusedBatchNorm/Switch_3
# stage1_unit1_bn3/cond/FusedBatchNorm/Switch_4
# stage1_unit1_bn3/cond/Merge
# stage1_unit1_relu3/Relu
# stage1_unit1_conv3/random_uniform/shape
# stage1_unit1_conv3/random_uniform/min
# stage1_unit1_conv3/random_uniform/max
# stage1_unit1_conv3/random_uniform/RandomUniform
# stage1_unit1_conv3/random_uniform/sub
# stage1_unit1_conv3/random_uniform/mul
# stage1_unit1_conv3/random_uniform
# stage1_unit1_conv3/kernel
# stage1_unit1_conv3/kernel/Assign
# stage1_unit1_conv3/kernel/read
# stage1_unit1_conv3/convolution/dilation_rate
# stage1_unit1_conv3/convolution
# add_1/add
# stage1_unit2_bn1/Const
# stage1_unit2_bn1/gamma
# stage1_unit2_bn1/gamma/Assign
# stage1_unit2_bn1/gamma/read
# stage1_unit2_bn1/Const_1
# stage1_unit2_bn1/beta
# stage1_unit2_bn1/beta/Assign
# stage1_unit2_bn1/beta/read
# stage1_unit2_bn1/Const_2
# stage1_unit2_bn1/moving_mean
# stage1_unit2_bn1/moving_mean/Assign
# stage1_unit2_bn1/moving_mean/read
# stage1_unit2_bn1/Const_3
# stage1_unit2_bn1/moving_variance
# stage1_unit2_bn1/moving_variance/Assign
# stage1_unit2_bn1/moving_variance/read
# stage1_unit2_bn1/Const_4
# stage1_unit2_bn1/Const_5
# stage1_unit2_bn1/FusedBatchNorm
# stage1_unit2_bn1/Shape
# stage1_unit2_bn1/strided_slice/stack
# stage1_unit2_bn1/strided_slice/stack_1
# stage1_unit2_bn1/strided_slice/stack_2
# stage1_unit2_bn1/strided_slice
# stage1_unit2_bn1/Shape_1
# stage1_unit2_bn1/strided_slice_1/stack
# stage1_unit2_bn1/strided_slice_1/stack_1
# stage1_unit2_bn1/strided_slice_1/stack_2
# stage1_unit2_bn1/strided_slice_1
# stage1_unit2_bn1/Shape_2
# stage1_unit2_bn1/strided_slice_2/stack
# stage1_unit2_bn1/strided_slice_2/stack_1
# stage1_unit2_bn1/strided_slice_2/stack_2
# stage1_unit2_bn1/strided_slice_2
# stage1_unit2_bn1/Rank/packed
# stage1_unit2_bn1/Rank
# stage1_unit2_bn1/range/start
# stage1_unit2_bn1/range/delta
# stage1_unit2_bn1/range
# stage1_unit2_bn1/Prod/input
# stage1_unit2_bn1/Prod
# stage1_unit2_bn1/Cast
# stage1_unit2_bn1/sub/y
# stage1_unit2_bn1/sub
# stage1_unit2_bn1/truediv
# stage1_unit2_bn1/mul
# stage1_unit2_bn1/AssignMovingAvg/decay
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/zeros
# stage1_unit2_bn1/moving_mean/biased
# stage1_unit2_bn1/moving_mean/biased/Assign
# stage1_unit2_bn1/moving_mean/biased/read
# stage1_unit2_bn1/moving_mean/local_step/Initializer/zeros
# stage1_unit2_bn1/moving_mean/local_step
# stage1_unit2_bn1/moving_mean/local_step/Assign
# stage1_unit2_bn1/moving_mean/local_step/read
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/sub
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/mul
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/stage1_unit2_bn1/moving_mean
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/AssignAdd/value
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/AssignAdd
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/read
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/sub_1/x
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/sub_1
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/read_1
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/Pow
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/sub_2/x
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/sub_2
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/truediv
# stage1_unit2_bn1/AssignMovingAvg/stage1_unit2_bn1/moving_mean/sub_3
# stage1_unit2_bn1/AssignMovingAvg
# stage1_unit2_bn1/AssignMovingAvg_1/decay
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/zeros
# stage1_unit2_bn1/moving_variance/biased
# stage1_unit2_bn1/moving_variance/biased/Assign
# stage1_unit2_bn1/moving_variance/biased/read
# stage1_unit2_bn1/moving_variance/local_step/Initializer/zeros
# stage1_unit2_bn1/moving_variance/local_step
# stage1_unit2_bn1/moving_variance/local_step/Assign
# stage1_unit2_bn1/moving_variance/local_step/read
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/sub
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/mul
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/stage1_unit2_bn1/moving_variance
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/AssignAdd/value
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/AssignAdd
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/read
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/sub_1/x
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/sub_1
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/read_1
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/Pow
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/sub_2/x
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/sub_2
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/truediv
# stage1_unit2_bn1/AssignMovingAvg_1/stage1_unit2_bn1/moving_variance/sub_3
# stage1_unit2_bn1/AssignMovingAvg_1
# stage1_unit2_bn1/cond/Switch
# stage1_unit2_bn1/cond/switch_t
# stage1_unit2_bn1/cond/switch_f
# stage1_unit2_bn1/cond/pred_id
# stage1_unit2_bn1/cond/Switch_1
# stage1_unit2_bn1/cond/FusedBatchNorm
# stage1_unit2_bn1/cond/FusedBatchNorm/Switch
# stage1_unit2_bn1/cond/FusedBatchNorm/Switch_1
# stage1_unit2_bn1/cond/FusedBatchNorm/Switch_2
# stage1_unit2_bn1/cond/FusedBatchNorm/Switch_3
# stage1_unit2_bn1/cond/FusedBatchNorm/Switch_4
# stage1_unit2_bn1/cond/Merge
# stage1_unit2_relu1/Relu
# stage1_unit2_conv1/random_uniform/shape
# stage1_unit2_conv1/random_uniform/min
# stage1_unit2_conv1/random_uniform/max
# stage1_unit2_conv1/random_uniform/RandomUniform
# stage1_unit2_conv1/random_uniform/sub
# stage1_unit2_conv1/random_uniform/mul
# stage1_unit2_conv1/random_uniform
# stage1_unit2_conv1/kernel
# stage1_unit2_conv1/kernel/Assign
# stage1_unit2_conv1/kernel/read
# stage1_unit2_conv1/convolution/dilation_rate
# stage1_unit2_conv1/convolution
# stage1_unit2_bn2/Const
# stage1_unit2_bn2/gamma
# stage1_unit2_bn2/gamma/Assign
# stage1_unit2_bn2/gamma/read
# stage1_unit2_bn2/Const_1
# stage1_unit2_bn2/beta
# stage1_unit2_bn2/beta/Assign
# stage1_unit2_bn2/beta/read
# stage1_unit2_bn2/Const_2
# stage1_unit2_bn2/moving_mean
# stage1_unit2_bn2/moving_mean/Assign
# stage1_unit2_bn2/moving_mean/read
# stage1_unit2_bn2/Const_3
# stage1_unit2_bn2/moving_variance
# stage1_unit2_bn2/moving_variance/Assign
# stage1_unit2_bn2/moving_variance/read
# stage1_unit2_bn2/Const_4
# stage1_unit2_bn2/Const_5
# stage1_unit2_bn2/FusedBatchNorm
# stage1_unit2_bn2/Shape
# stage1_unit2_bn2/strided_slice/stack
# stage1_unit2_bn2/strided_slice/stack_1
# stage1_unit2_bn2/strided_slice/stack_2
# stage1_unit2_bn2/strided_slice
# stage1_unit2_bn2/Shape_1
# stage1_unit2_bn2/strided_slice_1/stack
# stage1_unit2_bn2/strided_slice_1/stack_1
# stage1_unit2_bn2/strided_slice_1/stack_2
# stage1_unit2_bn2/strided_slice_1
# stage1_unit2_bn2/Shape_2
# stage1_unit2_bn2/strided_slice_2/stack
# stage1_unit2_bn2/strided_slice_2/stack_1
# stage1_unit2_bn2/strided_slice_2/stack_2
# stage1_unit2_bn2/strided_slice_2
# stage1_unit2_bn2/Rank/packed
# stage1_unit2_bn2/Rank
# stage1_unit2_bn2/range/start
# stage1_unit2_bn2/range/delta
# stage1_unit2_bn2/range
# stage1_unit2_bn2/Prod/input
# stage1_unit2_bn2/Prod
# stage1_unit2_bn2/Cast
# stage1_unit2_bn2/sub/y
# stage1_unit2_bn2/sub
# stage1_unit2_bn2/truediv
# stage1_unit2_bn2/mul
# stage1_unit2_bn2/AssignMovingAvg/decay
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/zeros
# stage1_unit2_bn2/moving_mean/biased
# stage1_unit2_bn2/moving_mean/biased/Assign
# stage1_unit2_bn2/moving_mean/biased/read
# stage1_unit2_bn2/moving_mean/local_step/Initializer/zeros
# stage1_unit2_bn2/moving_mean/local_step
# stage1_unit2_bn2/moving_mean/local_step/Assign
# stage1_unit2_bn2/moving_mean/local_step/read
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/sub
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/mul
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/stage1_unit2_bn2/moving_mean
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/AssignAdd/value
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/AssignAdd
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/read
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/sub_1/x
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/sub_1
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/read_1
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/Pow
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/sub_2/x
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/sub_2
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/truediv
# stage1_unit2_bn2/AssignMovingAvg/stage1_unit2_bn2/moving_mean/sub_3
# stage1_unit2_bn2/AssignMovingAvg
# stage1_unit2_bn2/AssignMovingAvg_1/decay
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/zeros
# stage1_unit2_bn2/moving_variance/biased
# stage1_unit2_bn2/moving_variance/biased/Assign
# stage1_unit2_bn2/moving_variance/biased/read
# stage1_unit2_bn2/moving_variance/local_step/Initializer/zeros
# stage1_unit2_bn2/moving_variance/local_step
# stage1_unit2_bn2/moving_variance/local_step/Assign
# stage1_unit2_bn2/moving_variance/local_step/read
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/sub
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/mul
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/stage1_unit2_bn2/moving_variance
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/AssignAdd/value
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/AssignAdd
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/read
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/sub_1/x
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/sub_1
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/read_1
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/Pow
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/sub_2/x
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/sub_2
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/truediv
# stage1_unit2_bn2/AssignMovingAvg_1/stage1_unit2_bn2/moving_variance/sub_3
# stage1_unit2_bn2/AssignMovingAvg_1
# stage1_unit2_bn2/cond/Switch
# stage1_unit2_bn2/cond/switch_t
# stage1_unit2_bn2/cond/switch_f
# stage1_unit2_bn2/cond/pred_id
# stage1_unit2_bn2/cond/Switch_1
# stage1_unit2_bn2/cond/FusedBatchNorm
# stage1_unit2_bn2/cond/FusedBatchNorm/Switch
# stage1_unit2_bn2/cond/FusedBatchNorm/Switch_1
# stage1_unit2_bn2/cond/FusedBatchNorm/Switch_2
# stage1_unit2_bn2/cond/FusedBatchNorm/Switch_3
# stage1_unit2_bn2/cond/FusedBatchNorm/Switch_4
# stage1_unit2_bn2/cond/Merge
# stage1_unit2_relu2/Relu
# zero_padding2d_4/Pad/paddings
# zero_padding2d_4/Pad
# stage1_unit2_conv2/random_uniform/shape
# stage1_unit2_conv2/random_uniform/min
# stage1_unit2_conv2/random_uniform/max
# stage1_unit2_conv2/random_uniform/RandomUniform
# stage1_unit2_conv2/random_uniform/sub
# stage1_unit2_conv2/random_uniform/mul
# stage1_unit2_conv2/random_uniform
# stage1_unit2_conv2/kernel
# stage1_unit2_conv2/kernel/Assign
# stage1_unit2_conv2/kernel/read
# stage1_unit2_conv2/convolution/dilation_rate
# stage1_unit2_conv2/convolution
# stage1_unit2_bn3/Const
# stage1_unit2_bn3/gamma
# stage1_unit2_bn3/gamma/Assign
# stage1_unit2_bn3/gamma/read
# stage1_unit2_bn3/Const_1
# stage1_unit2_bn3/beta
# stage1_unit2_bn3/beta/Assign
# stage1_unit2_bn3/beta/read
# stage1_unit2_bn3/Const_2
# stage1_unit2_bn3/moving_mean
# stage1_unit2_bn3/moving_mean/Assign
# stage1_unit2_bn3/moving_mean/read
# stage1_unit2_bn3/Const_3
# stage1_unit2_bn3/moving_variance
# stage1_unit2_bn3/moving_variance/Assign
# stage1_unit2_bn3/moving_variance/read
# stage1_unit2_bn3/Const_4
# stage1_unit2_bn3/Const_5
# stage1_unit2_bn3/FusedBatchNorm
# stage1_unit2_bn3/Shape
# stage1_unit2_bn3/strided_slice/stack
# stage1_unit2_bn3/strided_slice/stack_1
# stage1_unit2_bn3/strided_slice/stack_2
# stage1_unit2_bn3/strided_slice
# stage1_unit2_bn3/Shape_1
# stage1_unit2_bn3/strided_slice_1/stack
# stage1_unit2_bn3/strided_slice_1/stack_1
# stage1_unit2_bn3/strided_slice_1/stack_2
# stage1_unit2_bn3/strided_slice_1
# stage1_unit2_bn3/Shape_2
# stage1_unit2_bn3/strided_slice_2/stack
# stage1_unit2_bn3/strided_slice_2/stack_1
# stage1_unit2_bn3/strided_slice_2/stack_2
# stage1_unit2_bn3/strided_slice_2
# stage1_unit2_bn3/Rank/packed
# stage1_unit2_bn3/Rank
# stage1_unit2_bn3/range/start
# stage1_unit2_bn3/range/delta
# stage1_unit2_bn3/range
# stage1_unit2_bn3/Prod/input
# stage1_unit2_bn3/Prod
# stage1_unit2_bn3/Cast
# stage1_unit2_bn3/sub/y
# stage1_unit2_bn3/sub
# stage1_unit2_bn3/truediv
# stage1_unit2_bn3/mul
# stage1_unit2_bn3/AssignMovingAvg/decay
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/zeros
# stage1_unit2_bn3/moving_mean/biased
# stage1_unit2_bn3/moving_mean/biased/Assign
# stage1_unit2_bn3/moving_mean/biased/read
# stage1_unit2_bn3/moving_mean/local_step/Initializer/zeros
# stage1_unit2_bn3/moving_mean/local_step
# stage1_unit2_bn3/moving_mean/local_step/Assign
# stage1_unit2_bn3/moving_mean/local_step/read
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/sub
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/mul
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/stage1_unit2_bn3/moving_mean
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/AssignAdd/value
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/AssignAdd
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/read
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/sub_1/x
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/sub_1
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/read_1
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/Pow
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/sub_2/x
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/sub_2
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/truediv
# stage1_unit2_bn3/AssignMovingAvg/stage1_unit2_bn3/moving_mean/sub_3
# stage1_unit2_bn3/AssignMovingAvg
# stage1_unit2_bn3/AssignMovingAvg_1/decay
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/zeros
# stage1_unit2_bn3/moving_variance/biased
# stage1_unit2_bn3/moving_variance/biased/Assign
# stage1_unit2_bn3/moving_variance/biased/read
# stage1_unit2_bn3/moving_variance/local_step/Initializer/zeros
# stage1_unit2_bn3/moving_variance/local_step
# stage1_unit2_bn3/moving_variance/local_step/Assign
# stage1_unit2_bn3/moving_variance/local_step/read
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/sub
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/mul
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/stage1_unit2_bn3/moving_variance
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/AssignAdd/value
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/AssignAdd
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/read
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/sub_1/x
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/sub_1
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/read_1
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/Pow
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/sub_2/x
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/sub_2
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/truediv
# stage1_unit2_bn3/AssignMovingAvg_1/stage1_unit2_bn3/moving_variance/sub_3
# stage1_unit2_bn3/AssignMovingAvg_1
# stage1_unit2_bn3/cond/Switch
# stage1_unit2_bn3/cond/switch_t
# stage1_unit2_bn3/cond/switch_f
# stage1_unit2_bn3/cond/pred_id
# stage1_unit2_bn3/cond/Switch_1
# stage1_unit2_bn3/cond/FusedBatchNorm
# stage1_unit2_bn3/cond/FusedBatchNorm/Switch
# stage1_unit2_bn3/cond/FusedBatchNorm/Switch_1
# stage1_unit2_bn3/cond/FusedBatchNorm/Switch_2
# stage1_unit2_bn3/cond/FusedBatchNorm/Switch_3
# stage1_unit2_bn3/cond/FusedBatchNorm/Switch_4
# stage1_unit2_bn3/cond/Merge
# stage1_unit2_relu3/Relu
# stage1_unit2_conv3/random_uniform/shape
# stage1_unit2_conv3/random_uniform/min
# stage1_unit2_conv3/random_uniform/max
# stage1_unit2_conv3/random_uniform/RandomUniform
# stage1_unit2_conv3/random_uniform/sub
# stage1_unit2_conv3/random_uniform/mul
# stage1_unit2_conv3/random_uniform
# stage1_unit2_conv3/kernel
# stage1_unit2_conv3/kernel/Assign
# stage1_unit2_conv3/kernel/read
# stage1_unit2_conv3/convolution/dilation_rate
# stage1_unit2_conv3/convolution
# add_2/add
# stage1_unit3_bn1/Const
# stage1_unit3_bn1/gamma
# stage1_unit3_bn1/gamma/Assign
# stage1_unit3_bn1/gamma/read
# stage1_unit3_bn1/Const_1
# stage1_unit3_bn1/beta
# stage1_unit3_bn1/beta/Assign
# stage1_unit3_bn1/beta/read
# stage1_unit3_bn1/Const_2
# stage1_unit3_bn1/moving_mean
# stage1_unit3_bn1/moving_mean/Assign
# stage1_unit3_bn1/moving_mean/read
# stage1_unit3_bn1/Const_3
# stage1_unit3_bn1/moving_variance
# stage1_unit3_bn1/moving_variance/Assign
# stage1_unit3_bn1/moving_variance/read
# stage1_unit3_bn1/Const_4
# stage1_unit3_bn1/Const_5
# stage1_unit3_bn1/FusedBatchNorm
# stage1_unit3_bn1/Shape
# stage1_unit3_bn1/strided_slice/stack
# stage1_unit3_bn1/strided_slice/stack_1
# stage1_unit3_bn1/strided_slice/stack_2
# stage1_unit3_bn1/strided_slice
# stage1_unit3_bn1/Shape_1
# stage1_unit3_bn1/strided_slice_1/stack
# stage1_unit3_bn1/strided_slice_1/stack_1
# stage1_unit3_bn1/strided_slice_1/stack_2
# stage1_unit3_bn1/strided_slice_1
# stage1_unit3_bn1/Shape_2
# stage1_unit3_bn1/strided_slice_2/stack
# stage1_unit3_bn1/strided_slice_2/stack_1
# stage1_unit3_bn1/strided_slice_2/stack_2
# stage1_unit3_bn1/strided_slice_2
# stage1_unit3_bn1/Rank/packed
# stage1_unit3_bn1/Rank
# stage1_unit3_bn1/range/start
# stage1_unit3_bn1/range/delta
# stage1_unit3_bn1/range
# stage1_unit3_bn1/Prod/input
# stage1_unit3_bn1/Prod
# stage1_unit3_bn1/Cast
# stage1_unit3_bn1/sub/y
# stage1_unit3_bn1/sub
# stage1_unit3_bn1/truediv
# stage1_unit3_bn1/mul
# stage1_unit3_bn1/AssignMovingAvg/decay
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/zeros
# stage1_unit3_bn1/moving_mean/biased
# stage1_unit3_bn1/moving_mean/biased/Assign
# stage1_unit3_bn1/moving_mean/biased/read
# stage1_unit3_bn1/moving_mean/local_step/Initializer/zeros
# stage1_unit3_bn1/moving_mean/local_step
# stage1_unit3_bn1/moving_mean/local_step/Assign
# stage1_unit3_bn1/moving_mean/local_step/read
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/sub
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/mul
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/stage1_unit3_bn1/moving_mean
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/AssignAdd/value
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/AssignAdd
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/read
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/sub_1/x
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/sub_1
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/read_1
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/Pow
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/sub_2/x
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/sub_2
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/truediv
# stage1_unit3_bn1/AssignMovingAvg/stage1_unit3_bn1/moving_mean/sub_3
# stage1_unit3_bn1/AssignMovingAvg
# stage1_unit3_bn1/AssignMovingAvg_1/decay
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/zeros
# stage1_unit3_bn1/moving_variance/biased
# stage1_unit3_bn1/moving_variance/biased/Assign
# stage1_unit3_bn1/moving_variance/biased/read
# stage1_unit3_bn1/moving_variance/local_step/Initializer/zeros
# stage1_unit3_bn1/moving_variance/local_step
# stage1_unit3_bn1/moving_variance/local_step/Assign
# stage1_unit3_bn1/moving_variance/local_step/read
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/sub
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/mul
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/stage1_unit3_bn1/moving_variance
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/AssignAdd/value
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/AssignAdd
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/read
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/sub_1/x
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/sub_1
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/read_1
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/Pow
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/sub_2/x
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/sub_2
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/truediv
# stage1_unit3_bn1/AssignMovingAvg_1/stage1_unit3_bn1/moving_variance/sub_3
# stage1_unit3_bn1/AssignMovingAvg_1
# stage1_unit3_bn1/cond/Switch
# stage1_unit3_bn1/cond/switch_t
# stage1_unit3_bn1/cond/switch_f
# stage1_unit3_bn1/cond/pred_id
# stage1_unit3_bn1/cond/Switch_1
# stage1_unit3_bn1/cond/FusedBatchNorm
# stage1_unit3_bn1/cond/FusedBatchNorm/Switch
# stage1_unit3_bn1/cond/FusedBatchNorm/Switch_1
# stage1_unit3_bn1/cond/FusedBatchNorm/Switch_2
# stage1_unit3_bn1/cond/FusedBatchNorm/Switch_3
# stage1_unit3_bn1/cond/FusedBatchNorm/Switch_4
# stage1_unit3_bn1/cond/Merge
# stage1_unit3_relu1/Relu
# stage1_unit3_conv1/random_uniform/shape
# stage1_unit3_conv1/random_uniform/min
# stage1_unit3_conv1/random_uniform/max
# stage1_unit3_conv1/random_uniform/RandomUniform
# stage1_unit3_conv1/random_uniform/sub
# stage1_unit3_conv1/random_uniform/mul
# stage1_unit3_conv1/random_uniform
# stage1_unit3_conv1/kernel
# stage1_unit3_conv1/kernel/Assign
# stage1_unit3_conv1/kernel/read
# stage1_unit3_conv1/convolution/dilation_rate
# stage1_unit3_conv1/convolution
# stage1_unit3_bn2/Const
# stage1_unit3_bn2/gamma
# stage1_unit3_bn2/gamma/Assign
# stage1_unit3_bn2/gamma/read
# stage1_unit3_bn2/Const_1
# stage1_unit3_bn2/beta
# stage1_unit3_bn2/beta/Assign
# stage1_unit3_bn2/beta/read
# stage1_unit3_bn2/Const_2
# stage1_unit3_bn2/moving_mean
# stage1_unit3_bn2/moving_mean/Assign
# stage1_unit3_bn2/moving_mean/read
# stage1_unit3_bn2/Const_3
# stage1_unit3_bn2/moving_variance
# stage1_unit3_bn2/moving_variance/Assign
# stage1_unit3_bn2/moving_variance/read
# stage1_unit3_bn2/Const_4
# stage1_unit3_bn2/Const_5
# stage1_unit3_bn2/FusedBatchNorm
# stage1_unit3_bn2/Shape
# stage1_unit3_bn2/strided_slice/stack
# stage1_unit3_bn2/strided_slice/stack_1
# stage1_unit3_bn2/strided_slice/stack_2
# stage1_unit3_bn2/strided_slice
# stage1_unit3_bn2/Shape_1
# stage1_unit3_bn2/strided_slice_1/stack
# stage1_unit3_bn2/strided_slice_1/stack_1
# stage1_unit3_bn2/strided_slice_1/stack_2
# stage1_unit3_bn2/strided_slice_1
# stage1_unit3_bn2/Shape_2
# stage1_unit3_bn2/strided_slice_2/stack
# stage1_unit3_bn2/strided_slice_2/stack_1
# stage1_unit3_bn2/strided_slice_2/stack_2
# stage1_unit3_bn2/strided_slice_2
# stage1_unit3_bn2/Rank/packed
# stage1_unit3_bn2/Rank
# stage1_unit3_bn2/range/start
# stage1_unit3_bn2/range/delta
# stage1_unit3_bn2/range
# stage1_unit3_bn2/Prod/input
# stage1_unit3_bn2/Prod
# stage1_unit3_bn2/Cast
# stage1_unit3_bn2/sub/y
# stage1_unit3_bn2/sub
# stage1_unit3_bn2/truediv
# stage1_unit3_bn2/mul
# stage1_unit3_bn2/AssignMovingAvg/decay
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/zeros
# stage1_unit3_bn2/moving_mean/biased
# stage1_unit3_bn2/moving_mean/biased/Assign
# stage1_unit3_bn2/moving_mean/biased/read
# stage1_unit3_bn2/moving_mean/local_step/Initializer/zeros
# stage1_unit3_bn2/moving_mean/local_step
# stage1_unit3_bn2/moving_mean/local_step/Assign
# stage1_unit3_bn2/moving_mean/local_step/read
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/sub
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/mul
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/stage1_unit3_bn2/moving_mean
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/AssignAdd/value
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/AssignAdd
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/read
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/sub_1/x
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/sub_1
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/read_1
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/Pow
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/sub_2/x
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/sub_2
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/truediv
# stage1_unit3_bn2/AssignMovingAvg/stage1_unit3_bn2/moving_mean/sub_3
# stage1_unit3_bn2/AssignMovingAvg
# stage1_unit3_bn2/AssignMovingAvg_1/decay
# stage1_unit3_bn2/AssignMovingAvg_1/stage1_unit3_bn2/moving_variance/zeros
# stage1_unit3_bn2/moving_variance/biased
# stage1_unit3_bn2/moving_variance/biased/Assign
# stage1_unit3_bn2/moving_variance/biased/read
# stage1_unit3_bn2/moving_variance/local_step/Initializer/zeros
# stage1_unit3_bn2/moving_variance/local_step
# stage1_unit3_bn2/moving_variance/local_step/Assign
# stage1_unit3_bn2/moving_variance/local_step/read
# ...
# decoder_stage3_bn2/cond/FusedBatchNorm/Switch_1
# decoder_stage3_bn2/cond/FusedBatchNorm/Switch_2
# decoder_stage3_bn2/cond/FusedBatchNorm/Switch_3
# decoder_stage3_bn2/cond/FusedBatchNorm/Switch_4
# decoder_stage3_bn2/cond/Merge
# decoder_stage3_relu2/Relu
# decoder_stage4_upsample/Shape
# decoder_stage4_upsample/strided_slice/stack
# decoder_stage4_upsample/strided_slice/stack_1
# decoder_stage4_upsample/strided_slice/stack_2
# decoder_stage4_upsample/strided_slice
# decoder_stage4_upsample/Const
# decoder_stage4_upsample/mul
# decoder_stage4_upsample/ResizeNearestNeighbor
# decoder_stage4_conv1/random_uniform/shape
# decoder_stage4_conv1/random_uniform/min
# decoder_stage4_conv1/random_uniform/max
# decoder_stage4_conv1/random_uniform/RandomUniform
# decoder_stage4_conv1/random_uniform/sub
# decoder_stage4_conv1/random_uniform/mul
# decoder_stage4_conv1/random_uniform
# decoder_stage4_conv1/kernel
# decoder_stage4_conv1/kernel/Assign
# decoder_stage4_conv1/kernel/read
# decoder_stage4_conv1/convolution/dilation_rate
# decoder_stage4_conv1/convolution
# decoder_stage4_bn1/Const
# decoder_stage4_bn1/gamma
# decoder_stage4_bn1/gamma/Assign
# decoder_stage4_bn1/gamma/read
# decoder_stage4_bn1/Const_1
# decoder_stage4_bn1/beta
# decoder_stage4_bn1/beta/Assign
# decoder_stage4_bn1/beta/read
# decoder_stage4_bn1/Const_2
# decoder_stage4_bn1/moving_mean
# decoder_stage4_bn1/moving_mean/Assign
# decoder_stage4_bn1/moving_mean/read
# decoder_stage4_bn1/Const_3
# decoder_stage4_bn1/moving_variance
# decoder_stage4_bn1/moving_variance/Assign
# decoder_stage4_bn1/moving_variance/read
# decoder_stage4_bn1/Const_4
# decoder_stage4_bn1/Const_5
# decoder_stage4_bn1/FusedBatchNorm
# decoder_stage4_bn1/Shape
# decoder_stage4_bn1/strided_slice/stack
# decoder_stage4_bn1/strided_slice/stack_1
# decoder_stage4_bn1/strided_slice/stack_2
# decoder_stage4_bn1/strided_slice
# decoder_stage4_bn1/Shape_1
# decoder_stage4_bn1/strided_slice_1/stack
# decoder_stage4_bn1/strided_slice_1/stack_1
# decoder_stage4_bn1/strided_slice_1/stack_2
# decoder_stage4_bn1/strided_slice_1
# decoder_stage4_bn1/Shape_2
# decoder_stage4_bn1/strided_slice_2/stack
# decoder_stage4_bn1/strided_slice_2/stack_1
# decoder_stage4_bn1/strided_slice_2/stack_2
# decoder_stage4_bn1/strided_slice_2
# decoder_stage4_bn1/Rank/packed
# decoder_stage4_bn1/Rank
# decoder_stage4_bn1/range/start
# decoder_stage4_bn1/range/delta
# decoder_stage4_bn1/range
# decoder_stage4_bn1/Prod/input
# decoder_stage4_bn1/Prod
# decoder_stage4_bn1/Cast
# decoder_stage4_bn1/sub/y
# decoder_stage4_bn1/sub
# decoder_stage4_bn1/truediv
# decoder_stage4_bn1/mul
# decoder_stage4_bn1/AssignMovingAvg/decay
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/zeros
# decoder_stage4_bn1/moving_mean/biased
# decoder_stage4_bn1/moving_mean/biased/Assign
# decoder_stage4_bn1/moving_mean/biased/read
# decoder_stage4_bn1/moving_mean/local_step/Initializer/zeros
# decoder_stage4_bn1/moving_mean/local_step
# decoder_stage4_bn1/moving_mean/local_step/Assign
# decoder_stage4_bn1/moving_mean/local_step/read
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/sub
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/mul
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/decoder_stage4_bn1/moving_mean
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/AssignAdd/value
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/AssignAdd
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/read
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/sub_1/x
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/sub_1
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/read_1
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/Pow
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/sub_2/x
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/sub_2
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/truediv
# decoder_stage4_bn1/AssignMovingAvg/decoder_stage4_bn1/moving_mean/sub_3
# decoder_stage4_bn1/AssignMovingAvg
# decoder_stage4_bn1/AssignMovingAvg_1/decay
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/zeros
# decoder_stage4_bn1/moving_variance/biased
# decoder_stage4_bn1/moving_variance/biased/Assign
# decoder_stage4_bn1/moving_variance/biased/read
# decoder_stage4_bn1/moving_variance/local_step/Initializer/zeros
# decoder_stage4_bn1/moving_variance/local_step
# decoder_stage4_bn1/moving_variance/local_step/Assign
# decoder_stage4_bn1/moving_variance/local_step/read
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/sub
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/mul
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/decoder_stage4_bn1/moving_variance
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/AssignAdd/value
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/AssignAdd
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/read
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/sub_1/x
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/sub_1
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/read_1
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/Pow
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/sub_2/x
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/sub_2
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/truediv
# decoder_stage4_bn1/AssignMovingAvg_1/decoder_stage4_bn1/moving_variance/sub_3
# decoder_stage4_bn1/AssignMovingAvg_1
# decoder_stage4_bn1/cond/Switch
# decoder_stage4_bn1/cond/switch_t
# decoder_stage4_bn1/cond/switch_f
# decoder_stage4_bn1/cond/pred_id
# decoder_stage4_bn1/cond/Switch_1
# decoder_stage4_bn1/cond/FusedBatchNorm
# decoder_stage4_bn1/cond/FusedBatchNorm/Switch
# decoder_stage4_bn1/cond/FusedBatchNorm/Switch_1
# decoder_stage4_bn1/cond/FusedBatchNorm/Switch_2
# decoder_stage4_bn1/cond/FusedBatchNorm/Switch_3
# decoder_stage4_bn1/cond/FusedBatchNorm/Switch_4
# decoder_stage4_bn1/cond/Merge
# decoder_stage4_relu1/Relu
# decoder_stage4_conv2/random_uniform/shape
# decoder_stage4_conv2/random_uniform/min
# decoder_stage4_conv2/random_uniform/max
# decoder_stage4_conv2/random_uniform/RandomUniform
# decoder_stage4_conv2/random_uniform/sub
# decoder_stage4_conv2/random_uniform/mul
# decoder_stage4_conv2/random_uniform
# decoder_stage4_conv2/kernel
# decoder_stage4_conv2/kernel/Assign
# decoder_stage4_conv2/kernel/read
# decoder_stage4_conv2/convolution/dilation_rate
# decoder_stage4_conv2/convolution
# decoder_stage4_bn2/Const
# decoder_stage4_bn2/gamma
# decoder_stage4_bn2/gamma/Assign
# decoder_stage4_bn2/gamma/read
# decoder_stage4_bn2/Const_1
# decoder_stage4_bn2/beta
# decoder_stage4_bn2/beta/Assign
# decoder_stage4_bn2/beta/read
# decoder_stage4_bn2/Const_2
# decoder_stage4_bn2/moving_mean
# decoder_stage4_bn2/moving_mean/Assign
# decoder_stage4_bn2/moving_mean/read
# decoder_stage4_bn2/Const_3
# decoder_stage4_bn2/moving_variance
# decoder_stage4_bn2/moving_variance/Assign
# decoder_stage4_bn2/moving_variance/read
# decoder_stage4_bn2/Const_4
# decoder_stage4_bn2/Const_5
# decoder_stage4_bn2/FusedBatchNorm
# decoder_stage4_bn2/Shape
# decoder_stage4_bn2/strided_slice/stack
# decoder_stage4_bn2/strided_slice/stack_1
# decoder_stage4_bn2/strided_slice/stack_2
# decoder_stage4_bn2/strided_slice
# decoder_stage4_bn2/Shape_1
# decoder_stage4_bn2/strided_slice_1/stack
# decoder_stage4_bn2/strided_slice_1/stack_1
# decoder_stage4_bn2/strided_slice_1/stack_2
# decoder_stage4_bn2/strided_slice_1
# decoder_stage4_bn2/Shape_2
# decoder_stage4_bn2/strided_slice_2/stack
# decoder_stage4_bn2/strided_slice_2/stack_1
# decoder_stage4_bn2/strided_slice_2/stack_2
# decoder_stage4_bn2/strided_slice_2
# decoder_stage4_bn2/Rank/packed
# decoder_stage4_bn2/Rank
# decoder_stage4_bn2/range/start
# decoder_stage4_bn2/range/delta
# decoder_stage4_bn2/range
# decoder_stage4_bn2/Prod/input
# decoder_stage4_bn2/Prod
# decoder_stage4_bn2/Cast
# decoder_stage4_bn2/sub/y
# decoder_stage4_bn2/sub
# decoder_stage4_bn2/truediv
# decoder_stage4_bn2/mul
# decoder_stage4_bn2/AssignMovingAvg/decay
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/zeros
# decoder_stage4_bn2/moving_mean/biased
# decoder_stage4_bn2/moving_mean/biased/Assign
# decoder_stage4_bn2/moving_mean/biased/read
# decoder_stage4_bn2/moving_mean/local_step/Initializer/zeros
# decoder_stage4_bn2/moving_mean/local_step
# decoder_stage4_bn2/moving_mean/local_step/Assign
# decoder_stage4_bn2/moving_mean/local_step/read
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/sub
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/mul
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/decoder_stage4_bn2/moving_mean
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/AssignAdd/value
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/AssignAdd
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/read
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/sub_1/x
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/sub_1
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/read_1
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/Pow
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/sub_2/x
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/sub_2
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/truediv
# decoder_stage4_bn2/AssignMovingAvg/decoder_stage4_bn2/moving_mean/sub_3
# decoder_stage4_bn2/AssignMovingAvg
# decoder_stage4_bn2/AssignMovingAvg_1/decay
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/zeros
# decoder_stage4_bn2/moving_variance/biased
# decoder_stage4_bn2/moving_variance/biased/Assign
# decoder_stage4_bn2/moving_variance/biased/read
# decoder_stage4_bn2/moving_variance/local_step/Initializer/zeros
# decoder_stage4_bn2/moving_variance/local_step
# decoder_stage4_bn2/moving_variance/local_step/Assign
# decoder_stage4_bn2/moving_variance/local_step/read
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/sub
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/mul
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/decoder_stage4_bn2/moving_variance
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/AssignAdd/value
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/AssignAdd
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/read
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/sub_1/x
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/sub_1
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/read_1
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/Pow
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/sub_2/x
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/sub_2
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/truediv
# decoder_stage4_bn2/AssignMovingAvg_1/decoder_stage4_bn2/moving_variance/sub_3
# decoder_stage4_bn2/AssignMovingAvg_1
# decoder_stage4_bn2/cond/Switch
# decoder_stage4_bn2/cond/switch_t
# decoder_stage4_bn2/cond/switch_f
# decoder_stage4_bn2/cond/pred_id
# decoder_stage4_bn2/cond/Switch_1
# decoder_stage4_bn2/cond/FusedBatchNorm
# decoder_stage4_bn2/cond/FusedBatchNorm/Switch
# decoder_stage4_bn2/cond/FusedBatchNorm/Switch_1
# decoder_stage4_bn2/cond/FusedBatchNorm/Switch_2
# decoder_stage4_bn2/cond/FusedBatchNorm/Switch_3
# decoder_stage4_bn2/cond/FusedBatchNorm/Switch_4
# decoder_stage4_bn2/cond/Merge
# decoder_stage4_relu2/Relu
# final_conv/random_uniform/shape
# final_conv/random_uniform/min
# final_conv/random_uniform/max
# final_conv/random_uniform/RandomUniform
# final_conv/random_uniform/sub
# final_conv/random_uniform/mul
# final_conv/random_uniform
# final_conv/kernel
# final_conv/kernel/Assign
# final_conv/kernel/read
# final_conv/Const
# final_conv/bias
# final_conv/bias/Assign
# final_conv/bias/read
# final_conv/convolution/dilation_rate
# final_conv/convolution
# final_conv/BiasAdd
# sigmoid/Sigmoid
# Placeholder_256
# Assign_256
# Placeholder_257
# Assign_257
# Placeholder_258
# Assign_258
# Placeholder_259
# Assign_259
# Placeholder_260
# Assign_260
# Placeholder_261
# Assign_261
# Placeholder_262
# Assign_262
# Placeholder_263
# Assign_263
# Placeholder_264
# Assign_264
# Placeholder_265
# Assign_265
# Placeholder_266
# Assign_266
# Placeholder_267
# Assign_267
# Placeholder_268
# Assign_268
# Placeholder_269
# Assign_269
# Placeholder_270
# Assign_270
# Placeholder_271
# Assign_271
# Placeholder_272
# Assign_272
# Placeholder_273
# Assign_273
# Placeholder_274
# Assign_274
# Placeholder_275
# Assign_275
# Placeholder_276
# Assign_276
# Placeholder_277
# Assign_277
# Placeholder_278
# Assign_278
# Placeholder_279
# Assign_279
# Placeholder_280
# Assign_280
# Placeholder_281
# Assign_281
# Placeholder_282
# Assign_282
# Placeholder_283
# Assign_283
# Placeholder_284
# Assign_284
# Placeholder_285
# Assign_285
# Placeholder_286
# Assign_286
# Placeholder_287
# Assign_287
# Placeholder_288
# Assign_288
# Placeholder_289
# Assign_289
# Placeholder_290
# Assign_290
# Placeholder_291
# Assign_291
# Placeholder_292
# Assign_292
# Placeholder_293
# Assign_293
# Placeholder_294
# Assign_294
# Placeholder_295
# Assign_295
# Placeholder_296
# Assign_296
# Placeholder_297
# Assign_297
# Placeholder_298
# Assign_298
# Placeholder_299
# Assign_299
# Placeholder_300
# Assign_300
# Placeholder_301
# Assign_301
# Placeholder_302
# Assign_302
# Placeholder_303
# Assign_303
# Placeholder_304
# Assign_304
# Placeholder_305
# Assign_305
# Placeholder_306
# Assign_306
# Placeholder_307
# Assign_307
# IsVariableInitialized_457
# IsVariableInitialized_458
# IsVariableInitialized_459
# IsVariableInitialized_460
# IsVariableInitialized_461
# IsVariableInitialized_462
# IsVariableInitialized_463
# IsVariableInitialized_464
# IsVariableInitialized_465
# IsVariableInitialized_466
# IsVariableInitialized_467
# IsVariableInitialized_468
# IsVariableInitialized_469
# IsVariableInitialized_470
# IsVariableInitialized_471
# IsVariableInitialized_472
# IsVariableInitialized_473
# IsVariableInitialized_474
# IsVariableInitialized_475
# IsVariableInitialized_476
# IsVariableInitialized_477
# IsVariableInitialized_478
# IsVariableInitialized_479
# IsVariableInitialized_480
# IsVariableInitialized_481
# IsVariableInitialized_482
# IsVariableInitialized_483
# IsVariableInitialized_484
# IsVariableInitialized_485
# IsVariableInitialized_486
# IsVariableInitialized_487
# IsVariableInitialized_488
# IsVariableInitialized_489
# IsVariableInitialized_490
# IsVariableInitialized_491
# IsVariableInitialized_492
# IsVariableInitialized_493
# IsVariableInitialized_494
# IsVariableInitialized_495
# IsVariableInitialized_496
# IsVariableInitialized_497
# IsVariableInitialized_498
# IsVariableInitialized_499
# IsVariableInitialized_500
# IsVariableInitialized_501
# IsVariableInitialized_502
# IsVariableInitialized_503
# IsVariableInitialized_504
# IsVariableInitialized_505
# IsVariableInitialized_506
# IsVariableInitialized_507
# IsVariableInitialized_508
# IsVariableInitialized_509
# IsVariableInitialized_510
# IsVariableInitialized_511
# IsVariableInitialized_512
# IsVariableInitialized_513
# IsVariableInitialized_514
# IsVariableInitialized_515
# IsVariableInitialized_516
# IsVariableInitialized_517
# IsVariableInitialized_518
# IsVariableInitialized_519
# IsVariableInitialized_520
# IsVariableInitialized_521
# IsVariableInitialized_522
# IsVariableInitialized_523
# IsVariableInitialized_524
# IsVariableInitialized_525
# IsVariableInitialized_526
# IsVariableInitialized_527
# IsVariableInitialized_528
# IsVariableInitialized_529
# IsVariableInitialized_530
# IsVariableInitialized_531
# IsVariableInitialized_532
# IsVariableInitialized_533
# IsVariableInitialized_534
# IsVariableInitialized_535
# IsVariableInitialized_536
# IsVariableInitialized_537
# IsVariableInitialized_538
# IsVariableInitialized_539
# IsVariableInitialized_540
# IsVariableInitialized_541
# IsVariableInitialized_542
# IsVariableInitialized_543
# IsVariableInitialized_544
# IsVariableInitialized_545
# IsVariableInitialized_546
# IsVariableInitialized_547
# IsVariableInitialized_548
# init_1

# %%
# Converting a tf.keras model.
converter = tf.lite.TFLiteConverter.from_session(K.get_session(), model.inputs, model.outputs)
converter.post_training_quantize=True
tflite_model = converter.convert()
with open(os.path.join(MODEL_PATH,tflite_filename), "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Froze 308 variables.
# INFO:tensorflow:Froze 308 variables.
# INFO:tensorflow:Converted 308 variables to const ops.
# INFO:tensorflow:Converted 308 variables to const ops.

# %% [markdown]
# ### Freezing the model to .mlmodel

# %%
coreml_model = coremltools.converters.keras.convert(model,
                                                    input_names=input_node_names,
                                                    image_input_names=input_node_names,
                                                    output_names=output_node_names,
                                                    image_scale=1/255.0
                                                   )
# Out:
# 0 : data, <keras.engine.input_layer.InputLayer object at 0x7fd00071ad30>
# 1 : bn_data, <keras.layers.normalization.BatchNormalization object at 0x7fd00071a7b8>
# 2 : zero_padding2d_1, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf57b97470>
# 3 : conv0, <keras.layers.convolutional.Conv2D object at 0x7fd000712ef0>
# 4 : bn0, <keras.layers.normalization.BatchNormalization object at 0x7fcf5409aeb8>
# 5 : relu0, <keras.layers.core.Activation object at 0x7fcf5404ab38>
# 6 : zero_padding2d_2, <keras.layers.convolutional.ZeroPadding2D object at 0x7fd00071af60>
# 7 : pooling0, <keras.layers.pooling.MaxPooling2D object at 0x7fcf54078e10>
# 8 : stage1_unit1_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcf540629b0>
# 9 : stage1_unit1_relu1, <keras.layers.core.Activation object at 0x7fcf3c6fa588>
# 10 : stage1_unit1_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcf3c6e64a8>
# 11 : stage1_unit1_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcf3c676320>
# 12 : stage1_unit1_relu2, <keras.layers.core.Activation object at 0x7fcf3c6764a8>
# 13 : zero_padding2d_3, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf3c628f98>
# 14 : stage1_unit1_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcf3c5bfcf8>
# 15 : stage1_unit1_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcf3c56fdd8>
# 16 : stage1_unit1_relu3, <keras.layers.core.Activation object at 0x7fcf3c56fc18>
# 17 : stage1_unit1_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcf3c50e470>
# 18 : stage1_unit1_sc, <keras.layers.convolutional.Conv2D object at 0x7fcf3c6c9be0>
# 19 : add_1, <keras.layers.merge.Add object at 0x7fcf3c4e0fd0>
# 20 : stage1_unit2_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcf3c47d860>
# 21 : stage1_unit2_relu1, <keras.layers.core.Activation object at 0x7fcf3c46edd8>
# 22 : stage1_unit2_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcf3c427cf8>
# 23 : stage1_unit2_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcf3c3dfac8>
# 24 : stage1_unit2_relu2, <keras.layers.core.Activation object at 0x7fcf3c37d7f0>
# 25 : zero_padding2d_4, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf3c30a908>
# 26 : stage1_unit2_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcf3c324e48>
# 27 : stage1_unit2_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcf3c26acc0>
# 28 : stage1_unit2_relu3, <keras.layers.core.Activation object at 0x7fcf3c26aa90>
# 29 : stage1_unit2_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcf3c222eb8>
# 30 : add_2, <keras.layers.merge.Add object at 0x7fcf3c1d9e80>
# 31 : stage1_unit3_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcf3c179748>
# 32 : stage1_unit3_relu1, <keras.layers.core.Activation object at 0x7fcf3c16acf8>
# 33 : stage1_unit3_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcf3c121ef0>
# 34 : stage1_unit3_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcf3c0d7e10>
# 35 : stage1_unit3_relu2, <keras.layers.core.Activation object at 0x7fcf3c0f5860>
# 36 : zero_padding2d_5, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf307c97b8>
# 37 : stage1_unit3_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcf307e3cc0>
# 38 : stage1_unit3_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcf3072cb38>
# 39 : stage1_unit3_relu3, <keras.layers.core.Activation object at 0x7fcf3072c908>
# 40 : stage1_unit3_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcf306e3dd8>
# 41 : add_3, <keras.layers.merge.Add object at 0x7fcf3069a5c0>
# 42 : stage2_unit1_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcf3066c630>
# 43 : stage2_unit1_relu1, <keras.layers.core.Activation object at 0x7fcf3062bbe0>
# 44 : stage2_unit1_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcf305e0908>
# 45 : stage2_unit1_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcf305285c0>
# 46 : stage2_unit1_relu2, <keras.layers.core.Activation object at 0x7fcf305288d0>
# 47 : zero_padding2d_6, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf304df588>
# 48 : stage2_unit1_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcf304c6f60>
# 49 : stage2_unit1_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcf303bf8d0>
# 50 : stage2_unit1_relu3, <keras.layers.core.Activation object at 0x7fcf303bffd0>
# 51 : stage2_unit1_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcf304f7f28>
# 52 : stage2_unit1_sc, <keras.layers.convolutional.Conv2D object at 0x7fcf305c7f98>
# 53 : add_4, <keras.layers.merge.Add object at 0x7fcf303b0390>
# 54 : stage2_unit2_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcf30301710>
# 55 : stage2_unit2_relu1, <keras.layers.core.Activation object at 0x7fcf3033b978>
# 56 : stage2_unit2_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcf302dcfd0>
# 57 : stage2_unit2_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcf302ae358>
# 58 : stage2_unit2_relu2, <keras.layers.core.Activation object at 0x7fcf3024d4e0>
# 59 : zero_padding2d_7, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf301dc438>
# 60 : stage2_unit2_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcf3023b8d0>
# 61 : stage2_unit2_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcf3013a7b8>
# 62 : stage2_unit2_relu3, <keras.layers.core.Activation object at 0x7fcf3013af28>
# 63 : stage2_unit2_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcf3013afd0>
# 64 : add_5, <keras.layers.merge.Add object at 0x7fcf300ab240>
# 65 : stage2_unit3_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcf30057f60>
# 66 : stage2_unit3_relu1, <keras.layers.core.Activation object at 0x7fcf1c7f8860>
# 67 : stage2_unit3_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcf1c79feb8>
# 68 : stage2_unit3_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcf1c76a1d0>
# 69 : stage2_unit3_relu2, <keras.layers.core.Activation object at 0x7fcf1c709358>
# 70 : zero_padding2d_8, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf1c6f7518>
# 71 : stage2_unit3_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcf1c6f77b8>
# 72 : stage2_unit3_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcf1c580630>
# 73 : stage2_unit3_relu3, <keras.layers.core.Activation object at 0x7fcf1c5993c8>
# 74 : stage2_unit3_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcf1c580e48>
# 75 : add_6, <keras.layers.merge.Add object at 0x7fcf1c5670b8>
# 76 : stage2_unit4_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcf1c567710>
# 77 : stage2_unit4_relu1, <keras.layers.core.Activation object at 0x7fcf1c47e128>
# 78 : stage2_unit4_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcf1c498d30>
# 79 : stage2_unit4_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcf1c4632b0>
# 80 : stage2_unit4_relu2, <keras.layers.core.Activation object at 0x7fcf1c463048>
# 81 : zero_padding2d_9, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf1c37f080>
# 82 : stage2_unit4_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcf1c37fef0>
# 83 : stage2_unit4_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcf1c2fb4a8>
# 84 : stage2_unit4_relu3, <keras.layers.core.Activation object at 0x7fcf1c2fbd30>
# 85 : stage2_unit4_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcf1c2fbc18>
# 86 : add_7, <keras.layers.merge.Add object at 0x7fcf1c2665f8>
# 87 : stage3_unit1_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcf1c266048>
# 88 : stage3_unit1_relu1, <keras.layers.core.Activation object at 0x7fcf1c266fd0>
# 89 : stage3_unit1_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcf1c0ff3c8>
# 90 : stage3_unit1_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcf1c0f6c88>
# 91 : stage3_unit1_relu2, <keras.layers.core.Activation object at 0x7fcf1c0f6cc0>
# 92 : zero_padding2d_10, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcf1c093518>
# 93 : stage3_unit1_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcf1c093c88>
# 94 : stage3_unit1_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcefc7adf28>
# 95 : stage3_unit1_relu3, <keras.layers.core.Activation object at 0x7fcefc74db00>
# 96 : stage3_unit1_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcefc74d898>
# 97 : stage3_unit1_sc, <keras.layers.convolutional.Conv2D object at 0x7fcf1c1f92b0>
# 98 : add_8, <keras.layers.merge.Add object at 0x7fcefc739da0>
# 99 : stage3_unit2_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcefc7395c0>
# 100 : stage3_unit2_relu1, <keras.layers.core.Activation object at 0x7fcefc739e10>
# 101 : stage3_unit2_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcefc64e080>
# 102 : stage3_unit2_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcefc639d68>
# 103 : stage3_unit2_relu2, <keras.layers.core.Activation object at 0x7fcefc639cc0>
# 104 : zero_padding2d_11, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcefc56b2e8>
# 105 : stage3_unit2_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcefc545780>
# 106 : stage3_unit2_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcefc44d668>
# 107 : stage3_unit2_relu3, <keras.layers.core.Activation object at 0x7fcefc468400>
# 108 : stage3_unit2_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcefc44de80>
# 109 : add_9, <keras.layers.merge.Add object at 0x7fcefc4330f0>
# 110 : stage3_unit3_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcefc3e0c18>
# 111 : stage3_unit3_relu1, <keras.layers.core.Activation object at 0x7fcefc34b160>
# 112 : stage3_unit3_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcefc365d68>
# 113 : stage3_unit3_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fcefc3312e8>
# 114 : stage3_unit3_relu2, <keras.layers.core.Activation object at 0x7fcefc331080>
# 115 : zero_padding2d_12, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcefc25e6a0>
# 116 : stage3_unit3_conv2, <keras.layers.convolutional.Conv2D object at 0x7fcefc241b38>
# 117 : stage3_unit3_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fcefc13fa20>
# 118 : stage3_unit3_relu3, <keras.layers.core.Activation object at 0x7fcefc2325f8>
# 119 : stage3_unit3_conv3, <keras.layers.convolutional.Conv2D object at 0x7fcefc174cc0>
# 120 : add_10, <keras.layers.merge.Add object at 0x7fcefc12b4a8>
# 121 : stage3_unit4_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcefc0837f0>
# 122 : stage3_unit4_relu1, <keras.layers.core.Activation object at 0x7fcefc03fa90>
# 123 : stage3_unit4_conv1, <keras.layers.convolutional.Conv2D object at 0x7fcefc05eeb8>
# 124 : stage3_unit4_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fced07e4438>
# 125 : stage3_unit4_relu2, <keras.layers.core.Activation object at 0x7fced0717b00>
# 126 : zero_padding2d_13, <keras.layers.convolutional.ZeroPadding2D object at 0x7fcefc05e400>
# 127 : stage3_unit4_conv2, <keras.layers.convolutional.Conv2D object at 0x7fced0732f60>
# 128 : stage3_unit4_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fced05fada0>
# 129 : stage3_unit4_relu3, <keras.layers.core.Activation object at 0x7fced05fabe0>
# 130 : stage3_unit4_conv3, <keras.layers.convolutional.Conv2D object at 0x7fced0633cf8>
# 131 : add_11, <keras.layers.merge.Add object at 0x7fced05e8ac8>
# 132 : stage3_unit5_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fced0589898>
# 133 : stage3_unit5_relu1, <keras.layers.core.Activation object at 0x7fced0576da0>
# 134 : stage3_unit5_conv1, <keras.layers.convolutional.Conv2D object at 0x7fced052fc88>
# 135 : stage3_unit5_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fced04e9f28>
# 136 : stage3_unit5_relu2, <keras.layers.core.Activation object at 0x7fced0486780>
# 137 : zero_padding2d_14, <keras.layers.convolutional.ZeroPadding2D object at 0x7fced0415080>
# 138 : stage3_unit5_conv2, <keras.layers.convolutional.Conv2D object at 0x7fced0415c50>
# 139 : stage3_unit5_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fced0372a90>
# 140 : stage3_unit5_relu3, <keras.layers.core.Activation object at 0x7fced0372f98>
# 141 : stage3_unit5_conv3, <keras.layers.convolutional.Conv2D object at 0x7fced03147f0>
# 142 : add_12, <keras.layers.merge.Add object at 0x7fced027f668>
# 143 : stage3_unit6_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fced027f358>
# 144 : stage3_unit6_relu1, <keras.layers.core.Activation object at 0x7fced0270e48>
# 145 : stage3_unit6_conv1, <keras.layers.convolutional.Conv2D object at 0x7fced02132b0>
# 146 : stage3_unit6_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fced0180470>
# 147 : stage3_unit6_relu2, <keras.layers.core.Activation object at 0x7fced0180b00>
# 148 : zero_padding2d_15, <keras.layers.convolutional.ZeroPadding2D object at 0x7fced010a4a8>
# 149 : stage3_unit6_conv2, <keras.layers.convolutional.Conv2D object at 0x7fced010a748>
# 150 : stage3_unit6_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fceb17d4208>
# 151 : stage3_unit6_relu3, <keras.layers.core.Activation object at 0x7fceb17f02e8>
# 152 : stage3_unit6_conv3, <keras.layers.convolutional.Conv2D object at 0x7fceb17d4d68>
# 153 : add_13, <keras.layers.merge.Add object at 0x7fceb17ba668>
# 154 : stage4_unit1_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fceb17ba6d8>
# 155 : stage4_unit1_relu1, <keras.layers.core.Activation object at 0x7fceb17ba710>
# 156 : stage4_unit1_conv1, <keras.layers.convolutional.Conv2D object at 0x7fceb163e5c0>
# 157 : stage4_unit1_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fceb15ca550>
# 158 : stage4_unit1_relu2, <keras.layers.core.Activation object at 0x7fceb15ca860>
# 159 : zero_padding2d_16, <keras.layers.convolutional.ZeroPadding2D object at 0x7fceb1581518>
# 160 : stage4_unit1_conv2, <keras.layers.convolutional.Conv2D object at 0x7fceb15e8ef0>
# 161 : stage4_unit1_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fceb14df898>
# 162 : stage4_unit1_relu3, <keras.layers.core.Activation object at 0x7fceb14dff98>
# 163 : stage4_unit1_conv3, <keras.layers.convolutional.Conv2D object at 0x7fceb1555470>
# 164 : stage4_unit1_sc, <keras.layers.convolutional.Conv2D object at 0x7fceb16d3390>
# 165 : add_14, <keras.layers.merge.Add object at 0x7fceb1451320>
# 166 : stage4_unit2_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fceb1421588>
# 167 : stage4_unit2_relu1, <keras.layers.core.Activation object at 0x7fceb13de940>
# 168 : stage4_unit2_conv1, <keras.layers.convolutional.Conv2D object at 0x7fceb137da58>
# 169 : stage4_unit2_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fceb13512e8>
# 170 : stage4_unit2_relu2, <keras.layers.core.Activation object at 0x7fceb136f470>
# 171 : zero_padding2d_17, <keras.layers.convolutional.ZeroPadding2D object at 0x7fceb12ade10>
# 172 : stage4_unit2_conv2, <keras.layers.convolutional.Conv2D object at 0x7fceb127be10>
# 173 : stage4_unit2_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fceb11ddc88>
# 174 : stage4_unit2_relu3, <keras.layers.core.Activation object at 0x7fceb11dda58>
# 175 : stage4_unit2_conv3, <keras.layers.convolutional.Conv2D object at 0x7fceb1198f28>
# 176 : add_15, <keras.layers.merge.Add object at 0x7fceb114de48>
# 177 : stage4_unit3_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fceb1120780>
# 178 : stage4_unit3_relu1, <keras.layers.core.Activation object at 0x7fceb10ddcc0>
# 179 : stage4_unit3_conv1, <keras.layers.convolutional.Conv2D object at 0x7fceb1093eb8>
# 180 : stage4_unit3_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fceb104bdd8>
# 181 : stage4_unit3_relu2, <keras.layers.core.Activation object at 0x7fceb0fd9c18>
# 182 : zero_padding2d_18, <keras.layers.convolutional.ZeroPadding2D object at 0x7fceb0f4af28>
# 183 : stage4_unit3_conv2, <keras.layers.convolutional.Conv2D object at 0x7fceb0fa9588>
# 184 : stage4_unit3_bn3, <keras.layers.normalization.BatchNormalization object at 0x7fceb0ed7940>
# 185 : stage4_unit3_relu3, <keras.layers.core.Activation object at 0x7fceb0ed7e10>
# 186 : stage4_unit3_conv3, <keras.layers.convolutional.Conv2D object at 0x7fceb0ef76a0>
# 187 : add_16, <keras.layers.merge.Add object at 0x7fceb0e65ac8>
# 188 : bn1, <keras.layers.normalization.BatchNormalization object at 0x7fcf54062240>
# 189 : relu1, <keras.layers.core.Activation object at 0x7fceb0df7a90>
# 190 : decoder_stage0_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fceb0d92cc0>
# 191 : concatenate_1, <keras.layers.merge.Concatenate object at 0x7fceb0cc6f60>
# 192 : decoder_stage0_conv1, <keras.layers.convolutional.Conv2D object at 0x7fceb0cee4a8>
# 193 : decoder_stage0_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fceb0d5fa58>
# 194 : decoder_stage0_relu1, <keras.layers.core.Activation object at 0x7fceb06312b0>
# 195 : decoder_stage0_conv2, <keras.layers.convolutional.Conv2D object at 0x7fceb07b05f8>
# 196 : decoder_stage0_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fceb05352e8>
# 197 : decoder_stage0_relu2, <keras.layers.core.Activation object at 0x7fceb05a07b8>
# 198 : decoder_stage1_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fceb048e5c0>
# 199 : concatenate_2, <keras.layers.merge.Concatenate object at 0x7fceb04f0898>
# 200 : decoder_stage1_conv1, <keras.layers.convolutional.Conv2D object at 0x7fceb03c8eb8>
# 201 : decoder_stage1_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fceb03945c0>
# 202 : decoder_stage1_relu1, <keras.layers.core.Activation object at 0x7fceb0394908>
# 203 : decoder_stage1_conv2, <keras.layers.convolutional.Conv2D object at 0x7fceb03944e0>
# 204 : decoder_stage1_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fceb03784a8>
# 205 : decoder_stage1_relu2, <keras.layers.core.Activation object at 0x7fceb0288908>
# 206 : decoder_stage2_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fceb03bab70>
# 207 : concatenate_3, <keras.layers.merge.Concatenate object at 0x7fceb02a2f60>
# 208 : decoder_stage2_conv1, <keras.layers.convolutional.Conv2D object at 0x7fceb02b9f60>
# 209 : decoder_stage2_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fceb0185a90>
# 210 : decoder_stage2_relu1, <keras.layers.core.Activation object at 0x7fceb01a52b0>
# 211 : decoder_stage2_conv2, <keras.layers.convolutional.Conv2D object at 0x7fceb0185d68>
# 212 : decoder_stage2_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fceb01745f8>
# 213 : decoder_stage2_relu2, <keras.layers.core.Activation object at 0x7fceb0174fd0>
# 214 : decoder_stage3_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fceb0087048>
# 215 : concatenate_4, <keras.layers.merge.Concatenate object at 0x7fceb0087cf8>
# 216 : decoder_stage3_conv1, <keras.layers.convolutional.Conv2D object at 0x7fceabfaa278>
# 217 : decoder_stage3_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fceabf48ef0>
# 218 : decoder_stage3_relu1, <keras.layers.core.Activation object at 0x7fceabf48da0>
# 219 : decoder_stage3_conv2, <keras.layers.convolutional.Conv2D object at 0x7fceabf666d8>
# 220 : decoder_stage3_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fceabf37390>
# 221 : decoder_stage3_relu2, <keras.layers.core.Activation object at 0x7fceabed3518>
# 222 : decoder_stage4_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fceabe69358>
# 223 : decoder_stage4_conv1, <keras.layers.convolutional.Conv2D object at 0x7fceabe437f0>
# 224 : decoder_stage4_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fceabd48c88>
# 225 : decoder_stage4_relu1, <keras.layers.core.Activation object at 0x7fceabd48cc0>
# 226 : decoder_stage4_conv2, <keras.layers.convolutional.Conv2D object at 0x7fceabd7ad30>
# 227 : decoder_stage4_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fceabd304a8>
# 228 : decoder_stage4_relu2, <keras.layers.core.Activation object at 0x7fceabccf630>
# 229 : final_conv, <keras.layers.convolutional.Conv2D object at 0x7fceabc604a8>
# 230 : sigmoid, <keras.layers.core.Activation object at 0x7fceabbe0b70>

# %%
spec = coreml_model.get_spec()
print(spec.description)
# Out:
# input {
#   name: "data"
#   type {
#     imageType {
#       width: 768
#       height: 768
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "sigmoid/Sigmoid"
#   type {
#     multiArrayType {
#       shape: 1
#       shape: 768
#       shape: 768
#       dataType: DOUBLE
#     }
#   }
# }

# %%
coreml_model.save(os.path.join(MODEL_PATH, mlmodel_filename))

# %% [markdown]
# ## load & inference the model

# %%
sess = tf.Session()

# %%
# load model from pb file
with tf.gfile.GFile(os.path.join(MODEL_PATH,pb_filename),'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    sess.graph.as_default()
    g_in = tf.import_graph_def(graph_def)

# %%
# Load Test Images
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import skimage
import glob
import os
import cv2
test_path = "../data/raw/test"
fnames = sorted(glob.glob(os.path.join(test_path,"*.jpg")))
images = []
outs = []
for f in fnames:
    img = skimage.io.imread(f)
    images.append(img)

# %%
# %%time
# Choose a random image and preprocess for inference.
i = random.choice(range(0,len(images)))
img  = images[i]
img_ = np.expand_dims(cv2.resize(img,INPUT_SHAPE[:2]),axis=0)
img_ = preprocess_input(img_, imgNorm="divide")
# inference by the model (op name must comes with :0 to specify the index of its output)
tensor_output = sess.graph.get_tensor_by_name('import/sigmoid/Sigmoid:0')
tensor_input = sess.graph.get_tensor_by_name('import/data:0')
output = sess.run(tensor_output, {tensor_input: img_})
# Resize and Apply Mask on input image.
mask = skimage.transform.resize(np.squeeze(output),img.shape[:2],preserve_range=True)
im = cv2.multiply(np.repeat(np.expand_dims(mask,axis=-1),3,axis=2).astype(float), img.astype(float))/255
plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(im)
# Out:
# CPU times: user 385 ms, sys: 175 ms, total: 560 ms
# Wall time: 400 ms

# %%
sess.close()

# %% [markdown]
# ### Testing TFLite model using Python API

# %%
# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path=os.path.join(MODEL_PATH,tflite_filename))
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
# %%time
# Choose a random image and preprocess for inference.
i = random.choice(range(0,len(images)))
img  = images[i]
img_ = np.expand_dims(cv2.resize(img,INPUT_SHAPE[:2]),axis=0)
img_ = preprocess_input(img_, imgNorm="divide")
interpreter.set_tensor(input_details[0]['index'], img_)
interpreter.invoke()
output = interpreter.get_tensor(output_details[0]['index'])
# Resize and Apply Mask on input image.
mask = skimage.transform.resize(np.squeeze(output),img.shape[:2],preserve_range=True)
im = cv2.multiply(np.repeat(np.expand_dims(mask,axis=-1),3,axis=2).astype(float), img.astype(float))/255
plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(im)
# Out:
# CPU times: user 32.6 s, sys: 326 ms, total: 33 s
# Wall time: 32.7 s
