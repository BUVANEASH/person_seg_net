# %% [markdown]
# # Keras to Tensorflow Model

# %%
import keras
import keras.backend as K
import tensorflow as tf
import numpy as np
np.random.seed(0)
import segmentation_models as sm
import sys
import os
sys.path.append("..")
from seg_net.data import *
from seg_net.fast_scnn import fast_scnn
# Out:
# Using TensorFlow backend.
# /home/avantariml/.local/lib/python3.5/site-packages/classification_models/resnext/__init__.py:4: UserWarning: Current ResNext models are deprecated, use keras.applications ResNeXt models
#   warnings.warn('Current ResNext models are deprecated, '

# %% [markdown]
# ## Set Model Architecture

# %%
INPUT_SHAPE = (512,512,3) #(528,528,3) (512,512,3) (768,768,3)
NUM_CLASS = 1
BACKBONE = 'mobilenetv2'
MODEL_NAME = 'Unet'
LOSS_METRICS = 'BCE_ACC_IOU'
MODEL_PATH = '../results/Models/Models'
ACTIVATION = 'sigmoid'

# Output protocol buffer model path
model_fname = '{0}_{1}_{2}_{3}_{4}_{5}'.format(BACKBONE,
                                              MODEL_NAME,
                                              LOSS_METRICS,
                                              NUM_CLASS,
                                              ACTIVATION,
                                              INPUT_SHAPE[0])
keras_filename = '{}.hdf5'.format(model_fname)
pb_filename = '{}.pb'.format(model_fname)
pb_op_filename = '{}_op.pb'.format(model_fname)
mlmodel_filename = '{}.mlmodel'.format(model_fname)
mlmodel_fp16_filename = '{}_fp16.mlmodel'.format(model_fname)
mlmodel_Q_filename = '{}_Q.mlmodel'.format(model_fname)
tflite_filename = '{}.tflite'.format(model_fname)
tflite_Q_filename = '{}_Q.tflite'.format(model_fname)

# %% [markdown]
# ## Build and Load Model

# %%
model = sm.Unet(BACKBONE, encoder_weights='imagenet', 
                  classes=NUM_CLASS,
                  activation=ACTIVATION,
                  input_shape = INPUT_SHAPE)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /home/avantariml/.local/lib/python3.5/site-packages/segmentation_models/backbones/mobilenetv2.py:273: UserWarning: MobileNet shape is undefined. Weights for input shape(224, 224) will be loaded.
#   warnings.warn('MobileNet shape is undefined.'

# %%
model = fast_scnn(input_shape = INPUT_SHAPE, num_classes = NUM_CLASS, activation = ACTIVATION, dropout_rate = 0.0)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.load_weights(os.path.join(MODEL_PATH,keras_filename))
print("Loading from ",os.path.join(MODEL_PATH,keras_filename))
# Out:
# Loading from  ../results/Models/Models/mobilenetv2_Unet_BCE_ACC_IOU_1_sigmoid_512.hdf5

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 513, 513, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 256, 256, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 256, 256, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 256, 256, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 256, 256, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 256, 256, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 256, 256, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 256, 256, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 256, 256, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 256, 256, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 256, 256, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 256, 256, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 257, 257, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 128, 128, 96) 864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 128, 128, 96) 384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 128, 128, 96) 0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 128, 128, 24) 2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 128, 128, 24) 96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 128, 128, 144 3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 128, 128, 144 576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 128, 128, 144 0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 128, 128, 144 1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 128, 128, 144 576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 128, 128, 144 0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 128, 128, 24) 3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 128, 128, 24) 96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 128, 128, 24) 0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 128, 128, 144 3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 128, 128, 144 576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 128, 128, 144 0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 129, 129, 144 0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 64, 64, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 64, 64, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 64, 64, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 64, 64, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 64, 64, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 64, 64, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 64, 64, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 64, 64, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 64, 64, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 64, 64, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 64, 64, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 64, 64, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 64, 64, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 64, 64, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 64, 64, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 64, 64, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 64, 64, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 64, 64, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 64, 64, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 64, 64, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 64, 64, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 64, 64, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 64, 64, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 64, 64, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 64, 64, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 64, 64, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 65, 65, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 32, 32, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 32, 32, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 32, 32, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 32, 32, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 32, 32, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 32, 32, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 32, 32, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 32, 32, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 32, 32, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 32, 32, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 32, 32, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 32, 32, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 32, 32, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 32, 32, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 32, 32, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 32, 32, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 32, 32, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 32, 32, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 32, 32, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 32, 32, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 32, 32, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 32, 32, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 32, 32, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 32, 32, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 32, 32, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 32, 32, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 32, 32, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 32, 32, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 32, 32, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 32, 32, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 32, 32, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 32, 32, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 32, 32, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 32, 32, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 32, 32, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 32, 32, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 32, 32, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 32, 32, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 32, 32, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 32, 32, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 32, 32, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 32, 32, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 32, 32, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 32, 32, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 32, 32, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 32, 32, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 32, 32, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 32, 32, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 32, 32, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 32, 32, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 32, 32, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 32, 32, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 32, 32, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 32, 32, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 32, 32, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 32, 32, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 32, 32, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 32, 32, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 32, 32, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 32, 32, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 32, 32, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 33, 33, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 16, 16, 576)  5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 16, 16, 576)  2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 16, 16, 576)  0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 16, 16, 160)  92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 16, 16, 160)  640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 16, 16, 960)  153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 16, 16, 960)  3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 16, 16, 960)  0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 16, 16, 960)  8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 16, 16, 960)  3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 16, 16, 960)  0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 16, 16, 160)  153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 16, 16, 160)  640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 16, 16, 160)  0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 16, 16, 960)  153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 16, 16, 960)  3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 16, 16, 960)  0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 16, 16, 960)  8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 16, 16, 960)  3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 16, 16, 960)  0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 16, 16, 160)  153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 16, 16, 160)  640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 16, 16, 160)  0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 16, 16, 960)  153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 16, 16, 960)  3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 16, 16, 960)  0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 16, 16, 960)  8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 16, 16, 960)  3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 16, 16, 960)  0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 16, 16, 320)  307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 16, 16, 320)  1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 16, 16, 1280) 409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 16, 16, 1280) 5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 16, 16, 1280) 0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsample (UpSamp (None, 32, 32, 1280) 0           out_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 1856) 0           decoder_stage0_upsample[0][0]
#                                                                  block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv1 (Conv2D)   (None, 32, 32, 256)  4276224     concatenate_1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_bn1 (BatchNormal (None, 32, 32, 256)  1024        decoder_stage0_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu1 (Activatio (None, 32, 32, 256)  0           decoder_stage0_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv2 (Conv2D)   (None, 32, 32, 256)  589824      decoder_stage0_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_bn2 (BatchNormal (None, 32, 32, 256)  1024        decoder_stage0_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu2 (Activatio (None, 32, 32, 256)  0           decoder_stage0_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsample (UpSamp (None, 64, 64, 256)  0           decoder_stage0_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 448)  0           decoder_stage1_upsample[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv1 (Conv2D)   (None, 64, 64, 128)  516096      concatenate_2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_bn1 (BatchNormal (None, 64, 64, 128)  512         decoder_stage1_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu1 (Activatio (None, 64, 64, 128)  0           decoder_stage1_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv2 (Conv2D)   (None, 64, 64, 128)  147456      decoder_stage1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_bn2 (BatchNormal (None, 64, 64, 128)  512         decoder_stage1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu2 (Activatio (None, 64, 64, 128)  0           decoder_stage1_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsample (UpSamp (None, 128, 128, 128 0           decoder_stage1_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 272 0           decoder_stage2_upsample[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv1 (Conv2D)   (None, 128, 128, 64) 156672      concatenate_3[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_bn1 (BatchNormal (None, 128, 128, 64) 256         decoder_stage2_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu1 (Activatio (None, 128, 128, 64) 0           decoder_stage2_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv2 (Conv2D)   (None, 128, 128, 64) 36864       decoder_stage2_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_bn2 (BatchNormal (None, 128, 128, 64) 256         decoder_stage2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu2 (Activatio (None, 128, 128, 64) 0           decoder_stage2_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsample (UpSamp (None, 256, 256, 64) 0           decoder_stage2_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 160 0           decoder_stage3_upsample[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv1 (Conv2D)   (None, 256, 256, 32) 46080       concatenate_4[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_bn1 (BatchNormal (None, 256, 256, 32) 128         decoder_stage3_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu1 (Activatio (None, 256, 256, 32) 0           decoder_stage3_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv2 (Conv2D)   (None, 256, 256, 32) 9216        decoder_stage3_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_bn2 (BatchNormal (None, 256, 256, 32) 128         decoder_stage3_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu2 (Activatio (None, 256, 256, 32) 0           decoder_stage3_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsample (UpSamp (None, 512, 512, 32) 0           decoder_stage3_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv1 (Conv2D)   (None, 512, 512, 16) 4608        decoder_stage4_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_bn1 (BatchNormal (None, 512, 512, 16) 64          decoder_stage4_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu1 (Activatio (None, 512, 512, 16) 0           decoder_stage4_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv2 (Conv2D)   (None, 512, 512, 16) 2304        decoder_stage4_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_bn2 (BatchNormal (None, 512, 512, 16) 64          decoder_stage4_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu2 (Activatio (None, 512, 512, 16) 0           decoder_stage4_bn2[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 512, 512, 1)  145         decoder_stage4_relu2[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 512, 512, 1)  0           final_conv[0][0]
# ==================================================================================================
# Total params: 8,047,441
# Trainable params: 8,011,345
# Non-trainable params: 36,096
# __________________________________________________________________________________________________

# %% [markdown]
# ## save keras model as tf .pb and as CoreML .mlmodel

# %%
from tensorflow.python.tools.optimize_for_inference_lib import optimize_for_inference
import coremltools
from seg_net.keras_to_tensorflow import *
# Out:
# WARNING:root:TensorFlow version 1.13.1 detected. Last version known to be fully compatible is 1.12.0 .

# %%
input_node_names = [node.op.name for node in model.inputs]
print(input_node_names)
# Out:
# ['input_1']

# %%
# output_names
output_node_names = [node.op.name for node in model.outputs]
print(output_node_names)
# Out:
# ['sigmoid/Sigmoid']

# %% [markdown]
# ### Freezing the model to .pb

# %%
graphDef = freeze_keras(K.get_session(), input_node_names, output_node_names,
                        quantize=False, clear_devices = True)
tf.train.write_graph(graphDef, MODEL_PATH, pb_filename, as_text=False)
# Out:
# WARNING:tensorflow:From ../seg_net/keras_to_tensorflow.py:63: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From ../seg_net/keras_to_tensorflow.py:63: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 560 variables.
# INFO:tensorflow:Froze 560 variables.
# INFO:tensorflow:Converted 560 variables to const ops.
# INFO:tensorflow:Converted 560 variables to const ops.
# '../results/Models/Models/mobilenetv2_Unet_BCE_ACC_IOU_1_sigmoid_512.pb'

# %%
#sess.run(tf.global_variables_initializer())
graphDef = K.get_session().graph.as_graph_def()
output_node_names_gv = output_node_names + [v.op.name for v in tf.global_variables()]
graphDef = optimize_for_inference(graphDef,
                                   input_node_names,
                                   output_node_names_gv,
                                   tf.float32.as_datatype_enum,
                                   toco_compatible=True)
tf.train.write_graph(graphDef, MODEL_PATH, pb_op_filename, as_text=False)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/tools/optimize_for_inference_lib.py:113: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.remove_training_nodes
# WARNING:tensorflow:Didn't find expected conv Constant input to 'Conv1/convolution', found name: "Conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'Conv1/convolution', found name: "Conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'bn_Conv1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'bn_Conv1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_project/convolution', found name: "expanded_conv_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 16
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'expanded_conv_project/convolution', found name: "expanded_conv_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 16
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'expanded_conv_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_1_expand/convolution', found name: "block_1_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 16
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_1_expand/convolution', found name: "block_1_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 16
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_1_project/convolution', found name: "block_1_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 24
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_1_project/convolution', found name: "block_1_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 24
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_1_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_2_expand/convolution', found name: "block_2_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 24
#       }
#       dim {
#         size: 144
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_2_expand/convolution', found name: "block_2_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 24
#       }
#       dim {
#         size: 144
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_2_project/convolution', found name: "block_2_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 144
#       }
#       dim {
#         size: 24
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_2_project/convolution', found name: "block_2_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 144
#       }
#       dim {
#         size: 24
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_2_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_3_expand/convolution', found name: "block_3_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 24
#       }
#       dim {
#         size: 144
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_3_expand/convolution', found name: "block_3_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 24
#       }
#       dim {
#         size: 144
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_3_project/convolution', found name: "block_3_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 144
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_3_project/convolution', found name: "block_3_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 144
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_3_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_4_expand/convolution', found name: "block_4_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_4_expand/convolution', found name: "block_4_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_4_project/convolution', found name: "block_4_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_4_project/convolution', found name: "block_4_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_4_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_5_expand/convolution', found name: "block_5_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_5_expand/convolution', found name: "block_5_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_5_project/convolution', found name: "block_5_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_5_project/convolution', found name: "block_5_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_5_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_6_expand/convolution', found name: "block_6_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_6_expand/convolution', found name: "block_6_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 192
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_6_project/convolution', found name: "block_6_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_6_project/convolution', found name: "block_6_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 192
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_6_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_7_expand/convolution', found name: "block_7_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_7_expand/convolution', found name: "block_7_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_7_project/convolution', found name: "block_7_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_7_project/convolution', found name: "block_7_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_7_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_8_expand/convolution', found name: "block_8_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_8_expand/convolution', found name: "block_8_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_8_project/convolution', found name: "block_8_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_8_project/convolution', found name: "block_8_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_8_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_9_expand/convolution', found name: "block_9_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_9_expand/convolution', found name: "block_9_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_9_project/convolution', found name: "block_9_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_9_project/convolution', found name: "block_9_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_9_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_10_expand/convolution', found name: "block_10_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_10_expand/convolution', found name: "block_10_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 384
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_10_project/convolution', found name: "block_10_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_10_project/convolution', found name: "block_10_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 384
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_10_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_11_expand/convolution', found name: "block_11_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_11_expand/convolution', found name: "block_11_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_11_project/convolution', found name: "block_11_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_11_project/convolution', found name: "block_11_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_11_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_12_expand/convolution', found name: "block_12_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_12_expand/convolution', found name: "block_12_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_12_project/convolution', found name: "block_12_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_12_project/convolution', found name: "block_12_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 96
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_12_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_13_expand/convolution', found name: "block_13_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_13_expand/convolution', found name: "block_13_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 96
#       }
#       dim {
#         size: 576
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_13_project/convolution', found name: "block_13_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_13_project/convolution', found name: "block_13_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 576
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_13_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_14_expand/convolution', found name: "block_14_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_14_expand/convolution', found name: "block_14_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_depthwise_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_14_project/convolution', found name: "block_14_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_14_project/convolution', found name: "block_14_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 160
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_14_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_15_expand/convolution', found name: "block_15_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_15_expand/convolution', found name: "block_15_expand/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 960
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_expand_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_depthwise_BN/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_15_depthwise_BN/FusedBatchNorm'
# ...
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 320
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'block_16_project/convolution', found name: "block_16_project/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 960
#       }
#       dim {
#         size: 320
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'block_16_project_BN/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'Conv_1/convolution', found name: "Conv_1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 320
#       }
#       dim {
#         size: 1280
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'Conv_1/convolution', found name: "Conv_1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 320
#       }
#       dim {
#         size: 1280
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'Conv_1_bn/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'Conv_1_bn/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage0_conv1/convolution', found name: "decoder_stage0_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 1856
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage0_conv1/convolution', found name: "decoder_stage0_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 1856
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage0_conv2/convolution', found name: "decoder_stage0_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 256
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage0_conv2/convolution', found name: "decoder_stage0_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 256
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_bn2/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage0_bn2/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage1_conv1/convolution', found name: "decoder_stage1_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 448
#       }
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage1_conv1/convolution', found name: "decoder_stage1_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 448
#       }
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage1_conv2/convolution', found name: "decoder_stage1_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage1_conv2/convolution', found name: "decoder_stage1_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_bn2/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage1_bn2/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage2_conv1/convolution', found name: "decoder_stage2_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 272
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage2_conv1/convolution', found name: "decoder_stage2_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 272
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage2_conv2/convolution', found name: "decoder_stage2_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage2_conv2/convolution', found name: "decoder_stage2_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_bn2/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage2_bn2/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage3_conv1/convolution', found name: "decoder_stage3_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage3_conv1/convolution', found name: "decoder_stage3_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 160
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage3_conv2/convolution', found name: "decoder_stage3_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage3_conv2/convolution', found name: "decoder_stage3_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_bn2/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage3_bn2/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage4_conv1/convolution', found name: "decoder_stage4_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 16
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage4_conv1/convolution', found name: "decoder_stage4_conv1/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 16
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_bn1/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage4_conv2/convolution', found name: "decoder_stage4_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 16
#       }
#       dim {
#         size: 16
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected conv Constant input to 'decoder_stage4_conv2/convolution', found name: "decoder_stage4_conv2/kernel"
# op: "VariableV2"
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 16
#       }
#       dim {
#         size: 16
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#  instead. Maybe because freeze_graph wasn't run first?
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_bn2/cond/FusedBatchNorm'
# WARNING:tensorflow:Didn't find expected Conv2D input to 'decoder_stage4_bn2/cond/FusedBatchNorm'
# '../results/Models/Models/mobilenetv2_Unet_BCE_ACC_IOU_1_sigmoid_512_op.pb'

# %% [markdown]
# ### keras to .tflite

# %%
# Converting a tf.keras model.
converter = tf.lite.TFLiteConverter.from_session(K.get_session(), model.inputs, model.outputs)
tflite_model = converter.convert()
with open(os.path.join(MODEL_PATH,tflite_filename), "wb") as f:
    f.write(tflite_model)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/lite/python/lite.py:591: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 312 variables.
# INFO:tensorflow:Converted 312 variables to const ops.

# %%
# Converting a tf.keras model.
converter_Q = tf.lite.TFLiteConverter.from_session(K.get_session(), model.inputs, model.outputs)
converter_Q.post_training_quantize=True
tflite_Q_model = converter_Q.convert()
with open(os.path.join(MODEL_PATH,tflite_Q_filename), "wb") as f:
    f.write(tflite_Q_model)
# Out:
# INFO:tensorflow:Froze 312 variables.
# INFO:tensorflow:Converted 312 variables to const ops.

# %% [markdown]
# ### keras to .mlmodel

# %%
def convert_lambda(layer):
    
    import keras.backend as K
    # Only convert this Lambda layer if it is for our tf image resize function.
    if layer.function == K.tf.image.resize_images:

        from coremltools.proto import NeuralNetwork_pb2

        params = NeuralNetwork_pb2.CustomLayerParams()

        # The name of the Swift or Obj-C class that implements this layer.
        params.className = "Resize"

        # The desciption is shown in Xcode's mlmodel viewer.
        params.description = "A resize function"

        return params
    else:
        return None
    
coreml_model = coremltools.converters.keras.convert(model,
                                                    input_names=input_node_names,
                                                    image_input_names=input_node_names,
                                                    output_names=output_node_names,
                                                    image_scale=1/255.0,
                                                    add_custom_layers=True,
                                                    custom_conversion_functions={ "Lambda": convert_lambda }
                                                   )
# Out:
# Output name length mismatch
# 0 : input_1, <keras.engine.input_layer.InputLayer object at 0x7fbb88352d68>
# 1 : Conv1_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fbb8835abe0>
# 2 : Conv1, <keras.layers.convolutional.Conv2D object at 0x7fbb8835aba8>
# 3 : bn_Conv1, <keras.layers.normalization.BatchNormalization object at 0x7fbade824048>
# 4 : Conv1_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbade824b00>
# 5 : expanded_conv_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fbade824f98>
# 6 : expanded_conv_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbade8245c0>
# 7 : expanded_conv_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbadc24b748>
# 8 : expanded_conv_project, <keras.layers.convolutional.Conv2D object at 0x7fbadc1e0978>
# 9 : expanded_conv_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbadc1adfd0>
# 10 : block_1_expand, <keras.layers.convolutional.Conv2D object at 0x7fbadc14c7b8>
# 11 : block_1_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbadc08fc18>
# 12 : block_1_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbadc019cf8>
# 13 : block_1_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fbadc041f98>
# 14 : block_1_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fbadc041518>
# 15 : block_1_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbad47079e8>
# 16 : block_1_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbad472bf60>
# 17 : block_1_project, <keras.layers.convolutional.Conv2D object at 0x7fbad479f6a0>
# 18 : block_1_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbad469d5c0>
# 19 : block_2_expand, <keras.layers.convolutional.Conv2D object at 0x7fbad4605940>
# 20 : block_2_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbad45e4630>
# 21 : block_2_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbad45059b0>
# 22 : block_2_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fbad452ae80>
# 23 : block_2_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbad452af28>
# 24 : block_2_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbad4405780>
# 25 : block_2_project, <keras.layers.convolutional.Conv2D object at 0x7fbad4432f60>
# 26 : block_2_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbad439e358>
# 27 : block_2_add, <keras.layers.merge.Add object at 0x7fbad4307c88>
# 28 : block_3_expand, <keras.layers.convolutional.Conv2D object at 0x7fbad4332b38>
# 29 : block_3_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbad429da58>
# 30 : block_3_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbad429da20>
# 31 : block_3_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fbad420ee10>
# 32 : block_3_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fbad41cbcf8>
# 33 : block_3_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbad410eef0>
# 34 : block_3_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbad410e2e8>
# 35 : block_3_project, <keras.layers.convolutional.Conv2D object at 0x7fbad412c7f0>
# 36 : block_3_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbad409a3c8>
# 37 : block_4_expand, <keras.layers.convolutional.Conv2D object at 0x7fbad409aa90>
# 38 : block_4_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbaac7a0978>
# 39 : block_4_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbaac760860>
# 40 : block_4_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fbaac6ef438>
# 41 : block_4_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbaac640a90>
# 42 : block_4_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbaac62af28>
# 43 : block_4_project, <keras.layers.convolutional.Conv2D object at 0x7fbaac5d0940>
# 44 : block_4_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbaac53f6a0>
# 45 : block_4_add, <keras.layers.merge.Add object at 0x7fbaac52b9e8>
# 46 : block_5_expand, <keras.layers.convolutional.Conv2D object at 0x7fbaac4ef2b0>
# 47 : block_5_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbaac443470>
# 48 : block_5_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbaac4287b8>
# 49 : block_5_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fbaac3f4080>
# 50 : block_5_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbaac3ce780>
# 51 : block_5_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbaac329978>
# 52 : block_5_project, <keras.layers.convolutional.Conv2D object at 0x7fbaac2d7438>
# 53 : block_5_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbaac2430f0>
# 54 : block_5_add, <keras.layers.merge.Add object at 0x7fbaac22be80>
# 55 : block_6_expand, <keras.layers.convolutional.Conv2D object at 0x7fbaac1d4d30>
# 56 : block_6_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fbaac13f320>
# 57 : block_6_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fbaac127c50>
# 58 : block_6_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fbaac25db38>
# 59 : block_6_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fbaac0a1fd0>
# 60 : block_6_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba8c7f34e0>
# 61 : block_6_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba8c7f39e8>
# 62 : block_6_project, <keras.layers.convolutional.Conv2D object at 0x7fba8c7929e8>
# 63 : block_6_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba8c700358>
# 64 : block_7_expand, <keras.layers.convolutional.Conv2D object at 0x7fba8c6e8c50>
# 65 : block_7_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba8c63f2e8>
# 66 : block_7_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba8c5ff390>
# 67 : block_7_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba8c593630>
# 68 : block_7_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba8c5f3cc0>
# 69 : block_7_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba8c4cdf60>
# 70 : block_7_project, <keras.layers.convolutional.Conv2D object at 0x7fba8c4a9b00>
# 71 : block_7_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba8c464898>
# 72 : block_7_add, <keras.layers.merge.Add object at 0x7fba8c400710>
# 73 : block_8_expand, <keras.layers.convolutional.Conv2D object at 0x7fba8c391470>
# 74 : block_8_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba8c366668>
# 75 : block_8_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba8c2ca9b0>
# 76 : block_8_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba8c28f278>
# 77 : block_8_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba8c263748>
# 78 : block_8_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba8c1c8c18>
# 79 : block_8_project, <keras.layers.convolutional.Conv2D object at 0x7fba8c140f60>
# 80 : block_8_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba8c167630>
# 81 : block_8_add, <keras.layers.merge.Add object at 0x7fba8c0cb6a0>
# 82 : block_9_expand, <keras.layers.convolutional.Conv2D object at 0x7fba8c0f8f98>
# 83 : block_9_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba8c0640f0>
# 84 : block_9_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba7878be48>
# 85 : block_9_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba787b7cf8>
# 86 : block_9_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba787b7dd8>
# 87 : block_9_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba7868ae80>
# 88 : block_9_project, <keras.layers.convolutional.Conv2D object at 0x7fba786b5e10>
# 89 : block_9_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba78622470>
# 90 : block_9_add, <keras.layers.merge.Add object at 0x7fba78593fd0>
# 91 : block_10_expand, <keras.layers.convolutional.Conv2D object at 0x7fba78505d68>
# 92 : block_10_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba784d8d30>
# 93 : block_10_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba78527908>
# 94 : block_10_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba784b27b8>
# 95 : block_10_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba78494ef0>
# 96 : block_10_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba783ebf60>
# 97 : block_10_project, <keras.layers.convolutional.Conv2D object at 0x7fba7834bba8>
# 98 : block_10_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba78306898>
# 99 : block_11_expand, <keras.layers.convolutional.Conv2D object at 0x7fba782eeb38>
# 100 : block_11_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba7824ccf8>
# 101 : block_11_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba781eec50>
# 102 : block_11_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba78194f60>
# 103 : block_11_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba781055f8>
# 104 : block_11_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba780ed8d0>
# 105 : block_11_project, <keras.layers.convolutional.Conv2D object at 0x7fba7809b4e0>
# 106 : block_11_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba687c30b8>
# 107 : block_11_add, <keras.layers.merge.Add object at 0x7fba687abf28>
# 108 : block_12_expand, <keras.layers.convolutional.Conv2D object at 0x7fba68758e48>
# 109 : block_12_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba686c3c88>
# 110 : block_12_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba686aacf8>
# 111 : block_12_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba68658b70>
# 112 : block_12_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba68658c50>
# 113 : block_12_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba685b1f28>
# 114 : block_12_project, <keras.layers.convolutional.Conv2D object at 0x7fba68523f98>
# 115 : block_12_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba684c2470>
# 116 : block_12_add, <keras.layers.merge.Add object at 0x7fba684c29e8>
# 117 : block_13_expand, <keras.layers.convolutional.Conv2D object at 0x7fba68455ba8>
# 118 : block_13_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba68427c18>
# 119 : block_13_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba683c5828>
# 120 : block_13_pad, <keras.layers.convolutional.ZeroPadding2D object at 0x7fba68354630>
# 121 : block_13_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba6836eb38>
# 122 : block_13_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba683b4cc0>
# 123 : block_13_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba682b5ac8>
# 124 : block_13_project, <keras.layers.convolutional.Conv2D object at 0x7fba6826dcc0>
# 125 : block_13_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba68224da0>
# 126 : block_14_expand, <keras.layers.convolutional.Conv2D object at 0x7fba681c4940>
# 127 : block_14_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba68104d68>
# 128 : block_14_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba6808bf98>
# 129 : block_14_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba68051198>
# 130 : block_14_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba607e67f0>
# 131 : block_14_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba6074ecc0>
# 132 : block_14_project, <keras.layers.convolutional.Conv2D object at 0x7fba607746a0>
# 133 : block_14_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba606e6400>
# 134 : block_14_add, <keras.layers.merge.Add object at 0x7fba6064f6a0>
# 135 : block_15_expand, <keras.layers.convolutional.Conv2D object at 0x7fba60672fd0>
# 136 : block_15_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba605e9128>
# 137 : block_15_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba6054eef0>
# 138 : block_15_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba604f9e80>
# 139 : block_15_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba604f9e10>
# 140 : block_15_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba6044e6a0>
# 141 : block_15_project, <keras.layers.convolutional.Conv2D object at 0x7fba603f9e80>
# 142 : block_15_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba603e5c18>
# 143 : block_15_add, <keras.layers.merge.Add object at 0x7fba60357be0>
# 144 : block_16_expand, <keras.layers.convolutional.Conv2D object at 0x7fba602c7f60>
# 145 : block_16_expand_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba602eb7b8>
# 146 : block_16_expand_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba602eb978>
# 147 : block_16_depthwise, <keras.layers.convolutional.DepthwiseConv2D object at 0x7fba60278978>
# 148 : block_16_depthwise_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba60211a90>
# 149 : block_16_depthwise_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba601b1d68>
# 150 : block_16_project, <keras.layers.convolutional.Conv2D object at 0x7fba60176978>
# 151 : block_16_project_BN, <keras.layers.normalization.BatchNormalization object at 0x7fba600c7940>
# 152 : Conv_1, <keras.layers.convolutional.Conv2D object at 0x7fba600e57b8>
# 153 : Conv_1_bn, <keras.layers.normalization.BatchNormalization object at 0x7fba5afecc18>
# 154 : out_relu, <keras.layers.advanced_activations.ReLU object at 0x7fba5af73a20>
# 155 : decoder_stage0_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fba5ae8b3c8>
# 156 : concatenate_1, <keras.layers.merge.Concatenate object at 0x7fba5ae8b6d8>
# 157 : decoder_stage0_conv1, <keras.layers.convolutional.Conv2D object at 0x7fba5ae8bba8>
# 158 : decoder_stage0_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fba5aa150b8>
# 159 : decoder_stage0_relu1, <keras.layers.core.Activation object at 0x7fba5a815278>
# 160 : decoder_stage0_conv2, <keras.layers.convolutional.Conv2D object at 0x7fba5af1d860>
# 161 : decoder_stage0_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fba5a63f588>
# 162 : decoder_stage0_relu2, <keras.layers.core.Activation object at 0x7fba5a63f8d0>
# 163 : decoder_stage1_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fba5a5c8cc0>
# 164 : concatenate_2, <keras.layers.merge.Concatenate object at 0x7fba5a5c80b8>
# 165 : decoder_stage1_conv1, <keras.layers.convolutional.Conv2D object at 0x7fba5a5f34a8>
# 166 : decoder_stage1_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fba5a4c1e48>
# 167 : decoder_stage1_relu1, <keras.layers.core.Activation object at 0x7fba5a4c1cf8>
# 168 : decoder_stage1_conv2, <keras.layers.convolutional.Conv2D object at 0x7fba5a4e2400>
# 169 : decoder_stage1_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fba5a4add68>
# 170 : decoder_stage1_relu2, <keras.layers.core.Activation object at 0x7fba5a44a4a8>
# 171 : decoder_stage2_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fba5a3de080>
# 172 : concatenate_3, <keras.layers.merge.Concatenate object at 0x7fba5a437828>
# 173 : decoder_stage2_conv1, <keras.layers.convolutional.Conv2D object at 0x7fba5a437860>
# 174 : decoder_stage2_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fba5a2c0be0>
# 175 : decoder_stage2_relu1, <keras.layers.core.Activation object at 0x7fba5a2c0c88>
# 176 : decoder_stage2_conv2, <keras.layers.convolutional.Conv2D object at 0x7fba5a2f2c88>
# 177 : decoder_stage2_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fba5a2a8e80>
# 178 : decoder_stage2_relu2, <keras.layers.core.Activation object at 0x7fba5a2468d0>
# 179 : decoder_stage3_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fba5a1d74e0>
# 180 : concatenate_4, <keras.layers.merge.Concatenate object at 0x7fba5a239a90>
# 181 : decoder_stage3_conv1, <keras.layers.convolutional.Conv2D object at 0x7fba5a239cc0>
# 182 : decoder_stage3_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fba5a0df748>
# 183 : decoder_stage3_relu1, <keras.layers.core.Activation object at 0x7fba5a0dfcc0>
# 184 : decoder_stage3_conv2, <keras.layers.convolutional.Conv2D object at 0x7fba5a0dfda0>
# 185 : decoder_stage3_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fba5a040630>
# 186 : decoder_stage3_relu2, <keras.layers.core.Activation object at 0x7fba5a040358>
# 187 : decoder_stage4_upsample, <keras.layers.convolutional.UpSampling2D object at 0x7fba5a032ef0>
# 188 : decoder_stage4_conv1, <keras.layers.convolutional.Conv2D object at 0x7fba59fd4ba8>
# 189 : decoder_stage4_bn1, <keras.layers.normalization.BatchNormalization object at 0x7fba59ed0550>
# 190 : decoder_stage4_relu1, <keras.layers.core.Activation object at 0x7fba59ed0e80>
# 191 : decoder_stage4_conv2, <keras.layers.convolutional.Conv2D object at 0x7fba59ed0eb8>
# 192 : decoder_stage4_bn2, <keras.layers.normalization.BatchNormalization object at 0x7fba59e42470>
# 193 : decoder_stage4_relu2, <keras.layers.core.Activation object at 0x7fba59e31fd0>
# 194 : final_conv, <keras.layers.convolutional.Conv2D object at 0x7fba59da2d68>
# 195 : sigmoid, <keras.layers.core.Activation object at 0x7fba59d73c18>

# %%
spec = coreml_model.get_spec()
print(spec.description)
# Out:
# input {
#   name: "input_1"
#   type {
#     imageType {
#       width: 512
#       height: 512
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "sigmoid/Sigmoid"
#   type {
#     multiArrayType {
#       shape: 1
#       shape: 512
#       shape: 512
#       dataType: DOUBLE
#     }
#   }
# }

# %%
coreml_model.save(os.path.join(MODEL_PATH, mlmodel_filename))

# %%
model_spec = coremltools.utils.load_spec(os.path.join(MODEL_PATH, mlmodel_filename))
model_fp16_spec = coremltools.utils.convert_neural_network_spec_weights_to_fp16(model_spec)
coremltools.utils.save_spec(model_fp16_spec, os.path.join(MODEL_PATH, mlmodel_fp16_filename))

# %%
quantized_coreml_spec = coremltools.models.neural_network.quantization_utils.quantize_weights(coreml_model,8)
coremltools.utils.save_spec(quantized_coreml_spec, os.path.join(MODEL_PATH, mlmodel_Q_filename))
# Out:
# Quantizing using linear quantization
# Optimizing Neural Network before Quantization:
# Fused Conv1->bn_Conv1
# Fused expanded_conv_depthwise->expanded_conv_depthwise_BN
# Fused expanded_conv_project->expanded_conv_project_BN
# Fused block_1_expand->block_1_expand_BN
# Fused block_1_depthwise->block_1_depthwise_BN
# Fused block_1_project->block_1_project_BN
# Fused block_2_expand->block_2_expand_BN
# Fused block_2_depthwise->block_2_depthwise_BN
# Fused block_2_project->block_2_project_BN
# Fused block_3_expand->block_3_expand_BN
# Fused block_3_depthwise->block_3_depthwise_BN
# Fused block_3_project->block_3_project_BN
# Fused block_4_expand->block_4_expand_BN
# Fused block_4_depthwise->block_4_depthwise_BN
# Fused block_4_project->block_4_project_BN
# Fused block_5_expand->block_5_expand_BN
# Fused block_5_depthwise->block_5_depthwise_BN
# Fused block_5_project->block_5_project_BN
# Fused block_6_expand->block_6_expand_BN
# Fused block_6_depthwise->block_6_depthwise_BN
# Fused block_6_project->block_6_project_BN
# Fused block_7_expand->block_7_expand_BN
# Fused block_7_depthwise->block_7_depthwise_BN
# Fused block_7_project->block_7_project_BN
# Fused block_8_expand->block_8_expand_BN
# Fused block_8_depthwise->block_8_depthwise_BN
# Fused block_8_project->block_8_project_BN
# Fused block_9_expand->block_9_expand_BN
# Fused block_9_depthwise->block_9_depthwise_BN
# Fused block_9_project->block_9_project_BN
# Fused block_10_expand->block_10_expand_BN
# Fused block_10_depthwise->block_10_depthwise_BN
# Fused block_10_project->block_10_project_BN
# Fused block_11_expand->block_11_expand_BN
# Fused block_11_depthwise->block_11_depthwise_BN
# Fused block_11_project->block_11_project_BN
# Fused block_12_expand->block_12_expand_BN
# Fused block_12_depthwise->block_12_depthwise_BN
# Fused block_12_project->block_12_project_BN
# Fused block_13_expand->block_13_expand_BN
# Fused block_13_depthwise->block_13_depthwise_BN
# Fused block_13_project->block_13_project_BN
# Fused block_14_expand->block_14_expand_BN
# Fused block_14_depthwise->block_14_depthwise_BN
# Fused block_14_project->block_14_project_BN
# Fused block_15_expand->block_15_expand_BN
# Fused block_15_depthwise->block_15_depthwise_BN
# Fused block_15_project->block_15_project_BN
# Fused block_16_expand->block_16_expand_BN
# Fused block_16_depthwise->block_16_depthwise_BN
# Fused block_16_project->block_16_project_BN
# Fused Conv_1->Conv_1_bn
# Fused decoder_stage0_conv1->decoder_stage0_bn1
# Fused decoder_stage0_conv2->decoder_stage0_bn2
# Fused decoder_stage1_conv1->decoder_stage1_bn1
# Fused decoder_stage1_conv2->decoder_stage1_bn2
# Fused decoder_stage2_conv1->decoder_stage2_bn1
# Fused decoder_stage2_conv2->decoder_stage2_bn2
# Fused decoder_stage3_conv1->decoder_stage3_bn1
# Fused decoder_stage3_conv2->decoder_stage3_bn2
# Fused decoder_stage4_conv1->decoder_stage4_bn1
# Fused decoder_stage4_conv2->decoder_stage4_bn2
# Finished optimizing network. Quantizing neural network..
# Quantizing layer Conv1
# Quantizing layer expanded_conv_depthwise
# Quantizing layer expanded_conv_project
# Quantizing layer block_1_expand
# Quantizing layer block_1_depthwise
# Quantizing layer block_1_project
# Quantizing layer block_2_expand
# Quantizing layer block_2_depthwise
# Quantizing layer block_2_project
# Quantizing layer block_3_expand
# Quantizing layer block_3_depthwise
# Quantizing layer block_3_project
# Quantizing layer block_4_expand
# Quantizing layer block_4_depthwise
# Quantizing layer block_4_project
# Quantizing layer block_5_expand
# Quantizing layer block_5_depthwise
# Quantizing layer block_5_project
# Quantizing layer block_6_expand
# Quantizing layer block_6_depthwise
# Quantizing layer block_6_project
# Quantizing layer block_7_expand
# Quantizing layer block_7_depthwise
# Quantizing layer block_7_project
# Quantizing layer block_8_expand
# Quantizing layer block_8_depthwise
# Quantizing layer block_8_project
# Quantizing layer block_9_expand
# Quantizing layer block_9_depthwise
# Quantizing layer block_9_project
# Quantizing layer block_10_expand
# Quantizing layer block_10_depthwise
# Quantizing layer block_10_project
# Quantizing layer block_11_expand
# Quantizing layer block_11_depthwise
# Quantizing layer block_11_project
# Quantizing layer block_12_expand
# Quantizing layer block_12_depthwise
# Quantizing layer block_12_project
# Quantizing layer block_13_expand
# Quantizing layer block_13_depthwise
# Quantizing layer block_13_project
# Quantizing layer block_14_expand
# Quantizing layer block_14_depthwise
# Quantizing layer block_14_project
# Quantizing layer block_15_expand
# Quantizing layer block_15_depthwise
# Quantizing layer block_15_project
# Quantizing layer block_16_expand
# Quantizing layer block_16_depthwise
# Quantizing layer block_16_project
# Quantizing layer Conv_1
# Quantizing layer decoder_stage0_conv1
# Quantizing layer decoder_stage0_conv2
# Quantizing layer decoder_stage1_conv1
# Quantizing layer decoder_stage1_conv2
# Quantizing layer decoder_stage2_conv1
# Quantizing layer decoder_stage2_conv2
# Quantizing layer decoder_stage3_conv1
# Quantizing layer decoder_stage3_conv2
# Quantizing layer decoder_stage4_conv1
# Quantizing layer decoder_stage4_conv2
# Quantizing layer final_conv
# WARNING! Unable to return a quantized MLModel instance since OS != macOS 10.14 or later
# Returning quantized model specification instead

# %% [markdown]
# ## load & inference the model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import skimage
import glob
import os
import cv2

# %%
# Load Test Images
test_path = "../data/raw/test"
fnames = sorted(glob.glob(os.path.join(test_path,"*.jpg")))
images = []
outs = []
for f in fnames:
    img = skimage.io.imread(f)
    images.append(img)

# %%
# load model from pb file
with tf.gfile.GFile(os.path.join(MODEL_PATH,pb_op_filename),'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    sess.graph.as_default()
    g_in = tf.import_graph_def(graph_def)
print("Loading from ",os.path.join(MODEL_PATH,pb_op_filename))
# Out:
# Loading from  ../results/Models/Models/mobilenetv2_Unet_BCE_ACC_IOU_1_sigmoid_512_op.pb

# %%
# %%time
# Choose a random image and preprocess for inference.
i = random.choice(range(0,len(images)))
img  = images[i]
img_ = np.expand_dims(cv2.resize(img,INPUT_SHAPE[:2]),axis=0)
img_ = preprocess_input(img_, imgNorm="divide")
# inference by the model (op name must comes with :0 to specify the index of its output)
sess = tf.Session()
tensor_output = sess.graph.get_tensor_by_name('import/sigmoid/Sigmoid:0')
tensor_input = sess.graph.get_tensor_by_name('import/input_1:0')
output = sess.run(tensor_output, {tensor_input: img_})
sess.close()
# Resize and Apply Mask on input image.
mask = skimage.transform.resize(np.squeeze(output),img.shape[:2],preserve_range=True)
im = cv2.multiply(np.repeat(np.expand_dims(mask,axis=-1),3,axis=2).astype(float), img.astype(float))/255
plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(im)
# Out:
# CPU times: user 974 ms, sys: 79.3 ms, total: 1.05 s
# Wall time: 955 ms

# %% [markdown]
# ### Testing TFLite model using Python API

# %%
# Load TFLite model and allocate tensors.
#interpreter = tf.lite.Interpreter(model_path=os.path.join(MODEL_PATH,tflite_filename))
interpreter = tf.lite.Interpreter(model_path=os.path.join(MODEL_PATH,tflite_Q_filename))
#interpreter = tf.lite.Interpreter(model_path="/media/new_hdd2/seg_net/results/Models/Models/sample_tf.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
input_details[0]['shape']
# Out:
# array([  1, 512, 512,   3], dtype=int32)

# %%
# %%time
# Choose a random image and preprocess for inference.
i = random.choice(range(0,len(images)))
img  = images[i]#skimage.io.imread("/home/avantariml/Downloads/IMG_3309.jpg")
img_ = np.expand_dims(cv2.resize(img,INPUT_SHAPE[:2]),axis=0)
#img_ = np.expand_dims(cv2.resize(img,(257, 257)),axis=0)
img_ = preprocess_input(img_, imgNorm="divide")
interpreter.set_tensor(input_details[0]['index'], img_)
interpreter.invoke()
output = interpreter.get_tensor(output_details[0]['index'])
# Resize and Apply Mask on input image.
mask = skimage.transform.resize(np.squeeze(output),img.shape[:2],preserve_range=True)
im = cv2.multiply(np.repeat(np.expand_dims(mask,axis=-1),3,axis=2).astype(float), img.astype(float))/255
plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(im)#(np.squeeze(output))
# Out:
# CPU times: user 6.55 s, sys: 89.2 ms, total: 6.64 s
# Wall time: 6.39 s
