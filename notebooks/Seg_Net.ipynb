# %%
import keras_segmentation
# Out:
# Using TensorFlow backend.

# %%
model = keras_segmentation.pretrained.resnet_pspnet_VOC12_v0_1() # load the pretrained model
# Out:
# Downloading data from https://github.com/divamgupta/image-segmentation-keras/releases/download/pretrained_model_1/r2_voc12_resnetpspnet_384x576.24
# 122814464/122807072 [==============================] - 27s 0us/step
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 19s 0us/step

# %%
out = model.predict_segmentation(
                                inp="/media/new_hdd2/instance-level_human_parsing/Test/0000046.jpg",
                                out_fname="/media/new_hdd2/seg_net/Test/out.png"
                                )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(out)
