# %%
import keras
import keras.backend as K
import tensorflow as tf
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import segmentation_models as sm
import sys
sys.path.append("..")
from seg_net.data import *
from seg_net.fast_scnn import fast_scnn
# Out:
# Using TensorFlow backend.
# /home/avantariml/.local/lib/python3.5/site-packages/classification_models/resnext/__init__.py:4: UserWarning: Current ResNext models are deprecated, use keras.applications ResNeXt models
#   warnings.warn('Current ResNext models are deprecated, '

# %%
from seg_net.deeplabv3 import Deeplabv3

# %%
model = Deeplabv3(weights='pascal_voc', 
                  input_shape=(512, 512, 3), 
                  classes=21, backbone='mobilenetv2', OS=16, alpha=1., activation=None)
# Out:
# WARNING:tensorflow:From /home/avantariml/.local/lib/python3.5/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9c2ad88741db> in <module>
#       1 model = Deeplabv3(weights='pascal_voc',
#       2                   input_shape=(512, 512, 3),
# ----> 3                   classes=21, backbone='mobilenetv2', OS=16, alpha=1., activation=None)
#
# /media/new_hdd2/seg_net/seg_net/deeplabv3/model.py in Deeplabv3(weights, input_tensor, input_shape, classes, backbone, OS, alpha, activation)
#     328
#     329         x = _inverted_res_block(x, filters=24, alpha=alpha, stride=2,
# ...
